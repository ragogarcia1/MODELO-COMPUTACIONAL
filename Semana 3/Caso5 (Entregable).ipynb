# %% [markdown]
# # Caso 5: localización de depósitos con múltiples objetivos
#
# ---

# %% [markdown]
# ## Instrucciones generales
#
# El primer paso antes de resolver este laboratorio es leer y entender el **enunciado del caso**.
#
# Este laboratorio tiene las siguientes secciones:
# * **Formulación**: en este caso particular, definimos dos funciones objetivo $z_1$ y $z_2$
# * **Importación de librerías**
# * **Creación de parámetros**
# * **Modelado**: en esta práctica, haremos tres (3) implementaciones del mismo problema:
#     * **Minimización de costos**
#     * **Maximización de la satisfacción**
#     * **Maximización de la satisfacción con restricción de costos**
# * **Reporte de Resultados**
#
# Este tipo de actividades se evaluará sobre un total de 100 puntos. Las celdas calificables se distinguen por tener la instrucción `# your code here`. Antes de estas celdas encontrarás instrucciones y consejos para resolver las preguntas, también el puntaje que le corresponde.
#
# ¡Éxitos!

# %% [markdown]
# ## Formulación
# ---
#
# Te presentamos la formulación del caso de la semana de forma resumida. Te recomendamos revisar la formulación una vez hayas leído el enunciado del caso. Es bueno que te familiarices con los elementos de la formulación antes de iniciar la implementación.
#
# ### Conjuntos y Parámetros
# >#### **Conjuntos**
# >* $I:$ Depósitos
# >* $J:$ Centros de acopio consolidados (CACs)
#
# >#### **Parámetros**
# >* $k_i:$ Capacidad del depósito $i \in I$ (miles de toneladas por año)
# >* $f_i:$ Costo de operación del depósito $i \in I$ (millones de pesos por año)
# >* $d_j:$ Producción proyectada del CAC $j\in J$ (miles de tonaledas por año)
# >* $q:$ Costo anualizado (por cada mil toneladas por kilómetro) de transportar café
# >* $r:$ Distancia máxima (en kilómetros) entre el CAC y el depósito asignado para estar "bien" atendido
# >* $h_{ij}:$ Distancia (en kilómetros) entre el CAC $j \in J$ y el depósito $i \in I$
# >* $c_{ij}:$ Costo anualizado de atender el CAC $j\in J$ con el depósito $i\in I$ (Se calcula como: $c_{ij} = q\cdot d_j \cdot h_{ij}$)
#
# ### Variables de Decisión
# >* $x_{ij}=\begin{cases}1, & \text{si el CAC } j \in J \text{ es atendido por el depósito } i \in I \\0, & \text{de lo contrario} \end{cases}$
# >* $y_{i}=\begin{cases} 1, & \text{si se decide operar el depósito } i \in I  \\ 0, & \text{de lo contrario} \end{cases}$
#
# ### Restricciones
# >1. Cada CAC debe ser atendido por un único depósito
# >>`# Para desarrollo del estudiante`
# >2. No se debe superar la capacidad de los depósitos y sólo se puede atender CACs desde un depósito si se decide operar el mismo.
# >>$\sum_{j \in J}d_{j}x_{ij} \leq k_{i}y_{i}, \; \forall i \in I$
#
# > **Naturaleza de variables**
# >>$x_{ij} \in \{0,1\} , \;\forall i \in I, j \in J$
# >>
# >>$y_{i} \in \{0,1\} , \;\forall i \in I$
#
# ### Función Objetivo
# >* Minimizar los costos totales de operación y transporte
# >>`# Para desarrollo del estudiante`
# >* Maximizar satisfacción de los CACs
# >>$\max z_2 = \sum_{j \in J} d_{j} \sum_{\{i \in I | h_{ij} \leq r\}} x_{ij}$

# %% [markdown]
# ## Importación de librerías
# ---
# En esta práctica usaremos:
# * El paquete `pandas` es muy útil para el análisis de datos en general. Le asignamos el alias de `pd`.
# * El paquete `pulp` permite crear modelos de optimización, crear variables, añadir restricciones y muchos más. Le asignamos el alias de `lp`.
# * La función `distance` del módulo `geopy.distance` nos permite hallar fácilmente la distancia geodéisca en kilómetros entre dos pares de coordenadas de longitud y latitud.

# %%
import pandas as pd
import pulp as lp
from geopy.distance import distance

# %% [markdown]
# ## Creación de Parámetros
# ---

# %% [markdown]
# ### Lectura del archivo de soporte
#
# Los datos que necesitamos para esta práctica se encuentran disponibles en el archivo `Soporte Caso 5.xlsx`.
# En este archivo encontraremos los mismo datos del enunciado.
# Importamos las hojas `CACs` y `Depositos` del archivo `Soporte Caso 5.xlsx`.
# Estas hojas son importadas como objetos `DataFrame` de `pandas`.

# %%
cacs = pd.read_excel('Soporte Caso 5.xlsx', sheet_name='CACs')
depositos = pd.read_excel('Soporte Caso 5.xlsx', sheet_name='Depositos')

# %% [markdown]
# ### Procesamiento de archivos de soporte
#
# En este paso, se crean los **Conjuntos** y **Parámetros**.
# Es necesario dejar todo expresado en términos de listas y diccionarios para facilitar la implementación del modelo en PuLP. Adicionalmente, debemos procesar las coordenadas de longitud y latitud para obtener las distancias entre CACs y Depósitos.

# %%
I = depositos.Municipio.to_list()
J = cacs.Municipio.to_list()

capacidad = {row["Municipio"]: row["Capacidad"] for _, row in depositos.iterrows()}
costo_fijo = {row["Municipio"]: row["CostoFijo"] for _, row in depositos.iterrows()}
depositos_lat_lon = {
    row["Municipio"]: (row["Latitud"], row["Longitud"])
    for _, row in depositos.iterrows()
}

produccion = {row["Municipio"]: row["Produccion"] for _, row in cacs.iterrows()}
cacs_lat_lon = {
    row["Municipio"]: (row["Latitud"], row["Longitud"]) for _, row in cacs.iterrows()
}

q = 90  # Pesos anualizados por cada mil toneladas de café por kilómetro
r = 125  # Kilómetros

distancia = {
    (i, j): distance(depositos_lat_lon[i], cacs_lat_lon[j]).kilometers
    for i in I
    for j in J
}

# %%
distancia
# Out:
# {('Medellín, Antioquia', 'Andes, Antioquia'): 81.6407744153149,
#  ('Medellín, Antioquia', 'Medellín, Antioquia'): 0.0,
#  ('Medellín, Antioquia', 'Dabeiba, Antioquia'): 107.79278431038877,
#  ('Medellín, Antioquia', 'Salgar, Antioquia'): 53.335670657757895,
#  ('Medellín, Antioquia', 'San Pablo de Borbur, Boyacá'): 177.7022202999153,
#  ('Medellín, Antioquia', 'Labranzagrande, Boyacá'): 341.843300383342,
#  ('Medellín, Antioquia', 'Miraflores, Boyacá'): 295.50792681396376,
#  ('Medellín, Antioquia', 'Moniquirá, Boyacá'): 230.85325502996707,
#  ('Medellín, Antioquia', 'Manizales, Caldas'): 132.50832910815635,
#  ('Medellín, Antioquia', 'Anserma, Caldas'): 119.36408078562327,
#  ('Medellín, Antioquia', 'Pensilvania, Caldas'): 106.38936050657013,
#  ('Medellín, Antioquia', 'Riosucio, Caldas'): 91.7929643629694,
#  ('Medellín, Antioquia', 'Aguadas, Caldas'): 77.80655349448206,
#  ('Medellín, Antioquia', 'Morales, Cauca'): 399.20320142759863,
#  ('Medellín, Antioquia', 'El Tambo, Cauca'): 442.9927758625815,
#  ('Medellín, Antioquia', 'Bolívar, Cauca'): 506.82908024404173,
#  ('Medellín, Antioquia', 'Aguachica, Cesar'): 314.30868305575257,
#  ('Medellín, Antioquia', 'San Diego, Cesar'): 522.6122968773435,
#  ('Medellín, Antioquia', 'Caparrapí, Cundinamarca'): 155.5794959329134,
#  ('Medellín, Antioquia', 'Viotá, Cundinamarca'): 237.14728370467418,
#  ('Medellín, Antioquia', 'Sasaima, Cundinamarca'): 195.9470045546287,
#  ('Medellín, Antioquia', 'Neiva, Huila'): 359.0149655616235,
#  ('Medellín, Antioquia', 'Pitalito, Huila'): 500.28067135070114,
#  ('Medellín, Antioquia', 'Gigante, Huila'): 428.47632041782884,
#  ('Medellín, Antioquia', 'Santa Marta, Magdalena'): 570.5045941386736,
#  ('Medellín, Antioquia', 'La Unión, Nariño'): 543.2698934936254,
#  ('Medellín, Antioquia', 'Pasto, Nariño'): 603.9539268024233,
#  ('Medellín, Antioquia', 'Samaniego, Nariño'): 588.9737081094718,
#  ('Medellín, Antioquia', 'Sardinata, Norte de Santander'): 379.5300204804499,
#  ('Medellín, Antioquia', 'Ocaña, Norte de Santander'): 325.4838085170196,
#  ('Medellín, Antioquia', 'Convención, Norte de Santander'): 388.7920881623617,
#  ('Medellín, Antioquia', 'Génova, Quindío'): 230.2605503525202,
#  ('Medellín, Antioquia', 'Calarcá, Quindío'): 200.9003351641889,
#  ('Medellín, Antioquia', 'Quimbaya, Quindío'): 184.25490256239482,
#  ('Medellín, Antioquia', 'Pereira, Risaralda'): 164.19873864004808,
#  ('Medellín, Antioquia', 'Santuario, Risaralda'): 143.01289060496595,
#  ('Medellín, Antioquia', 'Belén de Umbria, Risaralda'): 122.98414262516638,
#  ('Medellín, Antioquia', 'Rionegro, Santander'): 278.4981296858733,
#  ('Medellín, Antioquia', 'Bucaramanga, Santander'): 292.4025708887414,
#  ('Medellín, Antioquia', 'Barbosa, Santander'): 220.75101824212203,
#  ('Medellín, Antioquia', 'Socorro, Santander'): 260.7619390111907,
#  ('Medellín, Antioquia', 'Simacota, Santander'): 222.72762973163123,
#  ('Medellín, Antioquia', 'Chaparral, Tolima'): 278.18369529067377,
#  ('Medellín, Antioquia', 'Dolores, Tolima'): 306.8400984627416,
#  ('Medellín, Antioquia', 'Ibagué, Tolima'): 201.8178937563914,
#  ('Medellín, Antioquia', 'Líbano, Tolima'): 165.83522834878679,
#  ('Medellín, Antioquia', 'Cartago, Valle'): 176.004000536389,
#  ('Medellín, Antioquia', 'Tulua, Valle'): 251.92318505577714,
#  ('Medellín, Antioquia', 'Jamundí, Valle'): 357.8701519601408,
#  ('Medellín, Antioquia', 'Sevilla, Valle'): 235.73341618182997,
#  ('Medellín, Antioquia', 'Caicedonia, Valle'): 218.59787759394675,
#  ('Medellín, Antioquia', 'Florencia, Caquetá'): 514.1772684267618,
#  ('Medellín, Antioquia', 'Puerto Milán, Caquetá'): 545.5974333166706,
#  ('Medellín, Antioquia', 'Nunchía, Casanare'): 398.63420472138824,
#  ('Medellín, Antioquia', 'Mesetas, Meta'): 386.01447379551115,
#  ('La Dorada, Caldas ', 'Andes, Antioquia'): 137.3090199438865,
#  ('La Dorada, Caldas ', 'Medellín, Antioquia'): 126.7422092929512,
#  ('La Dorada, Caldas ', 'Dabeiba, Antioquia'): 234.3459554597085,
#  ('La Dorada, Caldas ', 'Salgar, Antioquia'): 146.7636516992429,
#  ('La Dorada, Caldas ', 'San Pablo de Borbur, Boyacá'): 70.16484153884774,
#  ('La Dorada, Caldas ', 'Labranzagrande, Boyacá'): 235.05216940750856,
#  ('La Dorada, Caldas ', 'Miraflores, Boyacá'): 176.55871895373522,
#  ('La Dorada, Caldas ', 'Moniquirá, Boyacá'): 134.95676282539455,
#  ('La Dorada, Caldas ', 'Manizales, Caldas'): 100.43610726086901,
#  ('La Dorada, Caldas ', 'Anserma, Caldas'): 119.90533260758707,
#  ('La Dorada, Caldas ', 'Pensilvania, Caldas'): 52.53899359428046,
#  ('La Dorada, Caldas ', 'Riosucio, Caldas'): 112.8597814110697,
#  ('La Dorada, Caldas ', 'Aguadas, Caldas'): 81.66786478401428,
#  ('La Dorada, Caldas ', 'Morales, Cauca'): 372.47212806709456,
#  ('La Dorada, Caldas ', 'El Tambo, Cauca'): 412.09882068524445,
#  ('La Dorada, Caldas ', 'Bolívar, Cauca'): 473.2554558787713,
#  ('La Dorada, Caldas ', 'Aguachica, Cesar'): 330.3739848869927,
#  ('La Dorada, Caldas ', 'San Diego, Cesar'): 557.7776503136928,
#  ('La Dorada, Caldas ', 'Caparrapí, Cundinamarca'): 28.86434287352232,
#  ('La Dorada, Caldas ', 'Viotá, Cundinamarca'): 123.83027612165989,
#  ('La Dorada, Caldas ', 'Sasaima, Cundinamarca'): 72.7305478654577,
#  ('La Dorada, Caldas ', 'Neiva, Huila'): 283.2752841013991,
#  ('La Dorada, Caldas ', 'Pitalito, Huila'): 444.01286017679456,
#  ('La Dorada, Caldas ', 'Gigante, Huila'): 358.2872627379983,
#  ('La Dorada, Caldas ', 'Santa Marta, Magdalena'): 633.1953826702052,
#  ('La Dorada, Caldas ', 'La Unión, Nariño'): 510.70135648671385,
#  ('La Dorada, Caldas ', 'Pasto, Nariño'): 567.1959376843564,
#  ('La Dorada, Caldas ', 'Samaniego, Nariño'): 566.6568466676548,
#  ('La Dorada, Caldas ', 'Sardinata, Norte de Santander'): 369.0106167496432,
#  ('La Dorada, Caldas ', 'Ocaña, Norte de Santander'): 331.690717319853,
#  ('La Dorada, Caldas ', 'Convención, Norte de Santander'): 402.4785389983864,
#  ('La Dorada, Caldas ', 'Génova, Quindío'): 186.91756120650967,
#  ('La Dorada, Caldas ', 'Calarcá, Quindío'): 159.8270400535917,
#  ('La Dorada, Caldas ', 'Quimbaya, Quindío'): 155.80339519847513,
#  ('La Dorada, Caldas ', 'Pereira, Risaralda'): 132.5127059688446,
#  ('La Dorada, Caldas ', 'Santuario, Risaralda'): 149.65538731971185,
#  ('La Dorada, Caldas ', 'Belén de Umbria, Risaralda'): 132.6333441385035,
#  ('La Dorada, Caldas ', 'Rionegro, Santander'): 264.5339729787637,
#  ('La Dorada, Caldas ', 'Bucaramanga, Santander'): 253.8431598805216,
#  ('La Dorada, Caldas ', 'Barbosa, Santander'): 129.8060455933185,
#  ('La Dorada, Caldas ', 'Socorro, Santander'): 193.00727479957436,
#  ('La Dorada, Caldas ', 'Simacota, Santander'): 175.31625171214125,
#  ('La Dorada, Caldas ', 'Chaparral, Tolima'): 219.23583898949036,
#  ('La Dorada, Caldas ', 'Dolores, Tolima'): 211.19690549760637,
#  ('La Dorada, Caldas ', 'Ibagué, Tolima'): 130.13534853252278,
#  ('La Dorada, Caldas ', 'Líbano, Tolima'): 80.79753515813282,
#  ('La Dorada, Caldas ', 'Cartago, Valle'): 161.01480358527448,
#  ('La Dorada, Caldas ', 'Tulua, Valle'): 222.52517463326672,
#  ('La Dorada, Caldas ', 'Jamundí, Valle'): 333.29071646627125,
#  ('La Dorada, Caldas ', 'Sevilla, Valle'): 199.69871870441457,
#  ('La Dorada, Caldas ', 'Caicedonia, Valle'): 183.81531657793886,
#  ('La Dorada, Caldas ', 'Florencia, Caquetá'): 443.6468235425709,
#  ('La Dorada, Caldas ', 'Puerto Milán, Caquetá'): 472.22971020652295,
#  ('La Dorada, Caldas ', 'Nunchía, Casanare'): 293.3735489748105,
#  ('La Dorada, Caldas ', 'Mesetas, Meta'): 276.27066549354885,
#  ('Aguadas, Caldas', 'Andes, Antioquia'): 55.65161560538009,
#  ('Aguadas, Caldas', 'Medellín, Antioquia'): 77.80655349448206,
#  ('Aguadas, Caldas', 'Dabeiba, Antioquia'): 177.78513930479517,
#  ('Aguadas, Caldas', 'Salgar, Antioquia'): 71.43052859216482,
#  ('Aguadas, Caldas', 'San Pablo de Borbur, Boyacá'): 150.14965447301535,
#  ('Aguadas, Caldas', 'Labranzagrande, Boyacá'): 316.5853166168409,
#  ('Aguadas, Caldas', 'Miraflores, Boyacá'): 257.38898235436534,
#  ('Aguadas, Caldas', 'Moniquirá, Boyacá'): 213.56390660673168,
#  ('Aguadas, Caldas', 'Manizales, Caldas'): 56.120238106868484,
#  ('Aguadas, Caldas', 'Anserma, Caldas'): 53.13354178658698,
#  ('Aguadas, Caldas', 'Pensilvania, Caldas'): 36.53161409609451,
#  ('Aguadas, Caldas', 'Riosucio, Caldas'): 34.1228297579556,
#  ('Aguadas, Caldas', 'Aguadas, Caldas'): 0.0,
#  ('Aguadas, Caldas', 'Morales, Cauca'): 334.342414632783,
#  ('Aguadas, Caldas', 'El Tambo, Cauca'): 377.0964175011618,
#  ('Aguadas, Caldas', 'Bolívar, Cauca'): 440.51910777245104,
#  ('Aguadas, Caldas', 'Aguachica, Cesar'): 363.91512258958977,
#  ('Aguadas, Caldas', 'San Diego, Cesar'): 582.7474916995808,
#  ('Aguadas, Caldas', 'Caparrapí, Cundinamarca'): 106.91508095409831,
#  ('Aguadas, Caldas', 'Viotá, Cundinamarca'): 166.06160173454344,
#  ('Aguadas, Caldas', 'Sasaima, Cundinamarca'): 134.61959498913643,
#  ('Aguadas, Caldas', 'Neiva, Huila'): 281.79679999145606,
#  ('Aguadas, Caldas', 'Pitalito, Huila'): 427.20752722005284,
#  ('Aguadas, Caldas', 'Gigante, Huila'): 352.2716648175121,
#  ('Aguadas, Caldas', 'Santa Marta, Magdalena'): 640.6417329157617,
#  ('Aguadas, Caldas', 'La Unión, Nariño'): 477.5553488753063,
#  ('Aguadas, Caldas', 'Pasto, Nariño'): 537.121890004635,
#  ('Aguadas, Caldas', 'Samaniego, Nariño'): 527.3820290642581,
#  ('Aguadas, Caldas', 'Sardinata, Norte de Santander'): 417.3197744015035,
#  ('Aguadas, Caldas', 'Ocaña, Norte de Santander'): 370.66268128175716,
#  ('Aguadas, Caldas', 'Convención, Norte de Santander'): 438.47895180720127,
#  ('Aguadas, Caldas', 'Génova, Quindío'): 156.80864934634167,
#  ('Aguadas, Caldas', 'Calarcá, Quindío'): 126.93213303948242,
#  ('Aguadas, Caldas', 'Quimbaya, Quindío'): 112.9298418850283,
#  ('Aguadas, Caldas', 'Pereira, Risaralda'): 90.5833802322253,
#  ('Aguadas, Caldas', 'Santuario, Risaralda'): 83.5122727970633,
#  ('Aguadas, Caldas', 'Belén de Umbria, Risaralda'): 62.72402234876648,
#  ('Aguadas, Caldas', 'Rionegro, Santander'): 312.46653215640606,
#  ('Aguadas, Caldas', 'Bucaramanga, Santander'): 313.3504234802645,
#  ('Aguadas, Caldas', 'Barbosa, Santander'): 206.74586705827346,
#  ('Aguadas, Caldas', 'Socorro, Santander'): 263.35758973803723,
#  ('Aguadas, Caldas', 'Simacota, Santander'): 236.20372077125364,
#  ('Aguadas, Caldas', 'Chaparral, Tolima'): 202.53410147135023,
#  ('Aguadas, Caldas', 'Dolores, Tolima'): 229.59506756496185,
#  ('Aguadas, Caldas', 'Ibagué, Tolima'): 124.01411997396426,
#  ('Aguadas, Caldas', 'Líbano, Tolima'): 90.31983543253541,
#  ('Aguadas, Caldas', 'Cartago, Valle'): 108.99019561599076,
#  ('Aguadas, Caldas', 'Tulua, Valle'): 183.23834875174342,
#  ('Aguadas, Caldas', 'Jamundí, Valle'): 293.24453112870646,
#  ('Aguadas, Caldas', 'Sevilla, Valle'): 164.4284683101244,
#  ('Aguadas, Caldas', 'Caicedonia, Valle'): 147.03536765900378,
#  ('Aguadas, Caldas', 'Florencia, Caquetá'): 438.25806096034887,
#  ('Aguadas, Caldas', 'Puerto Milán, Caquetá'): 469.32667452918696,
#  ('Aguadas, Caldas', 'Nunchía, Casanare'): 374.89353960364423,
#  ('Aguadas, Caldas', 'Mesetas, Meta'): 310.89869965102974,
#  ('Salamina, Caldas', 'Andes, Antioquia'): 68.30203566758392,
#  ('Salamina, Caldas', 'Medellín, Antioquia'): 104.40019877556942,
#  ('Salamina, Caldas', 'Dabeiba, Antioquia'): 203.0477486751987,
#  ('Salamina, Caldas', 'Salgar, Antioquia'): 93.06095113733687,
#  ('Salamina, Caldas', 'San Pablo de Borbur, Boyacá'): 149.00265552780746,
#  ('Salamina, Caldas', 'Labranzagrande, Boyacá'): 311.85055349932827,
#  ('Salamina, Caldas', 'Miraflores, Boyacá'): 248.5358816684281,
#  ('Salamina, Caldas', 'Moniquirá, Boyacá'): 213.80710843935208,
#  ('Salamina, Caldas', 'Manizales, Caldas'): 31.693221430094418,
#  ('Salamina, Caldas', 'Anserma, Caldas'): 41.27044733802893,
#  ('Salamina, Caldas', 'Pensilvania, Caldas'): 26.321991828257524,
#  ('Salamina, Caldas', 'Riosucio, Caldas'): 38.286082000507655,
#  ('Salamina, Caldas', 'Aguadas, Caldas'): 26.593802521976546,
#  ('Salamina, Caldas', 'Morales, Cauca'): 313.59387961707864,
#  ('Salamina, Caldas', 'El Tambo, Cauca'): 355.74188996466785,
#  ('Salamina, Caldas', 'Bolívar, Cauca'): 418.82398822666613,
#  ('Salamina, Caldas', 'Aguachica, Cesar'): 382.9534971924048,
#  ('Salamina, Caldas', 'San Diego, Cesar'): 604.1633005148444,
#  ('Salamina, Caldas', 'Caparrapí, Cundinamarca'): 99.09687658771692,
#  ('Salamina, Caldas', 'Viotá, Cundinamarca'): 143.3147174761558,
#  ('Salamina, Caldas', 'Sasaima, Cundinamarca'): 118.10415928680455,
#  ('Salamina, Caldas', 'Neiva, Huila'): 255.50233222761332,
#  ('Salamina, Caldas', 'Pitalito, Huila'): 402.6797522330758,
#  ('Salamina, Caldas', 'Gigante, Huila'): 326.4242006368361,
#  ('Salamina, Caldas', 'Santa Marta, Magdalena'): 664.9624856851794,
#  ('Salamina, Caldas', 'La Unión, Nariño'): 456.02973156308747,
#  ('Salamina, Caldas', 'Pasto, Nariño'): 515.0446231632513,
#  ('Salamina, Caldas', 'Samaniego, Nariño'): 507.421574792614,
#  ('Salamina, Caldas', 'Sardinata, Norte de Santander'): 432.60635525400727,
#  ('Salamina, Caldas', 'Ocaña, Norte de Santander'): 388.40112642078077,
#  ('Salamina, Caldas', 'Convención, Norte de Santander'): 457.18692214611673,
#  ('Salamina, Caldas', 'Génova, Quindío'): 132.89485822074425,
#  ('Salamina, Caldas', 'Calarcá, Quindío'): 103.00682720173799,
#  ('Salamina, Caldas', 'Quimbaya, Quindío'): 91.08648995974727,
#  ('Salamina, Caldas', 'Pereira, Risaralda'): 67.67146717422398,
#  ('Salamina, Caldas', 'Santuario, Risaralda'): 71.82134585623596,
#  ('Salamina, Caldas', 'Belén de Umbria, Risaralda'): 53.823862286543296,
#  ('Salamina, Caldas', 'Rionegro, Santander'): 327.4377069825127,
#  ('Salamina, Caldas', 'Bucaramanga, Santander'): 324.40519532080697,
#  ('Salamina, Caldas', 'Barbosa, Santander'): 208.3964996650666,
#  ('Salamina, Caldas', 'Socorro, Santander'): 269.3365486625858,
#  ('Salamina, Caldas', 'Simacota, Santander'): 246.2399234392322,
#  ('Salamina, Caldas', 'Chaparral, Tolima'): 177.1398137878443,
#  ('Salamina, Caldas', 'Dolores, Tolima'): 203.27501774870478,
#  ('Salamina, Caldas', 'Ibagué, Tolima'): 97.42400796145094,
#  ('Salamina, Caldas', 'Líbano, Tolima'): 65.69872954296874,
#  ('Salamina, Caldas', 'Cartago, Valle'): 90.23403152327515,
#  ('Salamina, Caldas', 'Tulua, Valle'): 161.73422057483052,
#  ('Salamina, Caldas', 'Jamundí, Valle'): 272.80763360596745,
#  ('Salamina, Caldas', 'Sevilla, Valle'): 141.6936794965298,
#  ('Salamina, Caldas', 'Caicedonia, Valle'): 124.36777896422291,
#  ('Salamina, Caldas', 'Florencia, Caquetá'): 412.49726588219187,
#  ('Salamina, Caldas', 'Puerto Milán, Caquetá'): 443.40404844059816,
#  ('Salamina, Caldas', 'Nunchía, Casanare'): 370.0867026612928,
#  ('Salamina, Caldas', 'Mesetas, Meta'): 285.52161605835295,
#  ('Popayán, Cauca', 'Andes, Antioquia'): 358.52728742136617,
#  ('Popayán, Cauca', 'Medellín, Antioquia'): 436.8924820250337,
#  ('Popayán, Cauca', 'Dabeiba, Antioquia'): 499.7417176660346,
#  ('Popayán, Cauca', 'Salgar, Antioquia'): 395.4300051234283,
#  ('Popayán, Cauca', 'San Pablo de Borbur, Boyacá'): 451.07034964886327,
#  ('Popayán, Cauca', 'Labranzagrande, Boyacá'): 558.4105441188051,
#  ('Popayán, Cauca', 'Miraflores, Boyacá'): 482.50316560225684,
#  ('Popayán, Cauca', 'Moniquirá, Boyacá'): 506.625536880174,
#  ('Popayán, Cauca', 'Manizales, Caldas'): 314.54614108192004,
#  ('Popayán, Cauca', 'Anserma, Caldas'): 318.5098541530593,
#  ('Popayán, Cauca', 'Pensilvania, Caldas'): 362.51156230994684,
#  ('Popayán, Cauca', 'Riosucio, Caldas'): 345.51224724163166,
#  ('Popayán, Cauca', 'Aguadas, Caldas'): 368.579148722757,
#  ('Popayán, Cauca', 'Morales, Cauca'): 48.782857220960494,
#  ('Popayán, Cauca', 'El Tambo, Cauca'): 25.927515213126394,
#  ('Popayán, Cauca', 'Bolívar, Cauca'): 74.44635987615203,
#  ('Popayán, Cauca', 'Aguachica, Cesar'): 726.9282021228366,
#  ('Popayán, Cauca', 'San Diego, Cesar'): 950.2731916524571,
#  ('Popayán, Cauca', 'Caparrapí, Cundinamarca'): 397.00694372701923,
#  ('Popayán, Cauca', 'Viotá, Cundinamarca'): 320.65019234748854,
#  ('Popayán, Cauca', 'Sasaima, Cundinamarca'): 366.56975113313547,
#  ('Popayán, Cauca', 'Neiva, Huila'): 156.87865156010372,
#  ('Popayán, Cauca', 'Pitalito, Huila'): 88.35501723813292,
#  ('Popayán, Cauca', 'Gigante, Huila'): 116.97681818509325,
#  ('Popayán, Cauca', 'Santa Marta, Magdalena'): 1007.3394541634877,
#  ('Popayán, Cauca', 'La Unión, Nariño'): 111.807981148992,
#  ('Popayán, Cauca', 'Pasto, Nariño'): 168.93887548573207,
#  ('Popayán, Cauca', 'Samaniego, Nariño'): 172.5961831392774,
#  ('Popayán, Cauca', 'Sardinata, Norte de Santander'): 767.6223563515723,
#  ('Popayán, Cauca', 'Ocaña, Norte de Santander'): 730.0515313150862,
#  ('Popayán, Cauca', 'Convención, Norte de Santander'): 800.2720882851893,
#  ('Popayán, Cauca', 'Génova, Quindío'): 214.32229482886643,
#  ('Popayán, Cauca', 'Calarcá, Quindío'): 243.74766167111585,
#  ('Popayán, Cauca', 'Quimbaya, Quindío'): 255.668369036499,
#  ('Popayán, Cauca', 'Pereira, Risaralda'): 278.5833459416653,
#  ('Popayán, Cauca', 'Santuario, Risaralda'): 294.09539371198736,
#  ('Popayán, Cauca', 'Belén de Umbria, Risaralda'): 313.91160876662553,
#  ('Popayán, Cauca', 'Rionegro, Santander'): 663.5176133161041,
#  ('Popayán, Cauca', 'Bucaramanga, Santander'): 648.6915390501108,
#  ('Popayán, Cauca', 'Barbosa, Santander'): 508.08796437098476,
#  ('Popayán, Cauca', 'Socorro, Santander'): 578.3853994068144,
#  ('Popayán, Cauca', 'Simacota, Santander'): 571.4682111038986,
#  ('Popayán, Cauca', 'Chaparral, Tolima'): 181.60805379625643,
#  ('Popayán, Cauca', 'Dolores, Tolima'): 240.07669480486226,
#  ('Popayán, Cauca', 'Ibagué, Tolima'): 269.5569469129657,
#  ('Popayán, Cauca', 'Líbano, Tolima'): 318.6347186920519,
#  ('Popayán, Cauca', 'Cartago, Valle'): 261.2253772088501,
#  ('Popayán, Cauca', 'Tulua, Valle'): 185.545100505356,
#  ('Popayán, Cauca', 'Jamundí, Valle'): 84.02958862723425,
#  ('Popayán, Cauca', 'Sevilla, Valle'): 204.51426713804895,
#  ('Popayán, Cauca', 'Caicedonia, Valle'): 221.85459113899756,
#  ('Popayán, Cauca', 'Florencia, Caquetá'): 141.60968806322632,
#  ('Popayán, Cauca', 'Puerto Milán, Caquetá'): 170.58244752030936,
#  ('Popayán, Cauca', 'Nunchía, Casanare'): 605.8452855897602,
#  ('Popayán, Cauca', 'Mesetas, Meta'): 282.54755996792795,
#  ('Valledupar, Cesar', 'Andes, Antioquia'): 612.3078481180537,
#  ('Valledupar, Cesar', 'Medellín, Antioquia'): 530.6683460031395,
#  ('Valledupar, Cesar', 'Dabeiba, Antioquia'): 512.006237482126,
#  ('Valledupar, Cesar', 'Salgar, Antioquia'): 580.3485063595916,
#  ('Valledupar, Cesar', 'San Pablo de Borbur, Boyacá'): 537.5384772638129,
#  ('Valledupar, Cesar', 'Labranzagrande, Boyacá'): 550.5997778244293,
#  ('Valledupar, Cesar', 'Miraflores, Boyacá'): 587.6733985251383,
#  ('Valledupar, Cesar', 'Moniquirá, Boyacá'): 509.2151150822618,
#  ('Valledupar, Cesar', 'Manizales, Caldas'): 645.4762254278301,
#  ('Valledupar, Cesar', 'Anserma, Caldas'): 643.7433590497367,
#  ('Valledupar, Cesar', 'Pensilvania, Caldas'): 598.3437466261523,
#  ('Valledupar, Cesar', 'Riosucio, Caldas'): 618.0909937933791,
#  ('Valledupar, Cesar', 'Aguadas, Caldas'): 592.0484148156911,
#  ('Valledupar, Cesar', 'Morales, Cauca'): 926.3176806126598,
#  ('Valledupar, Cesar', 'El Tambo, Cauca'): 969.1388455030132,
#  ('Valledupar, Cesar', 'Bolívar, Cauca'): 1032.4860924270286,
#  ('Valledupar, Cesar', 'Aguachica, Cesar'): 241.89584749562144,
#  ('Valledupar, Cesar', 'San Diego, Cesar'): 16.6707932005103,
#  ('Valledupar, Cesar', 'Caparrapí, Cundinamarca'): 579.82806024177,
#  ('Valledupar, Cesar', 'Viotá, Cundinamarca'): 680.1793430214168,
#  ('Valledupar, Cesar', 'Sasaima, Cundinamarca'): 623.3555849775427,
#  ('Valledupar, Cesar', 'Neiva, Huila'): 851.8360970225406,
#  ('Valledupar, Cesar', 'Pitalito, Huila'): 1012.1144946527236,
#  ('Valledupar, Cesar', 'Gigante, Huila'): 927.0439406481987,
#  ('Valledupar, Cesar', 'Santa Marta, Magdalena'): 131.84979207213593,
#  ('Valledupar, Cesar', 'La Unión, Nariño'): 1069.5803739070097,
#  ('Valledupar, Cesar', 'Pasto, Nariño'): 1128.8593751500182,
#  ('Valledupar, Cesar', 'Samaniego, Nariño'): 1118.5203346836054,
#  ('Valledupar, Cesar', 'Sardinata, Norte de Santander'): 249.22152835617098,
#  ('Valledupar, Cesar', 'Ocaña, Norte de Santander'): 248.67529363841055,
#  ('Valledupar, Cesar', 'Convención, Norte de Santander'): 180.70952691500108,
#  ('Valledupar, Cesar', 'Génova, Quindío'): 746.1202657634518,
#  ('Valledupar, Cesar', 'Calarcá, Quindío'): 716.4385418155176,
#  ('Valledupar, Cesar', 'Quimbaya, Quindío'): 704.6089416886748,
#  ('Valledupar, Cesar', 'Pereira, Risaralda'): 681.4715532416304,
#  ('Valledupar, Cesar', 'Santuario, Risaralda'): 671.3007940000331,
#  ('Valledupar, Cesar', 'Belén de Umbria, Risaralda'): 650.3644168046235,
#  ('Valledupar, Cesar', 'Rionegro, Santander'): 323.96983150860706,
#  ('Valledupar, Cesar', 'Bucaramanga, Santander'): 365.33180493092203,
#  ('Valledupar, Cesar', 'Barbosa, Santander'): 500.4581212294301,
#  ('Valledupar, Cesar', 'Socorro, Santander'): 442.25641777561606,
#  ('Valledupar, Cesar', 'Simacota, Santander'): 420.92206851040095,
#  ('Valledupar, Cesar', 'Chaparral, Tolima'): 785.7312928570641,
#  ('Valledupar, Cesar', 'Dolores, Tolima'): 774.8011586989783,
#  ('Valledupar, Cesar', 'Ibagué, Tolima'): 697.3360012018215,
#  ('Valledupar, Cesar', 'Líbano, Tolima'): 648.6196090534982,
#  ('Valledupar, Cesar', 'Cartago, Valle'): 700.7941530631836,
#  ('Valledupar, Cesar', 'Tulua, Valle'): 775.1778837881874,
#  ('Valledupar, Cesar', 'Jamundí, Valle'): 885.1326860813085,
#  ('Valledupar, Cesar', 'Sevilla, Valle'): 755.5116051179367,
#  ('Valledupar, Cesar', 'Caicedonia, Valle'): 738.1872096003738,
#  ('Valledupar, Cesar', 'Florencia, Caquetá'): 1012.0401131412118,
#  ('Valledupar, Cesar', 'Puerto Milán, Caquetá'): 1039.8628077811975,
#  ('Valledupar, Cesar', 'Nunchía, Casanare'): 560.9962601170449,
#  ('Valledupar, Cesar', 'Mesetas, Meta'): 819.4409691810346,
#  ('Bogotá, Cundinamarca', 'Andes, Antioquia'): 231.58181254133297,
#  ('Bogotá, Cundinamarca', 'Medellín, Antioquia'): 243.55502528828927,
#  ('Bogotá, Cundinamarca', 'Dabeiba, Antioquia'): 351.2655427154147,
#  ('Bogotá, Cundinamarca', 'Salgar, Antioquia'): 252.86057405401291,
#  ('Bogotá, Cundinamarca', 'San Pablo de Borbur, Boyacá'): 113.85078344637125,
#  ('Bogotá, Cundinamarca', 'Labranzagrande, Boyacá'): 193.66451220594644,
#  ('Bogotá, Cundinamarca', 'Miraflores, Boyacá'): 117.70323916668319,
#  ('Bogotá, Cundinamarca', 'Moniquirá, Boyacá'): 148.56691004463605,
#  ('Bogotá, Cundinamarca', 'Manizales, Caldas'): 161.74838228152376,
#  ('Bogotá, Cundinamarca', 'Anserma, Caldas'): 192.11824555986274,
#  ('Bogotá, Cundinamarca', 'Pensilvania, Caldas'): 144.97848450888677,
#  ('Bogotá, Cundinamarca', 'Riosucio, Caldas'): 201.0894814551844,
#  ('Bogotá, Cundinamarca', 'Aguadas, Caldas'): 181.47264107459307,
#  ('Bogotá, Cundinamarca', 'Morales, Cauca'): 354.51180536939745,
#  ('Bogotá, Cundinamarca', 'El Tambo, Cauca'): 386.2149897956111,
#  ('Bogotá, Cundinamarca', 'Bolívar, Cauca'): 440.2228414484336,
#  ('Bogotá, Cundinamarca', 'Aguachica, Cesar'): 408.1965329063185,
#  ('Bogotá, Cundinamarca', 'San Diego, Cesar'): 637.2620940775327,
#  ('Bogotá, Cundinamarca', 'Caparrapí, Cundinamarca'): 91.88691507943935,
#  ('Bogotá, Cundinamarca', 'Viotá, Cundinamarca'): 47.79351838059698,
#  ('Bogotá, Cundinamarca', 'Sasaima, Cundinamarca'): 47.71469783782267,
#  ('Bogotá, Cundinamarca', 'Neiva, Huila'): 221.86919657881984,
#  ('Bogotá, Cundinamarca', 'Pitalito, Huila'): 389.5018638415791,
#  ('Bogotá, Cundinamarca', 'Gigante, Huila'): 294.9556754322364,
#  ('Bogotá, Cundinamarca', 'Santa Marta, Magdalena'): 728.12951961456,
#  ('Bogotá, Cundinamarca', 'La Unión, Nariño'): 476.50089619703397,
#  ('Bogotá, Cundinamarca', 'Pasto, Nariño'): 526.1599114931842,
#  ('Bogotá, Cundinamarca', 'Samaniego, Nariño'): 539.7732849311632,
#  ('Bogotá, Cundinamarca', 'Sardinata, Norte de Santander'): 424.8136702180597,
#  ('Bogotá, Cundinamarca', 'Ocaña, Norte de Santander'): 402.90719482225205,
#  ('Bogotá, Cundinamarca', 'Convención, Norte de Santander'): 473.826412391993,
#  ('Bogotá, Cundinamarca', 'Génova, Quindío'): 188.90323316852195,
#  ('Bogotá, Cundinamarca', 'Calarcá, Quindío'): 175.8501146208335,
#  ('Bogotá, Cundinamarca', 'Quimbaya, Quindío'): 186.23402733679066,
#  ('Bogotá, Cundinamarca', 'Pereira, Risaralda'): 172.32410387011635,
#  ('Bogotá, Cundinamarca', 'Santuario, Risaralda'): 211.41927625724225,
#  ('Bogotá, Cundinamarca', 'Belén de Umbria, Risaralda'): 204.13485920781187,
#  ('Bogotá, Cundinamarca', 'Rionegro, Santander'): 328.6971411179237,
#  ('Bogotá, Cundinamarca', 'Bucaramanga, Santander'): 299.51306328815514,
#  ('Bogotá, Cundinamarca', 'Barbosa, Santander'): 153.9739028332965,
#  ('Bogotá, Cundinamarca', 'Socorro, Santander'): 222.45681280915954,
#  ('Bogotá, Cundinamarca', 'Simacota, Santander'): 230.5735700076229,
#  ('Bogotá, Cundinamarca', 'Chaparral, Tolima'): 192.36716195126326,
#  ('Bogotá, Cundinamarca', 'Dolores, Tolima'): 134.92219074488602,
#  ('Bogotá, Cundinamarca', 'Ibagué, Tolima'): 127.43260035105715,
#  ('Bogotá, Cundinamarca', 'Líbano, Tolima'): 106.61909969689803,
#  ('Bogotá, Cundinamarca', 'Cartago, Valle'): 201.1045847081064,
#  ('Bogotá, Cundinamarca', 'Tulua, Valle'): 227.59624235582507,
#  ('Bogotá, Cundinamarca', 'Jamundí, Valle'): 322.0706482774737,
#  ('Bogotá, Cundinamarca', 'Sevilla, Valle'): 204.91324361235885,
#  ('Bogotá, Cundinamarca', 'Caicedonia, Valle'): 196.03113993419797,
#  ('Bogotá, Cundinamarca', 'Florencia, Caquetá'): 373.98228838522397,
#  ('Bogotá, Cundinamarca', 'Puerto Milán, Caquetá'): 398.13875018493593,
#  ('Bogotá, Cundinamarca', 'Nunchía, Casanare'): 245.94495523595015,
#  ('Bogotá, Cundinamarca', 'Mesetas, Meta'): 170.58964256111685,
#  ('Santana, Huila', 'Andes, Antioquia'): 264.5734715902947,
#  ('Santana, Huila', 'Medellín, Antioquia'): 312.57566410684643,
#  ('Santana, Huila', 'Dabeiba, Antioquia'): 411.58860028921526,
#  ('Santana, Huila', 'Salgar, Antioquia'): 298.2810415679197,
#  ('Santana, Huila', 'San Pablo de Borbur, Boyacá'): 240.6385056875891,
#  ('Santana, Huila', 'Labranzagrande, Boyacá'): 317.4895932354734,
#  ('Santana, Huila', 'Miraflores, Boyacá'): 242.6278145343595,
#  ('Santana, Huila', 'Moniquirá, Boyacá'): 283.1105632981388,
#  ('Santana, Huila', 'Manizales, Caldas'): 186.75890849803113,
#  ('Santana, Huila', 'Anserma, Caldas'): 212.78698493881495,
#  ('Santana, Huila', 'Pensilvania, Caldas'): 207.5464018357097,
#  ('Santana, Huila', 'Riosucio, Caldas'): 235.62944617196956,
#  ('Santana, Huila', 'Aguadas, Caldas'): 235.51927024236556,
#  ('Santana, Huila', 'Morales, Cauca'): 241.40186346154263,
#  ('Santana, Huila', 'El Tambo, Cauca'): 265.60541109700483,
#  ('Santana, Huila', 'Bolívar, Cauca'): 313.7005008356118,
#  ('Santana, Huila', 'Aguachica, Cesar'): 535.6996700251852,
#  ('Santana, Huila', 'San Diego, Cesar'): 765.1080089550906,
#  ('Santana, Huila', 'Caparrapí, Cundinamarca'): 198.65381722543228,
#  ('Santana, Huila', 'Viotá, Cundinamarca'): 97.16243916335719,
#  ('Santana, Huila', 'Sasaima, Cundinamarca'): 153.84640862423004,
#  ('Santana, Huila', 'Neiva, Huila'): 89.6409608538357,
#  ('Santana, Huila', 'Pitalito, Huila'): 255.81619473602242,
#  ('Santana, Huila', 'Gigante, Huila'): 160.467003660095,
#  ('Santana, Huila', 'Santa Marta, Magdalena'): 847.4000540182476,
#  ('Santana, Huila', 'La Unión, Nariño'): 348.67483988791133,
#  ('Santana, Huila', 'Pasto, Nariño'): 394.9764314325091,
#  ('Santana, Huila', 'Samaniego, Nariño'): 414.3704016008832,
#  ('Santana, Huila', 'Sardinata, Norte de Santander'): 558.1796718103869,
#  ('Santana, Huila', 'Ocaña, Norte de Santander'): 532.6447275444893,
#  ('Santana, Huila', 'Convención, Norte de Santander'): 603.9534831454422,
#  ('Santana, Huila', 'Génova, Quindío'): 133.739472321057,
#  ('Santana, Huila', 'Calarcá, Quindío'): 144.63469594868818,
#  ('Santana, Huila', 'Quimbaya, Quindío'): 165.15405863790082,
#  ('Santana, Huila', 'Pereira, Risaralda'): 169.31766545289,
#  ('Santana, Huila', 'Santuario, Risaralda'): 213.08489654715194,
#  ('Santana, Huila', 'Belén de Umbria, Risaralda'): 219.2248717181252,
#  ('Santana, Huila', 'Rionegro, Santander'): 459.7036643867101,
#  ('Santana, Huila', 'Bucaramanga, Santander'): 433.44055015462357,
#  ('Santana, Huila', 'Barbosa, Santander'): 287.83647140231625,
#  ('Santana, Huila', 'Socorro, Santander'): 357.03624941460976,
#  ('Santana, Huila', 'Simacota, Santander'): 362.0247403251272,
#  ('Santana, Huila', 'Chaparral, Tolima'): 100.36886694676812,
#  ('Santana, Huila', 'Dolores, Tolima'): 7.702651808742567,
#  ('Santana, Huila', 'Ibagué, Tolima'): 115.26185495328846,
#  ('Santana, Huila', 'Líbano, Tolima'): 147.32641500310507,
#  ('Santana, Huila', 'Cartago, Valle'): 183.29922765841056,
#  ('Santana, Huila', 'Tulua, Valle'): 159.28183243998657,
#  ('Santana, Huila', 'Jamundí, Valle'): 217.51316242548918,
#  ('Santana, Huila', 'Sevilla, Valle'): 145.70027186261373,
#  ('Santana, Huila', 'Caicedonia, Valle'): 149.1809427504997,
#  ('Santana, Huila', 'Florencia, Caquetá'): 239.47911195973592,
#  ('Santana, Huila', 'Puerto Milán, Caquetá'): 264.6015786383375,
#  ('Santana, Huila', 'Nunchía, Casanare'): 362.7871184690405,
#  ('Santana, Huila', 'Mesetas, Meta'): 83.67333455415324,
#  ('Neiva, Huila', 'Andes, Antioquia'): 295.3948736967109,
#  ('Neiva, Huila', 'Medellín, Antioquia'): 359.0149655616235,
#  ('Neiva, Huila', 'Dabeiba, Antioquia'): 446.9182756981476,
#  ('Neiva, Huila', 'Salgar, Antioquia'): 332.5936925651697,
#  ('Neiva, Huila', 'San Pablo de Borbur, Boyacá'): 320.7424337607124,
#  ('Neiva, Huila', 'Labranzagrande, Boyacá'): 407.13034502955827,
#  ('Neiva, Huila', 'Miraflores, Boyacá'): 332.1939855246385,
#  ('Neiva, Huila', 'Moniquirá, Boyacá'): 368.49425968300693,
#  ('Neiva, Huila', 'Manizales, Caldas'): 226.52900229670817,
#  ('Neiva, Huila', 'Anserma, Caldas'): 244.56824968810824,
#  ('Neiva, Huila', 'Pensilvania, Caldas'): 262.11938237612685,
#  ('Neiva, Huila', 'Riosucio, Caldas'): 271.3796222594213,
#  ('Neiva, Huila', 'Aguadas, Caldas'): 281.79679999145606,
#  ('Neiva, Huila', 'Morales, Cauca'): 162.79620386268408,
#  ('Neiva, Huila', 'El Tambo, Cauca'): 180.32877492452798,
#  ('Neiva, Huila', 'Bolívar, Cauca'): 224.82489709453753,
#  ('Neiva, Huila', 'Aguachica, Cesar'): 611.9258799812588,
#  ('Neiva, Huila', 'San Diego, Cesar'): 840.4648100360794,
#  ('Neiva, Huila', 'Caparrapí, Cundinamarca'): 272.6948910882189,
#  ('Neiva, Huila', 'Viotá, Cundinamarca'): 179.341639285876,
#  ('Neiva, Huila', 'Sasaima, Cundinamarca'): 232.89211009525994,
#  ('Neiva, Huila', 'Neiva, Huila'): 0.0,
#  ('Neiva, Huila', 'Pitalito, Huila'): 167.72705241619585,
#  ('Neiva, Huila', 'Gigante, Huila'): 75.43892155209964,
#  ('Neiva, Huila', 'Santa Marta, Magdalena'): 914.6752486025225,
#  ('Neiva, Huila', 'La Unión, Nariño'): 259.3300949518558,
#  ('Neiva, Huila', 'Pasto, Nariño'): 305.43246752880987,
#  ('Neiva, Huila', 'Samaniego, Nariño'): 325.57473331789,
#  ('Neiva, Huila', 'Sardinata, Norte de Santander'): 640.5202871658903,
#  ('Neiva, Huila', 'Ocaña, Norte de Santander'): 610.9483128401545,
#  ('Neiva, Huila', 'Convención, Norte de Santander'): 682.2750182111647,
#  ('Neiva, Huila', 'Génova, Quindío'): 137.30051486471214,
#  ('Neiva, Huila', 'Calarcá, Quindío'): 162.48108405159678,
#  ('Neiva, Huila', 'Quimbaya, Quindío'): 182.68035157187703,
#  ('Neiva, Huila', 'Pereira, Risaralda'): 197.45288782850403,
#  ('Neiva, Huila', 'Santuario, Risaralda'): 233.2356685959238,
#  ('Neiva, Huila', 'Belén de Umbria, Risaralda'): 246.48028551851334,
#  ('Neiva, Huila', 'Rionegro, Santander'): 539.7096707657029,
#  ('Neiva, Huila', 'Bucaramanga, Santander'): 517.0574560380494,
#  ('Neiva, Huila', 'Barbosa, Santander'): 372.1531803373357,
#  ('Neiva, Huila', 'Socorro, Santander'): 442.18652168936694,
#  ('Neiva, Huila', 'Simacota, Santander'): 443.22681310682106,
#  ('Neiva, Huila', 'Chaparral, Tolima'): 85.86892854787313,
#  ('Neiva, Huila', 'Dolores, Tolima'): 87.69994527232296,
#  ('Neiva, Huila', 'Ibagué, Tolima'): 159.589003401199,
#  ('Neiva, Huila', 'Líbano, Tolima'): 205.40736546806093,
#  ('Neiva, Huila', 'Cartago, Valle'): 197.63151579375713,
#  ('Neiva, Huila', 'Tulua, Valle'): 140.12632155006466,
#  ('Neiva, Huila', 'Jamundí, Valle'): 148.71180703043615,
#  ('Neiva, Huila', 'Sevilla, Valle'): 140.28730038064583,
#  ('Neiva, Huila', 'Caicedonia, Valle'): 153.01924840542324,
#  ('Neiva, Huila', 'Florencia, Caquetá'): 160.38016415216478,
#  ('Neiva, Huila', 'Puerto Milán, Caquetá'): 189.54137021173594,
#  ('Neiva, Huila', 'Nunchía, Casanare'): 451.9869941099102,
#  ('Neiva, Huila', 'Mesetas, Meta'): 130.5679050114241,
#  ('Santa Marta, Magdalena', 'Andes, Antioquia'): 650.1751430100634,
#  ('Santa Marta, Magdalena', 'Medellín, Antioquia'): 570.5045941386736,
#  ('Santa Marta, Magdalena', 'Dabeiba, Antioquia'): 526.9383347558776,
#  ('Santa Marta, Magdalena', 'Salgar, Antioquia'): 614.7093348886841,
#  ('Santa Marta, Magdalena', 'San Pablo de Borbur, Boyacá'): 614.2940780782207,
#  ('Santa Marta, Magdalena', 'Labranzagrande, Boyacá'): 654.2404332205766,
#  ('Santa Marta, Magdalena', 'Miraflores, Boyacá'): 681.5418995988462,
#  ('Santa Marta, Magdalena', 'Moniquirá, Boyacá'): 597.1008206167425,
#  ('Santa Marta, Magdalena', 'Manizales, Caldas'): 696.3558925412294,
#  ('Santa Marta, Magdalena', 'Anserma, Caldas'): 689.0212951356546,
#  ('Santa Marta, Magdalena', 'Pensilvania, Caldas'): 653.8177716595768,
#  ('Santa Marta, Magdalena', 'Riosucio, Caldas'): 661.8542124652425,
#  ('Santa Marta, Magdalena', 'Aguadas, Caldas'): 640.6417329157617,
#  ('Santa Marta, Magdalena', 'Morales, Cauca'): 969.3813879524503,
#  ('Santa Marta, Magdalena', 'El Tambo, Cauca'): 1013.3374724290508,
#  ('Santa Marta, Magdalena', 'Bolívar, Cauca'): 1077.1896341198965,
#  ('Santa Marta, Magdalena', 'Aguachica, Cesar'): 329.5931688544691,
#  ('Santa Marta, Magdalena', 'San Diego, Cesar'): 147.73209799315816,
#  ('Santa Marta, Magdalena', 'Caparrapí, Cundinamarca'): 648.9521210839616,
#  ('Santa Marta, Magdalena', 'Viotá, Cundinamarca'): 752.1760940884933,
#  ('Santa Marta, Magdalena', 'Sasaima, Cundinamarca'): 695.4276701519827,
#  ('Santa Marta, Magdalena', 'Neiva, Huila'): 914.6752486025225,
#  ('Santa Marta, Magdalena', 'Pitalito, Huila'): 1067.6421103451721,
#  ('Santa Marta, Magdalena', 'Gigante, Huila'): 988.5298322710139,
#  ('Santa Marta, Magdalena', 'Santa Marta, Magdalena'): 0.0,
#  ('Santa Marta, Magdalena', 'La Unión, Nariño'): 1113.437131892707,
#  ('Santa Marta, Magdalena', 'Pasto, Nariño'): 1174.3481378747665,
#  ('Santa Marta, Magdalena', 'Samaniego, Nariño'): 1156.6448615733234,
#  ('Santa Marta, Magdalena',
#   'Sardinata, Norte de Santander'): 362.25644566875275,
#  ('Santa Marta, Magdalena', 'Ocaña, Norte de Santander'): 344.22914170853517,
#  ('Santa Marta, Magdalena',
#   'Convención, Norte de Santander'): 286.9519710703289,
#  ('Santa Marta, Magdalena', 'Génova, Quindío'): 797.4433265996074,
#  ('Santa Marta, Magdalena', 'Calarcá, Quindío'): 767.5503296800364,
#  ('Santa Marta, Magdalena', 'Quimbaya, Quindío'): 752.9757265944194,
#  ('Santa Marta, Magdalena', 'Pereira, Risaralda'): 731.1946633625548,
#  ('Santa Marta, Magdalena', 'Santuario, Risaralda'): 713.485836635895,
#  ('Santa Marta, Magdalena', 'Belén de Umbria, Risaralda'): 693.4497828397706,
#  ('Santa Marta, Magdalena', 'Rionegro, Santander'): 416.76582135505726,
#  ('Santa Marta, Magdalena', 'Bucaramanga, Santander'): 464.99537991679193,
#  ('Santa Marta, Magdalena', 'Barbosa, Santander'): 586.8215717427619,
#  ('Santa Marta, Magdalena', 'Socorro, Santander'): 536.9970078066568,
#  ('Santa Marta, Magdalena', 'Simacota, Santander'): 507.5304633430298,
#  ('Santa Marta, Magdalena', 'Chaparral, Tolima'): 841.5931517400153,
#  ('Santa Marta, Magdalena', 'Dolores, Tolima'): 844.0119359505686,
#  ('Santa Marta, Magdalena', 'Ibagué, Tolima'): 755.9908550886921,
#  ('Santa Marta, Magdalena', 'Líbano, Tolima'): 709.2703442347951,
#  ('Santa Marta, Magdalena', 'Cartago, Valle'): 746.184396270243,
#  ('Santa Marta, Magdalena', 'Tulua, Valle'): 822.051245724508,
#  ('Santa Marta, Magdalena', 'Jamundí, Valle'): 928.0909133368948,
#  ('Santa Marta, Magdalena', 'Sevilla, Valle'): 804.6801751694301,
#  ('Santa Marta, Magdalena', 'Caicedonia, Valle'): 787.3290400596967,
#  ('Santa Marta, Magdalena', 'Florencia, Caquetá'): 1074.6099499829131,
#  ('Santa Marta, Magdalena', 'Puerto Milán, Caquetá'): 1104.211689694137,
#  ('Santa Marta, Magdalena', 'Nunchía, Casanare'): 671.7901232496911,
#  ('Santa Marta, Magdalena', 'Mesetas, Meta'): 898.6858101198605,
#  ('Cúcuta, Nor. de Santander', 'Andes, Antioquia'): 470.5808417823327,
#  ('Cúcuta, Nor. de Santander', 'Medellín, Antioquia'): 398.3920315970541,
#  ('Cúcuta, Nor. de Santander', 'Dabeiba, Antioquia'): 438.9093903747973,
#  ('Cúcuta, Nor. de Santander', 'Salgar, Antioquia'): 451.2161763381724,
#  ('Cúcuta, Nor. de Santander',
#   'San Pablo de Borbur, Boyacá'): 320.5594267283286,
#  ('Cúcuta, Nor. de Santander', 'Labranzagrande, Boyacá'): 282.0780109045361,
#  ('Cúcuta, Nor. de Santander', 'Miraflores, Boyacá'): 332.60200532777566,
#  ('Cúcuta, Nor. de Santander', 'Moniquirá, Boyacá'): 271.42265019862884,
#  ('Cúcuta, Nor. de Santander', 'Manizales, Caldas'): 471.4657402968298,
#  ('Cúcuta, Nor. de Santander', 'Anserma, Caldas'): 481.89084570094974,
#  ('Cúcuta, Nor. de Santander', 'Pensilvania, Caldas'): 420.14484325293137,
#  ('Cúcuta, Nor. de Santander', 'Riosucio, Caldas'): 462.7483260597944,
#  ('Cúcuta, Nor. de Santander', 'Aguadas, Caldas'): 429.7728754957145,
#  ('Cúcuta, Nor. de Santander', 'Morales, Cauca'): 747.2030695928593,
#  ('Cúcuta, Nor. de Santander', 'El Tambo, Cauca'): 785.864368361459,
#  ('Cúcuta, Nor. de Santander', 'Bolívar, Cauca'): 845.7047524617309,
#  ('Cúcuta, Nor. de Santander', 'Aguachica, Cesar'): 127.528481396562,
#  ('Cúcuta, Nor. de Santander', 'San Diego, Cesar'): 261.42122940175,
#  ('Cúcuta, Nor. de Santander', 'Caparrapí, Cundinamarca'): 374.31558752906636,
#  ('Cúcuta, Nor. de Santander', 'Viotá, Cundinamarca'): 459.7601290138682,
#  ('Cúcuta, Nor. de Santander', 'Sasaima, Cundinamarca'): 407.22895907557853,
#  ('Cúcuta, Nor. de Santander', 'Neiva, Huila'): 639.0572408896613,
#  ('Cúcuta, Nor. de Santander', 'Pitalito, Huila'): 806.3168159357938,
#  ('Cúcuta, Nor. de Santander', 'Gigante, Huila'): 713.6205764219999,
#  ('Cúcuta, Nor. de Santander', 'Santa Marta, Magdalena'): 395.8460945568736,
#  ('Cúcuta, Nor. de Santander', 'La Unión, Nariño'): 883.0342248032787,
#  ('Cúcuta, Nor. de Santander', 'Pasto, Nariño'): 937.4209195411239,
#  ('Cúcuta, Nor. de Santander', 'Samaniego, Nariño'): 940.9497244195331,
#  ('Cúcuta, Nor. de Santander',
#   'Sardinata, Norte de Santander'): 40.47569382076572,
#  ('Cúcuta, Nor. de Santander',
#   'Ocaña, Norte de Santander'): 101.83193056104857,
#  ('Cúcuta, Nor. de Santander',
#   'Convención, Norte de Santander'): 114.2723876439114,
#  ('Cúcuta, Nor. de Santander', 'Génova, Quindío'): 561.8435644497865,
#  ('Cúcuta, Nor. de Santander', 'Calarcá, Quindío'): 534.9934155845451,
#  ('Cúcuta, Nor. de Santander', 'Quimbaya, Quindío'): 529.8626296964455,
#  ('Cúcuta, Nor. de Santander', 'Pereira, Risaralda'): 506.1100741739315,
#  ('Cúcuta, Nor. de Santander', 'Santuario, Risaralda'): 512.8729280974856,
#  ('Cúcuta, Nor. de Santander',
#   'Belén de Umbria, Risaralda'): 492.41493921233666,
#  ('Cúcuta, Nor. de Santander', 'Rionegro, Santander'): 119.89580988281226,
#  ('Cúcuta, Nor. de Santander', 'Bucaramanga, Santander'): 122.62996208752588,
#  ('Cúcuta, Nor. de Santander', 'Barbosa, Santander'): 266.96390517037196,
#  ('Cúcuta, Nor. de Santander', 'Socorro, Santander'): 197.51275071464258,
#  ('Cúcuta, Nor. de Santander', 'Simacota, Santander'): 200.16256387265983,
#  ('Cúcuta, Nor. de Santander', 'Chaparral, Tolima'): 589.6943160309191,
#  ('Cúcuta, Nor. de Santander', 'Dolores, Tolima'): 554.0358424097682,
#  ('Cúcuta, Nor. de Santander', 'Ibagué, Tolima'): 502.12812179279854,
#  ('Cúcuta, Nor. de Santander', 'Líbano, Tolima'): 453.6906105411729,
#  ('Cúcuta, Nor. de Santander', 'Cartago, Valle'): 532.5884468268271,
#  ('Cúcuta, Nor. de Santander', 'Tulua, Valle'): 597.6770104932572,
#  ('Cúcuta, Nor. de Santander', 'Jamundí, Valle'): 708.3769188003123,
#  ('Cúcuta, Nor. de Santander', 'Sevilla, Valle'): 574.8604972840711,
#  ('Cúcuta, Nor. de Santander', 'Caicedonia, Valle'): 558.9520421624513,
#  ('Cúcuta, Nor. de Santander', 'Florencia, Caquetá'): 793.9158900826468,
#  ('Cúcuta, Nor. de Santander', 'Puerto Milán, Caquetá'): 817.9503229086267,
#  ('Cúcuta, Nor. de Santander', 'Nunchía, Casanare'): 285.06053036169715,
#  ('Cúcuta, Nor. de Santander', 'Mesetas, Meta'): 579.3126247926174,
#  ('Pasto, Nariño', 'Andes, Antioquia'): 524.3395565999031,
#  ('Pasto, Nariño', 'Medellín, Antioquia'): 603.9539268024233,
#  ('Pasto, Nariño', 'Dabeiba, Antioquia'): 660.3754406789634,
#  ('Pasto, Nariño', 'Salgar, Antioquia'): 560.4841433465521,
#  ('Pasto, Nariño', 'San Pablo de Borbur, Boyacá'): 616.861670416939,
#  ('Pasto, Nariño', 'Labranzagrande, Boyacá'): 712.3004077239935,
#  ('Pasto, Nariño', 'Miraflores, Boyacá'): 637.6006788845664,
#  ('Pasto, Nariño', 'Moniquirá, Boyacá'): 669.992332698319,
#  ('Pasto, Nariño', 'Manizales, Caldas'): 483.4050904557729,
#  ('Pasto, Nariño', 'Anserma, Caldas'): 486.4485252008906,
#  ('Pasto, Nariño', 'Pensilvania, Caldas'): 531.4357534604953,
#  ('Pasto, Nariño', 'Riosucio, Caldas'): 513.1198654109312,
#  ('Pasto, Nariño', 'Aguadas, Caldas'): 537.121890004635,
#  ('Pasto, Nariño', 'Morales, Cauca'): 205.12590617187809,
#  ('Pasto, Nariño', 'El Tambo, Cauca'): 161.01939439663195,
#  ('Pasto, Nariño', 'Bolívar, Cauca'): 97.16949749250364,
#  ('Pasto, Nariño', 'Aguachica, Cesar'): 895.7572084949932,
#  ('Pasto, Nariño', 'San Diego, Cesar'): 1119.1727045583345,
#  ('Pasto, Nariño', 'Caparrapí, Cundinamarca'): 563.8586513805137,
#  ('Pasto, Nariño', 'Viotá, Cundinamarca'): 481.44990187345064,
#  ('Pasto, Nariño', 'Sasaima, Cundinamarca'): 530.7949599197727,
#  ('Pasto, Nariño', 'Neiva, Huila'): 305.43246752880987,
#  ('Pasto, Nariño', 'Pitalito, Huila'): 143.44409137003817,
#  ('Pasto, Nariño', 'Gigante, Huila'): 238.6505723410831,
#  ('Pasto, Nariño', 'Santa Marta, Magdalena'): 1174.3481378747665,
#  ('Pasto, Nariño', 'La Unión, Nariño'): 61.95037867647127,
#  ('Pasto, Nariño', 'Pasto, Nariño'): 0.0,
#  ('Pasto, Nariño', 'Samaniego, Nariño'): 68.49117465720198,
#  ('Pasto, Nariño', 'Sardinata, Norte de Santander'): 935.0502331724806,
#  ('Pasto, Nariño', 'Ocaña, Norte de Santander'): 898.5961342246372,
#  ('Pasto, Nariño', 'Convención, Norte de Santander'): 968.9671755738173,
#  ('Pasto, Nariño', 'Génova, Quindío'): 383.24648410854604,
#  ('Pasto, Nariño', 'Calarcá, Quindío'): 412.6847914892862,
#  ('Pasto, Nariño', 'Quimbaya, Quindío'): 424.3139841777996,
#  ('Pasto, Nariño', 'Pereira, Risaralda'): 447.3879425170209,
#  ('Pasto, Nariño', 'Santuario, Risaralda'): 460.94244071877415,
#  ('Pasto, Nariño', 'Belén de Umbria, Risaralda'): 481.2042490148524,
#  ('Pasto, Nariño', 'Rionegro, Santander'): 831.3779721272043,
#  ('Pasto, Nariño', 'Bucaramanga, Santander'): 814.7940107737809,
#  ('Pasto, Nariño', 'Barbosa, Santander'): 672.345535649657,
#  ('Pasto, Nariño', 'Socorro, Santander'): 742.7733772530154,
#  ('Pasto, Nariño', 'Simacota, Santander'): 738.2523846907224,
#  ('Pasto, Nariño', 'Chaparral, Tolima'): 348.440556654478,
#  ('Pasto, Nariño', 'Dolores, Tolima'): 393.09925968787223,
#  ('Pasto, Nariño', 'Ibagué, Tolima'): 437.2512912319815,
#  ('Pasto, Nariño', 'Líbano, Tolima'): 486.53066048609327,
#  ('Pasto, Nariño', 'Cartago, Valle'): 429.11017693317154,
#  ('Pasto, Nariño', 'Tulua, Valle'): 353.8913521419691,
#  ('Pasto, Nariño', 'Jamundí, Valle'): 246.3231061322024,
#  ('Pasto, Nariño', 'Sevilla, Valle'): 373.3681216838942,
#  ('Pasto, Nariño', 'Caicedonia, Valle'): 390.67708238389656,
#  ('Pasto, Nariño', 'Florencia, Caquetá'): 189.12102279696128,
#  ('Pasto, Nariño', 'Puerto Milán, Caquetá'): 191.38039660754444,
#  ('Pasto, Nariño', 'Nunchía, Casanare'): 755.5858469569781,
#  ('Pasto, Nariño', 'Mesetas, Meta'): 411.31020097848926,
#  ('Génova, Quindío', 'Andes, Antioquia'): 160.03785189817748,
#  ('Génova, Quindío', 'Medellín, Antioquia'): 230.2605503525202,
#  ('Génova, Quindío', 'Dabeiba, Antioquia'): 311.1569034028174,
#  ('Génova, Quindío', 'Salgar, Antioquia'): 197.7866121755596,
#  ('Génova, Quindío', 'San Pablo de Borbur, Boyacá'): 245.45109076118942,
#  ('Génova, Quindío', 'Labranzagrande, Boyacá'): 379.3526610650587,
#  ('Génova, Quindío', 'Miraflores, Boyacá'): 304.78743746700616,
#  ('Génova, Quindío', 'Moniquirá, Boyacá'): 306.350983916328,
#  ('Génova, Quindío', 'Manizales, Caldas'): 101.26325104910563,
#  ('Génova, Quindío', 'Anserma, Caldas'): 111.5053891553351,
#  ('Génova, Quindío', 'Pensilvania, Caldas'): 148.18999799789745,
#  ('Génova, Quindío', 'Riosucio, Caldas'): 139.15923489051568,
#  ('Génova, Quindío', 'Aguadas, Caldas'): 156.80864934634167,
#  ('Génova, Quindío', 'Morales, Cauca'): 185.56098097541172,
#  ('Génova, Quindío', 'El Tambo, Cauca'): 225.73164071414112,
#  ('Génova, Quindío', 'Bolívar, Cauca'): 287.82717674883617,
#  ('Génova, Quindío', 'Aguachica, Cesar'): 512.6819709685892,
#  ('Génova, Quindío', 'San Diego, Cesar'): 736.1835135497735,
#  ('Génova, Quindío', 'Caparrapí, Cundinamarca'): 189.28279551832006,
#  ('Génova, Quindío', 'Viotá, Cundinamarca'): 142.94898703580537,
#  ('Génova, Quindío', 'Sasaima, Cundinamarca'): 169.68046692651612,
#  ('Génova, Quindío', 'Neiva, Huila'): 137.30051486471214,
#  ('Génova, Quindío', 'Pitalito, Huila'): 270.50718351528815,
#  ('Génova, Quindío', 'Gigante, Huila'): 200.262574566957,
#  ('Génova, Quindío', 'Santa Marta, Magdalena'): 797.4433265996074,
#  ('Génova, Quindío', 'La Unión, Nariño'): 325.22612648513365,
#  ('Génova, Quindío', 'Pasto, Nariño'): 383.24648410854604,
#  ('Génova, Quindío', 'Samaniego, Nariño'): 379.8288642091193,
#  ('Génova, Quindío', 'Sardinata, Norte de Santander'): 555.8037950805646,
#  ('Génova, Quindío', 'Ocaña, Norte de Santander'): 516.2412093041494,
#  ('Génova, Quindío', 'Convención, Norte de Santander'): 586.2009683152166,
#  ('Génova, Quindío', 'Génova, Quindío'): 0.0,
#  ('Génova, Quindío', 'Calarcá, Quindío'): 29.913161349241737,
#  ('Génova, Quindío', 'Quimbaya, Quindío'): 46.78173961379427,
#  ('Génova, Quindío', 'Pereira, Risaralda'): 66.38215079034374,
#  ('Génova, Quindío', 'Santuario, Risaralda'): 96.27357335520183,
#  ('Génova, Quindío', 'Belén de Umbria, Risaralda'): 111.16903090646012,
#  ('Génova, Quindío', 'Rionegro, Santander'): 451.06531081816223,
#  ('Génova, Quindío', 'Bucaramanga, Santander'): 439.9776782720725,
#  ('Génova, Quindío', 'Barbosa, Santander'): 305.4525902935359,
#  ('Génova, Quindío', 'Socorro, Santander'): 374.20159733021706,
#  ('Génova, Quindío', 'Simacota, Santander'): 361.72527167399574,
#  ('Génova, Quindío', 'Chaparral, Tolima'): 51.479364793955945,
#  ('Génova, Quindío', 'Dolores, Tolima'): 126.0368509033706,
#  ('Génova, Quindío', 'Ibagué, Tolima'): 64.31280055956175,
#  ('Génova, Quindío', 'Líbano, Tolima'): 108.90317500013165,
#  ('Génova, Quindío', 'Cartago, Valle'): 60.39137427642882,
#  ('Génova, Quindío', 'Tulua, Valle'): 39.17368804625257,
#  ('Génova, Quindío', 'Jamundí, Valle'): 146.58516739577442,
#  ('Génova, Quindío', 'Sevilla, Valle'): 16.01585426030162,
#  ('Génova, Quindío', 'Caicedonia, Valle'): 16.410622730604327,
#  ('Génova, Quindío', 'Florencia, Caquetá'): 284.9804618120405,
#  ('Génova, Quindío', 'Puerto Milán, Caquetá'): 316.9662889014499,
#  ('Génova, Quindío', 'Nunchía, Casanare'): 433.7875029322686,
#  ('Génova, Quindío', 'Mesetas, Meta'): 216.71448882139032,
#  ('Calarcá, Quindío', 'Andes, Antioquia'): 132.95656365995694,
#  ('Calarcá, Quindío', 'Medellín, Antioquia'): 200.9003351641889,
#  ('Calarcá, Quindío', 'Dabeiba, Antioquia'): 284.4728689665647,
#  ('Calarcá, Quindío', 'Salgar, Antioquia'): 170.3476229144848,
#  ('Calarcá, Quindío', 'San Pablo de Borbur, Boyacá'): 221.1033716123769,
#  ('Calarcá, Quindío', 'Labranzagrande, Boyacá'): 361.89509591523415,
#  ('Calarcá, Quindío', 'Miraflores, Boyacá'): 288.6915555819263,
#  ('Calarcá, Quindío', 'Moniquirá, Boyacá'): 283.43472513638875,
#  ('Calarcá, Quindío', 'Manizales, Caldas'): 71.35780009193931,
#  ('Calarcá, Quindío', 'Anserma, Caldas'): 82.90252905196257,
#  ('Calarcá, Quindío', 'Pensilvania, Caldas'): 118.94163202405663,
#  ('Calarcá, Quindío', 'Riosucio, Caldas'): 110.35595855944531,
#  ('Calarcá, Quindío', 'Aguadas, Caldas'): 126.93213303948242,
#  ('Calarcá, Quindío', 'Morales, Cauca'): 213.5218188528296,
#  ('Calarcá, Quindío', 'El Tambo, Cauca'): 254.470881807097,
#  ('Calarcá, Quindío', 'Bolívar, Cauca'): 316.9593266928761,
#  ('Calarcá, Quindío', 'Aguachica, Cesar'): 483.5665962582873,
#  ('Calarcá, Quindío', 'San Diego, Cesar'): 706.575619788819,
#  ('Calarcá, Quindío', 'Caparrapí, Cundinamarca'): 164.62964450390135,
#  ('Calarcá, Quindío', 'Viotá, Cundinamarca'): 132.86874674765872,
#  ('Calarcá, Quindío', 'Sasaima, Cundinamarca'): 150.42944252454097,
#  ('Calarcá, Quindío', 'Neiva, Huila'): 162.48108405159678,
#  ('Calarcá, Quindío', 'Pitalito, Huila'): 300.3082777592506,
#  ('Calarcá, Quindío', 'Gigante, Huila'): 228.35737227623082,
# ...
#  ('Calarcá, Quindío', 'Líbano, Tolima'): 84.857366958847,
#  ('Calarcá, Quindío', 'Cartago, Valle'): 38.80450572365599,
#  ('Calarcá, Quindío', 'Tulua, Valle'): 62.710832141015366,
#  ('Calarcá, Quindío', 'Jamundí, Valle'): 173.73197045461964,
#  ('Calarcá, Quindío', 'Sevilla, Valle'): 40.09103869056908,
#  ('Calarcá, Quindío', 'Caicedonia, Valle'): 24.1006306029123,
#  ('Calarcá, Quindío', 'Florencia, Caquetá'): 313.60909571937407,
#  ('Calarcá, Quindío', 'Puerto Milán, Caquetá'): 345.3471899965596,
#  ('Calarcá, Quindío', 'Nunchía, Casanare'): 417.52730749130626,
#  ('Calarcá, Quindío', 'Mesetas, Meta'): 228.27389902665718,
#  ('Filandia, Quindío', 'Andes, Antioquia'): 111.27535697724957,
#  ('Filandia, Quindío', 'Medellín, Antioquia'): 177.5881575919001,
#  ('Filandia, Quindío', 'Dabeiba, Antioquia'): 262.6951702217879,
#  ('Filandia, Quindío', 'Salgar, Antioquia'): 148.23919204534786,
#  ('Filandia, Quindío', 'San Pablo de Borbur, Boyacá'): 205.37849974170376,
#  ('Filandia, Quindío', 'Labranzagrande, Boyacá'): 352.2480364194639,
#  ('Filandia, Quindío', 'Miraflores, Boyacá'): 280.63646518012234,
#  ('Filandia, Quindío', 'Moniquirá, Boyacá'): 268.8851527362607,
#  ('Filandia, Quindío', 'Manizales, Caldas'): 48.43245150102398,
#  ('Filandia, Quindío', 'Anserma, Caldas'): 60.24041789166671,
#  ('Filandia, Quindío', 'Pensilvania, Caldas'): 97.52433063688697,
#  ('Filandia, Quindío', 'Riosucio, Caldas'): 87.41645215356186,
#  ('Filandia, Quindío', 'Aguadas, Caldas'): 103.64463206769095,
#  ('Filandia, Quindío', 'Morales, Cauca'): 234.57965614594693,
#  ('Filandia, Quindío', 'El Tambo, Cauca'): 276.15975692700465,
#  ('Filandia, Quindío', 'Bolívar, Cauca'): 338.9922172021083,
#  ('Filandia, Quindío', 'Aguachica, Cesar'): 461.8782000926008,
#  ('Filandia, Quindío', 'San Diego, Cesar'): 684.1442647953423,
#  ('Filandia, Quindío', 'Caparrapí, Cundinamarca'): 149.04404462164754,
#  ('Filandia, Quindío', 'Viotá, Cundinamarca'): 132.48831451368073,
#  ('Filandia, Quindío', 'Sasaima, Cundinamarca'): 140.939750154003,
#  ('Filandia, Quindío', 'Neiva, Huila'): 184.37109709330116,
#  ('Filandia, Quindío', 'Pitalito, Huila'): 323.65717638945114,
#  ('Filandia, Quindío', 'Gigante, Huila'): 251.3459807149199,
#  ('Filandia, Quindío', 'Santa Marta, Magdalena'): 744.2859555967408,
#  ('Filandia, Quindío', 'La Unión, Nariño'): 376.26949897217565,
#  ('Filandia, Quindío', 'Pasto, Nariño'): 435.02844881042495,
#  ('Filandia, Quindío', 'Samaniego, Nariño'): 428.848861289306,
#  ('Filandia, Quindío', 'Sardinata, Norte de Santander'): 508.00702621418844,
#  ('Filandia, Quindío', 'Ocaña, Norte de Santander'): 466.3404261822429,
#  ('Filandia, Quindío', 'Convención, Norte de Santander'): 535.786186996409,
#  ('Filandia, Quindío', 'Génova, Quindío'): 53.17273011599935,
#  ('Filandia, Quindío', 'Calarcá, Quindío'): 23.37926952322915,
#  ('Filandia, Quindío', 'Quimbaya, Quindío'): 15.470337038124654,
#  ('Filandia, Quindío', 'Pereira, Risaralda'): 13.396167056298683,
#  ('Filandia, Quindío', 'Santuario, Risaralda'): 53.96753346371802,
#  ('Filandia, Quindío', 'Belén de Umbria, Risaralda'): 62.7428745178784,
#  ('Filandia, Quindío', 'Rionegro, Santander'): 402.9201458089082,
#  ('Filandia, Quindío', 'Bucaramanga, Santander'): 395.05659621385996,
#  ('Filandia, Quindío', 'Barbosa, Santander'): 266.36048722915075,
#  ('Filandia, Quindío', 'Socorro, Santander'): 333.01714294842765,
#  ('Filandia, Quindío', 'Simacota, Santander'): 316.481115930024,
#  ('Filandia, Quindío', 'Chaparral, Tolima'): 100.95544280803534,
#  ('Filandia, Quindío', 'Dolores, Tolima'): 151.82483457962093,
#  ('Filandia, Quindío', 'Ibagué, Tolima'): 50.14128915678227,
#  ('Filandia, Quindío', 'Líbano, Tolima'): 72.04578416036064,
#  ('Filandia, Quindío', 'Cartago, Valle'): 29.678867900136073,
#  ('Filandia, Quindío', 'Tulua, Valle'): 82.70505189487216,
#  ('Filandia, Quindío', 'Jamundí, Valle'): 194.25452353045875,
#  ('Filandia, Quindío', 'Sevilla, Valle'): 61.678695853309506,
#  ('Filandia, Quindío', 'Caicedonia, Valle'): 44.48075347098897,
#  ('Filandia, Quindío', 'Florencia, Caquetá'): 336.7603333087709,
#  ('Filandia, Quindío', 'Puerto Milán, Caquetá'): 368.40169957169326,
#  ('Filandia, Quindío', 'Nunchía, Casanare'): 408.77305198478524,
#  ('Filandia, Quindío', 'Mesetas, Meta'): 242.11811017936677,
#  ('Pereira, Risaralda', 'Andes, Antioquia'): 98.60204332949883,
#  ('Pereira, Risaralda', 'Medellín, Antioquia'): 164.19873864004808,
#  ('Pereira, Risaralda', 'Dabeiba, Antioquia'): 249.83658519497786,
#  ('Pereira, Risaralda', 'Salgar, Antioquia'): 135.28157811076198,
#  ('Pereira, Risaralda', 'San Pablo de Borbur, Boyacá'): 198.29292471093206,
#  ('Pereira, Risaralda', 'Labranzagrande, Boyacá'): 348.72857091104555,
#  ('Pereira, Risaralda', 'Miraflores, Boyacá'): 278.2607700180759,
#  ('Pereira, Risaralda', 'Moniquirá, Boyacá'): 262.4028490111548,
#  ('Pereira, Risaralda', 'Manizales, Caldas'): 36.14939884669452,
#  ('Pereira, Risaralda', 'Anserma, Caldas'): 47.12515145643546,
#  ('Pereira, Risaralda', 'Pensilvania, Caldas'): 86.54376987555285,
#  ('Pereira, Risaralda', 'Riosucio, Caldas'): 74.11146753490641,
#  ('Pereira, Risaralda', 'Aguadas, Caldas'): 90.5833802322253,
#  ('Pereira, Risaralda', 'Morales, Cauca'): 246.17659229743896,
#  ('Pereira, Risaralda', 'El Tambo, Cauca'): 288.122601664389,
#  ('Pereira, Risaralda', 'Bolívar, Cauca'): 351.1563226305258,
#  ('Pereira, Risaralda', 'Aguachica, Cesar'): 450.1882267546381,
#  ('Pereira, Risaralda', 'San Diego, Cesar'): 671.8343754447293,
#  ('Pereira, Risaralda', 'Caparrapí, Cundinamarca'): 142.36290278577425,
#  ('Pereira, Risaralda', 'Viotá, Cundinamarca'): 135.56898178583202,
#  ('Pereira, Risaralda', 'Sasaima, Cundinamarca'): 138.471748407086,
#  ('Pereira, Risaralda', 'Neiva, Huila'): 197.45288782850403,
#  ('Pereira, Risaralda', 'Pitalito, Huila'): 336.88851842529823,
#  ('Pereira, Risaralda', 'Gigante, Huila'): 264.71669590376894,
#  ('Pereira, Risaralda', 'Santa Marta, Magdalena'): 731.1946633625548,
#  ('Pereira, Risaralda', 'La Unión, Nariño'): 388.37326878595314,
#  ('Pereira, Risaralda', 'Pasto, Nariño'): 447.3879425170209,
#  ('Pereira, Risaralda', 'Samaniego, Nariño'): 440.25562823558363,
#  ('Pereira, Risaralda', 'Sardinata, Norte de Santander'): 497.51607839330734,
#  ('Pereira, Risaralda', 'Ocaña, Norte de Santander'): 455.03694723513,
#  ('Pereira, Risaralda', 'Convención, Norte de Santander'): 524.2428117579284,
#  ('Pereira, Risaralda', 'Génova, Quindío'): 66.38215079034374,
#  ('Pereira, Risaralda', 'Calarcá, Quindío'): 36.72286759708366,
#  ('Pereira, Risaralda', 'Quimbaya, Quindío'): 23.8959176609128,
#  ('Pereira, Risaralda', 'Pereira, Risaralda'): 0.0,
#  ('Pereira, Risaralda', 'Santuario, Risaralda'): 44.793376187637314,
#  ('Pereira, Risaralda', 'Belén de Umbria, Risaralda'): 50.60558971384892,
#  ('Pereira, Risaralda', 'Rionegro, Santander'): 392.3602704897711,
#  ('Pereira, Risaralda', 'Bucaramanga, Santander'): 385.7113850886459,
#  ('Pereira, Risaralda', 'Barbosa, Santander'): 259.33462322235545,
#  ('Pereira, Risaralda', 'Socorro, Santander'): 325.08450810646104,
#  ('Pereira, Risaralda', 'Simacota, Santander'): 307.1284611440879,
#  ('Pereira, Risaralda', 'Chaparral, Tolima'): 114.31814748974385,
#  ('Pereira, Risaralda', 'Dolores, Tolima'): 162.16578265295595,
#  ('Pereira, Risaralda', 'Ibagué, Tolima'): 56.8789919610177,
#  ('Pereira, Risaralda', 'Líbano, Tolima'): 68.77054200839946,
#  ('Pereira, Risaralda', 'Cartago, Valle'): 30.456881023959685,
#  ('Pereira, Risaralda', 'Tulua, Valle'): 94.21261495679562,
#  ('Pereira, Risaralda', 'Jamundí, Valle'): 205.58386349493273,
#  ('Pereira, Risaralda', 'Sevilla, Valle'): 74.09162842640082,
#  ('Pereira, Risaralda', 'Caicedonia, Valle'): 56.72962922688666,
#  ('Pereira, Risaralda', 'Florencia, Caquetá'): 350.15287089737836,
#  ('Pereira, Risaralda', 'Puerto Milán, Caquetá'): 381.7814548884968,
#  ('Pereira, Risaralda', 'Nunchía, Casanare'): 405.71423544079255,
#  ('Pereira, Risaralda', 'Mesetas, Meta'): 251.75908185212285,
#  ('Bucaramanga, Santander', 'Andes, Antioquia'): 358.16421083177977,
#  ('Bucaramanga, Santander', 'Medellín, Antioquia'): 292.4025708887414,
#  ('Bucaramanga, Santander', 'Dabeiba, Antioquia'): 352.40143604156606,
#  ('Bucaramanga, Santander', 'Salgar, Antioquia'): 343.3159076771058,
#  ('Bucaramanga, Santander', 'San Pablo de Borbur, Boyacá'): 197.934955276456,
#  ('Bucaramanga, Santander', 'Labranzagrande, Boyacá'): 189.3969409327598,
#  ('Bucaramanga, Santander', 'Miraflores, Boyacá'): 222.75652219137922,
#  ('Bucaramanga, Santander', 'Moniquirá, Boyacá'): 151.33847825411064,
#  ('Bucaramanga, Santander', 'Manizales, Caldas'): 351.732791146194,
#  ('Bucaramanga, Santander', 'Anserma, Caldas'): 364.2757208597768,
#  ('Bucaramanga, Santander', 'Pensilvania, Caldas'): 300.55624487510374,
#  ('Bucaramanga, Santander', 'Riosucio, Caldas'): 347.05511471912826,
#  ('Bucaramanga, Santander', 'Aguadas, Caldas'): 313.3504234802645,
#  ('Bucaramanga, Santander', 'Morales, Cauca'): 625.1076970498616,
#  ('Bucaramanga, Santander', 'El Tambo, Cauca'): 663.4700436125287,
#  ('Bucaramanga, Santander', 'Bolívar, Cauca'): 723.1374926833262,
#  ('Bucaramanga, Santander', 'Aguachica, Cesar'): 137.85711671769525,
#  ('Bucaramanga, Santander', 'San Diego, Cesar'): 350.77138783650616,
#  ('Bucaramanga, Santander', 'Caparrapí, Cundinamarca'): 251.85160793655362,
#  ('Bucaramanga, Santander', 'Viotá, Cundinamarca'): 337.9411647039571,
#  ('Bucaramanga, Santander', 'Sasaima, Cundinamarca'): 284.79749044206557,
#  ('Bucaramanga, Santander', 'Neiva, Huila'): 517.0574560380494,
#  ('Bucaramanga, Santander', 'Pitalito, Huila'): 684.0795886675737,
#  ('Bucaramanga, Santander', 'Gigante, Huila'): 591.8557060647197,
#  ('Bucaramanga, Santander', 'Santa Marta, Magdalena'): 464.99537991679193,
#  ('Bucaramanga, Santander', 'La Unión, Nariño'): 760.4528486703051,
#  ('Bucaramanga, Santander', 'Pasto, Nariño'): 814.7940107737809,
#  ('Bucaramanga, Santander', 'Samaniego, Nariño'): 818.6313453385271,
#  ('Bucaramanga, Santander',
#   'Sardinata, Norte de Santander'): 125.7680631403689,
#  ('Bucaramanga, Santander', 'Ocaña, Norte de Santander'): 120.76817955056046,
#  ('Bucaramanga, Santander',
#   'Convención, Norte de Santander'): 184.62246577465953,
#  ('Bucaramanga, Santander', 'Génova, Quindío'): 439.9776782720725,
#  ('Bucaramanga, Santander', 'Calarcá, Quindío'): 413.56093538500113,
#  ('Bucaramanga, Santander', 'Quimbaya, Quindío'): 409.30194296745077,
#  ('Bucaramanga, Santander', 'Pereira, Risaralda'): 385.7113850886459,
#  ('Bucaramanga, Santander', 'Santuario, Risaralda'): 395.35994055121756,
#  ('Bucaramanga, Santander', 'Belén de Umbria, Risaralda'): 375.40787553879056,
#  ('Bucaramanga, Santander', 'Rionegro, Santander'): 53.976026129857544,
#  ('Bucaramanga, Santander', 'Bucaramanga, Santander'): 0.0,
#  ('Bucaramanga, Santander', 'Barbosa, Santander'): 145.63444586706373,
#  ('Bucaramanga, Santander', 'Socorro, Santander'): 78.82336017923774,
#  ('Bucaramanga, Santander', 'Simacota, Santander'): 78.58710588392164,
#  ('Bucaramanga, Santander', 'Chaparral, Tolima'): 467.10697783229995,
#  ('Bucaramanga, Santander', 'Dolores, Tolima'): 432.6801577748519,
#  ('Bucaramanga, Santander', 'Ibagué, Tolima'): 379.7327084838995,
#  ('Bucaramanga, Santander', 'Líbano, Tolima'): 331.513962862666,
#  ('Bucaramanga, Santander', 'Cartago, Valle'): 412.9820314349867,
#  ('Bucaramanga, Santander', 'Tulua, Valle'): 476.2710224388767,
#  ('Bucaramanga, Santander', 'Jamundí, Valle'): 586.5625478168209,
#  ('Bucaramanga, Santander', 'Sevilla, Valle'): 453.2629009637877,
#  ('Bucaramanga, Santander', 'Caicedonia, Valle'): 437.59815249445256,
#  ('Bucaramanga, Santander', 'Florencia, Caquetá'): 672.9096269790343,
#  ('Bucaramanga, Santander', 'Puerto Milán, Caquetá'): 697.5958783445584,
#  ('Bucaramanga, Santander', 'Nunchía, Casanare'): 213.879116315138,
#  ('Bucaramanga, Santander', 'Mesetas, Meta'): 462.8089897675601,
#  ('Barbosa, Santander', 'Andes, Antioquia'): 260.5203440904896,
#  ('Barbosa, Santander', 'Medellín, Antioquia'): 220.75101824212203,
#  ('Barbosa, Santander', 'Dabeiba, Antioquia'): 314.669123095938,
#  ('Barbosa, Santander', 'Salgar, Antioquia'): 259.63987258929234,
#  ('Barbosa, Santander', 'San Pablo de Borbur, Boyacá'): 61.04244659777593,
#  ('Barbosa, Santander', 'Labranzagrande, Boyacá'): 123.18673685966951,
#  ('Barbosa, Santander', 'Miraflores, Boyacá'): 102.04721397756946,
#  ('Barbosa, Santander', 'Moniquirá, Boyacá'): 12.723158932441716,
#  ('Barbosa, Santander', 'Manizales, Caldas'): 229.54166378204283,
#  ('Barbosa, Santander', 'Anserma, Caldas'): 249.59815770202246,
#  ('Barbosa, Santander', 'Pensilvania, Caldas'): 182.16874049029985,
#  ('Barbosa, Santander', 'Riosucio, Caldas'): 240.11308091809443,
#  ('Barbosa, Santander', 'Aguadas, Caldas'): 206.74586705827346,
#  ('Barbosa, Santander', 'Morales, Cauca'): 487.8651931352696,
#  ('Barbosa, Santander', 'El Tambo, Cauca'): 524.3128858660319,
#  ('Barbosa, Santander', 'Bolívar, Cauca'): 582.3766460209969,
#  ('Barbosa, Santander', 'Aguachica, Cesar'): 260.0437729145946,
#  ('Barbosa, Santander', 'San Diego, Cesar'): 487.032553357181,
#  ('Barbosa, Santander', 'Caparrapí, Cundinamarca'): 117.34117199765194,
#  ('Barbosa, Santander', 'Viotá, Cundinamarca'): 192.82077889610392,
#  ('Barbosa, Santander', 'Sasaima, Cundinamarca'): 141.6427033705636,
#  ('Barbosa, Santander', 'Neiva, Huila'): 372.1531803373357,
#  ('Barbosa, Santander', 'Pitalito, Huila'): 539.5782556866004,
#  ('Barbosa, Santander', 'Gigante, Huila'): 446.656819210012,
#  ('Barbosa, Santander', 'Santa Marta, Magdalena'): 586.8215717427619,
#  ('Barbosa, Santander', 'La Unión, Nariño'): 619.4605500695612,
#  ('Barbosa, Santander', 'Pasto, Nariño'): 672.345535649657,
#  ('Barbosa, Santander', 'Samaniego, Nariño'): 679.5738398396174,
#  ('Barbosa, Santander', 'Sardinata, Norte de Santander'): 270.8439048506267,
#  ('Barbosa, Santander', 'Ocaña, Norte de Santander'): 251.9187209958453,
#  ('Barbosa, Santander', 'Convención, Norte de Santander'): 321.9878845008854,
#  ('Barbosa, Santander', 'Génova, Quindío'): 305.4525902935359,
#  ('Barbosa, Santander', 'Calarcá, Quindío'): 281.7298460168558,
#  ('Barbosa, Santander', 'Quimbaya, Quindío'): 281.546249145236,
#  ('Barbosa, Santander', 'Pereira, Risaralda'): 259.33462322235545,
#  ('Barbosa, Santander', 'Santuario, Risaralda'): 279.45973020064633,
#  ('Barbosa, Santander', 'Belén de Umbria, Risaralda'): 262.21805741483183,
#  ('Barbosa, Santander', 'Rionegro, Santander'): 176.80570052745662,
#  ('Barbosa, Santander', 'Bucaramanga, Santander'): 145.63444586706373,
#  ('Barbosa, Santander', 'Barbosa, Santander'): 0.0,
#  ('Barbosa, Santander', 'Socorro, Santander'): 70.42807226167132,
#  ('Barbosa, Santander', 'Simacota, Santander'): 79.81934933514738,
#  ('Barbosa, Santander', 'Chaparral, Tolima'): 326.86946746556583,
#  ('Barbosa, Santander', 'Dolores, Tolima'): 287.1751821706188,
#  ('Barbosa, Santander', 'Ibagué, Tolima'): 242.43300949650947,
#  ('Barbosa, Santander', 'Líbano, Tolima'): 197.0172000171336,
#  ('Barbosa, Santander', 'Cartago, Valle'): 288.9474654958576,
#  ('Barbosa, Santander', 'Tulua, Valle'): 343.54637933778736,
#  ('Barbosa, Santander', 'Jamundí, Valle'): 450.9224745749511,
#  ('Barbosa, Santander', 'Sevilla, Valle'): 319.9482304303164,
#  ('Barbosa, Santander', 'Caicedonia, Valle'): 305.703463623065,
#  ('Barbosa, Santander', 'Florencia, Caquetá'): 527.3150034172473,
#  ('Barbosa, Santander', 'Puerto Milán, Caquetá'): 551.9732263194812,
#  ('Barbosa, Santander', 'Nunchía, Casanare'): 178.41440098203694,
#  ('Barbosa, Santander', 'Mesetas, Meta'): 319.8308931289402,
#  ('Cali, Valle del Cauca', 'Andes, Antioquia'): 254.47232290827992,
#  ('Cali, Valle del Cauca', 'Medellín, Antioquia'): 334.06922819618984,
#  ('Cali, Valle del Cauca', 'Dabeiba, Antioquia'): 394.2736398505958,
#  ('Cali, Valle del Cauca', 'Salgar, Antioquia'): 290.9083172055795,
#  ('Cali, Valle del Cauca', 'San Pablo de Borbur, Boyacá'): 368.70512027944574,
#  ('Cali, Valle del Cauca', 'Labranzagrande, Boyacá'): 495.63954939653394,
#  ('Cali, Valle del Cauca', 'Miraflores, Boyacá'): 419.8347027666379,
#  ('Cali, Valle del Cauca', 'Moniquirá, Boyacá'): 428.8573940197983,
#  ('Cali, Valle del Cauca', 'Manizales, Caldas'): 217.63466987921387,
#  ('Cali, Valle del Cauca', 'Anserma, Caldas'): 217.39684465140576,
#  ...}

# %% [markdown]
# **Pregunta 1 (10 puntos)**
#
# * Crea el parámetro de costo de transporte $c_{ij}$ en un diccionario llamado `costo_transporte`
# * Las **llaves** de este diccionario deben ser los pares $(i,j)$, es decir, (depósitos, CACs)
# * Los **valores** de este diccionario deben ser los costos de transporte definidos en la formulación

# %%
# your code here
costo_transporte = {
    (i, j): q * produccion[j] * distancia[(i, j)]
    for i in I
    for j in J
}

# %%
# Esta celda esta reservada para uso del equipo docente

# %%
# Esta celda esta reservada para uso del equipo docente

# %% [markdown]
# **Celda de Prueba (0 puntos)**
#
# Es una buena práctica imprimir algunos objetos que contienen los parámetros en la consola luego de crearlos. De esta forma puedes corregir errores y familiarizarte con las estructuras de datos que se van a utilizar. Puedes hacer estas pruebas en la celda a continuación.
#
# * **Esta celda no es calificable**

# %%
# your code here

print(produccion)
print(distancia)
costo_transporte
# costo_transporte = {}
# for i in I:
#     for j in J:
#         costo_transporte[(i, j)] = q * produccion[j] * distancia[(i, j)]
# Out:
# {'Andes, Antioquia': 35.37, 'Medellín, Antioquia': 10.63, 'Dabeiba, Antioquia': 27.28, 'Salgar, Antioquia': 24.05, 'San Pablo de Borbur, Boyacá': 1.59, 'Labranzagrande, Boyacá': 1.2, 'Miraflores, Boyacá': 1.11, 'Moniquirá, Boyacá': 1.28, 'Manizales, Caldas': 24.76, 'Anserma, Caldas': 8.23, 'Pensilvania, Caldas': 6.6, 'Riosucio, Caldas': 6.63, 'Aguadas, Caldas': 6.74, 'Morales, Cauca': 14.19, 'El Tambo, Cauca': 13.25, 'Bolívar, Cauca': 11.89, 'Aguachica, Cesar': 3.6, 'San Diego, Cesar': 2.71, 'Caparrapí, Cundinamarca': 1.45, 'Viotá, Cundinamarca': 1.75, 'Sasaima, Cundinamarca': 2.29, 'Neiva, Huila': 22.25, 'Pitalito, Huila': 21.85, 'Gigante, Huila': 21.92, 'Santa Marta, Magdalena': 3.8, 'La Unión, Nariño': 7.59, 'Pasto, Nariño': 8.12, 'Samaniego, Nariño': 5.7, 'Sardinata, Norte de Santander': 2.52, 'Ocaña, Norte de Santander': 2.6, 'Convención, Norte de Santander': 2.34, 'Génova, Quindío': 4.99, 'Calarcá, Quindío': 6.09, 'Quimbaya, Quindío': 5.49, 'Pereira, Risaralda': 8.89, 'Santuario, Risaralda': 7.36, 'Belén de Umbria, Risaralda': 9.06, 'Rionegro, Santander': 1.87, 'Bucaramanga, Santander': 1.79, 'Barbosa, Santander': 8.56, 'Socorro, Santander': 7.92, 'Simacota, Santander': 6.5, 'Chaparral, Tolima': 8.73, 'Dolores, Tolima': 11.86, 'Ibagué, Tolima': 1.43, 'Líbano, Tolima': 1.19, 'Cartago, Valle': 6.27, 'Tulua, Valle': 5.94, 'Jamundí, Valle': 3.54, 'Sevilla, Valle': 2.84, 'Caicedonia, Valle': 3.11, 'Florencia, Caquetá': 0.37, 'Puerto Milán, Caquetá': 0.33, 'Nunchía, Casanare': 0.38, 'Mesetas, Meta': 0.43}
# {('Medellín, Antioquia', 'Andes, Antioquia'): 81.6407744153149, ('Medellín, Antioquia', 'Medellín, Antioquia'): 0.0, ('Medellín, Antioquia', 'Dabeiba, Antioquia'): 107.79278431038877, ('Medellín, Antioquia', 'Salgar, Antioquia'): 53.335670657757895, ('Medellín, Antioquia', 'San Pablo de Borbur, Boyacá'): 177.7022202999153, ('Medellín, Antioquia', 'Labranzagrande, Boyacá'): 341.843300383342, ('Medellín, Antioquia', 'Miraflores, Boyacá'): 295.50792681396376, ('Medellín, Antioquia', 'Moniquirá, Boyacá'): 230.85325502996707, ('Medellín, Antioquia', 'Manizales, Caldas'): 132.50832910815635, ('Medellín, Antioquia', 'Anserma, Caldas'): 119.36408078562327, ('Medellín, Antioquia', 'Pensilvania, Caldas'): 106.38936050657013, ('Medellín, Antioquia', 'Riosucio, Caldas'): 91.7929643629694, ('Medellín, Antioquia', 'Aguadas, Caldas'): 77.80655349448206, ('Medellín, Antioquia', 'Morales, Cauca'): 399.20320142759863, ('Medellín, Antioquia', 'El Tambo, Cauca'): 442.9927758625815, ('Medellín, Antioquia', 'Bolívar, Cauca'): 506.82908024404173, ('Medellín, Antioquia', 'Aguachica, Cesar'): 314.30868305575257, ('Medellín, Antioquia', 'San Diego, Cesar'): 522.6122968773435, ('Medellín, Antioquia', 'Caparrapí, Cundinamarca'): 155.5794959329134, ('Medellín, Antioquia', 'Viotá, Cundinamarca'): 237.14728370467418, ('Medellín, Antioquia', 'Sasaima, Cundinamarca'): 195.9470045546287, ('Medellín, Antioquia', 'Neiva, Huila'): 359.0149655616235, ('Medellín, Antioquia', 'Pitalito, Huila'): 500.28067135070114, ('Medellín, Antioquia', 'Gigante, Huila'): 428.47632041782884, ('Medellín, Antioquia', 'Santa Marta, Magdalena'): 570.5045941386736, ('Medellín, Antioquia', 'La Unión, Nariño'): 543.2698934936254, ('Medellín, Antioquia', 'Pasto, Nariño'): 603.9539268024233, ('Medellín, Antioquia', 'Samaniego, Nariño'): 588.9737081094718, ('Medellín, Antioquia', 'Sardinata, Norte de Santander'): 379.5300204804499, ('Medellín, Antioquia', 'Ocaña, Norte de Santander'): 325.4838085170196, ('Medellín, Antioquia', 'Convención, Norte de Santander'): 388.7920881623617, ('Medellín, Antioquia', 'Génova, Quindío'): 230.2605503525202, ('Medellín, Antioquia', 'Calarcá, Quindío'): 200.9003351641889, ('Medellín, Antioquia', 'Quimbaya, Quindío'): 184.25490256239482, ('Medellín, Antioquia', 'Pereira, Risaralda'): 164.19873864004808, ('Medellín, Antioquia', 'Santuario, Risaralda'): 143.01289060496595, ('Medellín, Antioquia', 'Belén de Umbria, Risaralda'): 122.98414262516638, ('Medellín, Antioquia', 'Rionegro, Santander'): 278.4981296858733, ('Medellín, Antioquia', 'Bucaramanga, Santander'): 292.4025708887414, ('Medellín, Antioquia', 'Barbosa, Santander'): 220.75101824212203, ('Medellín, Antioquia', 'Socorro, Santander'): 260.7619390111907, ('Medellín, Antioquia', 'Simacota, Santander'): 222.72762973163123, ('Medellín, Antioquia', 'Chaparral, Tolima'): 278.18369529067377, ('Medellín, Antioquia', 'Dolores, Tolima'): 306.8400984627416, ('Medellín, Antioquia', 'Ibagué, Tolima'): 201.8178937563914, ('Medellín, Antioquia', 'Líbano, Tolima'): 165.83522834878679, ('Medellín, Antioquia', 'Cartago, Valle'): 176.004000536389, ('Medellín, Antioquia', 'Tulua, Valle'): 251.92318505577714, ('Medellín, Antioquia', 'Jamundí, Valle'): 357.8701519601408, ('Medellín, Antioquia', 'Sevilla, Valle'): 235.73341618182997, ('Medellín, Antioquia', 'Caicedonia, Valle'): 218.59787759394675, ('Medellín, Antioquia', 'Florencia, Caquetá'): 514.1772684267618, ('Medellín, Antioquia', 'Puerto Milán, Caquetá'): 545.5974333166706, ('Medellín, Antioquia', 'Nunchía, Casanare'): 398.63420472138824, ('Medellín, Antioquia', 'Mesetas, Meta'): 386.01447379551115, ('La Dorada, Caldas ', 'Andes, Antioquia'): 137.3090199438865, ('La Dorada, Caldas ', 'Medellín, Antioquia'): 126.7422092929512, ('La Dorada, Caldas ', 'Dabeiba, Antioquia'): 234.3459554597085, ('La Dorada, Caldas ', 'Salgar, Antioquia'): 146.7636516992429, ('La Dorada, Caldas ', 'San Pablo de Borbur, Boyacá'): 70.16484153884774, ('La Dorada, Caldas ', 'Labranzagrande, Boya ...
# {('Medellín, Antioquia', 'Andes, Antioquia'): 259887.0771962719,
#  ('Medellín, Antioquia', 'Medellín, Antioquia'): 0.0,
#  ('Medellín, Antioquia', 'Dabeiba, Antioquia'): 264652.8440388665,
#  ('Medellín, Antioquia', 'Salgar, Antioquia'): 115445.05913871697,
#  ('Medellín, Antioquia', 'San Pablo de Borbur, Boyacá'): 25429.18772491788,
#  ('Medellín, Antioquia', 'Labranzagrande, Boyacá'): 36919.07644140094,
#  ('Medellín, Antioquia', 'Miraflores, Boyacá'): 29521.241888714983,
#  ('Medellín, Antioquia', 'Moniquirá, Boyacá'): 26594.294979452206,
#  ('Medellín, Antioquia', 'Manizales, Caldas'): 295281.5605846156,
#  ('Medellín, Antioquia', 'Anserma, Caldas'): 88412.97463791116,
#  ('Medellín, Antioquia', 'Pensilvania, Caldas'): 63195.28014090266,
#  ('Medellín, Antioquia', 'Riosucio, Caldas'): 54772.86183538385,
#  ('Medellín, Antioquia', 'Aguadas, Caldas'): 47197.45534975282,
#  ('Medellín, Antioquia', 'Morales, Cauca'): 509822.40854318615,
#  ('Medellín, Antioquia', 'El Tambo, Cauca'): 528268.8852161284,
#  ('Medellín, Antioquia', 'Bolívar, Cauca'): 542357.7987691491,
#  ('Medellín, Antioquia', 'Aguachica, Cesar'): 101836.01331006383,
#  ('Medellín, Antioquia', 'San Diego, Cesar'): 127465.13920838409,
#  ('Medellín, Antioquia', 'Caparrapí, Cundinamarca'): 20303.124219245197,
#  ('Medellín, Antioquia', 'Viotá, Cundinamarca'): 37350.69718348618,
#  ('Medellín, Antioquia', 'Sasaima, Cundinamarca'): 40384.67763870898,
#  ('Medellín, Antioquia', 'Neiva, Huila'): 718927.4685371511,
#  ('Medellín, Antioquia', 'Pitalito, Huila'): 983801.9402111539,
#  ('Medellín, Antioquia', 'Gigante, Huila'): 845298.0849202928,
#  ('Medellín, Antioquia', 'Santa Marta, Magdalena'): 195112.57119542637,
#  ('Medellín, Antioquia', 'La Unión, Nariño'): 371107.6642454956,
#  ('Medellín, Antioquia', 'Pasto, Nariño'): 441369.52970721095,
#  ('Medellín, Antioquia', 'Samaniego, Nariño'): 302143.512260159,
#  ('Medellín, Antioquia', 'Sardinata, Norte de Santander'): 86077.40864496604,
#  ('Medellín, Antioquia', 'Ocaña, Norte de Santander'): 76163.21119298259,
#  ('Medellín, Antioquia', 'Convención, Norte de Santander'): 81879.61376699338,
#  ('Medellín, Antioquia', 'Génova, Quindío'): 103410.01316331682,
#  ('Medellín, Antioquia', 'Calarcá, Quindío'): 110113.47370349194,
#  ('Medellín, Antioquia', 'Quimbaya, Quindío'): 91040.34735607928,
#  ('Medellín, Antioquia', 'Pereira, Risaralda'): 131375.41078590247,
#  ('Medellín, Antioquia', 'Santuario, Risaralda'): 94731.73873672944,
#  ('Medellín, Antioquia', 'Belén de Umbria, Risaralda'): 100281.26989656068,
#  ('Medellín, Antioquia', 'Rionegro, Santander'): 46871.235226132485,
#  ('Medellín, Antioquia', 'Bucaramanga, Santander'): 47106.05417017624,
#  ('Medellín, Antioquia', 'Barbosa, Santander'): 170066.58445373084,
#  ('Medellín, Antioquia', 'Socorro, Santander'): 185871.1101271767,
#  ('Medellín, Antioquia', 'Simacota, Santander'): 130295.66339300427,
#  ('Medellín, Antioquia', 'Chaparral, Tolima'): 218568.9293898824,
#  ('Medellín, Antioquia', 'Dolores, Tolima'): 327521.1210991303,
#  ('Medellín, Antioquia', 'Ibagué, Tolima'): 25973.962926447573,
#  ('Medellín, Antioquia', 'Líbano, Tolima'): 17760.952956155063,
#  ('Medellín, Antioquia', 'Cartago, Valle'): 99319.0575026843,
#  ('Medellín, Antioquia', 'Tulua, Valle'): 134678.13473081848,
#  ('Medellín, Antioquia', 'Jamundí, Valle'): 114017.43041450086,
#  ('Medellín, Antioquia', 'Sevilla, Valle'): 60253.46117607574,
#  ('Medellín, Antioquia', 'Caicedonia, Valle'): 61185.54593854569,
#  ('Medellín, Antioquia', 'Florencia, Caquetá'): 17122.103038611167,
#  ('Medellín, Antioquia', 'Puerto Milán, Caquetá'): 16204.24376950512,
#  ('Medellín, Antioquia', 'Nunchía, Casanare'): 13633.28980147148,
#  ('Medellín, Antioquia', 'Mesetas, Meta'): 14938.760135886283,
#  ('La Dorada, Caldas ', 'Andes, Antioquia'): 437095.8031873739,
#  ('La Dorada, Caldas ', 'Medellín, Antioquia'): 121254.27163056642,
#  ('La Dorada, Caldas ', 'Dabeiba, Antioquia'): 575366.1898446764,
#  ('La Dorada, Caldas ', 'Salgar, Antioquia'): 317669.92410301126,
#  ('La Dorada, Caldas ', 'San Pablo de Borbur, Boyacá'): 10040.588824209111,
#  ('La Dorada, Caldas ', 'Labranzagrande, Boyacá'): 25385.634296010925,
#  ('La Dorada, Caldas ', 'Miraflores, Boyacá'): 17638.21602347815,
#  ('La Dorada, Caldas ', 'Moniquirá, Boyacá'): 15547.019077485453,
#  ('La Dorada, Caldas ', 'Manizales, Caldas'): 223811.8214201205,
#  ('La Dorada, Caldas ', 'Anserma, Caldas'): 88813.87986243975,
#  ('La Dorada, Caldas ', 'Pensilvania, Caldas'): 31208.162195002595,
#  ('La Dorada, Caldas ', 'Riosucio, Caldas'): 67343.4315679853,
#  ('La Dorada, Caldas ', 'Aguadas, Caldas'): 49539.726777983065,
#  ('La Dorada, Caldas ', 'Morales, Cauca'): 475684.1547544864,
#  ('La Dorada, Caldas ', 'El Tambo, Cauca'): 491427.843667154,
#  ('La Dorada, Caldas ', 'Bolívar, Cauca'): 506430.6633358732,
#  ('La Dorada, Caldas ', 'Aguachica, Cesar'): 107041.17110338563,
#  ('La Dorada, Caldas ', 'San Diego, Cesar'): 136041.96891150967,
#  ('La Dorada, Caldas ', 'Caparrapí, Cundinamarca'): 3766.796744994663,
#  ('La Dorada, Caldas ', 'Viotá, Cundinamarca'): 19503.268489161434,
#  ('La Dorada, Caldas ', 'Sasaima, Cundinamarca'): 14989.76591507083,
#  ('La Dorada, Caldas ', 'Neiva, Huila'): 567258.7564130517,
#  ('La Dorada, Caldas ', 'Pitalito, Huila'): 873151.2895376666,
#  ('La Dorada, Caldas ', 'Gigante, Huila'): 706829.1119295231,
#  ('La Dorada, Caldas ', 'Santa Marta, Magdalena'): 216552.82087321018,
#  ('La Dorada, Caldas ', 'La Unión, Nariño'): 348860.09661607427,
#  ('La Dorada, Caldas ', 'Pasto, Nariño'): 414506.7912597276,
#  ('La Dorada, Caldas ', 'Samaniego, Nariño'): 290694.9623405069,
#  ('La Dorada, Caldas ', 'Sardinata, Norte de Santander'): 83691.60787881908,
#  ('La Dorada, Caldas ', 'Ocaña, Norte de Santander'): 77615.6278528456,
#  ('La Dorada, Caldas ', 'Convención, Norte de Santander'): 84761.98031306018,
#  ('La Dorada, Caldas ', 'Génova, Quindío'): 83944.6767378435,
#  ('La Dorada, Caldas ', 'Calarcá, Quindío'): 87601.20065337361,
#  ('La Dorada, Caldas ', 'Quimbaya, Quindío'): 76982.45756756657,
#  ('La Dorada, Caldas ', 'Pereira, Risaralda'): 106023.41604567258,
#  ('La Dorada, Caldas ', 'Santuario, Risaralda'): 99131.72856057713,
#  ('La Dorada, Caldas ', 'Belén de Umbria, Risaralda'): 108149.22881053577,
#  ('La Dorada, Caldas ', 'Rionegro, Santander'): 44521.06765232593,
#  ('La Dorada, Caldas ', 'Bucaramanga, Santander'): 40894.13305675203,
#  ('La Dorada, Caldas ', 'Barbosa, Santander'): 100002.57752509258,
#  ('La Dorada, Caldas ', 'Socorro, Santander'): 137575.5854771366,
#  ('La Dorada, Caldas ', 'Simacota, Santander'): 102560.00725160263,
#  ('La Dorada, Caldas ', 'Chaparral, Tolima'): 172253.5986940426,
#  ('La Dorada, Caldas ', 'Dolores, Tolima'): 225431.57692814502,
#  ('La Dorada, Caldas ', 'Ibagué, Tolima'): 16748.41935613568,
#  ('La Dorada, Caldas ', 'Líbano, Tolima'): 8653.416015436023,
#  ('La Dorada, Caldas ', 'Cartago, Valle'): 90860.65366317038,
#  ('La Dorada, Caldas ', 'Tulua, Valle'): 118961.9583589444,
#  ('La Dorada, Caldas ', 'Jamundí, Valle'): 106186.42226615403,
#  ('La Dorada, Caldas ', 'Sevilla, Valle'): 51042.99250084836,
#  ('La Dorada, Caldas ', 'Caicedonia, Valle'): 51449.907110165084,
#  ('La Dorada, Caldas ', 'Florencia, Caquetá'): 14773.43922396761,
#  ('La Dorada, Caldas ', 'Puerto Milán, Caquetá'): 14025.222393133734,
#  ('La Dorada, Caldas ', 'Nunchía, Casanare'): 10033.37537493852,
#  ('La Dorada, Caldas ', 'Mesetas, Meta'): 10691.67475460034,
#  ('Aguadas, Caldas', 'Andes, Antioquia'): 177155.78795660642,
#  ('Aguadas, Caldas', 'Medellín, Antioquia'): 74437.529728171,
#  ('Aguadas, Caldas', 'Dabeiba, Antioquia'): 436498.0740211331,
#  ('Aguadas, Caldas', 'Salgar, Antioquia'): 154611.37913774076,
#  ('Aguadas, Caldas', 'San Pablo de Borbur, Boyacá'): 21486.415555088493,
#  ('Aguadas, Caldas', 'Labranzagrande, Boyacá'): 34191.21419461881,
#  ('Aguadas, Caldas', 'Miraflores, Boyacá'): 25713.159337201098,
#  ('Aguadas, Caldas', 'Moniquirá, Boyacá'): 24602.56204109549,
#  ('Aguadas, Caldas', 'Manizales, Caldas'): 125058.33859734573,
#  ('Aguadas, Caldas', 'Anserma, Caldas'): 39356.01440132498,
#  ('Aguadas, Caldas', 'Pensilvania, Caldas'): 21699.77877308014,
#  ('Aguadas, Caldas', 'Riosucio, Caldas'): 20361.09251657211,
#  ('Aguadas, Caldas', 'Aguadas, Caldas'): 0.0,
#  ('Aguadas, Caldas', 'Morales, Cauca'): 426988.6977275271,
#  ('Aguadas, Caldas', 'El Tambo, Cauca'): 449687.47787013545,
#  ('Aguadas, Caldas', 'Bolívar, Cauca'): 471399.4972272999,
#  ('Aguadas, Caldas', 'Aguachica, Cesar'): 117908.49971902708,
#  ('Aguadas, Caldas', 'San Diego, Cesar'): 142132.11322552775,
#  ('Aguadas, Caldas', 'Caparrapí, Cundinamarca'): 13952.41806450983,
#  ('Aguadas, Caldas', 'Viotá, Cundinamarca'): 26154.702273190593,
#  ('Aguadas, Caldas', 'Sasaima, Cundinamarca'): 27745.098527261016,
#  ('Aguadas, Caldas', 'Neiva, Huila'): 564298.0919828907,
#  ('Aguadas, Caldas', 'Pitalito, Huila'): 840103.602278234,
#  ('Aguadas, Caldas', 'Gigante, Huila'): 694961.5403519879,
#  ('Aguadas, Caldas', 'Santa Marta, Magdalena'): 219099.47265719052,
#  ('Aguadas, Caldas', 'La Unión, Nariño'): 326218.0588167218,
#  ('Aguadas, Caldas', 'Pasto, Nariño'): 392528.67721538723,
#  ('Aguadas, Caldas', 'Samaniego, Nariño'): 270546.98090996436,
#  ('Aguadas, Caldas', 'Sardinata, Norte de Santander'): 94648.12483426099,
#  ('Aguadas, Caldas', 'Ocaña, Norte de Santander'): 86735.06741993118,
#  ('Aguadas, Caldas', 'Convención, Norte de Santander'): 92343.66725059658,
#  ('Aguadas, Caldas', 'Génova, Quindío'): 70422.76442144204,
#  ('Aguadas, Caldas', 'Calarcá, Quindío'): 69571.50211894032,
#  ('Aguadas, Caldas', 'Quimbaya, Quindío'): 55798.63487539248,
#  ('Aguadas, Caldas', 'Pereira, Risaralda'): 72475.76252380347,
#  ('Aguadas, Caldas', 'Santuario, Risaralda'): 55318.52950077473,
#  ('Aguadas, Caldas', 'Belén de Umbria, Risaralda'): 51145.167823184194,
#  ('Aguadas, Caldas', 'Rionegro, Santander'): 52588.11736192314,
#  ('Aguadas, Caldas', 'Bucaramanga, Santander'): 50480.75322267061,
#  ('Aguadas, Caldas', 'Barbosa, Santander'): 159277.0159816939,
#  ('Aguadas, Caldas', 'Socorro, Santander'): 187721.28996527294,
#  ('Aguadas, Caldas', 'Simacota, Santander'): 138179.17665118337,
#  ('Aguadas, Caldas', 'Chaparral, Tolima'): 159131.0435260399,
#  ('Aguadas, Caldas', 'Dolores, Tolima'): 245069.77511884025,
#  ('Aguadas, Caldas', 'Ibagué, Tolima'): 15960.617240649199,
#  ('Aguadas, Caldas', 'Líbano, Tolima'): 9673.254374824543,
#  ('Aguadas, Caldas', 'Cartago, Valle'): 61503.16738610358,
#  ('Aguadas, Caldas', 'Tulua, Valle'): 97959.22124268203,
#  ('Aguadas, Caldas', 'Jamundí, Valle'): 93427.70761760588,
#  ('Aguadas, Caldas', 'Sevilla, Valle'): 42027.9165000678,
#  ('Aguadas, Caldas', 'Caicedonia, Valle'): 41155.19940775516,
#  ('Aguadas, Caldas', 'Florencia, Caquetá'): 14593.993429979617,
#  ('Aguadas, Caldas', 'Puerto Milán, Caquetá'): 13939.002233516854,
#  ('Aguadas, Caldas', 'Nunchía, Casanare'): 12821.359054444634,
#  ('Aguadas, Caldas', 'Mesetas, Meta'): 12031.779676494853,
#  ('Salamina, Caldas', 'Andes, Antioquia'): 217425.8701406199,
#  ('Salamina, Caldas', 'Medellín, Antioquia'): 99879.67016858727,
#  ('Salamina, Caldas', 'Dabeiba, Antioquia'): 498522.83254734793,
#  ('Salamina, Caldas', 'Salgar, Antioquia'): 201430.42873676567,
#  ('Salamina, Caldas', 'San Pablo de Borbur, Boyacá'): 21322.280006029247,
#  ('Salamina, Caldas', 'Labranzagrande, Boyacá'): 33679.85977792746,
#  ('Salamina, Caldas', 'Miraflores, Boyacá'): 24828.73457867597,
#  ('Salamina, Caldas', 'Moniquirá, Boyacá'): 24630.57889221336,
#  ('Salamina, Caldas', 'Manizales, Caldas'): 70625.17463482241,
#  ('Salamina, Caldas', 'Anserma, Caldas'): 30569.02034327803,
#  ('Salamina, Caldas', 'Pensilvania, Caldas'): 15635.263145984969,
#  ('Salamina, Caldas', 'Riosucio, Caldas'): 22845.30512970292,
#  ('Salamina, Caldas', 'Aguadas, Caldas'): 16131.800609830972,
#  ('Salamina, Caldas', 'Morales, Cauca'): 400490.7436589711,
#  ('Salamina, Caldas', 'El Tambo, Cauca'): 424222.2037828664,
#  ('Salamina, Caldas', 'Bolívar, Cauca'): 448183.54980135546,
#  ('Salamina, Caldas', 'Aguachica, Cesar'): 124076.93309033917,
#  ('Salamina, Caldas', 'San Diego, Cesar'): 147355.42899557055,
#  ('Salamina, Caldas', 'Caparrapí, Cundinamarca'): 12932.142394697059,
#  ('Salamina, Caldas', 'Viotá, Cundinamarca'): 22572.06800249454,
#  ('Salamina, Caldas', 'Sasaima, Cundinamarca'): 24341.267229010416,
#  ('Salamina, Caldas', 'Neiva, Huila'): 511643.4202857957,
#  ('Salamina, Caldas', 'Pitalito, Huila'): 791869.7327663436,
#  ('Salamina, Caldas', 'Gigante, Huila'): 643969.6630163502,
#  ('Salamina, Caldas', 'Santa Marta, Magdalena'): 227417.17010433137,
#  ('Salamina, Caldas', 'La Unión, Nariño'): 311513.90963074507,
#  ('Salamina, Caldas', 'Pasto, Nariño'): 376394.61060770403,
#  ('Salamina, Caldas', 'Samaniego, Nariño'): 260307.267868611,
#  ('Salamina, Caldas', 'Sardinata, Norte de Santander'): 98115.12137160885,
#  ('Salamina, Caldas', 'Ocaña, Norte de Santander'): 90885.8635824627,
#  ('Salamina, Caldas', 'Convención, Norte de Santander'): 96283.56580397217,
#  ('Salamina, Caldas', 'Génova, Quindío'): 59683.080826936246,
#  ('Salamina, Caldas', 'Calarcá, Quindío'): 56458.0419892726,
#  ('Salamina, Caldas', 'Quimbaya, Quindío'): 45005.83468911113,
#  ('Salamina, Caldas', 'Pereira, Risaralda'): 54143.94088609661,
#  ('Salamina, Caldas', 'Santuario, Risaralda'): 47574.459495170704,
#  ('Salamina, Caldas', 'Belén de Umbria, Risaralda'): 43887.97730844741,
#  ('Salamina, Caldas', 'Rionegro, Santander'): 55107.76608515689,
#  ('Salamina, Caldas', 'Bucaramanga, Santander'): 52261.676966182,
#  ('Salamina, Caldas', 'Barbosa, Santander'): 160548.66334196733,
#  ('Salamina, Caldas', 'Socorro, Santander'): 191983.09188669117,
#  ('Salamina, Caldas', 'Simacota, Santander'): 144050.35521195084,
#  ('Salamina, Caldas', 'Chaparral, Tolima'): 139178.75169310928,
#  ('Salamina, Caldas', 'Dolores, Tolima'): 216975.75394496747,
#  ('Salamina, Caldas', 'Ibagué, Tolima'): 12538.469824638734,
#  ('Salamina, Caldas', 'Líbano, Tolima'): 7036.3339340519515,
#  ('Salamina, Caldas', 'Cartago, Valle'): 50919.06398858416,
#  ('Salamina, Caldas', 'Tulua, Valle'): 86463.1143193044,
#  ('Salamina, Caldas', 'Jamundí, Valle'): 86916.51206686124,
#  ('Salamina, Caldas', 'Sevilla, Valle'): 36216.904479313016,
#  ('Salamina, Caldas', 'Caicedonia, Valle'): 34810.54133208599,
#  ('Salamina, Caldas', 'Florencia, Caquetá'): 13736.158953876988,
#  ('Salamina, Caldas', 'Puerto Milán, Caquetá'): 13169.100238685767,
#  ('Salamina, Caldas', 'Nunchía, Casanare'): 12656.965231016215,
#  ('Salamina, Caldas', 'Mesetas, Meta'): 11049.68654145826,
#  ('Popayán, Cauca', 'Andes, Antioquia'): 1141299.914048435,
#  ('Popayán, Cauca', 'Medellín, Antioquia'): 417975.03755334974,
#  ('Popayán, Cauca', 'Dabeiba, Antioquia'): 1226965.8652136484,
#  ('Popayán, Cauca', 'Salgar, Antioquia'): 855908.2460896606,
#  ('Popayán, Cauca', 'San Pablo de Borbur, Boyacá'): 64548.16703475233,
#  ('Popayán, Cauca', 'Labranzagrande, Boyacá'): 60308.33876483095,
#  ('Popayán, Cauca', 'Miraflores, Boyacá'): 48202.06624366546,
#  ('Popayán, Cauca', 'Moniquirá, Boyacá'): 58363.26184859605,
#  ('Popayán, Cauca', 'Manizales, Caldas'): 700934.6207869507,
#  ('Popayán, Cauca', 'Anserma, Caldas'): 235920.24897117104,
#  ('Popayán, Cauca', 'Pensilvania, Caldas'): 215331.86801210843,
#  ('Popayán, Cauca', 'Riosucio, Caldas'): 206167.15792908162,
#  ('Popayán, Cauca', 'Aguadas, Caldas'): 223580.1116152244,
#  ('Popayán, Cauca', 'Morales, Cauca'): 62300.58695688864,
#  ('Popayán, Cauca', 'El Tambo, Cauca'): 30918.561891653226,
#  ('Popayán, Cauca', 'Bolívar, Cauca'): 79665.0497034703,
#  ('Popayán, Cauca', 'Aguachica, Cesar'): 235524.73748779908,
#  ('Popayán, Cauca', 'San Diego, Cesar'): 231771.63144403428,
#  ('Popayán, Cauca', 'Caparrapí, Cundinamarca'): 51809.40615637601,
#  ('Popayán, Cauca', 'Viotá, Cundinamarca'): 50502.40529472945,
#  ('Popayán, Cauca', 'Sasaima, Cundinamarca'): 75550.02570853922,
#  ('Popayán, Cauca', 'Neiva, Huila'): 314149.4997491077,
#  ('Popayán, Cauca', 'Pitalito, Huila'): 173750.1413987884,
#  ('Popayán, Cauca', 'Gigante, Huila'): 230771.86691555197,
#  ('Popayán, Cauca', 'Santa Marta, Magdalena'): 344510.0933239128,
#  ('Popayán, Cauca', 'La Unión, Nariño'): 76376.03192287644,
#  ('Popayán, Cauca', 'Pasto, Nariño'): 123460.530204973,
#  ('Popayán, Cauca', 'Samaniego, Nariño'): 88541.8419504493,
#  ('Popayán, Cauca', 'Sardinata, Norte de Santander'): 174096.7504205366,
#  ('Popayán, Cauca', 'Ocaña, Norte de Santander'): 170832.05832773016,
#  ('Popayán, Cauca', 'Convención, Norte de Santander'): 168537.30179286085,
#  ('Popayán, Cauca', 'Génova, Quindío'): 96252.14260764392,
#  ('Popayán, Cauca', 'Calarcá, Quindío'): 133598.0933619386,
#  ('Popayán, Cauca', 'Quimbaya, Quindío'): 126325.74114093416,
#  ('Popayán, Cauca', 'Pereira, Risaralda'): 222894.5350879264,
#  ('Popayán, Cauca', 'Santuario, Risaralda'): 194808.78879482043,
#  ('Popayán, Cauca', 'Belén de Umbria, Risaralda'): 255963.5257883065,
#  ('Popayán, Cauca', 'Rionegro, Santander'): 111670.01432110033,
#  ('Popayán, Cauca', 'Bucaramanga, Santander'): 104504.20694097284,
#  ('Popayán, Cauca', 'Barbosa, Santander'): 391430.9677514067,
#  ('Popayán, Cauca', 'Socorro, Santander'): 412273.1126971773,
#  ('Popayán, Cauca', 'Simacota, Santander'): 334308.9034957807,
#  ('Popayán, Cauca', 'Chaparral, Tolima'): 142689.44786771867,
#  ('Popayán, Cauca', 'Dolores, Tolima'): 256257.86403470993,
#  ('Popayán, Cauca', 'Ibagué, Tolima'): 34691.97906769868,
#  ('Popayán, Cauca', 'Líbano, Tolima'): 34125.77837191876,
#  ('Popayán, Cauca', 'Cartago, Valle'): 147409.48035895408,
#  ('Popayán, Cauca', 'Tulua, Valle'): 99192.41073016332,
#  ('Popayán, Cauca', 'Jamundí, Valle'): 26771.826936636833,
#  ('Popayán, Cauca', 'Sevilla, Valle'): 52273.84668048531,
#  ('Popayán, Cauca', 'Caicedonia, Valle'): 62097.100059805416,
#  ('Popayán, Cauca', 'Florencia, Caquetá'): 4715.602612505436,
#  ('Popayán, Cauca', 'Puerto Milán, Caquetá'): 5066.298691353189,
#  ('Popayán, Cauca', 'Nunchía, Casanare'): 20719.908767169803,
#  ('Popayán, Cauca', 'Mesetas, Meta'): 10934.590570758812,
#  ('Valledupar, Cesar', 'Andes, Antioquia'): 1949159.5729142001,
#  ('Valledupar, Cesar', 'Medellín, Antioquia'): 507690.4066212036,
#  ('Valledupar, Cesar', 'Dabeiba, Antioquia'): 1257077.714266116,
#  ('Valledupar, Cesar', 'Salgar, Antioquia'): 1256164.342015336,
#  ('Valledupar, Cesar', 'San Pablo de Borbur, Boyacá'): 76921.75609645162,
#  ('Valledupar, Cesar', 'Labranzagrande, Boyacá'): 59464.776005038366,
#  ('Valledupar, Cesar', 'Miraflores, Boyacá'): 58708.57251266132,
#  ('Valledupar, Cesar', 'Moniquirá, Boyacá'): 58661.58125747656,
#  ('Valledupar, Cesar', 'Manizales, Caldas'): 1438379.2207433765,
#  ('Valledupar, Cesar', 'Anserma, Caldas'): 476820.70604814,
#  ('Valledupar, Cesar', 'Pensilvania, Caldas'): 355416.1854959345,
#  ('Valledupar, Cesar', 'Riosucio, Caldas'): 368814.89599650935,
#  ('Valledupar, Cesar', 'Aguadas, Caldas'): 359136.5684271982,
#  ('Valledupar, Cesar', 'Morales, Cauca'): 1183000.3099104278,
#  ('Valledupar, Cesar', 'El Tambo, Cauca'): 1155698.0732623432,
#  ('Valledupar, Cesar', 'Bolívar, Cauca'): 1104863.3675061634,
#  ('Valledupar, Cesar', 'Aguachica, Cesar'): 78374.25458858135,
#  ('Valledupar, Cesar', 'San Diego, Cesar'): 4066.0064616044624,
#  ('Valledupar, Cesar', 'Caparrapí, Cundinamarca'): 75667.56186155099,
#  ('Valledupar, Cesar', 'Viotá, Cundinamarca'): 107128.24652587314,
#  ('Valledupar, Cesar', 'Sasaima, Cundinamarca'): 128473.58606387154,
#  ('Valledupar, Cesar', 'Neiva, Huila'): 1705801.7842876376,
#  ('Valledupar, Cesar', 'Pitalito, Huila'): 1990323.153734581,
#  ('Valledupar, Cesar', 'Gigante, Huila'): 1828872.2861107667,
#  ('Valledupar, Cesar', 'Santa Marta, Magdalena'): 45092.628888670486,
#  ('Valledupar, Cesar', 'La Unión, Nariño'): 730630.3534158784,
#  ('Valledupar, Cesar', 'Pasto, Nariño'): 824970.4313596332,
#  ('Valledupar, Cesar', 'Samaniego, Nariño'): 573800.9316926895,
#  ('Valledupar, Cesar', 'Sardinata, Norte de Santander'): 56523.44263117958,
#  ('Valledupar, Cesar', 'Ocaña, Norte de Santander'): 58190.01871138807,
#  ('Valledupar, Cesar', 'Convención, Norte de Santander'): 38057.426368299224,
#  ('Valledupar, Cesar', 'Génova, Quindío'): 335082.61135436624,
#  ('Valledupar, Cesar', 'Calarcá, Quindío'): 392679.9647690852,
#  ('Valledupar, Cesar', 'Quimbaya, Quindío'): 348147.27808837424,
#  ('Valledupar, Cesar', 'Pereira, Risaralda'): 545245.3897486285,
#  ('Valledupar, Cesar', 'Santuario, Risaralda'): 444669.6459456219,
#  ('Valledupar, Cesar', 'Belén de Umbria, Risaralda'): 530307.14546249,
#  ('Valledupar, Cesar', 'Rionegro, Santander'): 54524.12264289857,
#  ('Valledupar, Cesar', 'Bucaramanga, Santander'): 58854.95377437154,
#  ('Valledupar, Cesar', 'Barbosa, Santander'): 385552.936595153,
#  ('Valledupar, Cesar', 'Socorro, Santander'): 315240.3745904591,
#  ('Valledupar, Cesar', 'Simacota, Santander'): 246239.41007858457,
#  ('Valledupar, Cesar', 'Chaparral, Tolima'): 617349.0767977952,
#  ('Valledupar, Cesar', 'Dolores, Tolima'): 827022.7567952893,
#  ('Valledupar, Cesar', 'Ibagué, Tolima'): 89747.14335467442,
#  ('Valledupar, Cesar', 'Líbano, Tolima'): 69467.16012962964,
#  ('Valledupar, Cesar', 'Cartago, Valle'): 395458.14057355444,
#  ('Valledupar, Cesar', 'Tulua, Valle'): 414410.096673165,
#  ('Valledupar, Cesar', 'Jamundí, Valle'): 282003.2737855049,
#  ('Valledupar, Cesar', 'Sevilla, Valle'): 193108.76626814462,
#  ('Valledupar, Cesar', 'Caicedonia, Valle'): 206618.5999671446,
#  ('Valledupar, Cesar', 'Florencia, Caquetá'): 33700.93576760235,
#  ('Valledupar, Cesar', 'Puerto Milán, Caquetá'): 30883.92539110157,
#  ('Valledupar, Cesar', 'Nunchía, Casanare'): 19186.07209600294,
#  ('Valledupar, Cesar', 'Mesetas, Meta'): 31712.36550730604,
#  ('Bogotá, Cundinamarca', 'Andes, Antioquia'): 737194.3838628251,
#  ('Bogotá, Cundinamarca', 'Medellín, Antioquia'): 233009.09269330636,
#  ('Bogotá, Cundinamarca', 'Dabeiba, Antioquia'): 862427.1604748863,
#  ('Bogotá, Cundinamarca', 'Salgar, Antioquia'): 547316.7125399109,
#  ('Bogotá, Cundinamarca', 'San Pablo de Borbur, Boyacá'): 16292.047111175725,
#  ('Bogotá, Cundinamarca', 'Labranzagrande, Boyacá'): 20915.767318242215,
#  ('Bogotá, Cundinamarca', 'Miraflores, Boyacá'): 11758.553592751652,
#  ('Bogotá, Cundinamarca', 'Moniquirá, Boyacá'): 17114.90803714207,
#  ('Bogotá, Cundinamarca', 'Manizales, Caldas'): 360440.0950761476,
#  ('Bogotá, Cundinamarca', 'Anserma, Caldas'): 142301.98448619034,
#  ('Bogotá, Cundinamarca', 'Pensilvania, Caldas'): 86117.21979827873,
#  ('Bogotá, Cundinamarca', 'Riosucio, Caldas'): 119990.09358430855,
#  ('Bogotá, Cundinamarca', 'Aguadas, Caldas'): 110081.30407584817,
#  ('Bogotá, Cundinamarca', 'Morales, Cauca'): 452747.0266372574,
#  ('Bogotá, Cundinamarca', 'El Tambo, Cauca'): 460561.3753312662,
#  ('Bogotá, Cundinamarca', 'Bolívar, Cauca'): 471082.46263396885,
#  ('Bogotá, Cundinamarca', 'Aguachica, Cesar'): 132255.6766616472,
#  ('Bogotá, Cundinamarca', 'San Diego, Cesar'): 155428.2247455102,
#  ('Bogotá, Cundinamarca', 'Caparrapí, Cundinamarca'): 11991.242417866835,
#  ('Bogotá, Cundinamarca', 'Viotá, Cundinamarca'): 7527.4791449440245,
#  ('Bogotá, Cundinamarca', 'Sasaima, Cundinamarca'): 9833.999224375251,
#  ('Bogotá, Cundinamarca', 'Neiva, Huila'): 444293.06614908675,
#  ('Bogotá, Cundinamarca', 'Pitalito, Huila'): 765955.4152444655,
#  ('Bogotá, Cundinamarca', 'Gigante, Huila'): 581888.556492716,
#  ('Bogotá, Cundinamarca', 'Santa Marta, Magdalena'): 249020.2957081795,
#  ('Bogotá, Cundinamarca', 'La Unión, Nariño'): 325497.76219219394,
#  ('Bogotá, Cundinamarca', 'Pasto, Nariño'): 384517.66331921896,
#  ('Bogotá, Cundinamarca', 'Samaniego, Nariño'): 276903.6951696867,
#  ('Bogotá, Cundinamarca', 'Sardinata, Norte de Santander'): 96347.74040545594,
#  ('Bogotá, Cundinamarca', 'Ocaña, Norte de Santander'): 94280.28358840698,
#  ('Bogotá, Cundinamarca', 'Convención, Norte de Santander'): 99787.84244975372,
#  ('Bogotá, Cundinamarca', 'Génova, Quindío'): 84836.44201598321,
#  ('Bogotá, Cundinamarca', 'Calarcá, Quindío'): 96383.44782367884,
#  ('Bogotá, Cundinamarca', 'Quimbaya, Quindío'): 92018.23290710826,
#  ('Bogotá, Cundinamarca', 'Pereira, Risaralda'): 137876.5155064801,
#  ('Bogotá, Cundinamarca', 'Santuario, Risaralda'): 140044.12859279726,
#  ('Bogotá, Cundinamarca', 'Belén de Umbria, Risaralda'): 166451.5641980498,
#  ('Bogotá, Cundinamarca', 'Rionegro, Santander'): 55319.72885014657,
#  ('Bogotá, Cundinamarca', 'Bucaramanga, Santander'): 48251.55449572179,
#  ('Bogotá, Cundinamarca', 'Barbosa, Santander'): 118621.49474277164,
#  ('Bogotá, Cundinamarca', 'Socorro, Santander'): 158567.21617036892,
#  ('Bogotá, Cundinamarca', 'Simacota, Santander'): 134885.5384544594,
#  ('Bogotá, Cundinamarca', 'Chaparral, Tolima'): 151142.87914510755,
#  ('Bogotá, Cundinamarca', 'Dolores, Tolima'): 144015.94640109132,
#  ('Bogotá, Cundinamarca', 'Ibagué, Tolima'): 16400.57566518105,
#  ('Bogotá, Cundinamarca', 'Líbano, Tolima'): 11418.905577537778,
#  ('Bogotá, Cundinamarca', 'Cartago, Valle'): 113483.31715078442,
#  ('Bogotá, Cundinamarca', 'Tulua, Valle'): 121672.95116342409,
#  ('Bogotá, Cundinamarca', 'Jamundí, Valle'): 102611.70854120313,
#  ('Bogotá, Cundinamarca', 'Sevilla, Valle'): 52375.825067318925,
#  ('Bogotá, Cundinamarca', 'Caicedonia, Valle'): 54869.11606758201,
#  ('Bogotá, Cundinamarca', 'Florencia, Caquetá'): 12453.610203227958,
#  ('Bogotá, Cundinamarca', 'Puerto Milán, Caquetá'): 11824.720880492598,
#  ('Bogotá, Cundinamarca', 'Nunchía, Casanare'): 8411.317469069496,
#  ('Bogotá, Cundinamarca', 'Mesetas, Meta'): 6601.819167115223,
#  ('Santana, Huila', 'Andes, Antioquia'): 842216.732113385,
#  ('Santana, Huila', 'Medellín, Antioquia'): 299041.13785102,
#  ('Santana, Huila', 'Dabeiba, Antioquia'): 1010532.3314300814,
#  ('Santana, Huila', 'Salgar, Antioquia'): 645629.3144737622,
#  ('Santana, Huila', 'San Pablo de Borbur, Boyacá'): 34435.370163894,
#  ('Santana, Huila', 'Labranzagrande, Boyacá'): 34288.87606943113,
#  ('Santana, Huila', 'Miraflores, Boyacá'): 24238.518671982514,
#  ('Santana, Huila', 'Moniquirá, Boyacá'): 32614.33689194559,
#  ('Santana, Huila', 'Manizales, Caldas'): 416173.5516970126,
#  ('Santana, Huila', 'Anserma, Caldas'): 157611.31974418025,
#  ('Santana, Huila', 'Pensilvania, Caldas'): 123282.56269041156,
#  ('Santana, Huila', 'Riosucio, Caldas'): 140600.09053081425,
#  ('Santana, Huila', 'Aguadas, Caldas'): 142865.98932901895,
#  ('Santana, Huila', 'Morales, Cauca'): 308294.31982673606,
#  ('Santana, Huila', 'El Tambo, Cauca'): 316734.4527331783,
#  ('Santana, Huila', 'Bolívar, Cauca'): 335690.90594418824,
#  ('Santana, Huila', 'Aguachica, Cesar'): 173566.69308816,
#  ('Santana, Huila', 'San Diego, Cesar'): 186609.8433841466,
#  ('Santana, Huila', 'Caparrapí, Cundinamarca'): 25924.323147918913,
#  ('Santana, Huila', 'Viotá, Cundinamarca'): 15303.084168228757,
#  ('Santana, Huila', 'Sasaima, Cundinamarca'): 31707.74481745381,
#  ('Santana, Huila', 'Neiva, Huila'): 179506.02410980596,
#  ('Santana, Huila', 'Pitalito, Huila'): 503062.54694838816,
#  ('Santana, Huila', 'Gigante, Huila'): 316569.3048206355,
#  ('Santana, Huila', 'Santa Marta, Magdalena'): 289810.81847424066,
#  ('Santana, Huila', 'La Unión, Nariño'): 238179.78312743225,
#  ('Santana, Huila', 'Pasto, Nariño'): 288648.77609087765,
#  ('Santana, Huila', 'Samaniego, Nariño'): 212572.01602125308,
#  ('Santana, Huila', 'Sardinata, Norte de Santander'): 126595.14956659576,
#  ('Santana, Huila', 'Ocaña, Norte de Santander'): 124638.8662454105,
#  ('Santana, Huila', 'Convención, Norte de Santander'): 127192.60355043013,
#  ('Santana, Huila', 'Génova, Quindío'): 60062.397019386706,
#  ('Santana, Huila', 'Calarcá, Quindío'): 79274.276849476,
#  ('Santana, Huila', 'Quimbaya, Quindío'): 81602.6203729868,
#  ('Santana, Huila', 'Pereira, Risaralda'): 135471.06412885728,
#  ('Santana, Huila', 'Santuario, Risaralda'): 141147.43547283343,
#  ('Santana, Huila', 'Belén de Umbria, Risaralda'): 178755.96039895932,
#  ('Santana, Huila', 'Rionegro, Santander'): 77368.12671628331,
#  ('Santana, Huila', 'Bucaramanga, Santander'): 69827.27262990986,
#  ('Santana, Huila', 'Barbosa, Santander'): 221749.21756834447,
#  ('Santana, Huila', 'Socorro, Santander'): 254495.43858273383,
#  ('Santana, Huila', 'Simacota, Santander'): 211784.4730901994,
#  ('Santana, Huila', 'Chaparral, Tolima'): 78859.81876007572,
#  ('Santana, Huila', 'Dolores, Tolima'): 8221.810540651815,
#  ('Santana, Huila', 'Ibagué, Tolima'): 14834.200732488223,
#  ('Santana, Huila', 'Líbano, Tolima'): 15778.659046832552,
#  ('Santana, Huila', 'Cartago, Valle'): 103435.75416764108,
#  ('Santana, Huila', 'Tulua, Valle'): 85152.06762241683,
#  ('Santana, Huila', 'Jamundí, Valle'): 69299.69354876086,
#  ('Santana, Huila', 'Sevilla, Valle'): 37240.989488084066,
#  ('Santana, Huila', 'Caicedonia, Valle'): 41755.745875864865,
#  ('Santana, Huila', 'Florencia, Caquetá'): 7974.654428259205,
#  ('Santana, Huila', 'Puerto Milán, Caquetá'): 7858.666885558625,
#  ('Santana, Huila', 'Nunchía, Casanare'): 12407.319451641186,
#  ('Santana, Huila', 'Mesetas, Meta'): 3238.158047245731,
#  ('Neiva, Huila', 'Andes, Antioquia'): 940330.5014387396,
#  ('Neiva, Huila', 'Medellín, Antioquia'): 343469.6175528052,
#  ('Neiva, Huila', 'Dabeiba, Antioquia'): 1097273.7504940922,
#  ('Neiva, Huila', 'Salgar, Antioquia'): 719899.0475573099,
#  ('Neiva, Huila', 'San Pablo de Borbur, Boyacá'): 45898.24227115794,
#  ('Neiva, Huila', 'Labranzagrande, Boyacá'): 43970.077263192296,
#  ('Neiva, Huila', 'Miraflores, Boyacá'): 33186.179153911384,
#  ('Neiva, Huila', 'Moniquirá, Boyacá'): 42450.5387154824,
#  ('Neiva, Huila', 'Manizales, Caldas'): 504797.2287179845,
#  ('Neiva, Huila', 'Anserma, Caldas'): 181151.70254398178,
#  ('Neiva, Huila', 'Pensilvania, Caldas'): 155698.91313141934,
#  ('Neiva, Huila', 'Riosucio, Caldas'): 161932.2206021967,
#  ('Neiva, Huila', 'Aguadas, Caldas'): 170937.93887481725,
#  ('Neiva, Huila', 'Morales, Cauca'): 207907.03195303382,
#  ('Neiva, Huila', 'El Tambo, Cauca'): 215042.06409749962,
#  ('Neiva, Huila', 'Bolívar, Cauca'): 240585.12238086463,
#  ('Neiva, Huila', 'Aguachica, Cesar'): 198263.98511392786,
#  ('Neiva, Huila', 'San Diego, Cesar'): 204989.36716779976,
#  ('Neiva, Huila', 'Caparrapí, Cundinamarca'): 35586.68328701257,
#  ('Neiva, Huila', 'Viotá, Cundinamarca'): 28246.30818752547,
#  ('Neiva, Huila', 'Sasaima, Cundinamarca'): 47999.06389063307,
#  ('Neiva, Huila', 'Neiva, Huila'): 0.0,
#  ('Neiva, Huila', 'Pitalito, Huila'): 329835.2485764492,
#  ('Neiva, Huila', 'Gigante, Huila'): 148825.9044379822,
#  ('Neiva, Huila', 'Santa Marta, Magdalena'): 312818.9350220627,
#  ('Neiva, Huila', 'La Unión, Nariño'): 177148.38786161272,
#  ('Neiva, Huila', 'Pasto, Nariño'): 223210.04727005423,
#  ('Neiva, Huila', 'Samaniego, Nariño'): 167019.83819207756,
#  ('Neiva, Huila', 'Sardinata, Norte de Santander'): 145270.00112922394,
#  ('Neiva, Huila', 'Ocaña, Norte de Santander'): 142961.90520459614,
#  ('Neiva, Huila', 'Convención, Norte de Santander'): 143687.11883527128,
#  ('Neiva, Huila', 'Génova, Quindío'): 61661.661225742224,
#  ('Neiva, Huila', 'Calarcá, Quindío'): 89055.8821686802,
#  ('Neiva, Huila', 'Quimbaya, Quindío'): 90262.36171166445,
#  ('Neiva, Huila', 'Pereira, Risaralda'): 157982.0555515861,
#  ('Neiva, Huila', 'Santuario, Risaralda'): 154495.30687793993,
#  ('Neiva, Huila', 'Belén de Umbria, Risaralda'): 200980.0248117958,
#  ('Neiva, Huila', 'Rionegro, Santander'): 90833.1375898678,
#  ('Neiva, Huila', 'Bucaramanga, Santander'): 83297.95616772976,
#  ('Neiva, Huila', 'Barbosa, Santander'): 286706.8101318835,
#  ('Neiva, Huila', 'Socorro, Santander'): 315190.5526601807,
#  ('Neiva, Huila', 'Simacota, Santander'): 259287.68566749032,
#  ('Neiva, Huila', 'Chaparral, Tolima'): 67467.21716006391,
#  ('Neiva, Huila', 'Dolores, Tolima'): 93610.92158367753,
#  ('Neiva, Huila', 'Ibagué, Tolima'): 20539.10473773431,
#  ('Neiva, Huila', 'Líbano, Tolima'): 21999.128841629325,
#  ('Neiva, Huila', 'Cartago, Valle'): 111523.46436241714,
#  ('Neiva, Huila', 'Tulua, Valle'): 74911.53150066457,
#  ('Neiva, Huila', 'Jamundí, Valle'): 47379.58171989696,
#  ('Neiva, Huila', 'Sevilla, Valle'): 35857.433977293076,
#  ('Neiva, Huila', 'Caicedonia, Valle'): 42830.08762867796,
#  ('Neiva, Huila', 'Florencia, Caquetá'): 5340.659466267087,
#  ('Neiva, Huila', 'Puerto Milán, Caquetá'): 5629.3786952885575,
#  ('Neiva, Huila', 'Nunchía, Casanare'): 15457.95519855893,
#  ('Neiva, Huila', 'Mesetas, Meta'): 5052.977923942113,
#  ('Santa Marta, Magdalena', 'Andes, Antioquia'): 2069702.5327439345,
#  ('Santa Marta, Magdalena', 'Medellín, Antioquia'): 545801.745212469,
#  ('Santa Marta, Magdalena', 'Dabeiba, Antioquia'): 1293738.9994926308,
#  ('Santa Marta, Magdalena', 'Salgar, Antioquia'): 1330538.3553665567,
#  ('Santa Marta, Magdalena', 'San Pablo de Borbur, Boyacá'): 87905.48257299337,
#  ('Santa Marta, Magdalena', 'Labranzagrande, Boyacá'): 70657.96678782227,
#  ('Santa Marta, Magdalena', 'Miraflores, Boyacá'): 68086.03576992474,
#  ('Santa Marta, Magdalena', 'Moniquirá, Boyacá'): 68786.01453504873,
#  ('Santa Marta, Magdalena', 'Manizales, Caldas'): 1551759.4709388758,
#  ('Santa Marta, Magdalena', 'Anserma, Caldas'): 510358.0733069794,
#  ('Santa Marta, Magdalena', 'Pensilvania, Caldas'): 388367.75636578863,
#  ('Santa Marta, Magdalena', 'Riosucio, Caldas'): 394928.4085780103,
#  ('Santa Marta, Magdalena', 'Aguadas, Caldas'): 388613.2751867011,
#  ('Santa Marta, Magdalena', 'Morales, Cauca'): 1237996.970554074,
#  ('Santa Marta, Magdalena', 'El Tambo, Cauca'): 1208404.935871643,
#  ('Santa Marta, Magdalena', 'Bolívar, Cauca'): 1152700.6274717015,
#  ('Santa Marta, Magdalena', 'Aguachica, Cesar'): 106788.18670884799,
#  ('Santa Marta, Magdalena', 'San Diego, Cesar'): 36031.85870053128,
#  ('Santa Marta, Magdalena', 'Caparrapí, Cundinamarca'): 84688.251801457,
#  ('Santa Marta, Magdalena', 'Viotá, Cundinamarca'): 118467.7348189377,
#  ('Santa Marta, Magdalena', 'Sasaima, Cundinamarca'): 143327.64281832363,
#  ('Santa Marta, Magdalena', 'Neiva, Huila'): 1831637.1853265513,
#  ('Santa Marta, Magdalena', 'Pitalito, Huila'): 2099518.209993781,
#  ('Santa Marta, Magdalena', 'Gigante, Huila'): 1950171.6531042564,
#  ('Santa Marta, Magdalena', 'Santa Marta, Magdalena'): 0.0,
#  ('Santa Marta, Magdalena', 'La Unión, Nariño'): 760588.9047959081,
#  ('Santa Marta, Magdalena', 'Pasto, Nariño'): 858213.6191588793,
#  ('Santa Marta, Magdalena', 'Samaniego, Nariño'): 593358.8139871149,
#  ('Santa Marta, Magdalena',
#   'Sardinata, Norte de Santander'): 82159.76187767313,
#  ('Santa Marta, Magdalena', 'Ocaña, Norte de Santander'): 80549.61915979724,
#  ('Santa Marta, Magdalena',
#   'Convención, Norte de Santander'): 60432.085107411265,
#  ('Santa Marta, Magdalena', 'Génova, Quindío'): 358131.7979758837,
#  ('Santa Marta, Magdalena', 'Calarcá, Quindío'): 420694.335697628,
#  ('Santa Marta, Magdalena', 'Quimbaya, Quindío'): 372045.30651030265,
#  ('Santa Marta, Magdalena', 'Pereira, Risaralda'): 585028.8501563801,
#  ('Santa Marta, Magdalena', 'Santuario, Risaralda'): 472613.01818761684,
#  ('Santa Marta, Magdalena', 'Belén de Umbria, Risaralda'): 565438.952927549,
#  ('Santa Marta, Magdalena', 'Rionegro, Santander'): 70141.68773405615,
#  ('Santa Marta, Magdalena', 'Bucaramanga, Santander'): 74910.75570459518,
#  ('Santa Marta, Magdalena', 'Barbosa, Santander'): 452087.3388706238,
#  ('Santa Marta, Magdalena', 'Socorro, Santander'): 382771.46716458496,
#  ('Santa Marta, Magdalena', 'Simacota, Santander'): 296905.3210556724,
#  ('Santa Marta, Magdalena', 'Chaparral, Tolima'): 661239.7393221301,
#  ('Santa Marta, Magdalena', 'Dolores, Tolima'): 900898.3404336368,
#  ('Santa Marta, Magdalena', 'Ibagué, Tolima'): 97296.02304991467,
#  ('Santa Marta, Magdalena', 'Líbano, Tolima'): 75962.85386754655,
#  ('Santa Marta, Magdalena', 'Cartago, Valle'): 421071.8548152981,
#  ('Santa Marta, Magdalena', 'Tulua, Valle'): 439468.595964322,
#  ('Santa Marta, Magdalena', 'Jamundí, Valle'): 295689.7649891347,
#  ('Santa Marta, Magdalena', 'Sevilla, Valle'): 205676.25277330633,
#  ('Santa Marta, Magdalena', 'Caicedonia, Valle'): 220373.3983127091,
#  ('Santa Marta, Magdalena', 'Florencia, Caquetá'): 35784.511334431,
#  ('Santa Marta, Magdalena', 'Puerto Milán, Caquetá'): 32795.08718391587,
#  ('Santa Marta, Magdalena', 'Nunchía, Casanare'): 22975.222215139438,
#  ('Santa Marta, Magdalena', 'Mesetas, Meta'): 34779.14085163861,
#  ('Cúcuta, Nor. de Santander', 'Andes, Antioquia'): 1497999.9936456995,
#  ('Cúcuta, Nor. de Santander', 'Medellín, Antioquia'): 381141.65662890166,
#  ('Cúcuta, Nor. de Santander', 'Dabeiba, Antioquia'): 1077610.3352482023,
#  ('Cúcuta, Nor. de Santander', 'Salgar, Antioquia'): 976657.4136839741,
#  ('Cúcuta, Nor. de Santander',
#   'San Pablo de Borbur, Boyacá'): 45872.05396482383,
#  ('Cúcuta, Nor. de Santander', 'Labranzagrande, Boyacá'): 30464.425177689896,
#  ('Cúcuta, Nor. de Santander', 'Miraflores, Boyacá'): 33226.94033224479,
#  ('Cúcuta, Nor. de Santander', 'Moniquirá, Boyacá'): 31267.889302882042,
#  ('Cúcuta, Nor. de Santander', 'Manizales, Caldas'): 1050614.2556774556,
#  ('Cúcuta, Nor. de Santander', 'Anserma, Caldas'): 356936.5494106935,
#  ('Cúcuta, Nor. de Santander', 'Pensilvania, Caldas'): 249566.03689224125,
#  ('Cúcuta, Nor. de Santander', 'Riosucio, Caldas'): 276121.92615987937,
#  ('Cúcuta, Nor. de Santander', 'Aguadas, Caldas'): 260700.22627570044,
#  ('Cúcuta, Nor. de Santander', 'Morales, Cauca'): 954253.0401770405,
#  ('Cúcuta, Nor. de Santander', 'El Tambo, Cauca'): 937143.2592710399,
#  ('Cúcuta, Nor. de Santander', 'Bolívar, Cauca'): 904988.6556092984,
#  ('Cúcuta, Nor. de Santander', 'Aguachica, Cesar'): 41319.227972486085,
#  ('Cúcuta, Nor. de Santander', 'San Diego, Cesar'): 63760.63785108682,
#  ('Cúcuta, Nor. de Santander', 'Caparrapí, Cundinamarca'): 48848.18417254316,
#  ('Cúcuta, Nor. de Santander', 'Viotá, Cundinamarca'): 72412.22031968425,
#  ('Cúcuta, Nor. de Santander', 'Sasaima, Cundinamarca'): 83929.88846547673,
#  ('Cúcuta, Nor. de Santander', 'Neiva, Huila'): 1279712.1248815467,
#  ('Cúcuta, Nor. de Santander', 'Pitalito, Huila'): 1585622.0185377386,
#  ('Cúcuta, Nor. de Santander', 'Gigante, Huila'): 1407830.6731653216,
#  ('Cúcuta, Nor. de Santander', 'Santa Marta, Magdalena'): 135379.36433845077,
#  ('Cúcuta, Nor. de Santander', 'La Unión, Nariño'): 603200.6789631196,
#  ('Cúcuta, Nor. de Santander', 'Pasto, Nariño'): 685067.2080006533,
#  ('Cúcuta, Nor. de Santander', 'Samaniego, Nariño'): 482707.2086272205,
#  ('Cúcuta, Nor. de Santander',
#   'Sardinata, Norte de Santander'): 9179.887358549666,
#  ('Cúcuta, Nor. de Santander',
#   'Ocaña, Norte de Santander'): 23828.671751285365,
#  ('Cúcuta, Nor. de Santander',
#   'Convención, Norte de Santander'): 24065.76483780774,
#  ('Cúcuta, Nor. de Santander', 'Génova, Quindío'): 252323.94479439914,
#  ('Cúcuta, Nor. de Santander', 'Calarcá, Quindío'): 293229.8910818892,
#  ('Cúcuta, Nor. de Santander', 'Quimbaya, Quindío'): 261805.12533301374,
#  ('Cúcuta, Nor. de Santander', 'Pereira, Risaralda'): 404938.6703465626,
#  ('Cúcuta, Nor. de Santander', 'Santuario, Risaralda'): 339727.02757177444,
#  ('Cúcuta, Nor. de Santander',
#   'Belén de Umbria, Risaralda'): 401515.14143373934,
#  ('Cúcuta, Nor. de Santander', 'Rionegro, Santander'): 20178.464803277304,
#  ('Cúcuta, Nor. de Santander', 'Bucaramanga, Santander'): 19755.68689230042,
#  ('Cúcuta, Nor. de Santander', 'Barbosa, Santander'): 205668.99254325457,
#  ('Cúcuta, Nor. de Santander', 'Socorro, Santander'): 140787.0887093972,
#  ('Cúcuta, Nor. de Santander', 'Simacota, Santander'): 117095.099865506,
#  ('Cúcuta, Nor. de Santander', 'Chaparral, Tolima'): 463322.8241054932,
#  ('Cúcuta, Nor. de Santander', 'Dolores, Tolima'): 591377.8581881864,
#  ('Cúcuta, Nor. de Santander', 'Ibagué, Tolima'): 64623.88927473316,
#  ('Cúcuta, Nor. de Santander', 'Líbano, Tolima'): 48590.264388959615,
#  ('Cúcuta, Nor. de Santander', 'Cartago, Valle'): 300539.6605443785,
#  ('Cúcuta, Nor. de Santander', 'Tulua, Valle'): 319518.1298096953,
#  ('Cúcuta, Nor. de Santander', 'Jamundí, Valle'): 225688.88632977952,
#  ('Cúcuta, Nor. de Santander', 'Sevilla, Valle'): 146934.34310580857,
#  ('Cúcuta, Nor. de Santander', 'Caicedonia, Valle'): 156450.67660127013,
#  ('Cúcuta, Nor. de Santander', 'Florencia, Caquetá'): 26437.399139752135,
#  ('Cúcuta, Nor. de Santander', 'Puerto Milán, Caquetá'): 24293.124590386215,
#  ('Cúcuta, Nor. de Santander', 'Nunchía, Casanare'): 9749.070138370043,
#  ('Cúcuta, Nor. de Santander', 'Mesetas, Meta'): 22419.398579474295,
#  ('Pasto, Nariño', 'Andes, Antioquia'): 1669130.1105244714,
#  ('Pasto, Nariño', 'Medellín, Antioquia'): 577802.7217718784,
#  ('Pasto, Nariño', 'Dabeiba, Antioquia'): 1621353.7819549912,
#  ('Pasto, Nariño', 'Salgar, Antioquia'): 1213167.928273612,
#  ('Pasto, Nariño', 'San Pablo de Borbur, Boyacá'): 88272.90503666397,
#  ('Pasto, Nariño', 'Labranzagrande, Boyacá'): 76928.4440341913,
#  ('Pasto, Nariño', 'Miraflores, Boyacá'): 63696.30782056818,
#  ('Pasto, Nariño', 'Moniquirá, Boyacá'): 77183.11672684636,
#  ('Pasto, Nariño', 'Manizales, Caldas'): 1077219.9035716443,
#  ('Pasto, Nariño', 'Anserma, Caldas'): 360312.42261629965,
#  ('Pasto, Nariño', 'Pensilvania, Caldas'): 315672.8375555342,
#  ('Pasto, Nariño', 'Riosucio, Caldas'): 306178.62369070266,
#  ('Pasto, Nariño', 'Aguadas, Caldas'): 325818.13847681164,
#  ('Pasto, Nariño', 'Morales, Cauca'): 261966.2947721055,
#  ('Pasto, Nariño', 'El Tambo, Cauca'): 192015.6278179836,
#  ('Pasto, Nariño', 'Bolívar, Cauca'): 103981.07926672815,
#  ('Pasto, Nariño', 'Aguachica, Cesar'): 290225.3355523778,
#  ('Pasto, Nariño', 'San Diego, Cesar'): 272966.22264177783,
#  ('Pasto, Nariño', 'Caparrapí, Cundinamarca'): 73583.55400515704,
#  ('Pasto, Nariño', 'Viotá, Cundinamarca'): 75828.35954506848,
#  ('Pasto, Nariño', 'Sasaima, Cundinamarca'): 109396.84123946515,
#  ('Pasto, Nariño', 'Neiva, Huila'): 611628.5162264417,
#  ('Pasto, Nariño', 'Pitalito, Huila'): 282082.8056791801,
#  ('Pasto, Nariño', 'Gigante, Huila'): 470809.84911448875,
#  ('Pasto, Nariño', 'Santa Marta, Magdalena'): 401627.06315317017,
#  ('Pasto, Nariño', 'La Unión, Nariño'): 42318.30367389752,
#  ('Pasto, Nariño', 'Pasto, Nariño'): 0.0,
#  ('Pasto, Nariño', 'Samaniego, Nariño'): 35135.97259914462,
#  ('Pasto, Nariño', 'Sardinata, Norte de Santander'): 212069.39288351862,
#  ('Pasto, Nariño', 'Ocaña, Norte de Santander'): 210271.49540856513,
#  ('Pasto, Nariño', 'Convención, Norte de Santander'): 204064.48717584592,
#  ('Pasto, Nariño', 'Génova, Quindío'): 172115.99601314805,
#  ('Pasto, Nariño', 'Calarcá, Quindío'): 226192.5342152778,
#  ('Pasto, Nariño', 'Quimbaya, Quindío'): 209653.5395822508,
#  ('Pasto, Nariño', 'Pereira, Risaralda'): 357955.09280786844,
#  ('Pasto, Nariño', 'Santuario, Risaralda'): 305328.272732116,
#  ('Pasto, Nariño', 'Belén de Umbria, Risaralda'): 392373.9446467107,
#  ('Pasto, Nariño', 'Rionegro, Santander'): 139920.9127090085,
#  ('Pasto, Nariño', 'Bucaramanga, Santander'): 131263.3151356561,
#  ('Pasto, Nariño', 'Barbosa, Santander'): 517975.0006644958,
#  ('Pasto, Nariño', 'Socorro, Santander'): 529448.8633059494,
#  ('Pasto, Nariño', 'Simacota, Santander'): 431877.6450440726,
#  ('Pasto, Nariño', 'Chaparral, Tolima'): 273769.74536342337,
#  ('Pasto, Nariño', 'Dolores, Tolima'): 419594.14979083475,
#  ('Pasto, Nariño', 'Ibagué, Tolima'): 56274.24118155601,
#  ('Pasto, Nariño', 'Líbano, Tolima'): 52107.43373806059,
# ...
#  ('Calarcá, Quindío', 'Cartago, Valle'): 21897.382579859073,
#  ('Calarcá, Quindío', 'Tulua, Valle'): 33525.21086258681,
#  ('Calarcá, Quindío', 'Jamundí, Valle'): 55351.00578684182,
#  ('Calarcá, Quindío', 'Sevilla, Valle'): 10247.269489309456,
#  ('Calarcá, Quindío', 'Caicedonia, Valle'): 6745.766505755152,
#  ('Calarcá, Quindío', 'Florencia, Caquetá'): 10443.182887455156,
#  ('Calarcá, Quindío', 'Puerto Milán, Caquetá'): 10256.811542897822,
#  ('Calarcá, Quindío', 'Nunchía, Casanare'): 14279.433916202675,
#  ('Calarcá, Quindío', 'Mesetas, Meta'): 8834.199892331633,
#  ('Filandia, Quindío', 'Andes, Antioquia'): 354222.84386567853,
#  ('Filandia, Quindío', 'Medellín, Antioquia'): 169898.59036817084,
#  ('Filandia, Quindío', 'Dabeiba, Antioquia'): 644969.1819285338,
#  ('Filandia, Quindío', 'Salgar, Antioquia'): 320863.73118215543,
#  ('Filandia, Quindío', 'San Pablo de Borbur, Boyacá'): 29389.663313037807,
#  ('Filandia, Quindío', 'Labranzagrande, Boyacá'): 38042.787933302105,
#  ('Filandia, Quindío', 'Miraflores, Boyacá'): 28035.582871494225,
#  ('Filandia, Quindío', 'Moniquirá, Boyacá'): 30975.569595217232,
#  ('Filandia, Quindío', 'Manizales, Caldas'): 107926.87492488183,
#  ('Filandia, Quindío', 'Anserma, Caldas'): 44620.077532357536,
#  ('Filandia, Quindío', 'Pensilvania, Caldas'): 57929.45239831086,
#  ('Filandia, Quindío', 'Riosucio, Caldas'): 52161.39700003037,
#  ('Filandia, Quindío', 'Aguadas, Caldas'): 62870.833812261335,
#  ('Filandia, Quindío', 'Morales, Cauca'): 299581.6788639888,
#  ('Filandia, Quindío', 'El Tambo, Cauca'): 329320.510135453,
#  ('Filandia, Quindío', 'Bolívar, Cauca'): 362755.57162797614,
#  ('Filandia, Quindío', 'Aguachica, Cesar'): 149648.53683000267,
#  ('Filandia, Quindío', 'San Diego, Cesar'): 166862.786183584,
#  ('Filandia, Quindío', 'Caparrapí, Cundinamarca'): 19450.247823125006,
#  ('Filandia, Quindío', 'Viotá, Cundinamarca'): 20866.909535904717,
#  ('Filandia, Quindío', 'Sasaima, Cundinamarca'): 29047.68250674002,
#  ('Filandia, Quindío', 'Neiva, Huila'): 369203.1219293356,
#  ('Filandia, Quindío', 'Pitalito, Huila'): 636471.8373698557,
#  ('Filandia, Quindío', 'Gigante, Huila'): 495855.350754394,
#  ('Filandia, Quindío', 'Santa Marta, Magdalena'): 254545.79681408536,
#  ('Filandia, Quindío', 'La Unión, Nariño'): 257029.6947478932,
#  ('Filandia, Quindío', 'Pasto, Nariño'): 317918.79039065854,
#  ('Filandia, Quindío', 'Samaniego, Nariño'): 219999.46584141397,
#  ('Filandia, Quindío', 'Sardinata, Norte de Santander'): 115215.99354537795,
#  ('Filandia, Quindío', 'Ocaña, Norte de Santander'): 109123.65972664484,
#  ('Filandia, Quindío', 'Convención, Norte de Santander'): 112836.57098144373,
#  ('Filandia, Quindío', 'Génova, Quindío'): 23879.87309509531,
#  ('Filandia, Quindío', 'Calarcá, Quindío'): 12814.177625681898,
#  ('Filandia, Quindío', 'Quimbaya, Quindío'): 7643.8935305373925,
#  ('Filandia, Quindío', 'Pereira, Risaralda'): 10718.273261744576,
#  ('Filandia, Quindío', 'Santuario, Risaralda'): 35748.09416636681,
#  ('Filandia, Quindío', 'Belén de Umbria, Risaralda'): 51160.53988187805,
#  ('Filandia, Quindío', 'Rionegro, Santander'): 67811.46053963926,
#  ('Filandia, Quindío', 'Bucaramanga, Santander'): 63643.61765005284,
#  ('Filandia, Quindío', 'Barbosa, Santander'): 205204.11936133777,
#  ('Filandia, Quindío', 'Socorro, Santander'): 237374.6194936392,
#  ('Filandia, Quindío', 'Simacota, Santander'): 185141.45281906403,
#  ('Filandia, Quindío', 'Chaparral, Tolima'): 79320.69141427337,
#  ('Filandia, Quindío', 'Dolores, Tolima'): 162057.82843028737,
#  ('Filandia, Quindío', 'Ibagué, Tolima'): 6453.183914477878,
#  ('Filandia, Quindío', 'Líbano, Tolima'): 7716.103483574624,
#  ('Filandia, Quindío', 'Cartago, Valle'): 16747.785156046786,
#  ('Filandia, Quindío', 'Tulua, Valle'): 44214.12074299865,
#  ('Filandia, Quindío', 'Jamundí, Valle'): 61889.49119680416,
#  ('Filandia, Quindío', 'Sevilla, Valle'): 15765.074660105909,
#  ('Filandia, Quindío', 'Caicedonia, Valle'): 12450.162896529813,
#  ('Filandia, Quindío', 'Florencia, Caquetá'): 11214.11909918207,
#  ('Filandia, Quindío', 'Puerto Milán, Caquetá'): 10941.530477279292,
#  ('Filandia, Quindío', 'Nunchía, Casanare'): 13980.038377879657,
#  ('Filandia, Quindío', 'Mesetas, Meta'): 9369.970863941495,
#  ('Pereira, Risaralda', 'Andes, Antioquia'): 313879.8845307936,
#  ('Pereira, Risaralda', 'Medellín, Antioquia'): 157088.933256934,
#  ('Pereira, Risaralda', 'Dabeiba, Antioquia'): 613398.7839707097,
#  ('Pereira, Risaralda', 'Salgar, Antioquia'): 292816.9758207443,
#  ('Pereira, Risaralda', 'San Pablo de Borbur, Boyacá'): 28375.717526134376,
#  ('Pereira, Risaralda', 'Labranzagrande, Boyacá'): 37662.68565839292,
#  ('Pereira, Risaralda', 'Miraflores, Boyacá'): 27798.250924805783,
#  ('Pereira, Risaralda', 'Moniquirá, Boyacá'): 30228.808206085032,
#  ('Pereira, Risaralda', 'Manizales, Caldas'): 80555.32038997406,
#  ('Pereira, Risaralda', 'Anserma, Caldas'): 34905.59968378175,
#  ('Pereira, Risaralda', 'Pensilvania, Caldas'): 51406.999306078396,
#  ('Pereira, Risaralda', 'Riosucio, Caldas'): 44222.312678078655,
#  ('Pereira, Risaralda', 'Aguadas, Caldas'): 54947.878448867865,
#  ('Pereira, Risaralda', 'Morales, Cauca'): 314392.12602305925,
#  ('Pereira, Risaralda', 'El Tambo, Cauca'): 343586.20248478383,
#  ('Pereira, Risaralda', 'Bolívar, Cauca'): 375772.38084692566,
#  ('Pereira, Risaralda', 'Aguachica, Cesar'): 145860.98546850274,
#  ('Pereira, Risaralda', 'San Diego, Cesar'): 163860.40417096947,
#  ('Pereira, Risaralda', 'Caparrapí, Cundinamarca'): 18578.35881354354,
#  ('Pereira, Risaralda', 'Viotá, Cundinamarca'): 21352.114631268545,
#  ('Pereira, Risaralda', 'Sasaima, Cundinamarca'): 28539.027346700426,
#  ('Pereira, Risaralda', 'Neiva, Huila'): 395399.4078765793,
#  ('Pereira, Risaralda', 'Pitalito, Huila'): 662491.271483349,
#  ('Pereira, Risaralda', 'Gigante, Huila'): 522233.0976789554,
#  ('Pereira, Risaralda', 'Santa Marta, Magdalena'): 250068.57486999375,
#  ('Pereira, Risaralda', 'La Unión, Nariño'): 265297.7799076846,
#  ('Pereira, Risaralda', 'Pasto, Nariño'): 326951.10839143884,
#  ('Pereira, Risaralda', 'Samaniego, Nariño'): 225851.1372848544,
#  ('Pereira, Risaralda', 'Sardinata, Norte de Santander'): 112836.64657960211,
#  ('Pereira, Risaralda', 'Ocaña, Norte de Santander'): 106478.64565302043,
#  ('Pereira, Risaralda', 'Convención, Norte de Santander'): 110405.53615621972,
#  ('Pereira, Risaralda', 'Génova, Quindío'): 29812.223919943375,
#  ('Pereira, Risaralda', 'Calarcá, Quindío'): 20127.803729961557,
#  ('Pereira, Risaralda', 'Quimbaya, Quindío'): 11806.972916257015,
#  ('Pereira, Risaralda', 'Pereira, Risaralda'): 0.0,
#  ('Pereira, Risaralda', 'Santuario, Risaralda'): 29671.132386690955,
#  ('Pereira, Risaralda', 'Belén de Umbria, Risaralda'): 41263.79785267242,
#  ('Pereira, Risaralda', 'Rionegro, Santander'): 66034.23352342848,
#  ('Pereira, Risaralda', 'Bucaramanga, Santander'): 62138.10413778085,
#  ('Pereira, Risaralda', 'Barbosa, Santander'): 199791.39373050266,
#  ('Pereira, Risaralda', 'Socorro, Santander'): 231720.2373782854,
#  ('Pereira, Risaralda', 'Simacota, Santander'): 179670.14976929143,
#  ('Pereira, Risaralda', 'Chaparral, Tolima'): 89819.76848269175,
#  ('Pereira, Risaralda', 'Dolores, Tolima'): 173095.75640376518,
#  ('Pereira, Risaralda', 'Ibagué, Tolima'): 7320.326265382977,
#  ('Pereira, Risaralda', 'Líbano, Tolima'): 7365.3250490995815,
#  ('Pereira, Risaralda', 'Cartago, Valle'): 17186.81796182045,
#  ('Pereira, Risaralda', 'Tulua, Valle'): 50366.06395590294,
#  ('Pereira, Risaralda', 'Jamundí, Valle'): 65499.018909485574,
#  ('Pereira, Risaralda', 'Sevilla, Valle'): 18937.820225788048,
#  ('Pereira, Risaralda', 'Caicedonia, Valle'): 15878.623220605574,
#  ('Pereira, Risaralda', 'Florencia, Caquetá'): 11660.090600882699,
#  ('Pereira, Risaralda', 'Puerto Milán, Caquetá'): 11338.909210188356,
#  ('Pereira, Risaralda', 'Nunchía, Casanare'): 13875.426852075107,
#  ('Pereira, Risaralda', 'Mesetas, Meta'): 9743.076467677154,
#  ('Bucaramanga, Santander', 'Andes, Antioquia'): 1140144.1323408044,
#  ('Bucaramanga, Santander', 'Medellín, Antioquia'): 279741.5395692589,
#  ('Bucaramanga, Santander', 'Dabeiba, Antioquia'): 865216.0057692531,
#  ('Bucaramanga, Santander', 'Salgar, Antioquia'): 743107.2821670956,
#  ('Bucaramanga, Santander', 'San Pablo de Borbur, Boyacá'): 28324.492100060852,
#  ('Bucaramanga, Santander', 'Labranzagrande, Boyacá'): 20454.86962073806,
#  ('Bucaramanga, Santander', 'Miraflores, Boyacá'): 22253.376566918785,
#  ('Bucaramanga, Santander', 'Moniquirá, Boyacá'): 17434.192694873545,
#  ('Bucaramanga, Santander', 'Manizales, Caldas'): 783801.3517901788,
#  ('Bucaramanga, Santander', 'Anserma, Caldas'): 269819.0264408367,
#  ('Bucaramanga, Santander', 'Pensilvania, Caldas'): 178530.40945581163,
#  ('Bucaramanga, Santander', 'Riosucio, Caldas'): 207087.78695290384,
#  ('Bucaramanga, Santander', 'Aguadas, Caldas'): 190078.36688312844,
#  ('Bucaramanga, Santander', 'Morales, Cauca'): 798325.0399023782,
#  ('Bucaramanga, Santander', 'El Tambo, Cauca'): 791188.0270079405,
#  ('Bucaramanga, Santander', 'Bolívar, Cauca'): 773829.4309204274,
#  ('Bucaramanga, Santander', 'Aguachica, Cesar'): 44665.705816533264,
#  ('Bucaramanga, Santander', 'San Diego, Cesar'): 85553.14149332386,
#  ('Bucaramanga, Santander', 'Caparrapí, Cundinamarca'): 32866.634835720244,
#  ('Bucaramanga, Santander', 'Viotá, Cundinamarca'): 53225.73344087324,
#  ('Bucaramanga, Santander', 'Sasaima, Cundinamarca'): 58696.76278010971,
#  ('Bucaramanga, Santander', 'Neiva, Huila'): 1035407.5557161939,
#  ('Bucaramanga, Santander', 'Pitalito, Huila'): 1345242.5111147838,
#  ('Bucaramanga, Santander', 'Gigante, Huila'): 1167612.9369244792,
#  ('Bucaramanga, Santander', 'Santa Marta, Magdalena'): 159028.41993154283,
#  ('Bucaramanga, Santander', 'La Unión, Nariño'): 519465.3409266854,
#  ('Bucaramanga, Santander', 'Pasto, Nariño'): 595451.463073479,
#  ('Bucaramanga, Santander', 'Samaniego, Nariño'): 419957.8801586644,
#  ('Bucaramanga, Santander',
#   'Sardinata, Norte de Santander'): 28524.196720235668,
#  ('Bucaramanga, Santander', 'Ocaña, Norte de Santander'): 28259.75401483115,
#  ('Bucaramanga, Santander',
#   'Convención, Norte de Santander'): 38881.4912921433,
#  ('Bucaramanga, Santander', 'Génova, Quindío'): 197593.97531198777,
#  ('Bucaramanga, Santander', 'Calarcá, Quindío'): 226672.74868451912,
#  ('Bucaramanga, Santander', 'Quimbaya, Quindío'): 202236.09002021744,
#  ('Bucaramanga, Santander', 'Pereira, Risaralda'): 308607.6792094256,
#  ('Bucaramanga, Santander', 'Santuario, Risaralda'): 261886.4246211265,
#  ('Bucaramanga, Santander', 'Belén de Umbria, Risaralda'): 306107.58171432983,
#  ('Bucaramanga, Santander', 'Rionegro, Santander'): 9084.165197655026,
#  ('Bucaramanga, Santander', 'Bucaramanga, Santander'): 0.0,
#  ('Bucaramanga, Santander', 'Barbosa, Santander'): 112196.77709598592,
#  ('Bucaramanga, Santander', 'Socorro, Santander'): 56185.29113576066,
#  ('Bucaramanga, Santander', 'Simacota, Santander'): 45973.456942094155,
#  ('Bucaramanga, Santander', 'Chaparral, Tolima'): 367005.95248283807,
#  ('Bucaramanga, Santander', 'Dolores, Tolima'): 461842.8004088769,
#  ('Bucaramanga, Santander', 'Ibagué, Tolima'): 48871.59958187786,
#  ('Bucaramanga, Santander', 'Líbano, Tolima'): 35505.14542259153,
#  ('Bucaramanga, Santander', 'Cartago, Valle'): 233045.76033876298,
#  ('Bucaramanga, Santander', 'Tulua, Valle'): 254614.4885958235,
#  ('Bucaramanga, Santander', 'Jamundí, Valle'): 186878.82773443917,
#  ('Bucaramanga, Santander', 'Sevilla, Valle'): 115853.99748634413,
#  ('Bucaramanga, Santander', 'Caicedonia, Valle'): 122483.72288319726,
#  ('Bucaramanga, Santander', 'Florencia, Caquetá'): 22407.890578401843,
#  ('Bucaramanga, Santander', 'Puerto Milán, Caquetá'): 20718.597586833388,
#  ('Bucaramanga, Santander', 'Nunchía, Casanare'): 7314.66577797772,
#  ('Bucaramanga, Santander', 'Mesetas, Meta'): 17910.707904004576,
#  ('Barbosa, Santander', 'Andes, Antioquia'): 829314.4113432554,
#  ('Barbosa, Santander', 'Medellín, Antioquia'): 211192.49915223816,
#  ('Barbosa, Santander', 'Dabeiba, Antioquia'): 772575.631025147,
#  ('Barbosa, Santander', 'Salgar, Antioquia'): 561990.5042195233,
#  ('Barbosa, Santander', 'San Pablo de Borbur, Boyacá'): 8735.174108141735,
#  ('Barbosa, Santander', 'Labranzagrande, Boyacá'): 13304.167580844307,
#  ('Barbosa, Santander', 'Miraflores, Boyacá'): 10194.51667635919,
#  ('Barbosa, Santander', 'Moniquirá, Boyacá'): 1465.7079090172858,
#  ('Barbosa, Santander', 'Manizales, Caldas'): 511510.6435719043,
#  ('Barbosa, Santander', 'Anserma, Caldas'): 184877.35540988806,
#  ('Barbosa, Santander', 'Pensilvania, Caldas'): 108208.23185123812,
#  ('Barbosa, Santander', 'Riosucio, Caldas'): 143275.47538382697,
#  ('Barbosa, Santander', 'Aguadas, Caldas'): 125412.04295754869,
#  ('Barbosa, Santander', 'Morales, Cauca'): 623052.6381530528,
#  ('Barbosa, Santander', 'El Tambo, Cauca'): 625243.1163952431,
#  ('Barbosa, Santander', 'Bolívar, Cauca'): 623201.2489070689,
#  ('Barbosa, Santander', 'Aguachica, Cesar'): 84254.18242432865,
#  ('Barbosa, Santander', 'San Diego, Cesar'): 118787.23976381644,
#  ('Barbosa, Santander', 'Caparrapí, Cundinamarca'): 15313.022945693578,
#  ('Barbosa, Santander', 'Viotá, Cundinamarca'): 30369.272676136366,
#  ('Barbosa, Santander', 'Sasaima, Cundinamarca'): 29192.561164673156,
#  ('Barbosa, Santander', 'Neiva, Huila'): 745236.7436255148,
#  ('Barbosa, Santander', 'Pitalito, Huila'): 1061080.6398077,
#  ('Barbosa, Santander', 'Gigante, Huila'): 881164.5729375117,
#  ('Barbosa, Santander', 'Santa Marta, Magdalena'): 200692.97753602455,
#  ('Barbosa, Santander', 'La Unión, Nariño'): 423153.5017525173,
#  ('Barbosa, Santander', 'Pasto, Nariño'): 491350.1174527693,
#  ('Barbosa, Santander', 'Samaniego, Nariño'): 348621.37983772374,
#  ('Barbosa, Santander', 'Sardinata, Norte de Santander'): 61427.39762012214,
#  ('Barbosa, Santander', 'Ocaña, Norte de Santander'): 58948.9807130278,
#  ('Barbosa, Santander', 'Convención, Norte de Santander'): 67810.64847588647,
#  ('Barbosa, Santander', 'Génova, Quindío'): 137178.75830082697,
#  ('Barbosa, Santander', 'Calarcá, Quindío'): 154416.12860183866,
#  ('Barbosa, Santander', 'Quimbaya, Quindío'): 139112.0017026611,
#  ('Barbosa, Santander', 'Pereira, Risaralda'): 207493.6320402066,
#  ('Barbosa, Santander', 'Santuario, Risaralda'): 185114.12528490814,
#  ('Barbosa, Santander', 'Belén de Umbria, Risaralda'): 213812.6040160539,
#  ('Barbosa, Santander', 'Rionegro, Santander'): 29756.39939877095,
#  ('Barbosa, Santander', 'Bucaramanga, Santander'): 23461.709229183965,
#  ('Barbosa, Santander', 'Barbosa, Santander'): 0.0,
#  ('Barbosa, Santander', 'Socorro, Santander'): 50201.129908119314,
#  ('Barbosa, Santander', 'Simacota, Santander'): 46694.319361061214,
#  ('Barbosa, Santander', 'Chaparral, Tolima'): 256821.3405876951,
#  ('Barbosa, Santander', 'Dolores, Tolima'): 306530.7894489185,
#  ('Barbosa, Santander', 'Ibagué, Tolima'): 31201.128322200766,
#  ('Barbosa, Santander', 'Líbano, Tolima'): 21100.54212183501,
#  ('Barbosa, Santander', 'Cartago, Valle'): 163053.05477931243,
#  ('Barbosa, Santander', 'Tulua, Valle'): 183659.89439398114,
#  ('Barbosa, Santander', 'Jamundí, Valle'): 143663.90039957943,
#  ('Barbosa, Santander', 'Sevilla, Valle'): 81778.76769798888,
#  ('Barbosa, Santander', 'Caicedonia, Valle'): 85566.39946809589,
#  ('Barbosa, Santander', 'Florencia, Caquetá'): 17559.589613794335,
#  ('Barbosa, Santander', 'Puerto Milán, Caquetá'): 16393.604821688594,
#  ('Barbosa, Santander', 'Nunchía, Casanare'): 6101.772513585664,
#  ('Barbosa, Santander', 'Mesetas, Meta'): 12377.455564089987,
#  ('Cali, Valle del Cauca', 'Andes, Antioquia'): 810061.7455139274,
#  ('Cali, Valle del Cauca', 'Medellín, Antioquia'): 319604.0306152948,
#  ('Cali, Valle del Cauca', 'Dabeiba, Antioquia'): 968020.640561183,
#  ('Cali, Valle del Cauca', 'Salgar, Antioquia'): 629671.0525914768,
#  ('Cali, Valle del Cauca', 'San Pablo de Borbur, Boyacá'): 52761.702711988684,
#  ('Cali, Valle del Cauca', 'Labranzagrande, Boyacá'): 53529.07133482567,
#  ('Cali, Valle del Cauca', 'Miraflores, Boyacá'): 41941.48680638713,
#  ('Cali, Valle del Cauca', 'Moniquirá, Boyacá'): 49404.37179108076,
#  ('Cali, Valle del Cauca', 'Manizales, Caldas'): 484977.0983588402,
#  ('Cali, Valle del Cauca', 'Anserma, Caldas'): 161025.84283329625,
#  ...}

# %% [markdown]
# ## Modelado - Minimización de costos ($z_1$)
# ---

# %% [markdown]
# ### Declaración del modelo

# %%
problema = lp.LpProblem(sense=lp.LpMinimize)

# %% [markdown]
# ### Variables de Decisión
#
# >* $x_{ij}=\begin{cases}1, & \text{si el CAC } j \in J \text{ es atendido por el depósito } i \in I \\0, & \text{de lo contrario} \end{cases}$
# >* $y_{i}=\begin{cases} 1, & \text{si se decide operar el depósito } i \in I  \\ 0, & \text{de lo contrario} \end{cases}$

# %%
x = lp.LpVariable.dicts("atender", [(i, j) for i in I for j in J], lowBound = 0, cat=lp.LpBinary)
y = lp.LpVariable.dicts("operar", I, lowBound = 0, cat=lp.LpBinary)

x
# Out:
# {('Medellín, Antioquia',
#   'Andes, Antioquia'): atender_('Medellín,_Antioquia',_'Andes,_Antioquia'),
#  ('Medellín, Antioquia',
#   'Medellín, Antioquia'): atender_('Medellín,_Antioquia',_'Medellín,_Antioquia'),
#  ('Medellín, Antioquia',
#   'Dabeiba, Antioquia'): atender_('Medellín,_Antioquia',_'Dabeiba,_Antioquia'),
#  ('Medellín, Antioquia',
#   'Salgar, Antioquia'): atender_('Medellín,_Antioquia',_'Salgar,_Antioquia'),
#  ('Medellín, Antioquia',
#   'San Pablo de Borbur, Boyacá'): atender_('Medellín,_Antioquia',_'San_Pablo_de_Borbur,_Boyacá'),
#  ('Medellín, Antioquia',
#   'Labranzagrande, Boyacá'): atender_('Medellín,_Antioquia',_'Labranzagrande,_Boyacá'),
#  ('Medellín, Antioquia',
#   'Miraflores, Boyacá'): atender_('Medellín,_Antioquia',_'Miraflores,_Boyacá'),
#  ('Medellín, Antioquia',
#   'Moniquirá, Boyacá'): atender_('Medellín,_Antioquia',_'Moniquirá,_Boyacá'),
#  ('Medellín, Antioquia',
#   'Manizales, Caldas'): atender_('Medellín,_Antioquia',_'Manizales,_Caldas'),
#  ('Medellín, Antioquia',
#   'Anserma, Caldas'): atender_('Medellín,_Antioquia',_'Anserma,_Caldas'),
#  ('Medellín, Antioquia',
#   'Pensilvania, Caldas'): atender_('Medellín,_Antioquia',_'Pensilvania,_Caldas'),
#  ('Medellín, Antioquia',
#   'Riosucio, Caldas'): atender_('Medellín,_Antioquia',_'Riosucio,_Caldas'),
#  ('Medellín, Antioquia',
#   'Aguadas, Caldas'): atender_('Medellín,_Antioquia',_'Aguadas,_Caldas'),
#  ('Medellín, Antioquia',
#   'Morales, Cauca'): atender_('Medellín,_Antioquia',_'Morales,_Cauca'),
#  ('Medellín, Antioquia',
#   'El Tambo, Cauca'): atender_('Medellín,_Antioquia',_'El_Tambo,_Cauca'),
#  ('Medellín, Antioquia',
#   'Bolívar, Cauca'): atender_('Medellín,_Antioquia',_'Bolívar,_Cauca'),
#  ('Medellín, Antioquia',
#   'Aguachica, Cesar'): atender_('Medellín,_Antioquia',_'Aguachica,_Cesar'),
#  ('Medellín, Antioquia',
#   'San Diego, Cesar'): atender_('Medellín,_Antioquia',_'San_Diego,_Cesar'),
#  ('Medellín, Antioquia',
#   'Caparrapí, Cundinamarca'): atender_('Medellín,_Antioquia',_'Caparrapí,_Cundinamarca'),
#  ('Medellín, Antioquia',
#   'Viotá, Cundinamarca'): atender_('Medellín,_Antioquia',_'Viotá,_Cundinamarca'),
#  ('Medellín, Antioquia',
#   'Sasaima, Cundinamarca'): atender_('Medellín,_Antioquia',_'Sasaima,_Cundinamarca'),
#  ('Medellín, Antioquia',
#   'Neiva, Huila'): atender_('Medellín,_Antioquia',_'Neiva,_Huila'),
#  ('Medellín, Antioquia',
#   'Pitalito, Huila'): atender_('Medellín,_Antioquia',_'Pitalito,_Huila'),
#  ('Medellín, Antioquia',
#   'Gigante, Huila'): atender_('Medellín,_Antioquia',_'Gigante,_Huila'),
#  ('Medellín, Antioquia',
#   'Santa Marta, Magdalena'): atender_('Medellín,_Antioquia',_'Santa_Marta,_Magdalena'),
#  ('Medellín, Antioquia',
#   'La Unión, Nariño'): atender_('Medellín,_Antioquia',_'La_Unión,_Nariño'),
#  ('Medellín, Antioquia',
#   'Pasto, Nariño'): atender_('Medellín,_Antioquia',_'Pasto,_Nariño'),
#  ('Medellín, Antioquia',
#   'Samaniego, Nariño'): atender_('Medellín,_Antioquia',_'Samaniego,_Nariño'),
#  ('Medellín, Antioquia',
#   'Sardinata, Norte de Santander'): atender_('Medellín,_Antioquia',_'Sardinata,_Norte_de_Santander'),
#  ('Medellín, Antioquia',
#   'Ocaña, Norte de Santander'): atender_('Medellín,_Antioquia',_'Ocaña,_Norte_de_Santander'),
#  ('Medellín, Antioquia',
#   'Convención, Norte de Santander'): atender_('Medellín,_Antioquia',_'Convención,_Norte_de_Santander'),
#  ('Medellín, Antioquia',
#   'Génova, Quindío'): atender_('Medellín,_Antioquia',_'Génova,_Quindío'),
#  ('Medellín, Antioquia',
#   'Calarcá, Quindío'): atender_('Medellín,_Antioquia',_'Calarcá,_Quindío'),
#  ('Medellín, Antioquia',
#   'Quimbaya, Quindío'): atender_('Medellín,_Antioquia',_'Quimbaya,_Quindío'),
#  ('Medellín, Antioquia',
#   'Pereira, Risaralda'): atender_('Medellín,_Antioquia',_'Pereira,_Risaralda'),
#  ('Medellín, Antioquia',
#   'Santuario, Risaralda'): atender_('Medellín,_Antioquia',_'Santuario,_Risaralda'),
#  ('Medellín, Antioquia',
#   'Belén de Umbria, Risaralda'): atender_('Medellín,_Antioquia',_'Belén_de_Umbria,_Risaralda'),
#  ('Medellín, Antioquia',
#   'Rionegro, Santander'): atender_('Medellín,_Antioquia',_'Rionegro,_Santander'),
#  ('Medellín, Antioquia',
#   'Bucaramanga, Santander'): atender_('Medellín,_Antioquia',_'Bucaramanga,_Santander'),
#  ('Medellín, Antioquia',
#   'Barbosa, Santander'): atender_('Medellín,_Antioquia',_'Barbosa,_Santander'),
#  ('Medellín, Antioquia',
#   'Socorro, Santander'): atender_('Medellín,_Antioquia',_'Socorro,_Santander'),
#  ('Medellín, Antioquia',
#   'Simacota, Santander'): atender_('Medellín,_Antioquia',_'Simacota,_Santander'),
#  ('Medellín, Antioquia',
#   'Chaparral, Tolima'): atender_('Medellín,_Antioquia',_'Chaparral,_Tolima'),
#  ('Medellín, Antioquia',
#   'Dolores, Tolima'): atender_('Medellín,_Antioquia',_'Dolores,_Tolima'),
#  ('Medellín, Antioquia',
#   'Ibagué, Tolima'): atender_('Medellín,_Antioquia',_'Ibagué,_Tolima'),
#  ('Medellín, Antioquia',
#   'Líbano, Tolima'): atender_('Medellín,_Antioquia',_'Líbano,_Tolima'),
#  ('Medellín, Antioquia',
#   'Cartago, Valle'): atender_('Medellín,_Antioquia',_'Cartago,_Valle'),
#  ('Medellín, Antioquia',
#   'Tulua, Valle'): atender_('Medellín,_Antioquia',_'Tulua,_Valle'),
#  ('Medellín, Antioquia',
#   'Jamundí, Valle'): atender_('Medellín,_Antioquia',_'Jamundí,_Valle'),
#  ('Medellín, Antioquia',
#   'Sevilla, Valle'): atender_('Medellín,_Antioquia',_'Sevilla,_Valle'),
#  ('Medellín, Antioquia',
#   'Caicedonia, Valle'): atender_('Medellín,_Antioquia',_'Caicedonia,_Valle'),
#  ('Medellín, Antioquia',
#   'Florencia, Caquetá'): atender_('Medellín,_Antioquia',_'Florencia,_Caquetá'),
#  ('Medellín, Antioquia',
#   'Puerto Milán, Caquetá'): atender_('Medellín,_Antioquia',_'Puerto_Milán,_Caquetá'),
#  ('Medellín, Antioquia',
#   'Nunchía, Casanare'): atender_('Medellín,_Antioquia',_'Nunchía,_Casanare'),
#  ('Medellín, Antioquia',
#   'Mesetas, Meta'): atender_('Medellín,_Antioquia',_'Mesetas,_Meta'),
#  ('La Dorada, Caldas ',
#   'Andes, Antioquia'): atender_('La_Dorada,_Caldas_',_'Andes,_Antioquia'),
#  ('La Dorada, Caldas ',
#   'Medellín, Antioquia'): atender_('La_Dorada,_Caldas_',_'Medellín,_Antioquia'),
#  ('La Dorada, Caldas ',
#   'Dabeiba, Antioquia'): atender_('La_Dorada,_Caldas_',_'Dabeiba,_Antioquia'),
#  ('La Dorada, Caldas ',
#   'Salgar, Antioquia'): atender_('La_Dorada,_Caldas_',_'Salgar,_Antioquia'),
#  ('La Dorada, Caldas ',
#   'San Pablo de Borbur, Boyacá'): atender_('La_Dorada,_Caldas_',_'San_Pablo_de_Borbur,_Boyacá'),
#  ('La Dorada, Caldas ',
#   'Labranzagrande, Boyacá'): atender_('La_Dorada,_Caldas_',_'Labranzagrande,_Boyacá'),
#  ('La Dorada, Caldas ',
#   'Miraflores, Boyacá'): atender_('La_Dorada,_Caldas_',_'Miraflores,_Boyacá'),
#  ('La Dorada, Caldas ',
#   'Moniquirá, Boyacá'): atender_('La_Dorada,_Caldas_',_'Moniquirá,_Boyacá'),
#  ('La Dorada, Caldas ',
#   'Manizales, Caldas'): atender_('La_Dorada,_Caldas_',_'Manizales,_Caldas'),
#  ('La Dorada, Caldas ',
#   'Anserma, Caldas'): atender_('La_Dorada,_Caldas_',_'Anserma,_Caldas'),
#  ('La Dorada, Caldas ',
#   'Pensilvania, Caldas'): atender_('La_Dorada,_Caldas_',_'Pensilvania,_Caldas'),
#  ('La Dorada, Caldas ',
#   'Riosucio, Caldas'): atender_('La_Dorada,_Caldas_',_'Riosucio,_Caldas'),
#  ('La Dorada, Caldas ',
#   'Aguadas, Caldas'): atender_('La_Dorada,_Caldas_',_'Aguadas,_Caldas'),
#  ('La Dorada, Caldas ',
#   'Morales, Cauca'): atender_('La_Dorada,_Caldas_',_'Morales,_Cauca'),
#  ('La Dorada, Caldas ',
#   'El Tambo, Cauca'): atender_('La_Dorada,_Caldas_',_'El_Tambo,_Cauca'),
#  ('La Dorada, Caldas ',
#   'Bolívar, Cauca'): atender_('La_Dorada,_Caldas_',_'Bolívar,_Cauca'),
#  ('La Dorada, Caldas ',
#   'Aguachica, Cesar'): atender_('La_Dorada,_Caldas_',_'Aguachica,_Cesar'),
#  ('La Dorada, Caldas ',
#   'San Diego, Cesar'): atender_('La_Dorada,_Caldas_',_'San_Diego,_Cesar'),
#  ('La Dorada, Caldas ',
#   'Caparrapí, Cundinamarca'): atender_('La_Dorada,_Caldas_',_'Caparrapí,_Cundinamarca'),
#  ('La Dorada, Caldas ',
#   'Viotá, Cundinamarca'): atender_('La_Dorada,_Caldas_',_'Viotá,_Cundinamarca'),
#  ('La Dorada, Caldas ',
#   'Sasaima, Cundinamarca'): atender_('La_Dorada,_Caldas_',_'Sasaima,_Cundinamarca'),
#  ('La Dorada, Caldas ',
#   'Neiva, Huila'): atender_('La_Dorada,_Caldas_',_'Neiva,_Huila'),
#  ('La Dorada, Caldas ',
#   'Pitalito, Huila'): atender_('La_Dorada,_Caldas_',_'Pitalito,_Huila'),
#  ('La Dorada, Caldas ',
#   'Gigante, Huila'): atender_('La_Dorada,_Caldas_',_'Gigante,_Huila'),
#  ('La Dorada, Caldas ',
#   'Santa Marta, Magdalena'): atender_('La_Dorada,_Caldas_',_'Santa_Marta,_Magdalena'),
#  ('La Dorada, Caldas ',
#   'La Unión, Nariño'): atender_('La_Dorada,_Caldas_',_'La_Unión,_Nariño'),
#  ('La Dorada, Caldas ',
#   'Pasto, Nariño'): atender_('La_Dorada,_Caldas_',_'Pasto,_Nariño'),
#  ('La Dorada, Caldas ',
#   'Samaniego, Nariño'): atender_('La_Dorada,_Caldas_',_'Samaniego,_Nariño'),
#  ('La Dorada, Caldas ',
#   'Sardinata, Norte de Santander'): atender_('La_Dorada,_Caldas_',_'Sardinata,_Norte_de_Santander'),
#  ('La Dorada, Caldas ',
#   'Ocaña, Norte de Santander'): atender_('La_Dorada,_Caldas_',_'Ocaña,_Norte_de_Santander'),
#  ('La Dorada, Caldas ',
#   'Convención, Norte de Santander'): atender_('La_Dorada,_Caldas_',_'Convención,_Norte_de_Santander'),
#  ('La Dorada, Caldas ',
#   'Génova, Quindío'): atender_('La_Dorada,_Caldas_',_'Génova,_Quindío'),
#  ('La Dorada, Caldas ',
#   'Calarcá, Quindío'): atender_('La_Dorada,_Caldas_',_'Calarcá,_Quindío'),
#  ('La Dorada, Caldas ',
#   'Quimbaya, Quindío'): atender_('La_Dorada,_Caldas_',_'Quimbaya,_Quindío'),
#  ('La Dorada, Caldas ',
#   'Pereira, Risaralda'): atender_('La_Dorada,_Caldas_',_'Pereira,_Risaralda'),
#  ('La Dorada, Caldas ',
#   'Santuario, Risaralda'): atender_('La_Dorada,_Caldas_',_'Santuario,_Risaralda'),
#  ('La Dorada, Caldas ',
#   'Belén de Umbria, Risaralda'): atender_('La_Dorada,_Caldas_',_'Belén_de_Umbria,_Risaralda'),
#  ('La Dorada, Caldas ',
#   'Rionegro, Santander'): atender_('La_Dorada,_Caldas_',_'Rionegro,_Santander'),
#  ('La Dorada, Caldas ',
#   'Bucaramanga, Santander'): atender_('La_Dorada,_Caldas_',_'Bucaramanga,_Santander'),
#  ('La Dorada, Caldas ',
#   'Barbosa, Santander'): atender_('La_Dorada,_Caldas_',_'Barbosa,_Santander'),
#  ('La Dorada, Caldas ',
#   'Socorro, Santander'): atender_('La_Dorada,_Caldas_',_'Socorro,_Santander'),
#  ('La Dorada, Caldas ',
#   'Simacota, Santander'): atender_('La_Dorada,_Caldas_',_'Simacota,_Santander'),
#  ('La Dorada, Caldas ',
#   'Chaparral, Tolima'): atender_('La_Dorada,_Caldas_',_'Chaparral,_Tolima'),
#  ('La Dorada, Caldas ',
#   'Dolores, Tolima'): atender_('La_Dorada,_Caldas_',_'Dolores,_Tolima'),
#  ('La Dorada, Caldas ',
#   'Ibagué, Tolima'): atender_('La_Dorada,_Caldas_',_'Ibagué,_Tolima'),
#  ('La Dorada, Caldas ',
#   'Líbano, Tolima'): atender_('La_Dorada,_Caldas_',_'Líbano,_Tolima'),
#  ('La Dorada, Caldas ',
#   'Cartago, Valle'): atender_('La_Dorada,_Caldas_',_'Cartago,_Valle'),
#  ('La Dorada, Caldas ',
#   'Tulua, Valle'): atender_('La_Dorada,_Caldas_',_'Tulua,_Valle'),
#  ('La Dorada, Caldas ',
#   'Jamundí, Valle'): atender_('La_Dorada,_Caldas_',_'Jamundí,_Valle'),
#  ('La Dorada, Caldas ',
#   'Sevilla, Valle'): atender_('La_Dorada,_Caldas_',_'Sevilla,_Valle'),
#  ('La Dorada, Caldas ',
#   'Caicedonia, Valle'): atender_('La_Dorada,_Caldas_',_'Caicedonia,_Valle'),
#  ('La Dorada, Caldas ',
#   'Florencia, Caquetá'): atender_('La_Dorada,_Caldas_',_'Florencia,_Caquetá'),
#  ('La Dorada, Caldas ',
#   'Puerto Milán, Caquetá'): atender_('La_Dorada,_Caldas_',_'Puerto_Milán,_Caquetá'),
#  ('La Dorada, Caldas ',
#   'Nunchía, Casanare'): atender_('La_Dorada,_Caldas_',_'Nunchía,_Casanare'),
#  ('La Dorada, Caldas ',
#   'Mesetas, Meta'): atender_('La_Dorada,_Caldas_',_'Mesetas,_Meta'),
#  ('Aguadas, Caldas',
#   'Andes, Antioquia'): atender_('Aguadas,_Caldas',_'Andes,_Antioquia'),
#  ('Aguadas, Caldas',
#   'Medellín, Antioquia'): atender_('Aguadas,_Caldas',_'Medellín,_Antioquia'),
#  ('Aguadas, Caldas',
#   'Dabeiba, Antioquia'): atender_('Aguadas,_Caldas',_'Dabeiba,_Antioquia'),
#  ('Aguadas, Caldas',
#   'Salgar, Antioquia'): atender_('Aguadas,_Caldas',_'Salgar,_Antioquia'),
#  ('Aguadas, Caldas',
#   'San Pablo de Borbur, Boyacá'): atender_('Aguadas,_Caldas',_'San_Pablo_de_Borbur,_Boyacá'),
#  ('Aguadas, Caldas',
#   'Labranzagrande, Boyacá'): atender_('Aguadas,_Caldas',_'Labranzagrande,_Boyacá'),
#  ('Aguadas, Caldas',
#   'Miraflores, Boyacá'): atender_('Aguadas,_Caldas',_'Miraflores,_Boyacá'),
#  ('Aguadas, Caldas',
#   'Moniquirá, Boyacá'): atender_('Aguadas,_Caldas',_'Moniquirá,_Boyacá'),
#  ('Aguadas, Caldas',
#   'Manizales, Caldas'): atender_('Aguadas,_Caldas',_'Manizales,_Caldas'),
#  ('Aguadas, Caldas',
#   'Anserma, Caldas'): atender_('Aguadas,_Caldas',_'Anserma,_Caldas'),
#  ('Aguadas, Caldas',
#   'Pensilvania, Caldas'): atender_('Aguadas,_Caldas',_'Pensilvania,_Caldas'),
#  ('Aguadas, Caldas',
#   'Riosucio, Caldas'): atender_('Aguadas,_Caldas',_'Riosucio,_Caldas'),
#  ('Aguadas, Caldas',
#   'Aguadas, Caldas'): atender_('Aguadas,_Caldas',_'Aguadas,_Caldas'),
#  ('Aguadas, Caldas',
#   'Morales, Cauca'): atender_('Aguadas,_Caldas',_'Morales,_Cauca'),
#  ('Aguadas, Caldas',
#   'El Tambo, Cauca'): atender_('Aguadas,_Caldas',_'El_Tambo,_Cauca'),
#  ('Aguadas, Caldas',
#   'Bolívar, Cauca'): atender_('Aguadas,_Caldas',_'Bolívar,_Cauca'),
#  ('Aguadas, Caldas',
#   'Aguachica, Cesar'): atender_('Aguadas,_Caldas',_'Aguachica,_Cesar'),
#  ('Aguadas, Caldas',
#   'San Diego, Cesar'): atender_('Aguadas,_Caldas',_'San_Diego,_Cesar'),
#  ('Aguadas, Caldas',
#   'Caparrapí, Cundinamarca'): atender_('Aguadas,_Caldas',_'Caparrapí,_Cundinamarca'),
#  ('Aguadas, Caldas',
#   'Viotá, Cundinamarca'): atender_('Aguadas,_Caldas',_'Viotá,_Cundinamarca'),
#  ('Aguadas, Caldas',
#   'Sasaima, Cundinamarca'): atender_('Aguadas,_Caldas',_'Sasaima,_Cundinamarca'),
#  ('Aguadas, Caldas',
#   'Neiva, Huila'): atender_('Aguadas,_Caldas',_'Neiva,_Huila'),
#  ('Aguadas, Caldas',
#   'Pitalito, Huila'): atender_('Aguadas,_Caldas',_'Pitalito,_Huila'),
#  ('Aguadas, Caldas',
#   'Gigante, Huila'): atender_('Aguadas,_Caldas',_'Gigante,_Huila'),
#  ('Aguadas, Caldas',
#   'Santa Marta, Magdalena'): atender_('Aguadas,_Caldas',_'Santa_Marta,_Magdalena'),
#  ('Aguadas, Caldas',
#   'La Unión, Nariño'): atender_('Aguadas,_Caldas',_'La_Unión,_Nariño'),
#  ('Aguadas, Caldas',
#   'Pasto, Nariño'): atender_('Aguadas,_Caldas',_'Pasto,_Nariño'),
#  ('Aguadas, Caldas',
#   'Samaniego, Nariño'): atender_('Aguadas,_Caldas',_'Samaniego,_Nariño'),
#  ('Aguadas, Caldas',
#   'Sardinata, Norte de Santander'): atender_('Aguadas,_Caldas',_'Sardinata,_Norte_de_Santander'),
#  ('Aguadas, Caldas',
#   'Ocaña, Norte de Santander'): atender_('Aguadas,_Caldas',_'Ocaña,_Norte_de_Santander'),
#  ('Aguadas, Caldas',
#   'Convención, Norte de Santander'): atender_('Aguadas,_Caldas',_'Convención,_Norte_de_Santander'),
#  ('Aguadas, Caldas',
#   'Génova, Quindío'): atender_('Aguadas,_Caldas',_'Génova,_Quindío'),
#  ('Aguadas, Caldas',
#   'Calarcá, Quindío'): atender_('Aguadas,_Caldas',_'Calarcá,_Quindío'),
#  ('Aguadas, Caldas',
#   'Quimbaya, Quindío'): atender_('Aguadas,_Caldas',_'Quimbaya,_Quindío'),
#  ('Aguadas, Caldas',
#   'Pereira, Risaralda'): atender_('Aguadas,_Caldas',_'Pereira,_Risaralda'),
#  ('Aguadas, Caldas',
#   'Santuario, Risaralda'): atender_('Aguadas,_Caldas',_'Santuario,_Risaralda'),
#  ('Aguadas, Caldas',
#   'Belén de Umbria, Risaralda'): atender_('Aguadas,_Caldas',_'Belén_de_Umbria,_Risaralda'),
#  ('Aguadas, Caldas',
#   'Rionegro, Santander'): atender_('Aguadas,_Caldas',_'Rionegro,_Santander'),
#  ('Aguadas, Caldas',
#   'Bucaramanga, Santander'): atender_('Aguadas,_Caldas',_'Bucaramanga,_Santander'),
#  ('Aguadas, Caldas',
#   'Barbosa, Santander'): atender_('Aguadas,_Caldas',_'Barbosa,_Santander'),
#  ('Aguadas, Caldas',
#   'Socorro, Santander'): atender_('Aguadas,_Caldas',_'Socorro,_Santander'),
#  ('Aguadas, Caldas',
#   'Simacota, Santander'): atender_('Aguadas,_Caldas',_'Simacota,_Santander'),
#  ('Aguadas, Caldas',
#   'Chaparral, Tolima'): atender_('Aguadas,_Caldas',_'Chaparral,_Tolima'),
#  ('Aguadas, Caldas',
#   'Dolores, Tolima'): atender_('Aguadas,_Caldas',_'Dolores,_Tolima'),
#  ('Aguadas, Caldas',
#   'Ibagué, Tolima'): atender_('Aguadas,_Caldas',_'Ibagué,_Tolima'),
#  ('Aguadas, Caldas',
#   'Líbano, Tolima'): atender_('Aguadas,_Caldas',_'Líbano,_Tolima'),
#  ('Aguadas, Caldas',
#   'Cartago, Valle'): atender_('Aguadas,_Caldas',_'Cartago,_Valle'),
#  ('Aguadas, Caldas',
#   'Tulua, Valle'): atender_('Aguadas,_Caldas',_'Tulua,_Valle'),
#  ('Aguadas, Caldas',
#   'Jamundí, Valle'): atender_('Aguadas,_Caldas',_'Jamundí,_Valle'),
#  ('Aguadas, Caldas',
#   'Sevilla, Valle'): atender_('Aguadas,_Caldas',_'Sevilla,_Valle'),
#  ('Aguadas, Caldas',
#   'Caicedonia, Valle'): atender_('Aguadas,_Caldas',_'Caicedonia,_Valle'),
#  ('Aguadas, Caldas',
#   'Florencia, Caquetá'): atender_('Aguadas,_Caldas',_'Florencia,_Caquetá'),
#  ('Aguadas, Caldas',
#   'Puerto Milán, Caquetá'): atender_('Aguadas,_Caldas',_'Puerto_Milán,_Caquetá'),
#  ('Aguadas, Caldas',
#   'Nunchía, Casanare'): atender_('Aguadas,_Caldas',_'Nunchía,_Casanare'),
#  ('Aguadas, Caldas',
#   'Mesetas, Meta'): atender_('Aguadas,_Caldas',_'Mesetas,_Meta'),
#  ('Salamina, Caldas',
#   'Andes, Antioquia'): atender_('Salamina,_Caldas',_'Andes,_Antioquia'),
#  ('Salamina, Caldas',
#   'Medellín, Antioquia'): atender_('Salamina,_Caldas',_'Medellín,_Antioquia'),
#  ('Salamina, Caldas',
#   'Dabeiba, Antioquia'): atender_('Salamina,_Caldas',_'Dabeiba,_Antioquia'),
#  ('Salamina, Caldas',
#   'Salgar, Antioquia'): atender_('Salamina,_Caldas',_'Salgar,_Antioquia'),
#  ('Salamina, Caldas',
#   'San Pablo de Borbur, Boyacá'): atender_('Salamina,_Caldas',_'San_Pablo_de_Borbur,_Boyacá'),
#  ('Salamina, Caldas',
#   'Labranzagrande, Boyacá'): atender_('Salamina,_Caldas',_'Labranzagrande,_Boyacá'),
#  ('Salamina, Caldas',
#   'Miraflores, Boyacá'): atender_('Salamina,_Caldas',_'Miraflores,_Boyacá'),
#  ('Salamina, Caldas',
#   'Moniquirá, Boyacá'): atender_('Salamina,_Caldas',_'Moniquirá,_Boyacá'),
#  ('Salamina, Caldas',
#   'Manizales, Caldas'): atender_('Salamina,_Caldas',_'Manizales,_Caldas'),
#  ('Salamina, Caldas',
#   'Anserma, Caldas'): atender_('Salamina,_Caldas',_'Anserma,_Caldas'),
#  ('Salamina, Caldas',
#   'Pensilvania, Caldas'): atender_('Salamina,_Caldas',_'Pensilvania,_Caldas'),
#  ('Salamina, Caldas',
#   'Riosucio, Caldas'): atender_('Salamina,_Caldas',_'Riosucio,_Caldas'),
#  ('Salamina, Caldas',
#   'Aguadas, Caldas'): atender_('Salamina,_Caldas',_'Aguadas,_Caldas'),
#  ('Salamina, Caldas',
#   'Morales, Cauca'): atender_('Salamina,_Caldas',_'Morales,_Cauca'),
#  ('Salamina, Caldas',
#   'El Tambo, Cauca'): atender_('Salamina,_Caldas',_'El_Tambo,_Cauca'),
#  ('Salamina, Caldas',
#   'Bolívar, Cauca'): atender_('Salamina,_Caldas',_'Bolívar,_Cauca'),
#  ('Salamina, Caldas',
#   'Aguachica, Cesar'): atender_('Salamina,_Caldas',_'Aguachica,_Cesar'),
#  ('Salamina, Caldas',
#   'San Diego, Cesar'): atender_('Salamina,_Caldas',_'San_Diego,_Cesar'),
#  ('Salamina, Caldas',
#   'Caparrapí, Cundinamarca'): atender_('Salamina,_Caldas',_'Caparrapí,_Cundinamarca'),
#  ('Salamina, Caldas',
#   'Viotá, Cundinamarca'): atender_('Salamina,_Caldas',_'Viotá,_Cundinamarca'),
#  ('Salamina, Caldas',
#   'Sasaima, Cundinamarca'): atender_('Salamina,_Caldas',_'Sasaima,_Cundinamarca'),
#  ('Salamina, Caldas',
#   'Neiva, Huila'): atender_('Salamina,_Caldas',_'Neiva,_Huila'),
#  ('Salamina, Caldas',
#   'Pitalito, Huila'): atender_('Salamina,_Caldas',_'Pitalito,_Huila'),
#  ('Salamina, Caldas',
#   'Gigante, Huila'): atender_('Salamina,_Caldas',_'Gigante,_Huila'),
#  ('Salamina, Caldas',
#   'Santa Marta, Magdalena'): atender_('Salamina,_Caldas',_'Santa_Marta,_Magdalena'),
#  ('Salamina, Caldas',
#   'La Unión, Nariño'): atender_('Salamina,_Caldas',_'La_Unión,_Nariño'),
#  ('Salamina, Caldas',
#   'Pasto, Nariño'): atender_('Salamina,_Caldas',_'Pasto,_Nariño'),
#  ('Salamina, Caldas',
#   'Samaniego, Nariño'): atender_('Salamina,_Caldas',_'Samaniego,_Nariño'),
#  ('Salamina, Caldas',
#   'Sardinata, Norte de Santander'): atender_('Salamina,_Caldas',_'Sardinata,_Norte_de_Santander'),
#  ('Salamina, Caldas',
#   'Ocaña, Norte de Santander'): atender_('Salamina,_Caldas',_'Ocaña,_Norte_de_Santander'),
#  ('Salamina, Caldas',
#   'Convención, Norte de Santander'): atender_('Salamina,_Caldas',_'Convención,_Norte_de_Santander'),
#  ('Salamina, Caldas',
#   'Génova, Quindío'): atender_('Salamina,_Caldas',_'Génova,_Quindío'),
#  ('Salamina, Caldas',
#   'Calarcá, Quindío'): atender_('Salamina,_Caldas',_'Calarcá,_Quindío'),
#  ('Salamina, Caldas',
#   'Quimbaya, Quindío'): atender_('Salamina,_Caldas',_'Quimbaya,_Quindío'),
#  ('Salamina, Caldas',
#   'Pereira, Risaralda'): atender_('Salamina,_Caldas',_'Pereira,_Risaralda'),
#  ('Salamina, Caldas',
#   'Santuario, Risaralda'): atender_('Salamina,_Caldas',_'Santuario,_Risaralda'),
#  ('Salamina, Caldas',
#   'Belén de Umbria, Risaralda'): atender_('Salamina,_Caldas',_'Belén_de_Umbria,_Risaralda'),
#  ('Salamina, Caldas',
#   'Rionegro, Santander'): atender_('Salamina,_Caldas',_'Rionegro,_Santander'),
#  ('Salamina, Caldas',
#   'Bucaramanga, Santander'): atender_('Salamina,_Caldas',_'Bucaramanga,_Santander'),
#  ('Salamina, Caldas',
#   'Barbosa, Santander'): atender_('Salamina,_Caldas',_'Barbosa,_Santander'),
#  ('Salamina, Caldas',
#   'Socorro, Santander'): atender_('Salamina,_Caldas',_'Socorro,_Santander'),
#  ('Salamina, Caldas',
#   'Simacota, Santander'): atender_('Salamina,_Caldas',_'Simacota,_Santander'),
#  ('Salamina, Caldas',
#   'Chaparral, Tolima'): atender_('Salamina,_Caldas',_'Chaparral,_Tolima'),
#  ('Salamina, Caldas',
#   'Dolores, Tolima'): atender_('Salamina,_Caldas',_'Dolores,_Tolima'),
#  ('Salamina, Caldas',
#   'Ibagué, Tolima'): atender_('Salamina,_Caldas',_'Ibagué,_Tolima'),
#  ('Salamina, Caldas',
#   'Líbano, Tolima'): atender_('Salamina,_Caldas',_'Líbano,_Tolima'),
#  ('Salamina, Caldas',
#   'Cartago, Valle'): atender_('Salamina,_Caldas',_'Cartago,_Valle'),
#  ('Salamina, Caldas',
#   'Tulua, Valle'): atender_('Salamina,_Caldas',_'Tulua,_Valle'),
#  ('Salamina, Caldas',
#   'Jamundí, Valle'): atender_('Salamina,_Caldas',_'Jamundí,_Valle'),
#  ('Salamina, Caldas',
#   'Sevilla, Valle'): atender_('Salamina,_Caldas',_'Sevilla,_Valle'),
#  ('Salamina, Caldas',
#   'Caicedonia, Valle'): atender_('Salamina,_Caldas',_'Caicedonia,_Valle'),
#  ('Salamina, Caldas',
#   'Florencia, Caquetá'): atender_('Salamina,_Caldas',_'Florencia,_Caquetá'),
#  ('Salamina, Caldas',
#   'Puerto Milán, Caquetá'): atender_('Salamina,_Caldas',_'Puerto_Milán,_Caquetá'),
#  ('Salamina, Caldas',
#   'Nunchía, Casanare'): atender_('Salamina,_Caldas',_'Nunchía,_Casanare'),
#  ('Salamina, Caldas',
#   'Mesetas, Meta'): atender_('Salamina,_Caldas',_'Mesetas,_Meta'),
#  ('Popayán, Cauca',
#   'Andes, Antioquia'): atender_('Popayán,_Cauca',_'Andes,_Antioquia'),
#  ('Popayán, Cauca',
#   'Medellín, Antioquia'): atender_('Popayán,_Cauca',_'Medellín,_Antioquia'),
#  ('Popayán, Cauca',
#   'Dabeiba, Antioquia'): atender_('Popayán,_Cauca',_'Dabeiba,_Antioquia'),
#  ('Popayán, Cauca',
#   'Salgar, Antioquia'): atender_('Popayán,_Cauca',_'Salgar,_Antioquia'),
#  ('Popayán, Cauca',
#   'San Pablo de Borbur, Boyacá'): atender_('Popayán,_Cauca',_'San_Pablo_de_Borbur,_Boyacá'),
#  ('Popayán, Cauca',
#   'Labranzagrande, Boyacá'): atender_('Popayán,_Cauca',_'Labranzagrande,_Boyacá'),
#  ('Popayán, Cauca',
#   'Miraflores, Boyacá'): atender_('Popayán,_Cauca',_'Miraflores,_Boyacá'),
#  ('Popayán, Cauca',
#   'Moniquirá, Boyacá'): atender_('Popayán,_Cauca',_'Moniquirá,_Boyacá'),
#  ('Popayán, Cauca',
#   'Manizales, Caldas'): atender_('Popayán,_Cauca',_'Manizales,_Caldas'),
#  ('Popayán, Cauca',
#   'Anserma, Caldas'): atender_('Popayán,_Cauca',_'Anserma,_Caldas'),
#  ('Popayán, Cauca',
#   'Pensilvania, Caldas'): atender_('Popayán,_Cauca',_'Pensilvania,_Caldas'),
#  ('Popayán, Cauca',
#   'Riosucio, Caldas'): atender_('Popayán,_Cauca',_'Riosucio,_Caldas'),
#  ('Popayán, Cauca',
#   'Aguadas, Caldas'): atender_('Popayán,_Cauca',_'Aguadas,_Caldas'),
#  ('Popayán, Cauca',
#   'Morales, Cauca'): atender_('Popayán,_Cauca',_'Morales,_Cauca'),
#  ('Popayán, Cauca',
#   'El Tambo, Cauca'): atender_('Popayán,_Cauca',_'El_Tambo,_Cauca'),
#  ('Popayán, Cauca',
#   'Bolívar, Cauca'): atender_('Popayán,_Cauca',_'Bolívar,_Cauca'),
#  ('Popayán, Cauca',
#   'Aguachica, Cesar'): atender_('Popayán,_Cauca',_'Aguachica,_Cesar'),
#  ('Popayán, Cauca',
#   'San Diego, Cesar'): atender_('Popayán,_Cauca',_'San_Diego,_Cesar'),
#  ('Popayán, Cauca',
#   'Caparrapí, Cundinamarca'): atender_('Popayán,_Cauca',_'Caparrapí,_Cundinamarca'),
#  ('Popayán, Cauca',
#   'Viotá, Cundinamarca'): atender_('Popayán,_Cauca',_'Viotá,_Cundinamarca'),
#  ('Popayán, Cauca',
#   'Sasaima, Cundinamarca'): atender_('Popayán,_Cauca',_'Sasaima,_Cundinamarca'),
#  ('Popayán, Cauca',
#   'Neiva, Huila'): atender_('Popayán,_Cauca',_'Neiva,_Huila'),
#  ('Popayán, Cauca',
#   'Pitalito, Huila'): atender_('Popayán,_Cauca',_'Pitalito,_Huila'),
#  ('Popayán, Cauca',
#   'Gigante, Huila'): atender_('Popayán,_Cauca',_'Gigante,_Huila'),
#  ('Popayán, Cauca',
#   'Santa Marta, Magdalena'): atender_('Popayán,_Cauca',_'Santa_Marta,_Magdalena'),
#  ('Popayán, Cauca',
#   'La Unión, Nariño'): atender_('Popayán,_Cauca',_'La_Unión,_Nariño'),
#  ('Popayán, Cauca',
#   'Pasto, Nariño'): atender_('Popayán,_Cauca',_'Pasto,_Nariño'),
#  ('Popayán, Cauca',
#   'Samaniego, Nariño'): atender_('Popayán,_Cauca',_'Samaniego,_Nariño'),
#  ('Popayán, Cauca',
#   'Sardinata, Norte de Santander'): atender_('Popayán,_Cauca',_'Sardinata,_Norte_de_Santander'),
#  ('Popayán, Cauca',
#   'Ocaña, Norte de Santander'): atender_('Popayán,_Cauca',_'Ocaña,_Norte_de_Santander'),
#  ('Popayán, Cauca',
#   'Convención, Norte de Santander'): atender_('Popayán,_Cauca',_'Convención,_Norte_de_Santander'),
#  ('Popayán, Cauca',
#   'Génova, Quindío'): atender_('Popayán,_Cauca',_'Génova,_Quindío'),
#  ('Popayán, Cauca',
#   'Calarcá, Quindío'): atender_('Popayán,_Cauca',_'Calarcá,_Quindío'),
#  ('Popayán, Cauca',
#   'Quimbaya, Quindío'): atender_('Popayán,_Cauca',_'Quimbaya,_Quindío'),
#  ('Popayán, Cauca',
#   'Pereira, Risaralda'): atender_('Popayán,_Cauca',_'Pereira,_Risaralda'),
#  ('Popayán, Cauca',
#   'Santuario, Risaralda'): atender_('Popayán,_Cauca',_'Santuario,_Risaralda'),
#  ('Popayán, Cauca',
#   'Belén de Umbria, Risaralda'): atender_('Popayán,_Cauca',_'Belén_de_Umbria,_Risaralda'),
#  ('Popayán, Cauca',
#   'Rionegro, Santander'): atender_('Popayán,_Cauca',_'Rionegro,_Santander'),
#  ('Popayán, Cauca',
#   'Bucaramanga, Santander'): atender_('Popayán,_Cauca',_'Bucaramanga,_Santander'),
#  ('Popayán, Cauca',
#   'Barbosa, Santander'): atender_('Popayán,_Cauca',_'Barbosa,_Santander'),
#  ('Popayán, Cauca',
#   'Socorro, Santander'): atender_('Popayán,_Cauca',_'Socorro,_Santander'),
#  ('Popayán, Cauca',
#   'Simacota, Santander'): atender_('Popayán,_Cauca',_'Simacota,_Santander'),
#  ('Popayán, Cauca',
#   'Chaparral, Tolima'): atender_('Popayán,_Cauca',_'Chaparral,_Tolima'),
#  ('Popayán, Cauca',
#   'Dolores, Tolima'): atender_('Popayán,_Cauca',_'Dolores,_Tolima'),
#  ('Popayán, Cauca',
#   'Ibagué, Tolima'): atender_('Popayán,_Cauca',_'Ibagué,_Tolima'),
#  ('Popayán, Cauca',
#   'Líbano, Tolima'): atender_('Popayán,_Cauca',_'Líbano,_Tolima'),
#  ('Popayán, Cauca',
#   'Cartago, Valle'): atender_('Popayán,_Cauca',_'Cartago,_Valle'),
#  ('Popayán, Cauca',
#   'Tulua, Valle'): atender_('Popayán,_Cauca',_'Tulua,_Valle'),
#  ('Popayán, Cauca',
#   'Jamundí, Valle'): atender_('Popayán,_Cauca',_'Jamundí,_Valle'),
#  ('Popayán, Cauca',
#   'Sevilla, Valle'): atender_('Popayán,_Cauca',_'Sevilla,_Valle'),
#  ('Popayán, Cauca',
#   'Caicedonia, Valle'): atender_('Popayán,_Cauca',_'Caicedonia,_Valle'),
#  ('Popayán, Cauca',
#   'Florencia, Caquetá'): atender_('Popayán,_Cauca',_'Florencia,_Caquetá'),
#  ('Popayán, Cauca',
#   'Puerto Milán, Caquetá'): atender_('Popayán,_Cauca',_'Puerto_Milán,_Caquetá'),
#  ('Popayán, Cauca',
#   'Nunchía, Casanare'): atender_('Popayán,_Cauca',_'Nunchía,_Casanare'),
#  ('Popayán, Cauca',
#   'Mesetas, Meta'): atender_('Popayán,_Cauca',_'Mesetas,_Meta'),
#  ('Valledupar, Cesar',
#   'Andes, Antioquia'): atender_('Valledupar,_Cesar',_'Andes,_Antioquia'),
#  ('Valledupar, Cesar',
#   'Medellín, Antioquia'): atender_('Valledupar,_Cesar',_'Medellín,_Antioquia'),
#  ('Valledupar, Cesar',
#   'Dabeiba, Antioquia'): atender_('Valledupar,_Cesar',_'Dabeiba,_Antioquia'),
#  ('Valledupar, Cesar',
#   'Salgar, Antioquia'): atender_('Valledupar,_Cesar',_'Salgar,_Antioquia'),
#  ('Valledupar, Cesar',
#   'San Pablo de Borbur, Boyacá'): atender_('Valledupar,_Cesar',_'San_Pablo_de_Borbur,_Boyacá'),
#  ('Valledupar, Cesar',
#   'Labranzagrande, Boyacá'): atender_('Valledupar,_Cesar',_'Labranzagrande,_Boyacá'),
#  ('Valledupar, Cesar',
#   'Miraflores, Boyacá'): atender_('Valledupar,_Cesar',_'Miraflores,_Boyacá'),
#  ('Valledupar, Cesar',
#   'Moniquirá, Boyacá'): atender_('Valledupar,_Cesar',_'Moniquirá,_Boyacá'),
#  ('Valledupar, Cesar',
#   'Manizales, Caldas'): atender_('Valledupar,_Cesar',_'Manizales,_Caldas'),
#  ('Valledupar, Cesar',
#   'Anserma, Caldas'): atender_('Valledupar,_Cesar',_'Anserma,_Caldas'),
#  ('Valledupar, Cesar',
#   'Pensilvania, Caldas'): atender_('Valledupar,_Cesar',_'Pensilvania,_Caldas'),
#  ('Valledupar, Cesar',
#   'Riosucio, Caldas'): atender_('Valledupar,_Cesar',_'Riosucio,_Caldas'),
#  ('Valledupar, Cesar',
#   'Aguadas, Caldas'): atender_('Valledupar,_Cesar',_'Aguadas,_Caldas'),
#  ('Valledupar, Cesar',
#   'Morales, Cauca'): atender_('Valledupar,_Cesar',_'Morales,_Cauca'),
#  ('Valledupar, Cesar',
#   'El Tambo, Cauca'): atender_('Valledupar,_Cesar',_'El_Tambo,_Cauca'),
#  ('Valledupar, Cesar',
#   'Bolívar, Cauca'): atender_('Valledupar,_Cesar',_'Bolívar,_Cauca'),
#  ('Valledupar, Cesar',
#   'Aguachica, Cesar'): atender_('Valledupar,_Cesar',_'Aguachica,_Cesar'),
#  ('Valledupar, Cesar',
#   'San Diego, Cesar'): atender_('Valledupar,_Cesar',_'San_Diego,_Cesar'),
#  ('Valledupar, Cesar',
#   'Caparrapí, Cundinamarca'): atender_('Valledupar,_Cesar',_'Caparrapí,_Cundinamarca'),
#  ('Valledupar, Cesar',
#   'Viotá, Cundinamarca'): atender_('Valledupar,_Cesar',_'Viotá,_Cundinamarca'),
#  ('Valledupar, Cesar',
#   'Sasaima, Cundinamarca'): atender_('Valledupar,_Cesar',_'Sasaima,_Cundinamarca'),
#  ('Valledupar, Cesar',
#   'Neiva, Huila'): atender_('Valledupar,_Cesar',_'Neiva,_Huila'),
#  ('Valledupar, Cesar',
#   'Pitalito, Huila'): atender_('Valledupar,_Cesar',_'Pitalito,_Huila'),
#  ('Valledupar, Cesar',
#   'Gigante, Huila'): atender_('Valledupar,_Cesar',_'Gigante,_Huila'),
#  ('Valledupar, Cesar',
#   'Santa Marta, Magdalena'): atender_('Valledupar,_Cesar',_'Santa_Marta,_Magdalena'),
#  ('Valledupar, Cesar',
#   'La Unión, Nariño'): atender_('Valledupar,_Cesar',_'La_Unión,_Nariño'),
#  ('Valledupar, Cesar',
#   'Pasto, Nariño'): atender_('Valledupar,_Cesar',_'Pasto,_Nariño'),
#  ('Valledupar, Cesar',
#   'Samaniego, Nariño'): atender_('Valledupar,_Cesar',_'Samaniego,_Nariño'),
#  ('Valledupar, Cesar',
#   'Sardinata, Norte de Santander'): atender_('Valledupar,_Cesar',_'Sardinata,_Norte_de_Santander'),
#  ('Valledupar, Cesar',
#   'Ocaña, Norte de Santander'): atender_('Valledupar,_Cesar',_'Ocaña,_Norte_de_Santander'),
#  ('Valledupar, Cesar',
#   'Convención, Norte de Santander'): atender_('Valledupar,_Cesar',_'Convención,_Norte_de_Santander'),
#  ('Valledupar, Cesar',
#   'Génova, Quindío'): atender_('Valledupar,_Cesar',_'Génova,_Quindío'),
#  ('Valledupar, Cesar',
#   'Calarcá, Quindío'): atender_('Valledupar,_Cesar',_'Calarcá,_Quindío'),
#  ('Valledupar, Cesar',
#   'Quimbaya, Quindío'): atender_('Valledupar,_Cesar',_'Quimbaya,_Quindío'),
#  ('Valledupar, Cesar',
#   'Pereira, Risaralda'): atender_('Valledupar,_Cesar',_'Pereira,_Risaralda'),
#  ('Valledupar, Cesar',
#   'Santuario, Risaralda'): atender_('Valledupar,_Cesar',_'Santuario,_Risaralda'),
#  ('Valledupar, Cesar',
#   'Belén de Umbria, Risaralda'): atender_('Valledupar,_Cesar',_'Belén_de_Umbria,_Risaralda'),
#  ('Valledupar, Cesar',
#   'Rionegro, Santander'): atender_('Valledupar,_Cesar',_'Rionegro,_Santander'),
#  ('Valledupar, Cesar',
#   'Bucaramanga, Santander'): atender_('Valledupar,_Cesar',_'Bucaramanga,_Santander'),
#  ('Valledupar, Cesar',
#   'Barbosa, Santander'): atender_('Valledupar,_Cesar',_'Barbosa,_Santander'),
#  ('Valledupar, Cesar',
#   'Socorro, Santander'): atender_('Valledupar,_Cesar',_'Socorro,_Santander'),
#  ('Valledupar, Cesar',
#   'Simacota, Santander'): atender_('Valledupar,_Cesar',_'Simacota,_Santander'),
#  ('Valledupar, Cesar',
#   'Chaparral, Tolima'): atender_('Valledupar,_Cesar',_'Chaparral,_Tolima'),
#  ('Valledupar, Cesar',
#   'Dolores, Tolima'): atender_('Valledupar,_Cesar',_'Dolores,_Tolima'),
#  ('Valledupar, Cesar',
#   'Ibagué, Tolima'): atender_('Valledupar,_Cesar',_'Ibagué,_Tolima'),
#  ('Valledupar, Cesar',
#   'Líbano, Tolima'): atender_('Valledupar,_Cesar',_'Líbano,_Tolima'),
#  ('Valledupar, Cesar',
#   'Cartago, Valle'): atender_('Valledupar,_Cesar',_'Cartago,_Valle'),
#  ('Valledupar, Cesar',
#   'Tulua, Valle'): atender_('Valledupar,_Cesar',_'Tulua,_Valle'),
#  ('Valledupar, Cesar',
#   'Jamundí, Valle'): atender_('Valledupar,_Cesar',_'Jamundí,_Valle'),
#  ('Valledupar, Cesar',
#   'Sevilla, Valle'): atender_('Valledupar,_Cesar',_'Sevilla,_Valle'),
#  ('Valledupar, Cesar',
#   'Caicedonia, Valle'): atender_('Valledupar,_Cesar',_'Caicedonia,_Valle'),
#  ('Valledupar, Cesar',
#   'Florencia, Caquetá'): atender_('Valledupar,_Cesar',_'Florencia,_Caquetá'),
#  ('Valledupar, Cesar',
#   'Puerto Milán, Caquetá'): atender_('Valledupar,_Cesar',_'Puerto_Milán,_Caquetá'),
#  ('Valledupar, Cesar',
#   'Nunchía, Casanare'): atender_('Valledupar,_Cesar',_'Nunchía,_Casanare'),
#  ('Valledupar, Cesar',
#   'Mesetas, Meta'): atender_('Valledupar,_Cesar',_'Mesetas,_Meta'),
#  ('Bogotá, Cundinamarca',
#   'Andes, Antioquia'): atender_('Bogotá,_Cundinamarca',_'Andes,_Antioquia'),
#  ('Bogotá, Cundinamarca',
#   'Medellín, Antioquia'): atender_('Bogotá,_Cundinamarca',_'Medellín,_Antioquia'),
#  ('Bogotá, Cundinamarca',
#   'Dabeiba, Antioquia'): atender_('Bogotá,_Cundinamarca',_'Dabeiba,_Antioquia'),
#  ('Bogotá, Cundinamarca',
#   'Salgar, Antioquia'): atender_('Bogotá,_Cundinamarca',_'Salgar,_Antioquia'),
#  ('Bogotá, Cundinamarca',
#   'San Pablo de Borbur, Boyacá'): atender_('Bogotá,_Cundinamarca',_'San_Pablo_de_Borbur,_Boyacá'),
#  ('Bogotá, Cundinamarca',
#   'Labranzagrande, Boyacá'): atender_('Bogotá,_Cundinamarca',_'Labranzagrande,_Boyacá'),
#  ('Bogotá, Cundinamarca',
#   'Miraflores, Boyacá'): atender_('Bogotá,_Cundinamarca',_'Miraflores,_Boyacá'),
#  ('Bogotá, Cundinamarca',
#   'Moniquirá, Boyacá'): atender_('Bogotá,_Cundinamarca',_'Moniquirá,_Boyacá'),
#  ('Bogotá, Cundinamarca',
#   'Manizales, Caldas'): atender_('Bogotá,_Cundinamarca',_'Manizales,_Caldas'),
#  ('Bogotá, Cundinamarca',
#   'Anserma, Caldas'): atender_('Bogotá,_Cundinamarca',_'Anserma,_Caldas'),
#  ('Bogotá, Cundinamarca',
#   'Pensilvania, Caldas'): atender_('Bogotá,_Cundinamarca',_'Pensilvania,_Caldas'),
#  ('Bogotá, Cundinamarca',
#   'Riosucio, Caldas'): atender_('Bogotá,_Cundinamarca',_'Riosucio,_Caldas'),
#  ('Bogotá, Cundinamarca',
#   'Aguadas, Caldas'): atender_('Bogotá,_Cundinamarca',_'Aguadas,_Caldas'),
#  ('Bogotá, Cundinamarca',
#   'Morales, Cauca'): atender_('Bogotá,_Cundinamarca',_'Morales,_Cauca'),
#  ('Bogotá, Cundinamarca',
#   'El Tambo, Cauca'): atender_('Bogotá,_Cundinamarca',_'El_Tambo,_Cauca'),
#  ('Bogotá, Cundinamarca',
#   'Bolívar, Cauca'): atender_('Bogotá,_Cundinamarca',_'Bolívar,_Cauca'),
#  ('Bogotá, Cundinamarca',
#   'Aguachica, Cesar'): atender_('Bogotá,_Cundinamarca',_'Aguachica,_Cesar'),
#  ('Bogotá, Cundinamarca',
#   'San Diego, Cesar'): atender_('Bogotá,_Cundinamarca',_'San_Diego,_Cesar'),
#  ('Bogotá, Cundinamarca',
#   'Caparrapí, Cundinamarca'): atender_('Bogotá,_Cundinamarca',_'Caparrapí,_Cundinamarca'),
#  ('Bogotá, Cundinamarca',
#   'Viotá, Cundinamarca'): atender_('Bogotá,_Cundinamarca',_'Viotá,_Cundinamarca'),
#  ('Bogotá, Cundinamarca',
#   'Sasaima, Cundinamarca'): atender_('Bogotá,_Cundinamarca',_'Sasaima,_Cundinamarca'),
#  ('Bogotá, Cundinamarca',
#   'Neiva, Huila'): atender_('Bogotá,_Cundinamarca',_'Neiva,_Huila'),
#  ('Bogotá, Cundinamarca',
#   'Pitalito, Huila'): atender_('Bogotá,_Cundinamarca',_'Pitalito,_Huila'),
#  ('Bogotá, Cundinamarca',
#   'Gigante, Huila'): atender_('Bogotá,_Cundinamarca',_'Gigante,_Huila'),
#  ('Bogotá, Cundinamarca',
#   'Santa Marta, Magdalena'): atender_('Bogotá,_Cundinamarca',_'Santa_Marta,_Magdalena'),
#  ('Bogotá, Cundinamarca',
#   'La Unión, Nariño'): atender_('Bogotá,_Cundinamarca',_'La_Unión,_Nariño'),
#  ('Bogotá, Cundinamarca',
#   'Pasto, Nariño'): atender_('Bogotá,_Cundinamarca',_'Pasto,_Nariño'),
#  ('Bogotá, Cundinamarca',
#   'Samaniego, Nariño'): atender_('Bogotá,_Cundinamarca',_'Samaniego,_Nariño'),
#  ('Bogotá, Cundinamarca',
#   'Sardinata, Norte de Santander'): atender_('Bogotá,_Cundinamarca',_'Sardinata,_Norte_de_Santander'),
#  ('Bogotá, Cundinamarca',
#   'Ocaña, Norte de Santander'): atender_('Bogotá,_Cundinamarca',_'Ocaña,_Norte_de_Santander'),
#  ('Bogotá, Cundinamarca',
#   'Convención, Norte de Santander'): atender_('Bogotá,_Cundinamarca',_'Convención,_Norte_de_Santander'),
#  ('Bogotá, Cundinamarca',
#   'Génova, Quindío'): atender_('Bogotá,_Cundinamarca',_'Génova,_Quindío'),
#  ('Bogotá, Cundinamarca',
#   'Calarcá, Quindío'): atender_('Bogotá,_Cundinamarca',_'Calarcá,_Quindío'),
#  ('Bogotá, Cundinamarca',
#   'Quimbaya, Quindío'): atender_('Bogotá,_Cundinamarca',_'Quimbaya,_Quindío'),
#  ('Bogotá, Cundinamarca',
#   'Pereira, Risaralda'): atender_('Bogotá,_Cundinamarca',_'Pereira,_Risaralda'),
#  ('Bogotá, Cundinamarca',
#   'Santuario, Risaralda'): atender_('Bogotá,_Cundinamarca',_'Santuario,_Risaralda'),
#  ('Bogotá, Cundinamarca',
#   'Belén de Umbria, Risaralda'): atender_('Bogotá,_Cundinamarca',_'Belén_de_Umbria,_Risaralda'),
#  ('Bogotá, Cundinamarca',
#   'Rionegro, Santander'): atender_('Bogotá,_Cundinamarca',_'Rionegro,_Santander'),
#  ('Bogotá, Cundinamarca',
#   'Bucaramanga, Santander'): atender_('Bogotá,_Cundinamarca',_'Bucaramanga,_Santander'),
#  ('Bogotá, Cundinamarca',
#   'Barbosa, Santander'): atender_('Bogotá,_Cundinamarca',_'Barbosa,_Santander'),
#  ('Bogotá, Cundinamarca',
#   'Socorro, Santander'): atender_('Bogotá,_Cundinamarca',_'Socorro,_Santander'),
#  ('Bogotá, Cundinamarca',
#   'Simacota, Santander'): atender_('Bogotá,_Cundinamarca',_'Simacota,_Santander'),
#  ('Bogotá, Cundinamarca',
#   'Chaparral, Tolima'): atender_('Bogotá,_Cundinamarca',_'Chaparral,_Tolima'),
#  ('Bogotá, Cundinamarca',
#   'Dolores, Tolima'): atender_('Bogotá,_Cundinamarca',_'Dolores,_Tolima'),
#  ('Bogotá, Cundinamarca',
#   'Ibagué, Tolima'): atender_('Bogotá,_Cundinamarca',_'Ibagué,_Tolima'),
#  ('Bogotá, Cundinamarca',
#   'Líbano, Tolima'): atender_('Bogotá,_Cundinamarca',_'Líbano,_Tolima'),
#  ('Bogotá, Cundinamarca',
#   'Cartago, Valle'): atender_('Bogotá,_Cundinamarca',_'Cartago,_Valle'),
#  ('Bogotá, Cundinamarca',
#   'Tulua, Valle'): atender_('Bogotá,_Cundinamarca',_'Tulua,_Valle'),
#  ('Bogotá, Cundinamarca',
#   'Jamundí, Valle'): atender_('Bogotá,_Cundinamarca',_'Jamundí,_Valle'),
#  ('Bogotá, Cundinamarca',
#   'Sevilla, Valle'): atender_('Bogotá,_Cundinamarca',_'Sevilla,_Valle'),
#  ('Bogotá, Cundinamarca',
#   'Caicedonia, Valle'): atender_('Bogotá,_Cundinamarca',_'Caicedonia,_Valle'),
#  ('Bogotá, Cundinamarca',
#   'Florencia, Caquetá'): atender_('Bogotá,_Cundinamarca',_'Florencia,_Caquetá'),
#  ('Bogotá, Cundinamarca',
#   'Puerto Milán, Caquetá'): atender_('Bogotá,_Cundinamarca',_'Puerto_Milán,_Caquetá'),
#  ('Bogotá, Cundinamarca',
#   'Nunchía, Casanare'): atender_('Bogotá,_Cundinamarca',_'Nunchía,_Casanare'),
#  ('Bogotá, Cundinamarca',
#   'Mesetas, Meta'): atender_('Bogotá,_Cundinamarca',_'Mesetas,_Meta'),
#  ('Santana, Huila',
#   'Andes, Antioquia'): atender_('Santana,_Huila',_'Andes,_Antioquia'),
#  ('Santana, Huila',
#   'Medellín, Antioquia'): atender_('Santana,_Huila',_'Medellín,_Antioquia'),
#  ('Santana, Huila',
#   'Dabeiba, Antioquia'): atender_('Santana,_Huila',_'Dabeiba,_Antioquia'),
#  ('Santana, Huila',
#   'Salgar, Antioquia'): atender_('Santana,_Huila',_'Salgar,_Antioquia'),
#  ('Santana, Huila',
#   'San Pablo de Borbur, Boyacá'): atender_('Santana,_Huila',_'San_Pablo_de_Borbur,_Boyacá'),
#  ('Santana, Huila',
#   'Labranzagrande, Boyacá'): atender_('Santana,_Huila',_'Labranzagrande,_Boyacá'),
#  ('Santana, Huila',
#   'Miraflores, Boyacá'): atender_('Santana,_Huila',_'Miraflores,_Boyacá'),
#  ('Santana, Huila',
#   'Moniquirá, Boyacá'): atender_('Santana,_Huila',_'Moniquirá,_Boyacá'),
#  ('Santana, Huila',
#   'Manizales, Caldas'): atender_('Santana,_Huila',_'Manizales,_Caldas'),
#  ('Santana, Huila',
#   'Anserma, Caldas'): atender_('Santana,_Huila',_'Anserma,_Caldas'),
#  ('Santana, Huila',
#   'Pensilvania, Caldas'): atender_('Santana,_Huila',_'Pensilvania,_Caldas'),
#  ('Santana, Huila',
#   'Riosucio, Caldas'): atender_('Santana,_Huila',_'Riosucio,_Caldas'),
#  ('Santana, Huila',
#   'Aguadas, Caldas'): atender_('Santana,_Huila',_'Aguadas,_Caldas'),
#  ('Santana, Huila',
#   'Morales, Cauca'): atender_('Santana,_Huila',_'Morales,_Cauca'),
#  ('Santana, Huila',
#   'El Tambo, Cauca'): atender_('Santana,_Huila',_'El_Tambo,_Cauca'),
#  ('Santana, Huila',
#   'Bolívar, Cauca'): atender_('Santana,_Huila',_'Bolívar,_Cauca'),
#  ('Santana, Huila',
#   'Aguachica, Cesar'): atender_('Santana,_Huila',_'Aguachica,_Cesar'),
#  ('Santana, Huila',
#   'San Diego, Cesar'): atender_('Santana,_Huila',_'San_Diego,_Cesar'),
#  ('Santana, Huila',
#   'Caparrapí, Cundinamarca'): atender_('Santana,_Huila',_'Caparrapí,_Cundinamarca'),
#  ('Santana, Huila',
#   'Viotá, Cundinamarca'): atender_('Santana,_Huila',_'Viotá,_Cundinamarca'),
#  ('Santana, Huila',
#   'Sasaima, Cundinamarca'): atender_('Santana,_Huila',_'Sasaima,_Cundinamarca'),
#  ('Santana, Huila',
#   'Neiva, Huila'): atender_('Santana,_Huila',_'Neiva,_Huila'),
#  ('Santana, Huila',
#   'Pitalito, Huila'): atender_('Santana,_Huila',_'Pitalito,_Huila'),
#  ('Santana, Huila',
#   'Gigante, Huila'): atender_('Santana,_Huila',_'Gigante,_Huila'),
#  ('Santana, Huila',
#   'Santa Marta, Magdalena'): atender_('Santana,_Huila',_'Santa_Marta,_Magdalena'),
#  ('Santana, Huila',
#   'La Unión, Nariño'): atender_('Santana,_Huila',_'La_Unión,_Nariño'),
#  ('Santana, Huila',
#   'Pasto, Nariño'): atender_('Santana,_Huila',_'Pasto,_Nariño'),
#  ('Santana, Huila',
#   'Samaniego, Nariño'): atender_('Santana,_Huila',_'Samaniego,_Nariño'),
#  ('Santana, Huila',
#   'Sardinata, Norte de Santander'): atender_('Santana,_Huila',_'Sardinata,_Norte_de_Santander'),
#  ('Santana, Huila',
#   'Ocaña, Norte de Santander'): atender_('Santana,_Huila',_'Ocaña,_Norte_de_Santander'),
#  ('Santana, Huila',
#   'Convención, Norte de Santander'): atender_('Santana,_Huila',_'Convención,_Norte_de_Santander'),
#  ('Santana, Huila',
#   'Génova, Quindío'): atender_('Santana,_Huila',_'Génova,_Quindío'),
#  ('Santana, Huila',
#   'Calarcá, Quindío'): atender_('Santana,_Huila',_'Calarcá,_Quindío'),
#  ('Santana, Huila',
#   'Quimbaya, Quindío'): atender_('Santana,_Huila',_'Quimbaya,_Quindío'),
#  ('Santana, Huila',
#   'Pereira, Risaralda'): atender_('Santana,_Huila',_'Pereira,_Risaralda'),
#  ('Santana, Huila',
#   'Santuario, Risaralda'): atender_('Santana,_Huila',_'Santuario,_Risaralda'),
#  ('Santana, Huila',
#   'Belén de Umbria, Risaralda'): atender_('Santana,_Huila',_'Belén_de_Umbria,_Risaralda'),
#  ('Santana, Huila',
#   'Rionegro, Santander'): atender_('Santana,_Huila',_'Rionegro,_Santander'),
#  ('Santana, Huila',
#   'Bucaramanga, Santander'): atender_('Santana,_Huila',_'Bucaramanga,_Santander'),
#  ('Santana, Huila',
#   'Barbosa, Santander'): atender_('Santana,_Huila',_'Barbosa,_Santander'),
#  ('Santana, Huila',
#   'Socorro, Santander'): atender_('Santana,_Huila',_'Socorro,_Santander'),
#  ('Santana, Huila',
#   'Simacota, Santander'): atender_('Santana,_Huila',_'Simacota,_Santander'),
#  ('Santana, Huila',
#   'Chaparral, Tolima'): atender_('Santana,_Huila',_'Chaparral,_Tolima'),
#  ('Santana, Huila',
#   'Dolores, Tolima'): atender_('Santana,_Huila',_'Dolores,_Tolima'),
#  ('Santana, Huila',
#   'Ibagué, Tolima'): atender_('Santana,_Huila',_'Ibagué,_Tolima'),
#  ('Santana, Huila',
#   'Líbano, Tolima'): atender_('Santana,_Huila',_'Líbano,_Tolima'),
#  ('Santana, Huila',
#   'Cartago, Valle'): atender_('Santana,_Huila',_'Cartago,_Valle'),
#  ('Santana, Huila',
#   'Tulua, Valle'): atender_('Santana,_Huila',_'Tulua,_Valle'),
#  ('Santana, Huila',
#   'Jamundí, Valle'): atender_('Santana,_Huila',_'Jamundí,_Valle'),
#  ('Santana, Huila',
#   'Sevilla, Valle'): atender_('Santana,_Huila',_'Sevilla,_Valle'),
#  ('Santana, Huila',
#   'Caicedonia, Valle'): atender_('Santana,_Huila',_'Caicedonia,_Valle'),
#  ('Santana, Huila',
#   'Florencia, Caquetá'): atender_('Santana,_Huila',_'Florencia,_Caquetá'),
#  ('Santana, Huila',
#   'Puerto Milán, Caquetá'): atender_('Santana,_Huila',_'Puerto_Milán,_Caquetá'),
#  ('Santana, Huila',
#   'Nunchía, Casanare'): atender_('Santana,_Huila',_'Nunchía,_Casanare'),
#  ('Santana, Huila',
#   'Mesetas, Meta'): atender_('Santana,_Huila',_'Mesetas,_Meta'),
#  ('Neiva, Huila',
#   'Andes, Antioquia'): atender_('Neiva,_Huila',_'Andes,_Antioquia'),
#  ('Neiva, Huila',
#   'Medellín, Antioquia'): atender_('Neiva,_Huila',_'Medellín,_Antioquia'),
#  ('Neiva, Huila',
#   'Dabeiba, Antioquia'): atender_('Neiva,_Huila',_'Dabeiba,_Antioquia'),
#  ('Neiva, Huila',
#   'Salgar, Antioquia'): atender_('Neiva,_Huila',_'Salgar,_Antioquia'),
#  ('Neiva, Huila',
#   'San Pablo de Borbur, Boyacá'): atender_('Neiva,_Huila',_'San_Pablo_de_Borbur,_Boyacá'),
#  ('Neiva, Huila',
#   'Labranzagrande, Boyacá'): atender_('Neiva,_Huila',_'Labranzagrande,_Boyacá'),
#  ('Neiva, Huila',
#   'Miraflores, Boyacá'): atender_('Neiva,_Huila',_'Miraflores,_Boyacá'),
#  ('Neiva, Huila',
#   'Moniquirá, Boyacá'): atender_('Neiva,_Huila',_'Moniquirá,_Boyacá'),
#  ('Neiva, Huila',
#   'Manizales, Caldas'): atender_('Neiva,_Huila',_'Manizales,_Caldas'),
#  ('Neiva, Huila',
#   'Anserma, Caldas'): atender_('Neiva,_Huila',_'Anserma,_Caldas'),
#  ('Neiva, Huila',
#   'Pensilvania, Caldas'): atender_('Neiva,_Huila',_'Pensilvania,_Caldas'),
#  ('Neiva, Huila',
#   'Riosucio, Caldas'): atender_('Neiva,_Huila',_'Riosucio,_Caldas'),
#  ('Neiva, Huila',
#   'Aguadas, Caldas'): atender_('Neiva,_Huila',_'Aguadas,_Caldas'),
#  ('Neiva, Huila',
#   'Morales, Cauca'): atender_('Neiva,_Huila',_'Morales,_Cauca'),
#  ('Neiva, Huila',
#   'El Tambo, Cauca'): atender_('Neiva,_Huila',_'El_Tambo,_Cauca'),
#  ('Neiva, Huila',
#   'Bolívar, Cauca'): atender_('Neiva,_Huila',_'Bolívar,_Cauca'),
#  ('Neiva, Huila',
#   'Aguachica, Cesar'): atender_('Neiva,_Huila',_'Aguachica,_Cesar'),
#  ('Neiva, Huila',
#   'San Diego, Cesar'): atender_('Neiva,_Huila',_'San_Diego,_Cesar'),
#  ('Neiva, Huila',
#   'Caparrapí, Cundinamarca'): atender_('Neiva,_Huila',_'Caparrapí,_Cundinamarca'),
#  ('Neiva, Huila',
#   'Viotá, Cundinamarca'): atender_('Neiva,_Huila',_'Viotá,_Cundinamarca'),
#  ('Neiva, Huila',
#   'Sasaima, Cundinamarca'): atender_('Neiva,_Huila',_'Sasaima,_Cundinamarca'),
#  ('Neiva, Huila', 'Neiva, Huila'): atender_('Neiva,_Huila',_'Neiva,_Huila'),
#  ('Neiva, Huila',
#   'Pitalito, Huila'): atender_('Neiva,_Huila',_'Pitalito,_Huila'),
#  ('Neiva, Huila',
#   'Gigante, Huila'): atender_('Neiva,_Huila',_'Gigante,_Huila'),
#  ('Neiva, Huila',
#   'Santa Marta, Magdalena'): atender_('Neiva,_Huila',_'Santa_Marta,_Magdalena'),
#  ('Neiva, Huila',
#   'La Unión, Nariño'): atender_('Neiva,_Huila',_'La_Unión,_Nariño'),
#  ('Neiva, Huila', 'Pasto, Nariño'): atender_('Neiva,_Huila',_'Pasto,_Nariño'),
#  ('Neiva, Huila',
#   'Samaniego, Nariño'): atender_('Neiva,_Huila',_'Samaniego,_Nariño'),
#  ('Neiva, Huila',
#   'Sardinata, Norte de Santander'): atender_('Neiva,_Huila',_'Sardinata,_Norte_de_Santander'),
#  ('Neiva, Huila',
#   'Ocaña, Norte de Santander'): atender_('Neiva,_Huila',_'Ocaña,_Norte_de_Santander'),
#  ('Neiva, Huila',
#   'Convención, Norte de Santander'): atender_('Neiva,_Huila',_'Convención,_Norte_de_Santander'),
#  ('Neiva, Huila',
#   'Génova, Quindío'): atender_('Neiva,_Huila',_'Génova,_Quindío'),
#  ('Neiva, Huila',
#   'Calarcá, Quindío'): atender_('Neiva,_Huila',_'Calarcá,_Quindío'),
#  ('Neiva, Huila',
#   'Quimbaya, Quindío'): atender_('Neiva,_Huila',_'Quimbaya,_Quindío'),
#  ('Neiva, Huila',
#   'Pereira, Risaralda'): atender_('Neiva,_Huila',_'Pereira,_Risaralda'),
#  ('Neiva, Huila',
#   'Santuario, Risaralda'): atender_('Neiva,_Huila',_'Santuario,_Risaralda'),
#  ('Neiva, Huila',
#   'Belén de Umbria, Risaralda'): atender_('Neiva,_Huila',_'Belén_de_Umbria,_Risaralda'),
#  ('Neiva, Huila',
#   'Rionegro, Santander'): atender_('Neiva,_Huila',_'Rionegro,_Santander'),
#  ('Neiva, Huila',
#   'Bucaramanga, Santander'): atender_('Neiva,_Huila',_'Bucaramanga,_Santander'),
#  ('Neiva, Huila',
#   'Barbosa, Santander'): atender_('Neiva,_Huila',_'Barbosa,_Santander'),
#  ('Neiva, Huila',
#   'Socorro, Santander'): atender_('Neiva,_Huila',_'Socorro,_Santander'),
#  ('Neiva, Huila',
#   'Simacota, Santander'): atender_('Neiva,_Huila',_'Simacota,_Santander'),
#  ('Neiva, Huila',
#   'Chaparral, Tolima'): atender_('Neiva,_Huila',_'Chaparral,_Tolima'),
#  ('Neiva, Huila',
#   'Dolores, Tolima'): atender_('Neiva,_Huila',_'Dolores,_Tolima'),
#  ('Neiva, Huila',
#   'Ibagué, Tolima'): atender_('Neiva,_Huila',_'Ibagué,_Tolima'),
# ...
#   'Santa Marta, Magdalena'): atender_('Pereira,_Risaralda',_'Santa_Marta,_Magdalena'),
#  ('Pereira, Risaralda',
#   'La Unión, Nariño'): atender_('Pereira,_Risaralda',_'La_Unión,_Nariño'),
#  ('Pereira, Risaralda',
#   'Pasto, Nariño'): atender_('Pereira,_Risaralda',_'Pasto,_Nariño'),
#  ('Pereira, Risaralda',
#   'Samaniego, Nariño'): atender_('Pereira,_Risaralda',_'Samaniego,_Nariño'),
#  ('Pereira, Risaralda',
#   'Sardinata, Norte de Santander'): atender_('Pereira,_Risaralda',_'Sardinata,_Norte_de_Santander'),
#  ('Pereira, Risaralda',
#   'Ocaña, Norte de Santander'): atender_('Pereira,_Risaralda',_'Ocaña,_Norte_de_Santander'),
#  ('Pereira, Risaralda',
#   'Convención, Norte de Santander'): atender_('Pereira,_Risaralda',_'Convención,_Norte_de_Santander'),
#  ('Pereira, Risaralda',
#   'Génova, Quindío'): atender_('Pereira,_Risaralda',_'Génova,_Quindío'),
#  ('Pereira, Risaralda',
#   'Calarcá, Quindío'): atender_('Pereira,_Risaralda',_'Calarcá,_Quindío'),
#  ('Pereira, Risaralda',
#   'Quimbaya, Quindío'): atender_('Pereira,_Risaralda',_'Quimbaya,_Quindío'),
#  ('Pereira, Risaralda',
#   'Pereira, Risaralda'): atender_('Pereira,_Risaralda',_'Pereira,_Risaralda'),
#  ('Pereira, Risaralda',
#   'Santuario, Risaralda'): atender_('Pereira,_Risaralda',_'Santuario,_Risaralda'),
#  ('Pereira, Risaralda',
#   'Belén de Umbria, Risaralda'): atender_('Pereira,_Risaralda',_'Belén_de_Umbria,_Risaralda'),
#  ('Pereira, Risaralda',
#   'Rionegro, Santander'): atender_('Pereira,_Risaralda',_'Rionegro,_Santander'),
#  ('Pereira, Risaralda',
#   'Bucaramanga, Santander'): atender_('Pereira,_Risaralda',_'Bucaramanga,_Santander'),
#  ('Pereira, Risaralda',
#   'Barbosa, Santander'): atender_('Pereira,_Risaralda',_'Barbosa,_Santander'),
#  ('Pereira, Risaralda',
#   'Socorro, Santander'): atender_('Pereira,_Risaralda',_'Socorro,_Santander'),
#  ('Pereira, Risaralda',
#   'Simacota, Santander'): atender_('Pereira,_Risaralda',_'Simacota,_Santander'),
#  ('Pereira, Risaralda',
#   'Chaparral, Tolima'): atender_('Pereira,_Risaralda',_'Chaparral,_Tolima'),
#  ('Pereira, Risaralda',
#   'Dolores, Tolima'): atender_('Pereira,_Risaralda',_'Dolores,_Tolima'),
#  ('Pereira, Risaralda',
#   'Ibagué, Tolima'): atender_('Pereira,_Risaralda',_'Ibagué,_Tolima'),
#  ('Pereira, Risaralda',
#   'Líbano, Tolima'): atender_('Pereira,_Risaralda',_'Líbano,_Tolima'),
#  ('Pereira, Risaralda',
#   'Cartago, Valle'): atender_('Pereira,_Risaralda',_'Cartago,_Valle'),
#  ('Pereira, Risaralda',
#   'Tulua, Valle'): atender_('Pereira,_Risaralda',_'Tulua,_Valle'),
#  ('Pereira, Risaralda',
#   'Jamundí, Valle'): atender_('Pereira,_Risaralda',_'Jamundí,_Valle'),
#  ('Pereira, Risaralda',
#   'Sevilla, Valle'): atender_('Pereira,_Risaralda',_'Sevilla,_Valle'),
#  ('Pereira, Risaralda',
#   'Caicedonia, Valle'): atender_('Pereira,_Risaralda',_'Caicedonia,_Valle'),
#  ('Pereira, Risaralda',
#   'Florencia, Caquetá'): atender_('Pereira,_Risaralda',_'Florencia,_Caquetá'),
#  ('Pereira, Risaralda',
#   'Puerto Milán, Caquetá'): atender_('Pereira,_Risaralda',_'Puerto_Milán,_Caquetá'),
#  ('Pereira, Risaralda',
#   'Nunchía, Casanare'): atender_('Pereira,_Risaralda',_'Nunchía,_Casanare'),
#  ('Pereira, Risaralda',
#   'Mesetas, Meta'): atender_('Pereira,_Risaralda',_'Mesetas,_Meta'),
#  ('Bucaramanga, Santander',
#   'Andes, Antioquia'): atender_('Bucaramanga,_Santander',_'Andes,_Antioquia'),
#  ('Bucaramanga, Santander',
#   'Medellín, Antioquia'): atender_('Bucaramanga,_Santander',_'Medellín,_Antioquia'),
#  ('Bucaramanga, Santander',
#   'Dabeiba, Antioquia'): atender_('Bucaramanga,_Santander',_'Dabeiba,_Antioquia'),
#  ('Bucaramanga, Santander',
#   'Salgar, Antioquia'): atender_('Bucaramanga,_Santander',_'Salgar,_Antioquia'),
#  ('Bucaramanga, Santander',
#   'San Pablo de Borbur, Boyacá'): atender_('Bucaramanga,_Santander',_'San_Pablo_de_Borbur,_Boyacá'),
#  ('Bucaramanga, Santander',
#   'Labranzagrande, Boyacá'): atender_('Bucaramanga,_Santander',_'Labranzagrande,_Boyacá'),
#  ('Bucaramanga, Santander',
#   'Miraflores, Boyacá'): atender_('Bucaramanga,_Santander',_'Miraflores,_Boyacá'),
#  ('Bucaramanga, Santander',
#   'Moniquirá, Boyacá'): atender_('Bucaramanga,_Santander',_'Moniquirá,_Boyacá'),
#  ('Bucaramanga, Santander',
#   'Manizales, Caldas'): atender_('Bucaramanga,_Santander',_'Manizales,_Caldas'),
#  ('Bucaramanga, Santander',
#   'Anserma, Caldas'): atender_('Bucaramanga,_Santander',_'Anserma,_Caldas'),
#  ('Bucaramanga, Santander',
#   'Pensilvania, Caldas'): atender_('Bucaramanga,_Santander',_'Pensilvania,_Caldas'),
#  ('Bucaramanga, Santander',
#   'Riosucio, Caldas'): atender_('Bucaramanga,_Santander',_'Riosucio,_Caldas'),
#  ('Bucaramanga, Santander',
#   'Aguadas, Caldas'): atender_('Bucaramanga,_Santander',_'Aguadas,_Caldas'),
#  ('Bucaramanga, Santander',
#   'Morales, Cauca'): atender_('Bucaramanga,_Santander',_'Morales,_Cauca'),
#  ('Bucaramanga, Santander',
#   'El Tambo, Cauca'): atender_('Bucaramanga,_Santander',_'El_Tambo,_Cauca'),
#  ('Bucaramanga, Santander',
#   'Bolívar, Cauca'): atender_('Bucaramanga,_Santander',_'Bolívar,_Cauca'),
#  ('Bucaramanga, Santander',
#   'Aguachica, Cesar'): atender_('Bucaramanga,_Santander',_'Aguachica,_Cesar'),
#  ('Bucaramanga, Santander',
#   'San Diego, Cesar'): atender_('Bucaramanga,_Santander',_'San_Diego,_Cesar'),
#  ('Bucaramanga, Santander',
#   'Caparrapí, Cundinamarca'): atender_('Bucaramanga,_Santander',_'Caparrapí,_Cundinamarca'),
#  ('Bucaramanga, Santander',
#   'Viotá, Cundinamarca'): atender_('Bucaramanga,_Santander',_'Viotá,_Cundinamarca'),
#  ('Bucaramanga, Santander',
#   'Sasaima, Cundinamarca'): atender_('Bucaramanga,_Santander',_'Sasaima,_Cundinamarca'),
#  ('Bucaramanga, Santander',
#   'Neiva, Huila'): atender_('Bucaramanga,_Santander',_'Neiva,_Huila'),
#  ('Bucaramanga, Santander',
#   'Pitalito, Huila'): atender_('Bucaramanga,_Santander',_'Pitalito,_Huila'),
#  ('Bucaramanga, Santander',
#   'Gigante, Huila'): atender_('Bucaramanga,_Santander',_'Gigante,_Huila'),
#  ('Bucaramanga, Santander',
#   'Santa Marta, Magdalena'): atender_('Bucaramanga,_Santander',_'Santa_Marta,_Magdalena'),
#  ('Bucaramanga, Santander',
#   'La Unión, Nariño'): atender_('Bucaramanga,_Santander',_'La_Unión,_Nariño'),
#  ('Bucaramanga, Santander',
#   'Pasto, Nariño'): atender_('Bucaramanga,_Santander',_'Pasto,_Nariño'),
#  ('Bucaramanga, Santander',
#   'Samaniego, Nariño'): atender_('Bucaramanga,_Santander',_'Samaniego,_Nariño'),
#  ('Bucaramanga, Santander',
#   'Sardinata, Norte de Santander'): atender_('Bucaramanga,_Santander',_'Sardinata,_Norte_de_Santander'),
#  ('Bucaramanga, Santander',
#   'Ocaña, Norte de Santander'): atender_('Bucaramanga,_Santander',_'Ocaña,_Norte_de_Santander'),
#  ('Bucaramanga, Santander',
#   'Convención, Norte de Santander'): atender_('Bucaramanga,_Santander',_'Convención,_Norte_de_Santander'),
#  ('Bucaramanga, Santander',
#   'Génova, Quindío'): atender_('Bucaramanga,_Santander',_'Génova,_Quindío'),
#  ('Bucaramanga, Santander',
#   'Calarcá, Quindío'): atender_('Bucaramanga,_Santander',_'Calarcá,_Quindío'),
#  ('Bucaramanga, Santander',
#   'Quimbaya, Quindío'): atender_('Bucaramanga,_Santander',_'Quimbaya,_Quindío'),
#  ('Bucaramanga, Santander',
#   'Pereira, Risaralda'): atender_('Bucaramanga,_Santander',_'Pereira,_Risaralda'),
#  ('Bucaramanga, Santander',
#   'Santuario, Risaralda'): atender_('Bucaramanga,_Santander',_'Santuario,_Risaralda'),
#  ('Bucaramanga, Santander',
#   'Belén de Umbria, Risaralda'): atender_('Bucaramanga,_Santander',_'Belén_de_Umbria,_Risaralda'),
#  ('Bucaramanga, Santander',
#   'Rionegro, Santander'): atender_('Bucaramanga,_Santander',_'Rionegro,_Santander'),
#  ('Bucaramanga, Santander',
#   'Bucaramanga, Santander'): atender_('Bucaramanga,_Santander',_'Bucaramanga,_Santander'),
#  ('Bucaramanga, Santander',
#   'Barbosa, Santander'): atender_('Bucaramanga,_Santander',_'Barbosa,_Santander'),
#  ('Bucaramanga, Santander',
#   'Socorro, Santander'): atender_('Bucaramanga,_Santander',_'Socorro,_Santander'),
#  ('Bucaramanga, Santander',
#   'Simacota, Santander'): atender_('Bucaramanga,_Santander',_'Simacota,_Santander'),
#  ('Bucaramanga, Santander',
#   'Chaparral, Tolima'): atender_('Bucaramanga,_Santander',_'Chaparral,_Tolima'),
#  ('Bucaramanga, Santander',
#   'Dolores, Tolima'): atender_('Bucaramanga,_Santander',_'Dolores,_Tolima'),
#  ('Bucaramanga, Santander',
#   'Ibagué, Tolima'): atender_('Bucaramanga,_Santander',_'Ibagué,_Tolima'),
#  ('Bucaramanga, Santander',
#   'Líbano, Tolima'): atender_('Bucaramanga,_Santander',_'Líbano,_Tolima'),
#  ('Bucaramanga, Santander',
#   'Cartago, Valle'): atender_('Bucaramanga,_Santander',_'Cartago,_Valle'),
#  ('Bucaramanga, Santander',
#   'Tulua, Valle'): atender_('Bucaramanga,_Santander',_'Tulua,_Valle'),
#  ('Bucaramanga, Santander',
#   'Jamundí, Valle'): atender_('Bucaramanga,_Santander',_'Jamundí,_Valle'),
#  ('Bucaramanga, Santander',
#   'Sevilla, Valle'): atender_('Bucaramanga,_Santander',_'Sevilla,_Valle'),
#  ('Bucaramanga, Santander',
#   'Caicedonia, Valle'): atender_('Bucaramanga,_Santander',_'Caicedonia,_Valle'),
#  ('Bucaramanga, Santander',
#   'Florencia, Caquetá'): atender_('Bucaramanga,_Santander',_'Florencia,_Caquetá'),
#  ('Bucaramanga, Santander',
#   'Puerto Milán, Caquetá'): atender_('Bucaramanga,_Santander',_'Puerto_Milán,_Caquetá'),
#  ('Bucaramanga, Santander',
#   'Nunchía, Casanare'): atender_('Bucaramanga,_Santander',_'Nunchía,_Casanare'),
#  ('Bucaramanga, Santander',
#   'Mesetas, Meta'): atender_('Bucaramanga,_Santander',_'Mesetas,_Meta'),
#  ('Barbosa, Santander',
#   'Andes, Antioquia'): atender_('Barbosa,_Santander',_'Andes,_Antioquia'),
#  ('Barbosa, Santander',
#   'Medellín, Antioquia'): atender_('Barbosa,_Santander',_'Medellín,_Antioquia'),
#  ('Barbosa, Santander',
#   'Dabeiba, Antioquia'): atender_('Barbosa,_Santander',_'Dabeiba,_Antioquia'),
#  ('Barbosa, Santander',
#   'Salgar, Antioquia'): atender_('Barbosa,_Santander',_'Salgar,_Antioquia'),
#  ('Barbosa, Santander',
#   'San Pablo de Borbur, Boyacá'): atender_('Barbosa,_Santander',_'San_Pablo_de_Borbur,_Boyacá'),
#  ('Barbosa, Santander',
#   'Labranzagrande, Boyacá'): atender_('Barbosa,_Santander',_'Labranzagrande,_Boyacá'),
#  ('Barbosa, Santander',
#   'Miraflores, Boyacá'): atender_('Barbosa,_Santander',_'Miraflores,_Boyacá'),
#  ('Barbosa, Santander',
#   'Moniquirá, Boyacá'): atender_('Barbosa,_Santander',_'Moniquirá,_Boyacá'),
#  ('Barbosa, Santander',
#   'Manizales, Caldas'): atender_('Barbosa,_Santander',_'Manizales,_Caldas'),
#  ('Barbosa, Santander',
#   'Anserma, Caldas'): atender_('Barbosa,_Santander',_'Anserma,_Caldas'),
#  ('Barbosa, Santander',
#   'Pensilvania, Caldas'): atender_('Barbosa,_Santander',_'Pensilvania,_Caldas'),
#  ('Barbosa, Santander',
#   'Riosucio, Caldas'): atender_('Barbosa,_Santander',_'Riosucio,_Caldas'),
#  ('Barbosa, Santander',
#   'Aguadas, Caldas'): atender_('Barbosa,_Santander',_'Aguadas,_Caldas'),
#  ('Barbosa, Santander',
#   'Morales, Cauca'): atender_('Barbosa,_Santander',_'Morales,_Cauca'),
#  ('Barbosa, Santander',
#   'El Tambo, Cauca'): atender_('Barbosa,_Santander',_'El_Tambo,_Cauca'),
#  ('Barbosa, Santander',
#   'Bolívar, Cauca'): atender_('Barbosa,_Santander',_'Bolívar,_Cauca'),
#  ('Barbosa, Santander',
#   'Aguachica, Cesar'): atender_('Barbosa,_Santander',_'Aguachica,_Cesar'),
#  ('Barbosa, Santander',
#   'San Diego, Cesar'): atender_('Barbosa,_Santander',_'San_Diego,_Cesar'),
#  ('Barbosa, Santander',
#   'Caparrapí, Cundinamarca'): atender_('Barbosa,_Santander',_'Caparrapí,_Cundinamarca'),
#  ('Barbosa, Santander',
#   'Viotá, Cundinamarca'): atender_('Barbosa,_Santander',_'Viotá,_Cundinamarca'),
#  ('Barbosa, Santander',
#   'Sasaima, Cundinamarca'): atender_('Barbosa,_Santander',_'Sasaima,_Cundinamarca'),
#  ('Barbosa, Santander',
#   'Neiva, Huila'): atender_('Barbosa,_Santander',_'Neiva,_Huila'),
#  ('Barbosa, Santander',
#   'Pitalito, Huila'): atender_('Barbosa,_Santander',_'Pitalito,_Huila'),
#  ('Barbosa, Santander',
#   'Gigante, Huila'): atender_('Barbosa,_Santander',_'Gigante,_Huila'),
#  ('Barbosa, Santander',
#   'Santa Marta, Magdalena'): atender_('Barbosa,_Santander',_'Santa_Marta,_Magdalena'),
#  ('Barbosa, Santander',
#   'La Unión, Nariño'): atender_('Barbosa,_Santander',_'La_Unión,_Nariño'),
#  ('Barbosa, Santander',
#   'Pasto, Nariño'): atender_('Barbosa,_Santander',_'Pasto,_Nariño'),
#  ('Barbosa, Santander',
#   'Samaniego, Nariño'): atender_('Barbosa,_Santander',_'Samaniego,_Nariño'),
#  ('Barbosa, Santander',
#   'Sardinata, Norte de Santander'): atender_('Barbosa,_Santander',_'Sardinata,_Norte_de_Santander'),
#  ('Barbosa, Santander',
#   'Ocaña, Norte de Santander'): atender_('Barbosa,_Santander',_'Ocaña,_Norte_de_Santander'),
#  ('Barbosa, Santander',
#   'Convención, Norte de Santander'): atender_('Barbosa,_Santander',_'Convención,_Norte_de_Santander'),
#  ('Barbosa, Santander',
#   'Génova, Quindío'): atender_('Barbosa,_Santander',_'Génova,_Quindío'),
#  ('Barbosa, Santander',
#   'Calarcá, Quindío'): atender_('Barbosa,_Santander',_'Calarcá,_Quindío'),
#  ('Barbosa, Santander',
#   'Quimbaya, Quindío'): atender_('Barbosa,_Santander',_'Quimbaya,_Quindío'),
#  ('Barbosa, Santander',
#   'Pereira, Risaralda'): atender_('Barbosa,_Santander',_'Pereira,_Risaralda'),
#  ('Barbosa, Santander',
#   'Santuario, Risaralda'): atender_('Barbosa,_Santander',_'Santuario,_Risaralda'),
#  ('Barbosa, Santander',
#   'Belén de Umbria, Risaralda'): atender_('Barbosa,_Santander',_'Belén_de_Umbria,_Risaralda'),
#  ('Barbosa, Santander',
#   'Rionegro, Santander'): atender_('Barbosa,_Santander',_'Rionegro,_Santander'),
#  ('Barbosa, Santander',
#   'Bucaramanga, Santander'): atender_('Barbosa,_Santander',_'Bucaramanga,_Santander'),
#  ('Barbosa, Santander',
#   'Barbosa, Santander'): atender_('Barbosa,_Santander',_'Barbosa,_Santander'),
#  ('Barbosa, Santander',
#   'Socorro, Santander'): atender_('Barbosa,_Santander',_'Socorro,_Santander'),
#  ('Barbosa, Santander',
#   'Simacota, Santander'): atender_('Barbosa,_Santander',_'Simacota,_Santander'),
#  ('Barbosa, Santander',
#   'Chaparral, Tolima'): atender_('Barbosa,_Santander',_'Chaparral,_Tolima'),
#  ('Barbosa, Santander',
#   'Dolores, Tolima'): atender_('Barbosa,_Santander',_'Dolores,_Tolima'),
#  ('Barbosa, Santander',
#   'Ibagué, Tolima'): atender_('Barbosa,_Santander',_'Ibagué,_Tolima'),
#  ('Barbosa, Santander',
#   'Líbano, Tolima'): atender_('Barbosa,_Santander',_'Líbano,_Tolima'),
#  ('Barbosa, Santander',
#   'Cartago, Valle'): atender_('Barbosa,_Santander',_'Cartago,_Valle'),
#  ('Barbosa, Santander',
#   'Tulua, Valle'): atender_('Barbosa,_Santander',_'Tulua,_Valle'),
#  ('Barbosa, Santander',
#   'Jamundí, Valle'): atender_('Barbosa,_Santander',_'Jamundí,_Valle'),
#  ('Barbosa, Santander',
#   'Sevilla, Valle'): atender_('Barbosa,_Santander',_'Sevilla,_Valle'),
#  ('Barbosa, Santander',
#   'Caicedonia, Valle'): atender_('Barbosa,_Santander',_'Caicedonia,_Valle'),
#  ('Barbosa, Santander',
#   'Florencia, Caquetá'): atender_('Barbosa,_Santander',_'Florencia,_Caquetá'),
#  ('Barbosa, Santander',
#   'Puerto Milán, Caquetá'): atender_('Barbosa,_Santander',_'Puerto_Milán,_Caquetá'),
#  ('Barbosa, Santander',
#   'Nunchía, Casanare'): atender_('Barbosa,_Santander',_'Nunchía,_Casanare'),
#  ('Barbosa, Santander',
#   'Mesetas, Meta'): atender_('Barbosa,_Santander',_'Mesetas,_Meta'),
#  ('Cali, Valle del Cauca',
#   'Andes, Antioquia'): atender_('Cali,_Valle_del_Cauca',_'Andes,_Antioquia'),
#  ('Cali, Valle del Cauca',
#   'Medellín, Antioquia'): atender_('Cali,_Valle_del_Cauca',_'Medellín,_Antioquia'),
#  ('Cali, Valle del Cauca',
#   'Dabeiba, Antioquia'): atender_('Cali,_Valle_del_Cauca',_'Dabeiba,_Antioquia'),
#  ('Cali, Valle del Cauca',
#   'Salgar, Antioquia'): atender_('Cali,_Valle_del_Cauca',_'Salgar,_Antioquia'),
#  ('Cali, Valle del Cauca',
#   'San Pablo de Borbur, Boyacá'): atender_('Cali,_Valle_del_Cauca',_'San_Pablo_de_Borbur,_Boyacá'),
#  ('Cali, Valle del Cauca',
#   'Labranzagrande, Boyacá'): atender_('Cali,_Valle_del_Cauca',_'Labranzagrande,_Boyacá'),
#  ('Cali, Valle del Cauca',
#   'Miraflores, Boyacá'): atender_('Cali,_Valle_del_Cauca',_'Miraflores,_Boyacá'),
#  ('Cali, Valle del Cauca',
#   'Moniquirá, Boyacá'): atender_('Cali,_Valle_del_Cauca',_'Moniquirá,_Boyacá'),
#  ('Cali, Valle del Cauca',
#   'Manizales, Caldas'): atender_('Cali,_Valle_del_Cauca',_'Manizales,_Caldas'),
#  ('Cali, Valle del Cauca',
#   'Anserma, Caldas'): atender_('Cali,_Valle_del_Cauca',_'Anserma,_Caldas'),
#  ...}

# %% [markdown]
# ### Función Objetivo
# Minimizar los costos totales de operación y transporte
# >`# Para desarrollo del estudiante`

# %% [markdown]
# **Pregunta 2 (10 puntos)**
# * Crea la función objetivo y agrégala al modelo `problema`
#
# > **Ejemplo**:
# >> $ \sum_{i \in I}c_i x_i$
# es equivalente a `lp.lpSum(c[i]*x[i] for i in I)`

# %%
# your code here

problema += (
    lp.lpSum(costo_fijo[i] * y[i] for i in I) +
    lp.lpSum(costo_transporte[(i, j)] * x[(i, j)] for i in I for j in J)
)

# for i in I:
#     print(costo_fijo[i] * y[i])

for i in I:
    for j in J:
        print(costo_transporte[(i, j)] * x[(i, j)])
# Out:
# 259887.0771962719*atender_('Medellín,_Antioquia',_'Andes,_Antioquia')
# 0.0
# 264652.8440388665*atender_('Medellín,_Antioquia',_'Dabeiba,_Antioquia')
# 115445.05913871697*atender_('Medellín,_Antioquia',_'Salgar,_Antioquia')
# 25429.18772491788*atender_('Medellín,_Antioquia',_'San_Pablo_de_Borbur,_Boyacá')
# 36919.07644140094*atender_('Medellín,_Antioquia',_'Labranzagrande,_Boyacá')
# 29521.241888714983*atender_('Medellín,_Antioquia',_'Miraflores,_Boyacá')
# 26594.294979452206*atender_('Medellín,_Antioquia',_'Moniquirá,_Boyacá')
# 295281.5605846156*atender_('Medellín,_Antioquia',_'Manizales,_Caldas')
# 88412.97463791116*atender_('Medellín,_Antioquia',_'Anserma,_Caldas')
# 63195.28014090266*atender_('Medellín,_Antioquia',_'Pensilvania,_Caldas')
# 54772.86183538385*atender_('Medellín,_Antioquia',_'Riosucio,_Caldas')
# 47197.45534975282*atender_('Medellín,_Antioquia',_'Aguadas,_Caldas')
# 509822.40854318615*atender_('Medellín,_Antioquia',_'Morales,_Cauca')
# 528268.8852161284*atender_('Medellín,_Antioquia',_'El_Tambo,_Cauca')
# 542357.7987691491*atender_('Medellín,_Antioquia',_'Bolívar,_Cauca')
# 101836.01331006383*atender_('Medellín,_Antioquia',_'Aguachica,_Cesar')
# 127465.13920838409*atender_('Medellín,_Antioquia',_'San_Diego,_Cesar')
# 20303.124219245197*atender_('Medellín,_Antioquia',_'Caparrapí,_Cundinamarca')
# 37350.69718348618*atender_('Medellín,_Antioquia',_'Viotá,_Cundinamarca')
# 40384.67763870898*atender_('Medellín,_Antioquia',_'Sasaima,_Cundinamarca')
# 718927.4685371511*atender_('Medellín,_Antioquia',_'Neiva,_Huila')
# 983801.9402111539*atender_('Medellín,_Antioquia',_'Pitalito,_Huila')
# 845298.0849202928*atender_('Medellín,_Antioquia',_'Gigante,_Huila')
# 195112.57119542637*atender_('Medellín,_Antioquia',_'Santa_Marta,_Magdalena')
# 371107.6642454956*atender_('Medellín,_Antioquia',_'La_Unión,_Nariño')
# 441369.52970721095*atender_('Medellín,_Antioquia',_'Pasto,_Nariño')
# 302143.512260159*atender_('Medellín,_Antioquia',_'Samaniego,_Nariño')
# 86077.40864496604*atender_('Medellín,_Antioquia',_'Sardinata,_Norte_de_Santander')
# 76163.21119298259*atender_('Medellín,_Antioquia',_'Ocaña,_Norte_de_Santander')
# 81879.61376699338*atender_('Medellín,_Antioquia',_'Convención,_Norte_de_Santander')
# 103410.01316331682*atender_('Medellín,_Antioquia',_'Génova,_Quindío')
# 110113.47370349194*atender_('Medellín,_Antioquia',_'Calarcá,_Quindío')
# 91040.34735607928*atender_('Medellín,_Antioquia',_'Quimbaya,_Quindío')
# 131375.41078590247*atender_('Medellín,_Antioquia',_'Pereira,_Risaralda')
# 94731.73873672944*atender_('Medellín,_Antioquia',_'Santuario,_Risaralda')
# 100281.26989656068*atender_('Medellín,_Antioquia',_'Belén_de_Umbria,_Risaralda')
# 46871.235226132485*atender_('Medellín,_Antioquia',_'Rionegro,_Santander')
# 47106.05417017624*atender_('Medellín,_Antioquia',_'Bucaramanga,_Santander')
# 170066.58445373084*atender_('Medellín,_Antioquia',_'Barbosa,_Santander')
# 185871.1101271767*atender_('Medellín,_Antioquia',_'Socorro,_Santander')
# 130295.66339300427*atender_('Medellín,_Antioquia',_'Simacota,_Santander')
# 218568.9293898824*atender_('Medellín,_Antioquia',_'Chaparral,_Tolima')
# 327521.1210991303*atender_('Medellín,_Antioquia',_'Dolores,_Tolima')
# 25973.962926447573*atender_('Medellín,_Antioquia',_'Ibagué,_Tolima')
# 17760.952956155063*atender_('Medellín,_Antioquia',_'Líbano,_Tolima')
# 99319.0575026843*atender_('Medellín,_Antioquia',_'Cartago,_Valle')
# 134678.13473081848*atender_('Medellín,_Antioquia',_'Tulua,_Valle')
# 114017.43041450086*atender_('Medellín,_Antioquia',_'Jamundí,_Valle')
# 60253.46117607574*atender_('Medellín,_Antioquia',_'Sevilla,_Valle')
# 61185.54593854569*atender_('Medellín,_Antioquia',_'Caicedonia,_Valle')
# 17122.103038611167*atender_('Medellín,_Antioquia',_'Florencia,_Caquetá')
# 16204.24376950512*atender_('Medellín,_Antioquia',_'Puerto_Milán,_Caquetá')
# 13633.28980147148*atender_('Medellín,_Antioquia',_'Nunchía,_Casanare')
# 14938.760135886283*atender_('Medellín,_Antioquia',_'Mesetas,_Meta')
# 437095.8031873739*atender_('La_Dorada,_Caldas_',_'Andes,_Antioquia')
# 121254.27163056642*atender_('La_Dorada,_Caldas_',_'Medellín,_Antioquia')
# 575366.1898446764*atender_('La_Dorada,_Caldas_',_'Dabeiba,_Antioquia')
# 317669.92410301126*atender_('La_Dorada,_Caldas_',_'Salgar,_Antioquia')
# 10040.588824209111*atender_('La_Dorada,_Caldas_',_'San_Pablo_de_Borbur,_Boyacá')
# 25385.634296010925*atender_('La_Dorada,_Caldas_',_'Labranzagrande,_Boyacá')
# 17638.21602347815*atender_('La_Dorada,_Caldas_',_'Miraflores,_Boyacá')
# 15547.019077485453*atender_('La_Dorada,_Caldas_',_'Moniquirá,_Boyacá')
# 223811.8214201205*atender_('La_Dorada,_Caldas_',_'Manizales,_Caldas')
# 88813.87986243975*atender_('La_Dorada,_Caldas_',_'Anserma,_Caldas')
# 31208.162195002595*atender_('La_Dorada,_Caldas_',_'Pensilvania,_Caldas')
# 67343.4315679853*atender_('La_Dorada,_Caldas_',_'Riosucio,_Caldas')
# 49539.726777983065*atender_('La_Dorada,_Caldas_',_'Aguadas,_Caldas')
# 475684.1547544864*atender_('La_Dorada,_Caldas_',_'Morales,_Cauca')
# 491427.843667154*atender_('La_Dorada,_Caldas_',_'El_Tambo,_Cauca')
# 506430.6633358732*atender_('La_Dorada,_Caldas_',_'Bolívar,_Cauca')
# 107041.17110338563*atender_('La_Dorada,_Caldas_',_'Aguachica,_Cesar')
# 136041.96891150967*atender_('La_Dorada,_Caldas_',_'San_Diego,_Cesar')
# 3766.796744994663*atender_('La_Dorada,_Caldas_',_'Caparrapí,_Cundinamarca')
# 19503.268489161434*atender_('La_Dorada,_Caldas_',_'Viotá,_Cundinamarca')
# 14989.76591507083*atender_('La_Dorada,_Caldas_',_'Sasaima,_Cundinamarca')
# 567258.7564130517*atender_('La_Dorada,_Caldas_',_'Neiva,_Huila')
# 873151.2895376666*atender_('La_Dorada,_Caldas_',_'Pitalito,_Huila')
# 706829.1119295231*atender_('La_Dorada,_Caldas_',_'Gigante,_Huila')
# 216552.82087321018*atender_('La_Dorada,_Caldas_',_'Santa_Marta,_Magdalena')
# 348860.09661607427*atender_('La_Dorada,_Caldas_',_'La_Unión,_Nariño')
# 414506.7912597276*atender_('La_Dorada,_Caldas_',_'Pasto,_Nariño')
# 290694.9623405069*atender_('La_Dorada,_Caldas_',_'Samaniego,_Nariño')
# 83691.60787881908*atender_('La_Dorada,_Caldas_',_'Sardinata,_Norte_de_Santander')
# 77615.6278528456*atender_('La_Dorada,_Caldas_',_'Ocaña,_Norte_de_Santander')
# 84761.98031306018*atender_('La_Dorada,_Caldas_',_'Convención,_Norte_de_Santander')
# 83944.6767378435*atender_('La_Dorada,_Caldas_',_'Génova,_Quindío')
# 87601.20065337361*atender_('La_Dorada,_Caldas_',_'Calarcá,_Quindío')
# 76982.45756756657*atender_('La_Dorada,_Caldas_',_'Quimbaya,_Quindío')
# 106023.41604567258*atender_('La_Dorada,_Caldas_',_'Pereira,_Risaralda')
# 99131.72856057713*atender_('La_Dorada,_Caldas_',_'Santuario,_Risaralda')
# 108149.22881053577*atender_('La_Dorada,_Caldas_',_'Belén_de_Umbria,_Risaralda')
# 44521.06765232593*atender_('La_Dorada,_Caldas_',_'Rionegro,_Santander')
# 40894.13305675203*atender_('La_Dorada,_Caldas_',_'Bucaramanga,_Santander')
# 100002.57752509258*atender_('La_Dorada,_Caldas_',_'Barbosa,_Santander')
# 137575.5854771366*atender_('La_Dorada,_Caldas_',_'Socorro,_Santander')
# 102560.00725160263*atender_('La_Dorada,_Caldas_',_'Simacota,_Santander')
# 172253.5986940426*atender_('La_Dorada,_Caldas_',_'Chaparral,_Tolima')
# 225431.57692814502*atender_('La_Dorada,_Caldas_',_'Dolores,_Tolima')
# 16748.41935613568*atender_('La_Dorada,_Caldas_',_'Ibagué,_Tolima')
# 8653.416015436023*atender_('La_Dorada,_Caldas_',_'Líbano,_Tolima')
# 90860.65366317038*atender_('La_Dorada,_Caldas_',_'Cartago,_Valle')
# 118961.9583589444*atender_('La_Dorada,_Caldas_',_'Tulua,_Valle')
# 106186.42226615403*atender_('La_Dorada,_Caldas_',_'Jamundí,_Valle')
# 51042.99250084836*atender_('La_Dorada,_Caldas_',_'Sevilla,_Valle')
# 51449.907110165084*atender_('La_Dorada,_Caldas_',_'Caicedonia,_Valle')
# 14773.43922396761*atender_('La_Dorada,_Caldas_',_'Florencia,_Caquetá')
# 14025.222393133734*atender_('La_Dorada,_Caldas_',_'Puerto_Milán,_Caquetá')
# 10033.37537493852*atender_('La_Dorada,_Caldas_',_'Nunchía,_Casanare')
# 10691.67475460034*atender_('La_Dorada,_Caldas_',_'Mesetas,_Meta')
# 177155.78795660642*atender_('Aguadas,_Caldas',_'Andes,_Antioquia')
# 74437.529728171*atender_('Aguadas,_Caldas',_'Medellín,_Antioquia')
# 436498.0740211331*atender_('Aguadas,_Caldas',_'Dabeiba,_Antioquia')
# 154611.37913774076*atender_('Aguadas,_Caldas',_'Salgar,_Antioquia')
# 21486.415555088493*atender_('Aguadas,_Caldas',_'San_Pablo_de_Borbur,_Boyacá')
# 34191.21419461881*atender_('Aguadas,_Caldas',_'Labranzagrande,_Boyacá')
# 25713.159337201098*atender_('Aguadas,_Caldas',_'Miraflores,_Boyacá')
# 24602.56204109549*atender_('Aguadas,_Caldas',_'Moniquirá,_Boyacá')
# 125058.33859734573*atender_('Aguadas,_Caldas',_'Manizales,_Caldas')
# 39356.01440132498*atender_('Aguadas,_Caldas',_'Anserma,_Caldas')
# 21699.77877308014*atender_('Aguadas,_Caldas',_'Pensilvania,_Caldas')
# 20361.09251657211*atender_('Aguadas,_Caldas',_'Riosucio,_Caldas')
# 0.0
# 426988.6977275271*atender_('Aguadas,_Caldas',_'Morales,_Cauca')
# 449687.47787013545*atender_('Aguadas,_Caldas',_'El_Tambo,_Cauca')
# 471399.4972272999*atender_('Aguadas,_Caldas',_'Bolívar,_Cauca')
# 117908.49971902708*atender_('Aguadas,_Caldas',_'Aguachica,_Cesar')
# 142132.11322552775*atender_('Aguadas,_Caldas',_'San_Diego,_Cesar')
# 13952.41806450983*atender_('Aguadas,_Caldas',_'Caparrapí,_Cundinamarca')
# 26154.702273190593*atender_('Aguadas,_Caldas',_'Viotá,_Cundinamarca')
# 27745.098527261016*atender_('Aguadas,_Caldas',_'Sasaima,_Cundinamarca')
# 564298.0919828907*atender_('Aguadas,_Caldas',_'Neiva,_Huila')
# 840103.602278234*atender_('Aguadas,_Caldas',_'Pitalito,_Huila')
# 694961.5403519879*atender_('Aguadas,_Caldas',_'Gigante,_Huila')
# 219099.47265719052*atender_('Aguadas,_Caldas',_'Santa_Marta,_Magdalena')
# 326218.0588167218*atender_('Aguadas,_Caldas',_'La_Unión,_Nariño')
# 392528.67721538723*atender_('Aguadas,_Caldas',_'Pasto,_Nariño')
# 270546.98090996436*atender_('Aguadas,_Caldas',_'Samaniego,_Nariño')
# 94648.12483426099*atender_('Aguadas,_Caldas',_'Sardinata,_Norte_de_Santander')
# 86735.06741993118*atender_('Aguadas,_Caldas',_'Ocaña,_Norte_de_Santander')
# 92343.66725059658*atender_('Aguadas,_Caldas',_'Convención,_Norte_de_Santander')
# 70422.76442144204*atender_('Aguadas,_Caldas',_'Génova,_Quindío')
# 69571.50211894032*atender_('Aguadas,_Caldas',_'Calarcá,_Quindío')
# 55798.63487539248*atender_('Aguadas,_Caldas',_'Quimbaya,_Quindío')
# 72475.76252380347*atender_('Aguadas,_Caldas',_'Pereira,_Risaralda')
# 55318.52950077473*atender_('Aguadas,_Caldas',_'Santuario,_Risaralda')
# 51145.167823184194*atender_('Aguadas,_Caldas',_'Belén_de_Umbria,_Risaralda')
# 52588.11736192314*atender_('Aguadas,_Caldas',_'Rionegro,_Santander')
# 50480.75322267061*atender_('Aguadas,_Caldas',_'Bucaramanga,_Santander')
# 159277.0159816939*atender_('Aguadas,_Caldas',_'Barbosa,_Santander')
# 187721.28996527294*atender_('Aguadas,_Caldas',_'Socorro,_Santander')
# 138179.17665118337*atender_('Aguadas,_Caldas',_'Simacota,_Santander')
# 159131.0435260399*atender_('Aguadas,_Caldas',_'Chaparral,_Tolima')
# 245069.77511884025*atender_('Aguadas,_Caldas',_'Dolores,_Tolima')
# 15960.617240649199*atender_('Aguadas,_Caldas',_'Ibagué,_Tolima')
# 9673.254374824543*atender_('Aguadas,_Caldas',_'Líbano,_Tolima')
# 61503.16738610358*atender_('Aguadas,_Caldas',_'Cartago,_Valle')
# 97959.22124268203*atender_('Aguadas,_Caldas',_'Tulua,_Valle')
# 93427.70761760588*atender_('Aguadas,_Caldas',_'Jamundí,_Valle')
# 42027.9165000678*atender_('Aguadas,_Caldas',_'Sevilla,_Valle')
# 41155.19940775516*atender_('Aguadas,_Caldas',_'Caicedonia,_Valle')
# 14593.993429979617*atender_('Aguadas,_Caldas',_'Florencia,_Caquetá')
# 13939.002233516854*atender_('Aguadas,_Caldas',_'Puerto_Milán,_Caquetá')
# 12821.359054444634*atender_('Aguadas,_Caldas',_'Nunchía,_Casanare')
# 12031.779676494853*atender_('Aguadas,_Caldas',_'Mesetas,_Meta')
# 217425.8701406199*atender_('Salamina,_Caldas',_'Andes,_Antioquia')
# 99879.67016858727*atender_('Salamina,_Caldas',_'Medellín,_Antioquia')
# 498522.83254734793*atender_('Salamina,_Caldas',_'Dabeiba,_Antioquia')
# 201430.42873676567*atender_('Salamina,_Caldas',_'Salgar,_Antioquia')
# 21322.280006029247*atender_('Salamina,_Caldas',_'San_Pablo_de_Borbur,_Boyacá')
# 33679.85977792746*atender_('Salamina,_Caldas',_'Labranzagrande,_Boyacá')
# 24828.73457867597*atender_('Salamina,_Caldas',_'Miraflores,_Boyacá')
# 24630.57889221336*atender_('Salamina,_Caldas',_'Moniquirá,_Boyacá')
# 70625.17463482241*atender_('Salamina,_Caldas',_'Manizales,_Caldas')
# 30569.02034327803*atender_('Salamina,_Caldas',_'Anserma,_Caldas')
# 15635.263145984969*atender_('Salamina,_Caldas',_'Pensilvania,_Caldas')
# 22845.30512970292*atender_('Salamina,_Caldas',_'Riosucio,_Caldas')
# 16131.800609830972*atender_('Salamina,_Caldas',_'Aguadas,_Caldas')
# 400490.7436589711*atender_('Salamina,_Caldas',_'Morales,_Cauca')
# 424222.2037828664*atender_('Salamina,_Caldas',_'El_Tambo,_Cauca')
# 448183.54980135546*atender_('Salamina,_Caldas',_'Bolívar,_Cauca')
# 124076.93309033917*atender_('Salamina,_Caldas',_'Aguachica,_Cesar')
# 147355.42899557055*atender_('Salamina,_Caldas',_'San_Diego,_Cesar')
# 12932.142394697059*atender_('Salamina,_Caldas',_'Caparrapí,_Cundinamarca')
# 22572.06800249454*atender_('Salamina,_Caldas',_'Viotá,_Cundinamarca')
# 24341.267229010416*atender_('Salamina,_Caldas',_'Sasaima,_Cundinamarca')
# 511643.4202857957*atender_('Salamina,_Caldas',_'Neiva,_Huila')
# 791869.7327663436*atender_('Salamina,_Caldas',_'Pitalito,_Huila')
# 643969.6630163502*atender_('Salamina,_Caldas',_'Gigante,_Huila')
# 227417.17010433137*atender_('Salamina,_Caldas',_'Santa_Marta,_Magdalena')
# 311513.90963074507*atender_('Salamina,_Caldas',_'La_Unión,_Nariño')
# 376394.61060770403*atender_('Salamina,_Caldas',_'Pasto,_Nariño')
# 260307.267868611*atender_('Salamina,_Caldas',_'Samaniego,_Nariño')
# 98115.12137160885*atender_('Salamina,_Caldas',_'Sardinata,_Norte_de_Santander')
# 90885.8635824627*atender_('Salamina,_Caldas',_'Ocaña,_Norte_de_Santander')
# 96283.56580397217*atender_('Salamina,_Caldas',_'Convención,_Norte_de_Santander')
# 59683.080826936246*atender_('Salamina,_Caldas',_'Génova,_Quindío')
# 56458.0419892726*atender_('Salamina,_Caldas',_'Calarcá,_Quindío')
# 45005.83468911113*atender_('Salamina,_Caldas',_'Quimbaya,_Quindío')
# 54143.94088609661*atender_('Salamina,_Caldas',_'Pereira,_Risaralda')
# 47574.459495170704*atender_('Salamina,_Caldas',_'Santuario,_Risaralda')
# 43887.97730844741*atender_('Salamina,_Caldas',_'Belén_de_Umbria,_Risaralda')
# 55107.76608515689*atender_('Salamina,_Caldas',_'Rionegro,_Santander')
# 52261.676966182*atender_('Salamina,_Caldas',_'Bucaramanga,_Santander')
# 160548.66334196733*atender_('Salamina,_Caldas',_'Barbosa,_Santander')
# 191983.09188669117*atender_('Salamina,_Caldas',_'Socorro,_Santander')
# 144050.35521195084*atender_('Salamina,_Caldas',_'Simacota,_Santander')
# 139178.75169310928*atender_('Salamina,_Caldas',_'Chaparral,_Tolima')
# 216975.75394496747*atender_('Salamina,_Caldas',_'Dolores,_Tolima')
# 12538.469824638734*atender_('Salamina,_Caldas',_'Ibagué,_Tolima')
# 7036.3339340519515*atender_('Salamina,_Caldas',_'Líbano,_Tolima')
# 50919.06398858416*atender_('Salamina,_Caldas',_'Cartago,_Valle')
# 86463.1143193044*atender_('Salamina,_Caldas',_'Tulua,_Valle')
# 86916.51206686124*atender_('Salamina,_Caldas',_'Jamundí,_Valle')
# 36216.904479313016*atender_('Salamina,_Caldas',_'Sevilla,_Valle')
# 34810.54133208599*atender_('Salamina,_Caldas',_'Caicedonia,_Valle')
# 13736.158953876988*atender_('Salamina,_Caldas',_'Florencia,_Caquetá')
# 13169.100238685767*atender_('Salamina,_Caldas',_'Puerto_Milán,_Caquetá')
# 12656.965231016215*atender_('Salamina,_Caldas',_'Nunchía,_Casanare')
# 11049.68654145826*atender_('Salamina,_Caldas',_'Mesetas,_Meta')
# 1141299.914048435*atender_('Popayán,_Cauca',_'Andes,_Antioquia')
# 417975.03755334974*atender_('Popayán,_Cauca',_'Medellín,_Antioquia')
# 1226965.8652136484*atender_('Popayán,_Cauca',_'Dabeiba,_Antioquia')
# 855908.2460896606*atender_('Popayán,_Cauca',_'Salgar,_Antioquia')
# 64548.16703475233*atender_('Popayán,_Cauca',_'San_Pablo_de_Borbur,_Boyacá')
# 60308.33876483095*atender_('Popayán,_Cauca',_'Labranzagrande,_Boyacá')
# 48202.06624366546*atender_('Popayán,_Cauca',_'Miraflores,_Boyacá')
# 58363.26184859605*atender_('Popayán,_Cauca',_'Moniquirá,_Boyacá')
# 700934.6207869507*atender_('Popayán,_Cauca',_'Manizales,_Caldas')
# 235920.24897117104*atender_('Popayán,_Cauca',_'Anserma,_Caldas')
# 215331.86801210843*atender_('Popayán,_Cauca',_'Pensilvania,_Caldas')
# 206167.15792908162*atender_('Popayán,_Cauca',_'Riosucio,_Caldas')
# 223580.1116152244*atender_('Popayán,_Cauca',_'Aguadas,_Caldas')
# 62300.58695688864*atender_('Popayán,_Cauca',_'Morales,_Cauca')
# 30918.561891653226*atender_('Popayán,_Cauca',_'El_Tambo,_Cauca')
# 79665.0497034703*atender_('Popayán,_Cauca',_'Bolívar,_Cauca')
# 235524.73748779908*atender_('Popayán,_Cauca',_'Aguachica,_Cesar')
# 231771.63144403428*atender_('Popayán,_Cauca',_'San_Diego,_Cesar')
# 51809.40615637601*atender_('Popayán,_Cauca',_'Caparrapí,_Cundinamarca')
# 50502.40529472945*atender_('Popayán,_Cauca',_'Viotá,_Cundinamarca')
# 75550.02570853922*atender_('Popayán,_Cauca',_'Sasaima,_Cundinamarca')
# 314149.4997491077*atender_('Popayán,_Cauca',_'Neiva,_Huila')
# 173750.1413987884*atender_('Popayán,_Cauca',_'Pitalito,_Huila')
# 230771.86691555197*atender_('Popayán,_Cauca',_'Gigante,_Huila')
# 344510.0933239128*atender_('Popayán,_Cauca',_'Santa_Marta,_Magdalena')
# 76376.03192287644*atender_('Popayán,_Cauca',_'La_Unión,_Nariño')
# 123460.530204973*atender_('Popayán,_Cauca',_'Pasto,_Nariño')
# 88541.8419504493*atender_('Popayán,_Cauca',_'Samaniego,_Nariño')
# 174096.7504205366*atender_('Popayán,_Cauca',_'Sardinata,_Norte_de_Santander')
# 170832.05832773016*atender_('Popayán,_Cauca',_'Ocaña,_Norte_de_Santander')
# 168537.30179286085*atender_('Popayán,_Cauca',_'Convención,_Norte_de_Santander')
# 96252.14260764392*atender_('Popayán,_Cauca',_'Génova,_Quindío')
# 133598.0933619386*atender_('Popayán,_Cauca',_'Calarcá,_Quindío')
# 126325.74114093416*atender_('Popayán,_Cauca',_'Quimbaya,_Quindío')
# 222894.5350879264*atender_('Popayán,_Cauca',_'Pereira,_Risaralda')
# 194808.78879482043*atender_('Popayán,_Cauca',_'Santuario,_Risaralda')
# 255963.5257883065*atender_('Popayán,_Cauca',_'Belén_de_Umbria,_Risaralda')
# 111670.01432110033*atender_('Popayán,_Cauca',_'Rionegro,_Santander')
# 104504.20694097284*atender_('Popayán,_Cauca',_'Bucaramanga,_Santander')
# 391430.9677514067*atender_('Popayán,_Cauca',_'Barbosa,_Santander')
# 412273.1126971773*atender_('Popayán,_Cauca',_'Socorro,_Santander')
# 334308.9034957807*atender_('Popayán,_Cauca',_'Simacota,_Santander')
# 142689.44786771867*atender_('Popayán,_Cauca',_'Chaparral,_Tolima')
# 256257.86403470993*atender_('Popayán,_Cauca',_'Dolores,_Tolima')
# 34691.97906769868*atender_('Popayán,_Cauca',_'Ibagué,_Tolima')
# 34125.77837191876*atender_('Popayán,_Cauca',_'Líbano,_Tolima')
# 147409.48035895408*atender_('Popayán,_Cauca',_'Cartago,_Valle')
# 99192.41073016332*atender_('Popayán,_Cauca',_'Tulua,_Valle')
# 26771.826936636833*atender_('Popayán,_Cauca',_'Jamundí,_Valle')
# 52273.84668048531*atender_('Popayán,_Cauca',_'Sevilla,_Valle')
# 62097.100059805416*atender_('Popayán,_Cauca',_'Caicedonia,_Valle')
# 4715.602612505436*atender_('Popayán,_Cauca',_'Florencia,_Caquetá')
# 5066.298691353189*atender_('Popayán,_Cauca',_'Puerto_Milán,_Caquetá')
# 20719.908767169803*atender_('Popayán,_Cauca',_'Nunchía,_Casanare')
# 10934.590570758812*atender_('Popayán,_Cauca',_'Mesetas,_Meta')
# 1949159.5729142001*atender_('Valledupar,_Cesar',_'Andes,_Antioquia')
# 507690.4066212036*atender_('Valledupar,_Cesar',_'Medellín,_Antioquia')
# 1257077.714266116*atender_('Valledupar,_Cesar',_'Dabeiba,_Antioquia')
# 1256164.342015336*atender_('Valledupar,_Cesar',_'Salgar,_Antioquia')
# 76921.75609645162*atender_('Valledupar,_Cesar',_'San_Pablo_de_Borbur,_Boyacá')
# 59464.776005038366*atender_('Valledupar,_Cesar',_'Labranzagrande,_Boyacá')
# 58708.57251266132*atender_('Valledupar,_Cesar',_'Miraflores,_Boyacá')
# 58661.58125747656*atender_('Valledupar,_Cesar',_'Moniquirá,_Boyacá')
# 1438379.2207433765*atender_('Valledupar,_Cesar',_'Manizales,_Caldas')
# 476820.70604814*atender_('Valledupar,_Cesar',_'Anserma,_Caldas')
# 355416.1854959345*atender_('Valledupar,_Cesar',_'Pensilvania,_Caldas')
# 368814.89599650935*atender_('Valledupar,_Cesar',_'Riosucio,_Caldas')
# 359136.5684271982*atender_('Valledupar,_Cesar',_'Aguadas,_Caldas')
# 1183000.3099104278*atender_('Valledupar,_Cesar',_'Morales,_Cauca')
# 1155698.0732623432*atender_('Valledupar,_Cesar',_'El_Tambo,_Cauca')
# 1104863.3675061634*atender_('Valledupar,_Cesar',_'Bolívar,_Cauca')
# 78374.25458858135*atender_('Valledupar,_Cesar',_'Aguachica,_Cesar')
# 4066.0064616044624*atender_('Valledupar,_Cesar',_'San_Diego,_Cesar')
# 75667.56186155099*atender_('Valledupar,_Cesar',_'Caparrapí,_Cundinamarca')
# 107128.24652587314*atender_('Valledupar,_Cesar',_'Viotá,_Cundinamarca')
# 128473.58606387154*atender_('Valledupar,_Cesar',_'Sasaima,_Cundinamarca')
# 1705801.7842876376*atender_('Valledupar,_Cesar',_'Neiva,_Huila')
# 1990323.153734581*atender_('Valledupar,_Cesar',_'Pitalito,_Huila')
# 1828872.2861107667*atender_('Valledupar,_Cesar',_'Gigante,_Huila')
# 45092.628888670486*atender_('Valledupar,_Cesar',_'Santa_Marta,_Magdalena')
# 730630.3534158784*atender_('Valledupar,_Cesar',_'La_Unión,_Nariño')
# 824970.4313596332*atender_('Valledupar,_Cesar',_'Pasto,_Nariño')
# 573800.9316926895*atender_('Valledupar,_Cesar',_'Samaniego,_Nariño')
# 56523.44263117958*atender_('Valledupar,_Cesar',_'Sardinata,_Norte_de_Santander')
# 58190.01871138807*atender_('Valledupar,_Cesar',_'Ocaña,_Norte_de_Santander')
# 38057.426368299224*atender_('Valledupar,_Cesar',_'Convención,_Norte_de_Santander')
# 335082.61135436624*atender_('Valledupar,_Cesar',_'Génova,_Quindío')
# 392679.9647690852*atender_('Valledupar,_Cesar',_'Calarcá,_Quindío')
# 348147.27808837424*atender_('Valledupar,_Cesar',_'Quimbaya,_Quindío')
# 545245.3897486285*atender_('Valledupar,_Cesar',_'Pereira,_Risaralda')
# 444669.6459456219*atender_('Valledupar,_Cesar',_'Santuario,_Risaralda')
# 530307.14546249*atender_('Valledupar,_Cesar',_'Belén_de_Umbria,_Risaralda')
# 54524.12264289857*atender_('Valledupar,_Cesar',_'Rionegro,_Santander')
# 58854.95377437154*atender_('Valledupar,_Cesar',_'Bucaramanga,_Santander')
# 385552.936595153*atender_('Valledupar,_Cesar',_'Barbosa,_Santander')
# 315240.3745904591*atender_('Valledupar,_Cesar',_'Socorro,_Santander')
# 246239.41007858457*atender_('Valledupar,_Cesar',_'Simacota,_Santander')
# 617349.0767977952*atender_('Valledupar,_Cesar',_'Chaparral,_Tolima')
# 827022.7567952893*atender_('Valledupar,_Cesar',_'Dolores,_Tolima')
# 89747.14335467442*atender_('Valledupar,_Cesar',_'Ibagué,_Tolima')
# 69467.16012962964*atender_('Valledupar,_Cesar',_'Líbano,_Tolima')
# 395458.14057355444*atender_('Valledupar,_Cesar',_'Cartago,_Valle')
# 414410.096673165*atender_('Valledupar,_Cesar',_'Tulua,_Valle')
# 282003.2737855049*atender_('Valledupar,_Cesar',_'Jamundí,_Valle')
# 193108.76626814462*atender_('Valledupar,_Cesar',_'Sevilla,_Valle')
# 206618.5999671446*atender_('Valledupar,_Cesar',_'Caicedonia,_Valle')
# 33700.93576760235*atender_('Valledupar,_Cesar',_'Florencia,_Caquetá')
# 30883.92539110157*atender_('Valledupar,_Cesar',_'Puerto_Milán,_Caquetá')
# 19186.07209600294*atender_('Valledupar,_Cesar',_'Nunchía,_Casanare')
# 31712.36550730604*atender_('Valledupar,_Cesar',_'Mesetas,_Meta')
# 737194.3838628251*atender_('Bogotá,_Cundinamarca',_'Andes,_Antioquia')
# 233009.09269330636*atender_('Bogotá,_Cundinamarca',_'Medellín,_Antioquia')
# 862427.1604748863*atender_('Bogotá,_Cundinamarca',_'Dabeiba,_Antioquia')
# 547316.7125399109*atender_('Bogotá,_Cundinamarca',_'Salgar,_Antioquia')
# 16292.047111175725*atender_('Bogotá,_Cundinamarca',_'San_Pablo_de_Borbur,_Boyacá')
# 20915.767318242215*atender_('Bogotá,_Cundinamarca',_'Labranzagrande,_Boyacá')
# 11758.553592751652*atender_('Bogotá,_Cundinamarca',_'Miraflores,_Boyacá')
# 17114.90803714207*atender_('Bogotá,_Cundinamarca',_'Moniquirá,_Boyacá')
# 360440.0950761476*atender_('Bogotá,_Cundinamarca',_'Manizales,_Caldas')
# 142301.98448619034*atender_('Bogotá,_Cundinamarca',_'Anserma,_Caldas')
# 86117.21979827873*atender_('Bogotá,_Cundinamarca',_'Pensilvania,_Caldas')
# 119990.09358430855*atender_('Bogotá,_Cundinamarca',_'Riosucio,_Caldas')
# 110081.30407584817*atender_('Bogotá,_Cundinamarca',_'Aguadas,_Caldas')
# 452747.0266372574*atender_('Bogotá,_Cundinamarca',_'Morales,_Cauca')
# 460561.3753312662*atender_('Bogotá,_Cundinamarca',_'El_Tambo,_Cauca')
# 471082.46263396885*atender_('Bogotá,_Cundinamarca',_'Bolívar,_Cauca')
# 132255.6766616472*atender_('Bogotá,_Cundinamarca',_'Aguachica,_Cesar')
# 155428.2247455102*atender_('Bogotá,_Cundinamarca',_'San_Diego,_Cesar')
# 11991.242417866835*atender_('Bogotá,_Cundinamarca',_'Caparrapí,_Cundinamarca')
# 7527.4791449440245*atender_('Bogotá,_Cundinamarca',_'Viotá,_Cundinamarca')
# 9833.999224375251*atender_('Bogotá,_Cundinamarca',_'Sasaima,_Cundinamarca')
# 444293.06614908675*atender_('Bogotá,_Cundinamarca',_'Neiva,_Huila')
# 765955.4152444655*atender_('Bogotá,_Cundinamarca',_'Pitalito,_Huila')
# 581888.556492716*atender_('Bogotá,_Cundinamarca',_'Gigante,_Huila')
# 249020.2957081795*atender_('Bogotá,_Cundinamarca',_'Santa_Marta,_Magdalena')
# 325497.76219219394*atender_('Bogotá,_Cundinamarca',_'La_Unión,_Nariño')
# 384517.66331921896*atender_('Bogotá,_Cundinamarca',_'Pasto,_Nariño')
# 276903.6951696867*atender_('Bogotá,_Cundinamarca',_'Samaniego,_Nariño')
# 96347.74040545594*atender_('Bogotá,_Cundinamarca',_'Sardinata,_Norte_de_Santander')
# 94280.28358840698*atender_('Bogotá,_Cundinamarca',_'Ocaña,_Norte_de_Santander')
# 99787.84244975372*atender_('Bogotá,_Cundinamarca',_'Convención,_Norte_de_Santander')
# 84836.44201598321*atender_('Bogotá,_Cundinamarca',_'Génova,_Quindío')
# 96383.44782367884*atender_('Bogotá,_Cundinamarca',_'Calarcá,_Quindío')
# 92018.23290710826*atender_('Bogotá,_Cundinamarca',_'Quimbaya,_Quindío')
# 137876.5155064801*atender_('Bogotá,_Cundinamarca',_'Pereira,_Risaralda')
# 140044.12859279726*atender_('Bogotá,_Cundinamarca',_'Santuario,_Risaralda')
# 166451.5641980498*atender_('Bogotá,_Cundinamarca',_'Belén_de_Umbria,_Risaralda')
# 55319.72885014657*atender_('Bogotá,_Cundinamarca',_'Rionegro,_Santander')
# 48251.55449572179*atender_('Bogotá,_Cundinamarca',_'Bucaramanga,_Santander')
# 118621.49474277164*atender_('Bogotá,_Cundinamarca',_'Barbosa,_Santander')
# 158567.21617036892*atender_('Bogotá,_Cundinamarca',_'Socorro,_Santander')
# 134885.5384544594*atender_('Bogotá,_Cundinamarca',_'Simacota,_Santander')
# 151142.87914510755*atender_('Bogotá,_Cundinamarca',_'Chaparral,_Tolima')
# 144015.94640109132*atender_('Bogotá,_Cundinamarca',_'Dolores,_Tolima')
# 16400.57566518105*atender_('Bogotá,_Cundinamarca',_'Ibagué,_Tolima')
# 11418.905577537778*atender_('Bogotá,_Cundinamarca',_'Líbano,_Tolima')
# 113483.31715078442*atender_('Bogotá,_Cundinamarca',_'Cartago,_Valle')
# 121672.95116342409*atender_('Bogotá,_Cundinamarca',_'Tulua,_Valle')
# 102611.70854120313*atender_('Bogotá,_Cundinamarca',_'Jamundí,_Valle')
# 52375.825067318925*atender_('Bogotá,_Cundinamarca',_'Sevilla,_Valle')
# 54869.11606758201*atender_('Bogotá,_Cundinamarca',_'Caicedonia,_Valle')
# 12453.610203227958*atender_('Bogotá,_Cundinamarca',_'Florencia,_Caquetá')
# 11824.720880492598*atender_('Bogotá,_Cundinamarca',_'Puerto_Milán,_Caquetá')
# 8411.317469069496*atender_('Bogotá,_Cundinamarca',_'Nunchía,_Casanare')
# 6601.819167115223*atender_('Bogotá,_Cundinamarca',_'Mesetas,_Meta')
# 842216.732113385*atender_('Santana,_Huila',_'Andes,_Antioquia')
# 299041.13785102*atender_('Santana,_Huila',_'Medellín,_Antioquia')
# 1010532.3314300814*atender_('Santana,_Huila',_'Dabeiba,_Antioquia')
# 645629.3144737622*atender_('Santana,_Huila',_'Salgar,_Antioquia')
# 34435.370163894*atender_('Santana,_Huila',_'San_Pablo_de_Borbur,_Boyacá')
# 34288.87606943113*atender_('Santana,_Huila',_'Labranzagrande,_Boyacá')
# 24238.518671982514*atender_('Santana,_Huila',_'Miraflores,_Boyacá')
# 32614.33689194559*atender_('Santana,_Huila',_'Moniquirá,_Boyacá')
# 416173.5516970126*atender_('Santana,_Huila',_'Manizales,_Caldas')
# 157611.31974418025*atender_('Santana,_Huila',_'Anserma,_Caldas')
# 123282.56269041156*atender_('Santana,_Huila',_'Pensilvania,_Caldas')
# 140600.09053081425*atender_('Santana,_Huila',_'Riosucio,_Caldas')
# 142865.98932901895*atender_('Santana,_Huila',_'Aguadas,_Caldas')
# 308294.31982673606*atender_('Santana,_Huila',_'Morales,_Cauca')
# 316734.4527331783*atender_('Santana,_Huila',_'El_Tambo,_Cauca')
# 335690.90594418824*atender_('Santana,_Huila',_'Bolívar,_Cauca')
# 173566.69308816*atender_('Santana,_Huila',_'Aguachica,_Cesar')
# 186609.8433841466*atender_('Santana,_Huila',_'San_Diego,_Cesar')
# 25924.323147918913*atender_('Santana,_Huila',_'Caparrapí,_Cundinamarca')
# 15303.084168228757*atender_('Santana,_Huila',_'Viotá,_Cundinamarca')
# 31707.74481745381*atender_('Santana,_Huila',_'Sasaima,_Cundinamarca')
# 179506.02410980596*atender_('Santana,_Huila',_'Neiva,_Huila')
# 503062.54694838816*atender_('Santana,_Huila',_'Pitalito,_Huila')
# 316569.3048206355*atender_('Santana,_Huila',_'Gigante,_Huila')
# 289810.81847424066*atender_('Santana,_Huila',_'Santa_Marta,_Magdalena')
# 238179.78312743225*atender_('Santana,_Huila',_'La_Unión,_Nariño')
# 288648.77609087765*atender_('Santana,_Huila',_'Pasto,_Nariño')
# 212572.01602125308*atender_('Santana,_Huila',_'Samaniego,_Nariño')
# 126595.14956659576*atender_('Santana,_Huila',_'Sardinata,_Norte_de_Santander')
# 124638.8662454105*atender_('Santana,_Huila',_'Ocaña,_Norte_de_Santander')
# 127192.60355043013*atender_('Santana,_Huila',_'Convención,_Norte_de_Santander')
# 60062.397019386706*atender_('Santana,_Huila',_'Génova,_Quindío')
# 79274.276849476*atender_('Santana,_Huila',_'Calarcá,_Quindío')
# 81602.6203729868*atender_('Santana,_Huila',_'Quimbaya,_Quindío')
# 135471.06412885728*atender_('Santana,_Huila',_'Pereira,_Risaralda')
# 141147.43547283343*atender_('Santana,_Huila',_'Santuario,_Risaralda')
# 178755.96039895932*atender_('Santana,_Huila',_'Belén_de_Umbria,_Risaralda')
# 77368.12671628331*atender_('Santana,_Huila',_'Rionegro,_Santander')
# 69827.27262990986*atender_('Santana,_Huila',_'Bucaramanga,_Santander')
# 221749.21756834447*atender_('Santana,_Huila',_'Barbosa,_Santander')
# 254495.43858273383*atender_('Santana,_Huila',_'Socorro,_Santander')
# 211784.4730901994*atender_('Santana,_Huila',_'Simacota,_Santander')
# 78859.81876007572*atender_('Santana,_Huila',_'Chaparral,_Tolima')
# 8221.810540651815*atender_('Santana,_Huila',_'Dolores,_Tolima')
# 14834.200732488223*atender_('Santana,_Huila',_'Ibagué,_Tolima')
# 15778.659046832552*atender_('Santana,_Huila',_'Líbano,_Tolima')
# 103435.75416764108*atender_('Santana,_Huila',_'Cartago,_Valle')
# 85152.06762241683*atender_('Santana,_Huila',_'Tulua,_Valle')
# 69299.69354876086*atender_('Santana,_Huila',_'Jamundí,_Valle')
# 37240.989488084066*atender_('Santana,_Huila',_'Sevilla,_Valle')
# 41755.745875864865*atender_('Santana,_Huila',_'Caicedonia,_Valle')
# 7974.654428259205*atender_('Santana,_Huila',_'Florencia,_Caquetá')
# 7858.666885558625*atender_('Santana,_Huila',_'Puerto_Milán,_Caquetá')
# 12407.319451641186*atender_('Santana,_Huila',_'Nunchía,_Casanare')
# 3238.158047245731*atender_('Santana,_Huila',_'Mesetas,_Meta')
# 940330.5014387396*atender_('Neiva,_Huila',_'Andes,_Antioquia')
# 343469.6175528052*atender_('Neiva,_Huila',_'Medellín,_Antioquia')
# 1097273.7504940922*atender_('Neiva,_Huila',_'Dabeiba,_Antioquia')
# 719899.0475573099*atender_('Neiva,_Huila',_'Salgar,_Antioquia')
# 45898.24227115794*atender_('Neiva,_Huila',_'San_Pablo_de_Borbur,_Boyacá')
# 43970.077263192296*atender_('Neiva,_Huila',_'Labranzagrande,_Boyacá')
# 33186.179153911384*atender_('Neiva,_Huila',_'Miraflores,_Boyacá')
# 42450.5387154824*atender_('Neiva,_Huila',_'Moniquirá,_Boyacá')
# 504797.2287179845*atender_('Neiva,_Huila',_'Manizales,_Caldas')
# 181151.70254398178*atender_('Neiva,_Huila',_'Anserma,_Caldas')
# 155698.91313141934*atender_('Neiva,_Huila',_'Pensilvania,_Caldas')
# 161932.2206021967*atender_('Neiva,_Huila',_'Riosucio,_Caldas')
# 170937.93887481725*atender_('Neiva,_Huila',_'Aguadas,_Caldas')
# 207907.03195303382*atender_('Neiva,_Huila',_'Morales,_Cauca')
# 215042.06409749962*atender_('Neiva,_Huila',_'El_Tambo,_Cauca')
# 240585.12238086463*atender_('Neiva,_Huila',_'Bolívar,_Cauca')
# 198263.98511392786*atender_('Neiva,_Huila',_'Aguachica,_Cesar')
# 204989.36716779976*atender_('Neiva,_Huila',_'San_Diego,_Cesar')
# 35586.68328701257*atender_('Neiva,_Huila',_'Caparrapí,_Cundinamarca')
# 28246.30818752547*atender_('Neiva,_Huila',_'Viotá,_Cundinamarca')
# 47999.06389063307*atender_('Neiva,_Huila',_'Sasaima,_Cundinamarca')
# 0.0
# 329835.2485764492*atender_('Neiva,_Huila',_'Pitalito,_Huila')
# 148825.9044379822*atender_('Neiva,_Huila',_'Gigante,_Huila')
# 312818.9350220627*atender_('Neiva,_Huila',_'Santa_Marta,_Magdalena')
# 177148.38786161272*atender_('Neiva,_Huila',_'La_Unión,_Nariño')
# 223210.04727005423*atender_('Neiva,_Huila',_'Pasto,_Nariño')
# 167019.83819207756*atender_('Neiva,_Huila',_'Samaniego,_Nariño')
# 145270.00112922394*atender_('Neiva,_Huila',_'Sardinata,_Norte_de_Santander')
# 142961.90520459614*atender_('Neiva,_Huila',_'Ocaña,_Norte_de_Santander')
# 143687.11883527128*atender_('Neiva,_Huila',_'Convención,_Norte_de_Santander')
# 61661.661225742224*atender_('Neiva,_Huila',_'Génova,_Quindío')
# 89055.8821686802*atender_('Neiva,_Huila',_'Calarcá,_Quindío')
# 90262.36171166445*atender_('Neiva,_Huila',_'Quimbaya,_Quindío')
# 157982.0555515861*atender_('Neiva,_Huila',_'Pereira,_Risaralda')
# 154495.30687793993*atender_('Neiva,_Huila',_'Santuario,_Risaralda')
# 200980.0248117958*atender_('Neiva,_Huila',_'Belén_de_Umbria,_Risaralda')
# 90833.1375898678*atender_('Neiva,_Huila',_'Rionegro,_Santander')
# 83297.95616772976*atender_('Neiva,_Huila',_'Bucaramanga,_Santander')
# 286706.8101318835*atender_('Neiva,_Huila',_'Barbosa,_Santander')
# 315190.5526601807*atender_('Neiva,_Huila',_'Socorro,_Santander')
# 259287.68566749032*atender_('Neiva,_Huila',_'Simacota,_Santander')
# 67467.21716006391*atender_('Neiva,_Huila',_'Chaparral,_Tolima')
# 93610.92158367753*atender_('Neiva,_Huila',_'Dolores,_Tolima')
# 20539.10473773431*atender_('Neiva,_Huila',_'Ibagué,_Tolima')
# 21999.128841629325*atender_('Neiva,_Huila',_'Líbano,_Tolima')
# 111523.46436241714*atender_('Neiva,_Huila',_'Cartago,_Valle')
# 74911.53150066457*atender_('Neiva,_Huila',_'Tulua,_Valle')
# 47379.58171989696*atender_('Neiva,_Huila',_'Jamundí,_Valle')
# 35857.433977293076*atender_('Neiva,_Huila',_'Sevilla,_Valle')
# 42830.08762867796*atender_('Neiva,_Huila',_'Caicedonia,_Valle')
# 5340.659466267087*atender_('Neiva,_Huila',_'Florencia,_Caquetá')
# 5629.3786952885575*atender_('Neiva,_Huila',_'Puerto_Milán,_Caquetá')
# 15457.95519855893*atender_('Neiva,_Huila',_'Nunchía,_Casanare')
# 5052.977923942113*atender_('Neiva,_Huila',_'Mesetas,_Meta')
# 2069702.5327439345*atender_('Santa_Marta,_Magdalena',_'Andes,_Antioquia')
# 545801.745212469*atender_('Santa_Marta,_Magdalena',_'Medellín,_Antioquia')
# 1293738.9994926308*atender_('Santa_Marta,_Magdalena',_'Dabeiba,_Antioquia')
# 1330538.3553665567*atender_('Santa_Marta,_Magdalena',_'Salgar,_Antioquia')
# 87905.48257299337*atender_('Santa_Marta,_Magdalena',_'San_Pablo_de_Borbur,_Boyacá')
# 70657.96678782227*atender_('Santa_Marta,_Magdalena',_'Labranzagrande,_Boyacá')
# 68086.03576992474*atender_('Santa_Marta,_Magdalena',_'Miraflores,_Boyacá')
# 68786.01453504873*atender_('Santa_Marta,_Magdalena',_'Moniquirá,_Boyacá')
# 1551759.4709388758*atender_('Santa_Marta,_Magdalena',_'Manizales,_Caldas')
# 510358.0733069794*atender_('Santa_Marta,_Magdalena',_'Anserma,_Caldas')
# 388367.75636578863*atender_('Santa_Marta,_Magdalena',_'Pensilvania,_Caldas')
# 394928.4085780103*atender_('Santa_Marta,_Magdalena',_'Riosucio,_Caldas')
# 388613.2751867011*atender_('Santa_Marta,_Magdalena',_'Aguadas,_Caldas')
# 1237996.970554074*atender_('Santa_Marta,_Magdalena',_'Morales,_Cauca')
# 1208404.935871643*atender_('Santa_Marta,_Magdalena',_'El_Tambo,_Cauca')
# 1152700.6274717015*atender_('Santa_Marta,_Magdalena',_'Bolívar,_Cauca')
# 106788.18670884799*atender_('Santa_Marta,_Magdalena',_'Aguachica,_Cesar')
# 36031.85870053128*atender_('Santa_Marta,_Magdalena',_'San_Diego,_Cesar')
# 84688.251801457*atender_('Santa_Marta,_Magdalena',_'Caparrapí,_Cundinamarca')
# 118467.7348189377*atender_('Santa_Marta,_Magdalena',_'Viotá,_Cundinamarca')
# 143327.64281832363*atender_('Santa_Marta,_Magdalena',_'Sasaima,_Cundinamarca')
# 1831637.1853265513*atender_('Santa_Marta,_Magdalena',_'Neiva,_Huila')
# 2099518.209993781*atender_('Santa_Marta,_Magdalena',_'Pitalito,_Huila')
# 1950171.6531042564*atender_('Santa_Marta,_Magdalena',_'Gigante,_Huila')
# 0.0
# 760588.9047959081*atender_('Santa_Marta,_Magdalena',_'La_Unión,_Nariño')
# 858213.6191588793*atender_('Santa_Marta,_Magdalena',_'Pasto,_Nariño')
# 593358.8139871149*atender_('Santa_Marta,_Magdalena',_'Samaniego,_Nariño')
# 82159.76187767313*atender_('Santa_Marta,_Magdalena',_'Sardinata,_Norte_de_Santander')
# 80549.61915979724*atender_('Santa_Marta,_Magdalena',_'Ocaña,_Norte_de_Santander')
# 60432.085107411265*atender_('Santa_Marta,_Magdalena',_'Convención,_Norte_de_Santander')
# 358131.7979758837*atender_('Santa_Marta,_Magdalena',_'Génova,_Quindío')
# 420694.335697628*atender_('Santa_Marta,_Magdalena',_'Calarcá,_Quindío')
# 372045.30651030265*atender_('Santa_Marta,_Magdalena',_'Quimbaya,_Quindío')
# 585028.8501563801*atender_('Santa_Marta,_Magdalena',_'Pereira,_Risaralda')
# 472613.01818761684*atender_('Santa_Marta,_Magdalena',_'Santuario,_Risaralda')
# 565438.952927549*atender_('Santa_Marta,_Magdalena',_'Belén_de_Umbria,_Risaralda')
# 70141.68773405615*atender_('Santa_Marta,_Magdalena',_'Rionegro,_Santander')
# 74910.75570459518*atender_('Santa_Marta,_Magdalena',_'Bucaramanga,_Santander')
# 452087.3388706238*atender_('Santa_Marta,_Magdalena',_'Barbosa,_Santander')
# 382771.46716458496*atender_('Santa_Marta,_Magdalena',_'Socorro,_Santander')
# 296905.3210556724*atender_('Santa_Marta,_Magdalena',_'Simacota,_Santander')
# 661239.7393221301*atender_('Santa_Marta,_Magdalena',_'Chaparral,_Tolima')
# 900898.3404336368*atender_('Santa_Marta,_Magdalena',_'Dolores,_Tolima')
# 97296.02304991467*atender_('Santa_Marta,_Magdalena',_'Ibagué,_Tolima')
# 75962.85386754655*atender_('Santa_Marta,_Magdalena',_'Líbano,_Tolima')
# 421071.8548152981*atender_('Santa_Marta,_Magdalena',_'Cartago,_Valle')
# 439468.595964322*atender_('Santa_Marta,_Magdalena',_'Tulua,_Valle')
# 295689.7649891347*atender_('Santa_Marta,_Magdalena',_'Jamundí,_Valle')
# 205676.25277330633*atender_('Santa_Marta,_Magdalena',_'Sevilla,_Valle')
# 220373.3983127091*atender_('Santa_Marta,_Magdalena',_'Caicedonia,_Valle')
# 35784.511334431*atender_('Santa_Marta,_Magdalena',_'Florencia,_Caquetá')
# 32795.08718391587*atender_('Santa_Marta,_Magdalena',_'Puerto_Milán,_Caquetá')
# 22975.222215139438*atender_('Santa_Marta,_Magdalena',_'Nunchía,_Casanare')
# 34779.14085163861*atender_('Santa_Marta,_Magdalena',_'Mesetas,_Meta')
# 1497999.9936456995*atender_('Cúcuta,_Nor._de_Santander',_'Andes,_Antioquia')
# 381141.65662890166*atender_('Cúcuta,_Nor._de_Santander',_'Medellín,_Antioquia')
# 1077610.3352482023*atender_('Cúcuta,_Nor._de_Santander',_'Dabeiba,_Antioquia')
# 976657.4136839741*atender_('Cúcuta,_Nor._de_Santander',_'Salgar,_Antioquia')
# 45872.05396482383*atender_('Cúcuta,_Nor._de_Santander',_'San_Pablo_de_Borbur,_Boyacá')
# 30464.425177689896*atender_('Cúcuta,_Nor._de_Santander',_'Labranzagrande,_Boyacá')
# 33226.94033224479*atender_('Cúcuta,_Nor._de_Santander',_'Miraflores,_Boyacá')
# 31267.889302882042*atender_('Cúcuta,_Nor._de_Santander',_'Moniquirá,_Boyacá')
# 1050614.2556774556*atender_('Cúcuta,_Nor._de_Santander',_'Manizales,_Caldas')
# 356936.5494106935*atender_('Cúcuta,_Nor._de_Santander',_'Anserma,_Caldas')
# 249566.03689224125*atender_('Cúcuta,_Nor._de_Santander',_'Pensilvania,_Caldas')
# 276121.92615987937*atender_('Cúcuta,_Nor._de_Santander',_'Riosucio,_Caldas')
# 260700.22627570044*atender_('Cúcuta,_Nor._de_Santander',_'Aguadas,_Caldas')
# 954253.0401770405*atender_('Cúcuta,_Nor._de_Santander',_'Morales,_Cauca')
# 937143.2592710399*atender_('Cúcuta,_Nor._de_Santander',_'El_Tambo,_Cauca')
# 904988.6556092984*atender_('Cúcuta,_Nor._de_Santander',_'Bolívar,_Cauca')
# 41319.227972486085*atender_('Cúcuta,_Nor._de_Santander',_'Aguachica,_Cesar')
# 63760.63785108682*atender_('Cúcuta,_Nor._de_Santander',_'San_Diego,_Cesar')
# 48848.18417254316*atender_('Cúcuta,_Nor._de_Santander',_'Caparrapí,_Cundinamarca')
# 72412.22031968425*atender_('Cúcuta,_Nor._de_Santander',_'Viotá,_Cundinamarca')
# 83929.88846547673*atender_('Cúcuta,_Nor._de_Santander',_'Sasaima,_Cundinamarca')
# 1279712.1248815467*atender_('Cúcuta,_Nor._de_Santander',_'Neiva,_Huila')
# 1585622.0185377386*atender_('Cúcuta,_Nor._de_Santander',_'Pitalito,_Huila')
# 1407830.6731653216*atender_('Cúcuta,_Nor._de_Santander',_'Gigante,_Huila')
# 135379.36433845077*atender_('Cúcuta,_Nor._de_Santander',_'Santa_Marta,_Magdalena')
# 603200.6789631196*atender_('Cúcuta,_Nor._de_Santander',_'La_Unión,_Nariño')
# 685067.2080006533*atender_('Cúcuta,_Nor._de_Santander',_'Pasto,_Nariño')
# 482707.2086272205*atender_('Cúcuta,_Nor._de_Santander',_'Samaniego,_Nariño')
# 9179.887358549666*atender_('Cúcuta,_Nor._de_Santander',_'Sardinata,_Norte_de_Santander')
# 23828.671751285365*atender_('Cúcuta,_Nor._de_Santander',_'Ocaña,_Norte_de_Santander')
# 24065.76483780774*atender_('Cúcuta,_Nor._de_Santander',_'Convención,_Norte_de_Santander')
# 252323.94479439914*atender_('Cúcuta,_Nor._de_Santander',_'Génova,_Quindío')
# 293229.8910818892*atender_('Cúcuta,_Nor._de_Santander',_'Calarcá,_Quindío')
# 261805.12533301374*atender_('Cúcuta,_Nor._de_Santander',_'Quimbaya,_Quindío')
# 404938.6703465626*atender_('Cúcuta,_Nor._de_Santander',_'Pereira,_Risaralda')
# 339727.02757177444*atender_('Cúcuta,_Nor._de_Santander',_'Santuario,_Risaralda')
# 401515.14143373934*atender_('Cúcuta,_Nor._de_Santander',_'Belén_de_Umbria,_Risaralda')
# 20178.464803277304*atender_('Cúcuta,_Nor._de_Santander',_'Rionegro,_Santander')
# 19755.68689230042*atender_('Cúcuta,_Nor._de_Santander',_'Bucaramanga,_Santander')
# 205668.99254325457*atender_('Cúcuta,_Nor._de_Santander',_'Barbosa,_Santander')
# 140787.0887093972*atender_('Cúcuta,_Nor._de_Santander',_'Socorro,_Santander')
# 117095.099865506*atender_('Cúcuta,_Nor._de_Santander',_'Simacota,_Santander')
# 463322.8241054932*atender_('Cúcuta,_Nor._de_Santander',_'Chaparral,_Tolima')
# 591377.8581881864*atender_('Cúcuta,_Nor._de_Santander',_'Dolores,_Tolima')
# 64623.88927473316*atender_('Cúcuta,_Nor._de_Santander',_'Ibagué,_Tolima')
# 48590.264388959615*atender_('Cúcuta,_Nor._de_Santander',_'Líbano,_Tolima')
# 300539.6605443785*atender_('Cúcuta,_Nor._de_Santander',_'Cartago,_Valle')
# 319518.1298096953*atender_('Cúcuta,_Nor._de_Santander',_'Tulua,_Valle')
# 225688.88632977952*atender_('Cúcuta,_Nor._de_Santander',_'Jamundí,_Valle')
# 146934.34310580857*atender_('Cúcuta,_Nor._de_Santander',_'Sevilla,_Valle')
# 156450.67660127013*atender_('Cúcuta,_Nor._de_Santander',_'Caicedonia,_Valle')
# 26437.399139752135*atender_('Cúcuta,_Nor._de_Santander',_'Florencia,_Caquetá')
# 24293.124590386215*atender_('Cúcuta,_Nor._de_Santander',_'Puerto_Milán,_Caquetá')
# 9749.070138370043*atender_('Cúcuta,_Nor._de_Santander',_'Nunchía,_Casanare')
# 22419.398579474295*atender_('Cúcuta,_Nor._de_Santander',_'Mesetas,_Meta')
# 1669130.1105244714*atender_('Pasto,_Nariño',_'Andes,_Antioquia')
# 577802.7217718784*atender_('Pasto,_Nariño',_'Medellín,_Antioquia')
# 1621353.7819549912*atender_('Pasto,_Nariño',_'Dabeiba,_Antioquia')
# 1213167.928273612*atender_('Pasto,_Nariño',_'Salgar,_Antioquia')
# 88272.90503666397*atender_('Pasto,_Nariño',_'San_Pablo_de_Borbur,_Boyacá')
# 76928.4440341913*atender_('Pasto,_Nariño',_'Labranzagrande,_Boyacá')
# 63696.30782056818*atender_('Pasto,_Nariño',_'Miraflores,_Boyacá')
# 77183.11672684636*atender_('Pasto,_Nariño',_'Moniquirá,_Boyacá')
# 1077219.9035716443*atender_('Pasto,_Nariño',_'Manizales,_Caldas')
# 360312.42261629965*atender_('Pasto,_Nariño',_'Anserma,_Caldas')
# 315672.8375555342*atender_('Pasto,_Nariño',_'Pensilvania,_Caldas')
# 306178.62369070266*atender_('Pasto,_Nariño',_'Riosucio,_Caldas')
# 325818.13847681164*atender_('Pasto,_Nariño',_'Aguadas,_Caldas')
# 261966.2947721055*atender_('Pasto,_Nariño',_'Morales,_Cauca')
# 192015.6278179836*atender_('Pasto,_Nariño',_'El_Tambo,_Cauca')
# 103981.07926672815*atender_('Pasto,_Nariño',_'Bolívar,_Cauca')
# 290225.3355523778*atender_('Pasto,_Nariño',_'Aguachica,_Cesar')
# 272966.22264177783*atender_('Pasto,_Nariño',_'San_Diego,_Cesar')
# 73583.55400515704*atender_('Pasto,_Nariño',_'Caparrapí,_Cundinamarca')
# 75828.35954506848*atender_('Pasto,_Nariño',_'Viotá,_Cundinamarca')
# 109396.84123946515*atender_('Pasto,_Nariño',_'Sasaima,_Cundinamarca')
# 611628.5162264417*atender_('Pasto,_Nariño',_'Neiva,_Huila')
# 282082.8056791801*atender_('Pasto,_Nariño',_'Pitalito,_Huila')
# 470809.84911448875*atender_('Pasto,_Nariño',_'Gigante,_Huila')
# 401627.06315317017*atender_('Pasto,_Nariño',_'Santa_Marta,_Magdalena')
# 42318.30367389752*atender_('Pasto,_Nariño',_'La_Unión,_Nariño')
# 0.0
# 35135.97259914462*atender_('Pasto,_Nariño',_'Samaniego,_Nariño')
# 212069.39288351862*atender_('Pasto,_Nariño',_'Sardinata,_Norte_de_Santander')
# 210271.49540856513*atender_('Pasto,_Nariño',_'Ocaña,_Norte_de_Santander')
# 204064.48717584592*atender_('Pasto,_Nariño',_'Convención,_Norte_de_Santander')
# 172115.99601314805*atender_('Pasto,_Nariño',_'Génova,_Quindío')
# 226192.5342152778*atender_('Pasto,_Nariño',_'Calarcá,_Quindío')
# 209653.5395822508*atender_('Pasto,_Nariño',_'Quimbaya,_Quindío')
# 357955.09280786844*atender_('Pasto,_Nariño',_'Pereira,_Risaralda')
# 305328.272732116*atender_('Pasto,_Nariño',_'Santuario,_Risaralda')
# 392373.9446467107*atender_('Pasto,_Nariño',_'Belén_de_Umbria,_Risaralda')
# 139920.9127090085*atender_('Pasto,_Nariño',_'Rionegro,_Santander')
# 131263.3151356561*atender_('Pasto,_Nariño',_'Bucaramanga,_Santander')
# 517975.0006644958*atender_('Pasto,_Nariño',_'Barbosa,_Santander')
# 529448.8633059494*atender_('Pasto,_Nariño',_'Socorro,_Santander')
# 431877.6450440726*atender_('Pasto,_Nariño',_'Simacota,_Santander')
# 273769.74536342337*atender_('Pasto,_Nariño',_'Chaparral,_Tolima')
# 419594.14979083475*atender_('Pasto,_Nariño',_'Dolores,_Tolima')
# 56274.24118155601*atender_('Pasto,_Nariño',_'Ibagué,_Tolima')
# 52107.43373806059*atender_('Pasto,_Nariño',_'Líbano,_Tolima')
# 242146.87284338867*atender_('Pasto,_Nariño',_'Cartago,_Valle')
# 189190.3168550967*atender_('Pasto,_Nariño',_'Tulua,_Valle')
# 78478.54161371969*atender_('Pasto,_Nariño',_'Jamundí,_Valle')
# 95432.89190240335*atender_('Pasto,_Nariño',_'Sevilla,_Valle')
# 109350.51535925263*atender_('Pasto,_Nariño',_'Caicedonia,_Valle')
# 6297.73005913881*atender_('Pasto,_Nariño',_'Florencia,_Caquetá')
# 5683.99777924407*atender_('Pasto,_Nariño',_'Puerto_Milán,_Caquetá')
# 25841.035965928655*atender_('Pasto,_Nariño',_'Nunchía,_Casanare')
# 15917.704777867535*atender_('Pasto,_Nariño',_'Mesetas,_Meta')
# 509448.49394746835*atender_('Génova,_Quindío',_'Andes,_Antioquia')
# 220290.26852225608*atender_('Génova,_Quindío',_'Medellín,_Antioquia')
# 763952.4292345974*atender_('Génova,_Quindío',_'Dabeiba,_Antioquia')
# 428109.12205399876*atender_('Génova,_Quindío',_'Salgar,_Antioquia')
# 35124.05108792621*atender_('Génova,_Quindío',_'San_Pablo_de_Borbur,_Boyacá')
# 40970.08739502634*atender_('Génova,_Quindío',_'Labranzagrande,_Boyacá')
# 30448.265002953918*atender_('Génova,_Quindío',_'Miraflores,_Boyacá')
# 35291.63334716099*atender_('Génova,_Quindío',_'Moniquirá,_Boyacá')
# 225655.028637827*atender_('Génova,_Quindío',_'Manizales,_Caldas')
# 82592.0417473567*atender_('Génova,_Quindío',_'Anserma,_Caldas')
# 88024.85881075109*atender_('Génova,_Quindío',_'Pensilvania,_Caldas')
# 83036.31545917071*atender_('Génova,_Quindío',_'Riosucio,_Caldas')
# 95120.12669349086*atender_('Génova,_Quindío',_'Aguadas,_Caldas')
# 236979.9288036983*atender_('Génova,_Quindío',_'Morales,_Cauca')
# 269184.9815516133*atender_('Génova,_Quindío',_'El_Tambo,_Cauca')
# 308003.86183892965*atender_('Génova,_Quindío',_'Bolívar,_Cauca')
# 166108.9585938229*atender_('Génova,_Quindío',_'Aguachica,_Cesar')
# 179555.15895478975*atender_('Génova,_Quindío',_'San_Diego,_Cesar')
# 24701.404815140766*atender_('Génova,_Quindío',_'Caparrapí,_Cundinamarca')
# 22514.465458139348*atender_('Génova,_Quindío',_'Viotá,_Cundinamarca')
# 34971.14423355497*atender_('Génova,_Quindío',_'Sasaima,_Cundinamarca')
# 274944.28101658606*atender_('Génova,_Quindío',_'Neiva,_Huila')
# 531952.3763828143*atender_('Génova,_Quindío',_'Pitalito,_Huila')
# 395078.0071056928*atender_('Génova,_Quindío',_'Gigante,_Huila')
# 272725.61769706575*atender_('Génova,_Quindío',_'Santa_Marta,_Magdalena')
# 222161.9670019948*atender_('Génova,_Quindío',_'La_Unión,_Nariño')
# 280076.53058652545*atender_('Génova,_Quindío',_'Pasto,_Nariño')
# 194852.2073392782*atender_('Génova,_Quindío',_'Samaniego,_Nariño')
# 126056.30072427205*atender_('Génova,_Quindío',_'Sardinata,_Norte_de_Santander')
# ...
# 13980.038377879657*atender_('Filandia,_Quindío',_'Nunchía,_Casanare')
# 9369.970863941495*atender_('Filandia,_Quindío',_'Mesetas,_Meta')
# 313879.8845307936*atender_('Pereira,_Risaralda',_'Andes,_Antioquia')
# 157088.933256934*atender_('Pereira,_Risaralda',_'Medellín,_Antioquia')
# 613398.7839707097*atender_('Pereira,_Risaralda',_'Dabeiba,_Antioquia')
# 292816.9758207443*atender_('Pereira,_Risaralda',_'Salgar,_Antioquia')
# 28375.717526134376*atender_('Pereira,_Risaralda',_'San_Pablo_de_Borbur,_Boyacá')
# 37662.68565839292*atender_('Pereira,_Risaralda',_'Labranzagrande,_Boyacá')
# 27798.250924805783*atender_('Pereira,_Risaralda',_'Miraflores,_Boyacá')
# 30228.808206085032*atender_('Pereira,_Risaralda',_'Moniquirá,_Boyacá')
# 80555.32038997406*atender_('Pereira,_Risaralda',_'Manizales,_Caldas')
# 34905.59968378175*atender_('Pereira,_Risaralda',_'Anserma,_Caldas')
# 51406.999306078396*atender_('Pereira,_Risaralda',_'Pensilvania,_Caldas')
# 44222.312678078655*atender_('Pereira,_Risaralda',_'Riosucio,_Caldas')
# 54947.878448867865*atender_('Pereira,_Risaralda',_'Aguadas,_Caldas')
# 314392.12602305925*atender_('Pereira,_Risaralda',_'Morales,_Cauca')
# 343586.20248478383*atender_('Pereira,_Risaralda',_'El_Tambo,_Cauca')
# 375772.38084692566*atender_('Pereira,_Risaralda',_'Bolívar,_Cauca')
# 145860.98546850274*atender_('Pereira,_Risaralda',_'Aguachica,_Cesar')
# 163860.40417096947*atender_('Pereira,_Risaralda',_'San_Diego,_Cesar')
# 18578.35881354354*atender_('Pereira,_Risaralda',_'Caparrapí,_Cundinamarca')
# 21352.114631268545*atender_('Pereira,_Risaralda',_'Viotá,_Cundinamarca')
# 28539.027346700426*atender_('Pereira,_Risaralda',_'Sasaima,_Cundinamarca')
# 395399.4078765793*atender_('Pereira,_Risaralda',_'Neiva,_Huila')
# 662491.271483349*atender_('Pereira,_Risaralda',_'Pitalito,_Huila')
# 522233.0976789554*atender_('Pereira,_Risaralda',_'Gigante,_Huila')
# 250068.57486999375*atender_('Pereira,_Risaralda',_'Santa_Marta,_Magdalena')
# 265297.7799076846*atender_('Pereira,_Risaralda',_'La_Unión,_Nariño')
# 326951.10839143884*atender_('Pereira,_Risaralda',_'Pasto,_Nariño')
# 225851.1372848544*atender_('Pereira,_Risaralda',_'Samaniego,_Nariño')
# 112836.64657960211*atender_('Pereira,_Risaralda',_'Sardinata,_Norte_de_Santander')
# 106478.64565302043*atender_('Pereira,_Risaralda',_'Ocaña,_Norte_de_Santander')
# 110405.53615621972*atender_('Pereira,_Risaralda',_'Convención,_Norte_de_Santander')
# 29812.223919943375*atender_('Pereira,_Risaralda',_'Génova,_Quindío')
# 20127.803729961557*atender_('Pereira,_Risaralda',_'Calarcá,_Quindío')
# 11806.972916257015*atender_('Pereira,_Risaralda',_'Quimbaya,_Quindío')
# 0.0
# 29671.132386690955*atender_('Pereira,_Risaralda',_'Santuario,_Risaralda')
# 41263.79785267242*atender_('Pereira,_Risaralda',_'Belén_de_Umbria,_Risaralda')
# 66034.23352342848*atender_('Pereira,_Risaralda',_'Rionegro,_Santander')
# 62138.10413778085*atender_('Pereira,_Risaralda',_'Bucaramanga,_Santander')
# 199791.39373050266*atender_('Pereira,_Risaralda',_'Barbosa,_Santander')
# 231720.2373782854*atender_('Pereira,_Risaralda',_'Socorro,_Santander')
# 179670.14976929143*atender_('Pereira,_Risaralda',_'Simacota,_Santander')
# 89819.76848269175*atender_('Pereira,_Risaralda',_'Chaparral,_Tolima')
# 173095.75640376518*atender_('Pereira,_Risaralda',_'Dolores,_Tolima')
# 7320.326265382977*atender_('Pereira,_Risaralda',_'Ibagué,_Tolima')
# 7365.3250490995815*atender_('Pereira,_Risaralda',_'Líbano,_Tolima')
# 17186.81796182045*atender_('Pereira,_Risaralda',_'Cartago,_Valle')
# 50366.06395590294*atender_('Pereira,_Risaralda',_'Tulua,_Valle')
# 65499.018909485574*atender_('Pereira,_Risaralda',_'Jamundí,_Valle')
# 18937.820225788048*atender_('Pereira,_Risaralda',_'Sevilla,_Valle')
# 15878.623220605574*atender_('Pereira,_Risaralda',_'Caicedonia,_Valle')
# 11660.090600882699*atender_('Pereira,_Risaralda',_'Florencia,_Caquetá')
# 11338.909210188356*atender_('Pereira,_Risaralda',_'Puerto_Milán,_Caquetá')
# 13875.426852075107*atender_('Pereira,_Risaralda',_'Nunchía,_Casanare')
# 9743.076467677154*atender_('Pereira,_Risaralda',_'Mesetas,_Meta')
# 1140144.1323408044*atender_('Bucaramanga,_Santander',_'Andes,_Antioquia')
# 279741.5395692589*atender_('Bucaramanga,_Santander',_'Medellín,_Antioquia')
# 865216.0057692531*atender_('Bucaramanga,_Santander',_'Dabeiba,_Antioquia')
# 743107.2821670956*atender_('Bucaramanga,_Santander',_'Salgar,_Antioquia')
# 28324.492100060852*atender_('Bucaramanga,_Santander',_'San_Pablo_de_Borbur,_Boyacá')
# 20454.86962073806*atender_('Bucaramanga,_Santander',_'Labranzagrande,_Boyacá')
# 22253.376566918785*atender_('Bucaramanga,_Santander',_'Miraflores,_Boyacá')
# 17434.192694873545*atender_('Bucaramanga,_Santander',_'Moniquirá,_Boyacá')
# 783801.3517901788*atender_('Bucaramanga,_Santander',_'Manizales,_Caldas')
# 269819.0264408367*atender_('Bucaramanga,_Santander',_'Anserma,_Caldas')
# 178530.40945581163*atender_('Bucaramanga,_Santander',_'Pensilvania,_Caldas')
# 207087.78695290384*atender_('Bucaramanga,_Santander',_'Riosucio,_Caldas')
# 190078.36688312844*atender_('Bucaramanga,_Santander',_'Aguadas,_Caldas')
# 798325.0399023782*atender_('Bucaramanga,_Santander',_'Morales,_Cauca')
# 791188.0270079405*atender_('Bucaramanga,_Santander',_'El_Tambo,_Cauca')
# 773829.4309204274*atender_('Bucaramanga,_Santander',_'Bolívar,_Cauca')
# 44665.705816533264*atender_('Bucaramanga,_Santander',_'Aguachica,_Cesar')
# 85553.14149332386*atender_('Bucaramanga,_Santander',_'San_Diego,_Cesar')
# 32866.634835720244*atender_('Bucaramanga,_Santander',_'Caparrapí,_Cundinamarca')
# 53225.73344087324*atender_('Bucaramanga,_Santander',_'Viotá,_Cundinamarca')
# 58696.76278010971*atender_('Bucaramanga,_Santander',_'Sasaima,_Cundinamarca')
# 1035407.5557161939*atender_('Bucaramanga,_Santander',_'Neiva,_Huila')
# 1345242.5111147838*atender_('Bucaramanga,_Santander',_'Pitalito,_Huila')
# 1167612.9369244792*atender_('Bucaramanga,_Santander',_'Gigante,_Huila')
# 159028.41993154283*atender_('Bucaramanga,_Santander',_'Santa_Marta,_Magdalena')
# 519465.3409266854*atender_('Bucaramanga,_Santander',_'La_Unión,_Nariño')
# 595451.463073479*atender_('Bucaramanga,_Santander',_'Pasto,_Nariño')
# 419957.8801586644*atender_('Bucaramanga,_Santander',_'Samaniego,_Nariño')
# 28524.196720235668*atender_('Bucaramanga,_Santander',_'Sardinata,_Norte_de_Santander')
# 28259.75401483115*atender_('Bucaramanga,_Santander',_'Ocaña,_Norte_de_Santander')
# 38881.4912921433*atender_('Bucaramanga,_Santander',_'Convención,_Norte_de_Santander')
# 197593.97531198777*atender_('Bucaramanga,_Santander',_'Génova,_Quindío')
# 226672.74868451912*atender_('Bucaramanga,_Santander',_'Calarcá,_Quindío')
# 202236.09002021744*atender_('Bucaramanga,_Santander',_'Quimbaya,_Quindío')
# 308607.6792094256*atender_('Bucaramanga,_Santander',_'Pereira,_Risaralda')
# 261886.4246211265*atender_('Bucaramanga,_Santander',_'Santuario,_Risaralda')
# 306107.58171432983*atender_('Bucaramanga,_Santander',_'Belén_de_Umbria,_Risaralda')
# 9084.165197655026*atender_('Bucaramanga,_Santander',_'Rionegro,_Santander')
# 0.0
# 112196.77709598592*atender_('Bucaramanga,_Santander',_'Barbosa,_Santander')
# 56185.29113576066*atender_('Bucaramanga,_Santander',_'Socorro,_Santander')
# 45973.456942094155*atender_('Bucaramanga,_Santander',_'Simacota,_Santander')
# 367005.95248283807*atender_('Bucaramanga,_Santander',_'Chaparral,_Tolima')
# 461842.8004088769*atender_('Bucaramanga,_Santander',_'Dolores,_Tolima')
# 48871.59958187786*atender_('Bucaramanga,_Santander',_'Ibagué,_Tolima')
# 35505.14542259153*atender_('Bucaramanga,_Santander',_'Líbano,_Tolima')
# 233045.76033876298*atender_('Bucaramanga,_Santander',_'Cartago,_Valle')
# 254614.4885958235*atender_('Bucaramanga,_Santander',_'Tulua,_Valle')
# 186878.82773443917*atender_('Bucaramanga,_Santander',_'Jamundí,_Valle')
# 115853.99748634413*atender_('Bucaramanga,_Santander',_'Sevilla,_Valle')
# 122483.72288319726*atender_('Bucaramanga,_Santander',_'Caicedonia,_Valle')
# 22407.890578401843*atender_('Bucaramanga,_Santander',_'Florencia,_Caquetá')
# 20718.597586833388*atender_('Bucaramanga,_Santander',_'Puerto_Milán,_Caquetá')
# 7314.66577797772*atender_('Bucaramanga,_Santander',_'Nunchía,_Casanare')
# 17910.707904004576*atender_('Bucaramanga,_Santander',_'Mesetas,_Meta')
# 829314.4113432554*atender_('Barbosa,_Santander',_'Andes,_Antioquia')
# 211192.49915223816*atender_('Barbosa,_Santander',_'Medellín,_Antioquia')
# 772575.631025147*atender_('Barbosa,_Santander',_'Dabeiba,_Antioquia')
# 561990.5042195233*atender_('Barbosa,_Santander',_'Salgar,_Antioquia')
# 8735.174108141735*atender_('Barbosa,_Santander',_'San_Pablo_de_Borbur,_Boyacá')
# 13304.167580844307*atender_('Barbosa,_Santander',_'Labranzagrande,_Boyacá')
# 10194.51667635919*atender_('Barbosa,_Santander',_'Miraflores,_Boyacá')
# 1465.7079090172858*atender_('Barbosa,_Santander',_'Moniquirá,_Boyacá')
# 511510.6435719043*atender_('Barbosa,_Santander',_'Manizales,_Caldas')
# 184877.35540988806*atender_('Barbosa,_Santander',_'Anserma,_Caldas')
# 108208.23185123812*atender_('Barbosa,_Santander',_'Pensilvania,_Caldas')
# 143275.47538382697*atender_('Barbosa,_Santander',_'Riosucio,_Caldas')
# 125412.04295754869*atender_('Barbosa,_Santander',_'Aguadas,_Caldas')
# 623052.6381530528*atender_('Barbosa,_Santander',_'Morales,_Cauca')
# 625243.1163952431*atender_('Barbosa,_Santander',_'El_Tambo,_Cauca')
# 623201.2489070689*atender_('Barbosa,_Santander',_'Bolívar,_Cauca')
# 84254.18242432865*atender_('Barbosa,_Santander',_'Aguachica,_Cesar')
# 118787.23976381644*atender_('Barbosa,_Santander',_'San_Diego,_Cesar')
# 15313.022945693578*atender_('Barbosa,_Santander',_'Caparrapí,_Cundinamarca')
# 30369.272676136366*atender_('Barbosa,_Santander',_'Viotá,_Cundinamarca')
# 29192.561164673156*atender_('Barbosa,_Santander',_'Sasaima,_Cundinamarca')
# 745236.7436255148*atender_('Barbosa,_Santander',_'Neiva,_Huila')
# 1061080.6398077*atender_('Barbosa,_Santander',_'Pitalito,_Huila')
# 881164.5729375117*atender_('Barbosa,_Santander',_'Gigante,_Huila')
# 200692.97753602455*atender_('Barbosa,_Santander',_'Santa_Marta,_Magdalena')
# 423153.5017525173*atender_('Barbosa,_Santander',_'La_Unión,_Nariño')
# 491350.1174527693*atender_('Barbosa,_Santander',_'Pasto,_Nariño')
# 348621.37983772374*atender_('Barbosa,_Santander',_'Samaniego,_Nariño')
# 61427.39762012214*atender_('Barbosa,_Santander',_'Sardinata,_Norte_de_Santander')
# 58948.9807130278*atender_('Barbosa,_Santander',_'Ocaña,_Norte_de_Santander')
# 67810.64847588647*atender_('Barbosa,_Santander',_'Convención,_Norte_de_Santander')
# 137178.75830082697*atender_('Barbosa,_Santander',_'Génova,_Quindío')
# 154416.12860183866*atender_('Barbosa,_Santander',_'Calarcá,_Quindío')
# 139112.0017026611*atender_('Barbosa,_Santander',_'Quimbaya,_Quindío')
# 207493.6320402066*atender_('Barbosa,_Santander',_'Pereira,_Risaralda')
# 185114.12528490814*atender_('Barbosa,_Santander',_'Santuario,_Risaralda')
# 213812.6040160539*atender_('Barbosa,_Santander',_'Belén_de_Umbria,_Risaralda')
# 29756.39939877095*atender_('Barbosa,_Santander',_'Rionegro,_Santander')
# 23461.709229183965*atender_('Barbosa,_Santander',_'Bucaramanga,_Santander')
# 0.0
# 50201.129908119314*atender_('Barbosa,_Santander',_'Socorro,_Santander')
# 46694.319361061214*atender_('Barbosa,_Santander',_'Simacota,_Santander')
# 256821.3405876951*atender_('Barbosa,_Santander',_'Chaparral,_Tolima')
# 306530.7894489185*atender_('Barbosa,_Santander',_'Dolores,_Tolima')
# 31201.128322200766*atender_('Barbosa,_Santander',_'Ibagué,_Tolima')
# 21100.54212183501*atender_('Barbosa,_Santander',_'Líbano,_Tolima')
# 163053.05477931243*atender_('Barbosa,_Santander',_'Cartago,_Valle')
# 183659.89439398114*atender_('Barbosa,_Santander',_'Tulua,_Valle')
# 143663.90039957943*atender_('Barbosa,_Santander',_'Jamundí,_Valle')
# 81778.76769798888*atender_('Barbosa,_Santander',_'Sevilla,_Valle')
# 85566.39946809589*atender_('Barbosa,_Santander',_'Caicedonia,_Valle')
# 17559.589613794335*atender_('Barbosa,_Santander',_'Florencia,_Caquetá')
# 16393.604821688594*atender_('Barbosa,_Santander',_'Puerto_Milán,_Caquetá')
# 6101.772513585664*atender_('Barbosa,_Santander',_'Nunchía,_Casanare')
# 12377.455564089987*atender_('Barbosa,_Santander',_'Mesetas,_Meta')
# 810061.7455139274*atender_('Cali,_Valle_del_Cauca',_'Andes,_Antioquia')
# 319604.0306152948*atender_('Cali,_Valle_del_Cauca',_'Medellín,_Antioquia')
# 968020.640561183*atender_('Cali,_Valle_del_Cauca',_'Dabeiba,_Antioquia')
# 629671.0525914768*atender_('Cali,_Valle_del_Cauca',_'Salgar,_Antioquia')
# 52761.702711988684*atender_('Cali,_Valle_del_Cauca',_'San_Pablo_de_Borbur,_Boyacá')
# 53529.07133482567*atender_('Cali,_Valle_del_Cauca',_'Labranzagrande,_Boyacá')
# 41941.48680638713*atender_('Cali,_Valle_del_Cauca',_'Miraflores,_Boyacá')
# 49404.37179108076*atender_('Cali,_Valle_del_Cauca',_'Moniquirá,_Boyacá')
# 484977.0983588402*atender_('Cali,_Valle_del_Cauca',_'Manizales,_Caldas')
# 161025.84283329625*atender_('Cali,_Valle_del_Cauca',_'Anserma,_Caldas')
# 159095.8769904832*atender_('Cali,_Valle_del_Cauca',_'Pensilvania,_Caldas')
# 145366.0278724873*atender_('Cali,_Valle_del_Cauca',_'Riosucio,_Caldas')
# 163270.4635087713*atender_('Cali,_Valle_del_Cauca',_'Aguadas,_Caldas')
# 83392.93441647597*atender_('Cali,_Valle_del_Cauca',_'Morales,_Cauca')
# 129905.60606282136*atender_('Cali,_Valle_del_Cauca',_'El_Tambo,_Cauca')
# 184897.85164195774*atender_('Cali,_Valle_del_Cauca',_'Bolívar,_Cauca')
# 204660.33692333952*atender_('Cali,_Valle_del_Cauca',_'Aguachica,_Cesar')
# 207774.13135197485*atender_('Cali,_Valle_del_Cauca',_'San_Diego,_Cesar')
# 40800.396859438624*atender_('Cali,_Valle_del_Cauca',_'Caparrapí,_Cundinamarca')
# 40066.12450610571*atender_('Cali,_Valle_del_Cauca',_'Viotá,_Cundinamarca')
# 59832.982149500014*atender_('Cali,_Valle_del_Cauca',_'Sasaima,_Cundinamarca')
# 284817.4407951797*atender_('Cali,_Valle_del_Cauca',_'Neiva,_Huila')
# 361802.8646582676*atender_('Cali,_Valle_del_Cauca',_'Pitalito,_Huila')
# 309102.06172530295*atender_('Cali,_Valle_del_Cauca',_'Gigante,_Huila')
# 309306.5854043783*atender_('Cali,_Valle_del_Cauca',_'Santa_Marta,_Magdalena')
# 142930.03373205487*atender_('Cali,_Valle_del_Cauca',_'La_Unión,_Nariño')
# 197274.90464529008*atender_('Cali,_Valle_del_Cauca',_'Pasto,_Nariño')
# 132714.6389215123*atender_('Cali,_Valle_del_Cauca',_'Samaniego,_Nariño')
# 153785.5076612613*atender_('Cali,_Valle_del_Cauca',_'Sardinata,_Norte_de_Santander')
# 148961.3156074749*atender_('Cali,_Valle_del_Cauca',_'Ocaña,_Norte_de_Santander')
# 148640.80112532745*atender_('Cali,_Valle_del_Cauca',_'Convención,_Norte_de_Santander')
# 55420.47186141617*atender_('Cali,_Valle_del_Cauca',_'Génova,_Quindío')
# 82248.08482486897*atender_('Cali,_Valle_del_Cauca',_'Calarcá,_Quindío')
# 77964.20523034429*atender_('Cali,_Valle_del_Cauca',_'Quimbaya,_Quindío')
# 145276.59149347834*atender_('Cali,_Valle_del_Cauca',_'Pereira,_Risaralda')
# 126578.13227344379*atender_('Cali,_Valle_del_Cauca',_'Santuario,_Risaralda')
# 172482.01769613297*atender_('Cali,_Valle_del_Cauca',_'Belén_de_Umbria,_Risaralda')
# 96448.07928695674*atender_('Cali,_Valle_del_Cauca',_'Rionegro,_Santander')
# 90740.42533007663*atender_('Cali,_Valle_del_Cauca',_'Bucaramanga,_Santander')
# 330043.07883981435*atender_('Cali,_Valle_del_Cauca',_'Barbosa,_Santander')
# 354588.79641747003*atender_('Cali,_Valle_del_Cauca',_'Socorro,_Santander')
# 283671.14252802293*atender_('Cali,_Valle_del_Cauca',_'Simacota,_Santander')
# 87117.18775412001*atender_('Cali,_Valle_del_Cauca',_'Chaparral,_Tolima')
# 210509.88409805438*atender_('Cali,_Valle_del_Cauca',_'Dolores,_Tolima')
# 23946.221342283963*atender_('Cali,_Valle_del_Cauca',_'Ibagué,_Tolima')
# 24877.79313077221*atender_('Cali,_Valle_del_Cauca',_'Líbano,_Tolima')
# 90441.39567205704*atender_('Cali,_Valle_del_Cauca',_'Cartago,_Valle')
# 46864.2925419663*atender_('Cali,_Valle_del_Cauca',_'Tulua,_Valle')
# 7675.475983507722*atender_('Cali,_Valle_del_Cauca',_'Jamundí,_Valle')
# 28137.198354365668*atender_('Cali,_Valle_del_Cauca',_'Sevilla,_Valle')
# 35353.78527535242*atender_('Cali,_Valle_del_Cauca',_'Caicedonia,_Valle')
# 7377.5972015145435*atender_('Cali,_Valle_del_Cauca',_'Florencia,_Caquetá')
# 7549.099664396026*atender_('Cali,_Valle_del_Cauca',_'Puerto_Milán,_Caquetá')
# 18734.981164407374*atender_('Cali,_Valle_del_Cauca',_'Nunchía,_Casanare')
# 10402.630577415099*atender_('Cali,_Valle_del_Cauca',_'Mesetas,_Meta')

# %%
# Esta celda esta reservada para uso del equipo docente

# %%
# Esta celda esta reservada para uso del equipo docente

# %% [markdown]
# ### Restricciones
#
# ____
# **Ejemplo**
# > La siguiente restricción: $\sum_{i \in I} a_{ij} x_{ij} \geq 1, \; \forall j \in J$ es equivalente a:
# >    * `for j in J:`
# >        * `model += lp.lpSum(a[i,j]*x[i,j] for i in I) >= 1, 'R1_'+str(j)`
#
# **Advertencia**: En `pulp` no es recomendable sobreescribir restricciones, entonces, si ya creaste una restricción y quieres crearla de nuevo para corregir algo, asegúrate de volver a crear el modelo `problema` desde el principio. (Nosotros haremos esto antes de calificar, no te preocupes)

# %% [markdown]
# **Pregunta 3 (10 puntos)**
#
# * Crea la siguiente restricción, asígnale el nombre `'R1_'+str(<indice_del_para_todo>)` y añádela al modelo:
# >1. Cada CAC debe ser atendido por un único depósito
# >>`# Para desarrollo del estudiante`

# %%
# your code here #I = Depositos , J = CAC
for j in J:
    problema += (
        lp.lpSum(x[(i, j)] for i in I) == 1,
        'R1_' + str(j)
    )

print(problema)
# Out:
# NoName:
# MINIMIZE
# 117908.49971902708*atender_('Aguadas,_Caldas',_'Aguachica,_Cesar') + 177155.78795660642*atender_('Aguadas,_Caldas',_'Andes,_Antioquia') + 39356.01440132498*atender_('Aguadas,_Caldas',_'Anserma,_Caldas') + 159277.0159816939*atender_('Aguadas,_Caldas',_'Barbosa,_Santander') + 51145.167823184194*atender_('Aguadas,_Caldas',_'Belén_de_Umbria,_Risaralda') + 471399.4972272999*atender_('Aguadas,_Caldas',_'Bolívar,_Cauca') + 50480.75322267061*atender_('Aguadas,_Caldas',_'Bucaramanga,_Santander') + 41155.19940775516*atender_('Aguadas,_Caldas',_'Caicedonia,_Valle') + 69571.50211894032*atender_('Aguadas,_Caldas',_'Calarcá,_Quindío') + 13952.41806450983*atender_('Aguadas,_Caldas',_'Caparrapí,_Cundinamarca') + 61503.16738610358*atender_('Aguadas,_Caldas',_'Cartago,_Valle') + 159131.0435260399*atender_('Aguadas,_Caldas',_'Chaparral,_Tolima') + 92343.66725059658*atender_('Aguadas,_Caldas',_'Convención,_Norte_de_Santander') + 436498.0740211331*atender_('Aguadas,_Caldas',_'Dabeiba,_Antioquia') + 245069.77511884025*atender_('Aguadas,_Caldas',_'Dolores,_Tolima') + 449687.47787013545*atender_('Aguadas,_Caldas',_'El_Tambo,_Cauca') + 14593.993429979617*atender_('Aguadas,_Caldas',_'Florencia,_Caquetá') + 694961.5403519879*atender_('Aguadas,_Caldas',_'Gigante,_Huila') + 70422.76442144204*atender_('Aguadas,_Caldas',_'Génova,_Quindío') + 15960.617240649199*atender_('Aguadas,_Caldas',_'Ibagué,_Tolima') + 93427.70761760588*atender_('Aguadas,_Caldas',_'Jamundí,_Valle') + 326218.0588167218*atender_('Aguadas,_Caldas',_'La_Unión,_Nariño') + 34191.21419461881*atender_('Aguadas,_Caldas',_'Labranzagrande,_Boyacá') + 9673.254374824543*atender_('Aguadas,_Caldas',_'Líbano,_Tolima') + 125058.33859734573*atender_('Aguadas,_Caldas',_'Manizales,_Caldas') + 74437.529728171*atender_('Aguadas,_Caldas',_'Medellín,_Antioquia') + 12031.779676494853*atender_('Aguadas,_Caldas',_'Mesetas,_Meta') + 25713.159337201098*atender_('Aguadas,_Caldas',_'Miraflores,_Boyacá') + 24602.56204109549*atender_('Aguadas,_Caldas',_'Moniquirá,_Boyacá') + 426988.6977275271*atender_('Aguadas,_Caldas',_'Morales,_Cauca') + 564298.0919828907*atender_('Aguadas,_Caldas',_'Neiva,_Huila') + 12821.359054444634*atender_('Aguadas,_Caldas',_'Nunchía,_Casanare') + 86735.06741993118*atender_('Aguadas,_Caldas',_'Ocaña,_Norte_de_Santander') + 392528.67721538723*atender_('Aguadas,_Caldas',_'Pasto,_Nariño') + 21699.77877308014*atender_('Aguadas,_Caldas',_'Pensilvania,_Caldas') + 72475.76252380347*atender_('Aguadas,_Caldas',_'Pereira,_Risaralda') + 840103.602278234*atender_('Aguadas,_Caldas',_'Pitalito,_Huila') + 13939.002233516854*atender_('Aguadas,_Caldas',_'Puerto_Milán,_Caquetá') + 55798.63487539248*atender_('Aguadas,_Caldas',_'Quimbaya,_Quindío') + 52588.11736192314*atender_('Aguadas,_Caldas',_'Rionegro,_Santander') + 20361.09251657211*atender_('Aguadas,_Caldas',_'Riosucio,_Caldas') + 154611.37913774076*atender_('Aguadas,_Caldas',_'Salgar,_Antioquia') + 270546.98090996436*atender_('Aguadas,_Caldas',_'Samaniego,_Nariño') + 142132.11322552775*atender_('Aguadas,_Caldas',_'San_Diego,_Cesar') + 21486.415555088493*atender_('Aguadas,_Caldas',_'San_Pablo_de_Borbur,_Boyacá') + 219099.47265719052*atender_('Aguadas,_Caldas',_'Santa_Marta,_Magdalena') + 55318.52950077473*atender_('Aguadas,_Caldas',_'Santuario,_Risaralda') + 94648.12483426099*atender_('Aguadas,_Caldas',_'Sardinata,_Norte_de_Santander') + 27745.098527261016*atender_('Aguadas,_Caldas',_'Sasaima,_Cundinamarca') + 42027.9165000678*atender_('Aguadas,_Caldas',_'Sevilla,_Valle') + 138179.17665118337*atender_('Aguadas,_Caldas',_'Simacota,_Santander') + 187721.28996527294*atender_('Aguadas,_Caldas',_'Socorro,_Santander') + 97959.22124268203*atender_('Aguadas,_Caldas',_'Tulua,_Valle') + 26154.702273190593*atender_('Aguadas,_Caldas',_'Viotá,_Cundinamarca') + 84254.18242432865*atender_('Barbosa,_Santander',_'Aguachica,_Cesar') + 125412.04295754869*atender_('Barbosa,_Santander',_'Aguadas,_Caldas') + 829314.4113432554*atender_('Barbosa,_Santander',_'Andes,_Antioquia') + 1 ...
# SUBJECT TO
# R1_Andes,_Antioquia: atender_('Aguadas,_Caldas',_'Andes,_Antioquia')
#  + atender_('Barbosa,_Santander',_'Andes,_Antioquia')
#  + atender_('Bogotá,_Cundinamarca',_'Andes,_Antioquia')
#  + atender_('Bucaramanga,_Santander',_'Andes,_Antioquia')
#  + atender_('Calarcá,_Quindío',_'Andes,_Antioquia')
#  + atender_('Cali,_Valle_del_Cauca',_'Andes,_Antioquia')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Andes,_Antioquia')
#  + atender_('Filandia,_Quindío',_'Andes,_Antioquia')
#  + atender_('Génova,_Quindío',_'Andes,_Antioquia')
#  + atender_('La_Dorada,_Caldas_',_'Andes,_Antioquia')
#  + atender_('Medellín,_Antioquia',_'Andes,_Antioquia')
#  + atender_('Neiva,_Huila',_'Andes,_Antioquia')
#  + atender_('Pasto,_Nariño',_'Andes,_Antioquia')
#  + atender_('Pereira,_Risaralda',_'Andes,_Antioquia')
#  + atender_('Popayán,_Cauca',_'Andes,_Antioquia')
#  + atender_('Salamina,_Caldas',_'Andes,_Antioquia')
#  + atender_('Santa_Marta,_Magdalena',_'Andes,_Antioquia')
#  + atender_('Santana,_Huila',_'Andes,_Antioquia')
#  + atender_('Valledupar,_Cesar',_'Andes,_Antioquia') = 1
#
# R1_Medellín,_Antioquia: atender_('Aguadas,_Caldas',_'Medellín,_Antioquia')
#  + atender_('Barbosa,_Santander',_'Medellín,_Antioquia')
#  + atender_('Bogotá,_Cundinamarca',_'Medellín,_Antioquia')
#  + atender_('Bucaramanga,_Santander',_'Medellín,_Antioquia')
#  + atender_('Calarcá,_Quindío',_'Medellín,_Antioquia')
#  + atender_('Cali,_Valle_del_Cauca',_'Medellín,_Antioquia')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Medellín,_Antioquia')
#  + atender_('Filandia,_Quindío',_'Medellín,_Antioquia')
#  + atender_('Génova,_Quindío',_'Medellín,_Antioquia')
#  + atender_('La_Dorada,_Caldas_',_'Medellín,_Antioquia')
#  + atender_('Medellín,_Antioquia',_'Medellín,_Antioquia')
#  + atender_('Neiva,_Huila',_'Medellín,_Antioquia')
#  + atender_('Pasto,_Nariño',_'Medellín,_Antioquia')
#  + atender_('Pereira,_Risaralda',_'Medellín,_Antioquia')
#  + atender_('Popayán,_Cauca',_'Medellín,_Antioquia')
#  + atender_('Salamina,_Caldas',_'Medellín,_Antioquia')
#  + atender_('Santa_Marta,_Magdalena',_'Medellín,_Antioquia')
#  + atender_('Santana,_Huila',_'Medellín,_Antioquia')
#  + atender_('Valledupar,_Cesar',_'Medellín,_Antioquia') = 1
#
# R1_Dabeiba,_Antioquia: atender_('Aguadas,_Caldas',_'Dabeiba,_Antioquia')
#  + atender_('Barbosa,_Santander',_'Dabeiba,_Antioquia')
#  + atender_('Bogotá,_Cundinamarca',_'Dabeiba,_Antioquia')
#  + atender_('Bucaramanga,_Santander',_'Dabeiba,_Antioquia')
#  + atender_('Calarcá,_Quindío',_'Dabeiba,_Antioquia')
#  + atender_('Cali,_Valle_del_Cauca',_'Dabeiba,_Antioquia')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Dabeiba,_Antioquia')
#  + atender_('Filandia,_Quindío',_'Dabeiba,_Antioquia')
#  + atender_('Génova,_Quindío',_'Dabeiba,_Antioquia')
#  + atender_('La_Dorada,_Caldas_',_'Dabeiba,_Antioquia')
#  + atender_('Medellín,_Antioquia',_'Dabeiba,_Antioquia')
#  + atender_('Neiva,_Huila',_'Dabeiba,_Antioquia')
#  + atender_('Pasto,_Nariño',_'Dabeiba,_Antioquia')
#  + atender_('Pereira,_Risaralda',_'Dabeiba,_Antioquia')
#  + atender_('Popayán,_Cauca',_'Dabeiba,_Antioquia')
#  + atender_('Salamina,_Caldas',_'Dabeiba,_Antioquia')
#  + atender_('Santa_Marta,_Magdalena',_'Dabeiba,_Antioquia')
#  + atender_('Santana,_Huila',_'Dabeiba,_Antioquia')
#  + atender_('Valledupar,_Cesar',_'Dabeiba,_Antioquia') = 1
#
# R1_Salgar,_Antioquia: atender_('Aguadas,_Caldas',_'Salgar,_Antioquia')
#  + atender_('Barbosa,_Santander',_'Salgar,_Antioquia')
#  + atender_('Bogotá,_Cundinamarca',_'Salgar,_Antioquia')
#  + atender_('Bucaramanga,_Santander',_'Salgar,_Antioquia')
#  + atender_('Calarcá,_Quindío',_'Salgar,_Antioquia')
#  + atender_('Cali,_Valle_del_Cauca',_'Salgar,_Antioquia')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Salgar,_Antioquia')
#  + atender_('Filandia,_Quindío',_'Salgar,_Antioquia')
#  + atender_('Génova,_Quindío',_'Salgar,_Antioquia')
#  + atender_('La_Dorada,_Caldas_',_'Salgar,_Antioquia')
#  + atender_('Medellín,_Antioquia',_'Salgar,_Antioquia')
#  + atender_('Neiva,_Huila',_'Salgar,_Antioquia')
#  + atender_('Pasto,_Nariño',_'Salgar,_Antioquia')
#  + atender_('Pereira,_Risaralda',_'Salgar,_Antioquia')
#  + atender_('Popayán,_Cauca',_'Salgar,_Antioquia')
#  + atender_('Salamina,_Caldas',_'Salgar,_Antioquia')
#  + atender_('Santa_Marta,_Magdalena',_'Salgar,_Antioquia')
#  + atender_('Santana,_Huila',_'Salgar,_Antioquia')
#  + atender_('Valledupar,_Cesar',_'Salgar,_Antioquia') = 1
#
# R1_San_Pablo_de_Borbur,_Boyacá:
#  atender_('Aguadas,_Caldas',_'San_Pablo_de_Borbur,_Boyacá')
#  + atender_('Barbosa,_Santander',_'San_Pablo_de_Borbur,_Boyacá')
#  + atender_('Bogotá,_Cundinamarca',_'San_Pablo_de_Borbur,_Boyacá')
#  + atender_('Bucaramanga,_Santander',_'San_Pablo_de_Borbur,_Boyacá')
#  + atender_('Calarcá,_Quindío',_'San_Pablo_de_Borbur,_Boyacá')
#  + atender_('Cali,_Valle_del_Cauca',_'San_Pablo_de_Borbur,_Boyacá')
#  + atender_('Cúcuta,_Nor._de_Santander',_'San_Pablo_de_Borbur,_Boyacá')
#  + atender_('Filandia,_Quindío',_'San_Pablo_de_Borbur,_Boyacá')
#  + atender_('Génova,_Quindío',_'San_Pablo_de_Borbur,_Boyacá')
#  + atender_('La_Dorada,_Caldas_',_'San_Pablo_de_Borbur,_Boyacá')
#  + atender_('Medellín,_Antioquia',_'San_Pablo_de_Borbur,_Boyacá')
#  + atender_('Neiva,_Huila',_'San_Pablo_de_Borbur,_Boyacá')
#  + atender_('Pasto,_Nariño',_'San_Pablo_de_Borbur,_Boyacá')
#  + atender_('Pereira,_Risaralda',_'San_Pablo_de_Borbur,_Boyacá')
#  + atender_('Popayán,_Cauca',_'San_Pablo_de_Borbur,_Boyacá')
#  + atender_('Salamina,_Caldas',_'San_Pablo_de_Borbur,_Boyacá')
#  + atender_('Santa_Marta,_Magdalena',_'San_Pablo_de_Borbur,_Boyacá')
#  + atender_('Santana,_Huila',_'San_Pablo_de_Borbur,_Boyacá')
#  + atender_('Valledupar,_Cesar',_'San_Pablo_de_Borbur,_Boyacá') = 1
#
# R1_Labranzagrande,_Boyacá:
#  atender_('Aguadas,_Caldas',_'Labranzagrande,_Boyacá')
#  + atender_('Barbosa,_Santander',_'Labranzagrande,_Boyacá')
#  + atender_('Bogotá,_Cundinamarca',_'Labranzagrande,_Boyacá')
#  + atender_('Bucaramanga,_Santander',_'Labranzagrande,_Boyacá')
#  + atender_('Calarcá,_Quindío',_'Labranzagrande,_Boyacá')
#  + atender_('Cali,_Valle_del_Cauca',_'Labranzagrande,_Boyacá')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Labranzagrande,_Boyacá')
#  + atender_('Filandia,_Quindío',_'Labranzagrande,_Boyacá')
#  + atender_('Génova,_Quindío',_'Labranzagrande,_Boyacá')
#  + atender_('La_Dorada,_Caldas_',_'Labranzagrande,_Boyacá')
#  + atender_('Medellín,_Antioquia',_'Labranzagrande,_Boyacá')
#  + atender_('Neiva,_Huila',_'Labranzagrande,_Boyacá')
#  + atender_('Pasto,_Nariño',_'Labranzagrande,_Boyacá')
#  + atender_('Pereira,_Risaralda',_'Labranzagrande,_Boyacá')
#  + atender_('Popayán,_Cauca',_'Labranzagrande,_Boyacá')
#  + atender_('Salamina,_Caldas',_'Labranzagrande,_Boyacá')
#  + atender_('Santa_Marta,_Magdalena',_'Labranzagrande,_Boyacá')
#  + atender_('Santana,_Huila',_'Labranzagrande,_Boyacá')
#  + atender_('Valledupar,_Cesar',_'Labranzagrande,_Boyacá') = 1
#
# R1_Miraflores,_Boyacá: atender_('Aguadas,_Caldas',_'Miraflores,_Boyacá')
#  + atender_('Barbosa,_Santander',_'Miraflores,_Boyacá')
#  + atender_('Bogotá,_Cundinamarca',_'Miraflores,_Boyacá')
#  + atender_('Bucaramanga,_Santander',_'Miraflores,_Boyacá')
#  + atender_('Calarcá,_Quindío',_'Miraflores,_Boyacá')
#  + atender_('Cali,_Valle_del_Cauca',_'Miraflores,_Boyacá')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Miraflores,_Boyacá')
#  + atender_('Filandia,_Quindío',_'Miraflores,_Boyacá')
#  + atender_('Génova,_Quindío',_'Miraflores,_Boyacá')
#  + atender_('La_Dorada,_Caldas_',_'Miraflores,_Boyacá')
#  + atender_('Medellín,_Antioquia',_'Miraflores,_Boyacá')
#  + atender_('Neiva,_Huila',_'Miraflores,_Boyacá')
#  + atender_('Pasto,_Nariño',_'Miraflores,_Boyacá')
#  + atender_('Pereira,_Risaralda',_'Miraflores,_Boyacá')
#  + atender_('Popayán,_Cauca',_'Miraflores,_Boyacá')
#  + atender_('Salamina,_Caldas',_'Miraflores,_Boyacá')
#  + atender_('Santa_Marta,_Magdalena',_'Miraflores,_Boyacá')
#  + atender_('Santana,_Huila',_'Miraflores,_Boyacá')
#  + atender_('Valledupar,_Cesar',_'Miraflores,_Boyacá') = 1
#
# R1_Moniquirá,_Boyacá: atender_('Aguadas,_Caldas',_'Moniquirá,_Boyacá')
#  + atender_('Barbosa,_Santander',_'Moniquirá,_Boyacá')
#  + atender_('Bogotá,_Cundinamarca',_'Moniquirá,_Boyacá')
#  + atender_('Bucaramanga,_Santander',_'Moniquirá,_Boyacá')
#  + atender_('Calarcá,_Quindío',_'Moniquirá,_Boyacá')
#  + atender_('Cali,_Valle_del_Cauca',_'Moniquirá,_Boyacá')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Moniquirá,_Boyacá')
#  + atender_('Filandia,_Quindío',_'Moniquirá,_Boyacá')
#  + atender_('Génova,_Quindío',_'Moniquirá,_Boyacá')
#  + atender_('La_Dorada,_Caldas_',_'Moniquirá,_Boyacá')
#  + atender_('Medellín,_Antioquia',_'Moniquirá,_Boyacá')
#  + atender_('Neiva,_Huila',_'Moniquirá,_Boyacá')
#  + atender_('Pasto,_Nariño',_'Moniquirá,_Boyacá')
#  + atender_('Pereira,_Risaralda',_'Moniquirá,_Boyacá')
#  + atender_('Popayán,_Cauca',_'Moniquirá,_Boyacá')
#  + atender_('Salamina,_Caldas',_'Moniquirá,_Boyacá')
#  + atender_('Santa_Marta,_Magdalena',_'Moniquirá,_Boyacá')
#  + atender_('Santana,_Huila',_'Moniquirá,_Boyacá')
#  + atender_('Valledupar,_Cesar',_'Moniquirá,_Boyacá') = 1
#
# R1_Manizales,_Caldas: atender_('Aguadas,_Caldas',_'Manizales,_Caldas')
#  + atender_('Barbosa,_Santander',_'Manizales,_Caldas')
#  + atender_('Bogotá,_Cundinamarca',_'Manizales,_Caldas')
#  + atender_('Bucaramanga,_Santander',_'Manizales,_Caldas')
#  + atender_('Calarcá,_Quindío',_'Manizales,_Caldas')
#  + atender_('Cali,_Valle_del_Cauca',_'Manizales,_Caldas')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Manizales,_Caldas')
#  + atender_('Filandia,_Quindío',_'Manizales,_Caldas')
#  + atender_('Génova,_Quindío',_'Manizales,_Caldas')
#  + atender_('La_Dorada,_Caldas_',_'Manizales,_Caldas')
#  + atender_('Medellín,_Antioquia',_'Manizales,_Caldas')
#  + atender_('Neiva,_Huila',_'Manizales,_Caldas')
#  + atender_('Pasto,_Nariño',_'Manizales,_Caldas')
#  + atender_('Pereira,_Risaralda',_'Manizales,_Caldas')
#  + atender_('Popayán,_Cauca',_'Manizales,_Caldas')
#  + atender_('Salamina,_Caldas',_'Manizales,_Caldas')
#  + atender_('Santa_Marta,_Magdalena',_'Manizales,_Caldas')
#  + atender_('Santana,_Huila',_'Manizales,_Caldas')
#  + atender_('Valledupar,_Cesar',_'Manizales,_Caldas') = 1
#
# R1_Anserma,_Caldas: atender_('Aguadas,_Caldas',_'Anserma,_Caldas')
#  + atender_('Barbosa,_Santander',_'Anserma,_Caldas')
#  + atender_('Bogotá,_Cundinamarca',_'Anserma,_Caldas')
#  + atender_('Bucaramanga,_Santander',_'Anserma,_Caldas')
#  + atender_('Calarcá,_Quindío',_'Anserma,_Caldas')
#  + atender_('Cali,_Valle_del_Cauca',_'Anserma,_Caldas')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Anserma,_Caldas')
#  + atender_('Filandia,_Quindío',_'Anserma,_Caldas')
#  + atender_('Génova,_Quindío',_'Anserma,_Caldas')
#  + atender_('La_Dorada,_Caldas_',_'Anserma,_Caldas')
#  + atender_('Medellín,_Antioquia',_'Anserma,_Caldas')
#  + atender_('Neiva,_Huila',_'Anserma,_Caldas')
#  + atender_('Pasto,_Nariño',_'Anserma,_Caldas')
#  + atender_('Pereira,_Risaralda',_'Anserma,_Caldas')
#  + atender_('Popayán,_Cauca',_'Anserma,_Caldas')
#  + atender_('Salamina,_Caldas',_'Anserma,_Caldas')
#  + atender_('Santa_Marta,_Magdalena',_'Anserma,_Caldas')
#  + atender_('Santana,_Huila',_'Anserma,_Caldas')
#  + atender_('Valledupar,_Cesar',_'Anserma,_Caldas') = 1
#
# R1_Pensilvania,_Caldas: atender_('Aguadas,_Caldas',_'Pensilvania,_Caldas')
#  + atender_('Barbosa,_Santander',_'Pensilvania,_Caldas')
#  + atender_('Bogotá,_Cundinamarca',_'Pensilvania,_Caldas')
#  + atender_('Bucaramanga,_Santander',_'Pensilvania,_Caldas')
#  + atender_('Calarcá,_Quindío',_'Pensilvania,_Caldas')
#  + atender_('Cali,_Valle_del_Cauca',_'Pensilvania,_Caldas')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Pensilvania,_Caldas')
#  + atender_('Filandia,_Quindío',_'Pensilvania,_Caldas')
#  + atender_('Génova,_Quindío',_'Pensilvania,_Caldas')
#  + atender_('La_Dorada,_Caldas_',_'Pensilvania,_Caldas')
#  + atender_('Medellín,_Antioquia',_'Pensilvania,_Caldas')
#  + atender_('Neiva,_Huila',_'Pensilvania,_Caldas')
#  + atender_('Pasto,_Nariño',_'Pensilvania,_Caldas')
#  + atender_('Pereira,_Risaralda',_'Pensilvania,_Caldas')
#  + atender_('Popayán,_Cauca',_'Pensilvania,_Caldas')
#  + atender_('Salamina,_Caldas',_'Pensilvania,_Caldas')
#  + atender_('Santa_Marta,_Magdalena',_'Pensilvania,_Caldas')
#  + atender_('Santana,_Huila',_'Pensilvania,_Caldas')
#  + atender_('Valledupar,_Cesar',_'Pensilvania,_Caldas') = 1
#
# R1_Riosucio,_Caldas: atender_('Aguadas,_Caldas',_'Riosucio,_Caldas')
#  + atender_('Barbosa,_Santander',_'Riosucio,_Caldas')
#  + atender_('Bogotá,_Cundinamarca',_'Riosucio,_Caldas')
#  + atender_('Bucaramanga,_Santander',_'Riosucio,_Caldas')
#  + atender_('Calarcá,_Quindío',_'Riosucio,_Caldas')
#  + atender_('Cali,_Valle_del_Cauca',_'Riosucio,_Caldas')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Riosucio,_Caldas')
#  + atender_('Filandia,_Quindío',_'Riosucio,_Caldas')
#  + atender_('Génova,_Quindío',_'Riosucio,_Caldas')
#  + atender_('La_Dorada,_Caldas_',_'Riosucio,_Caldas')
#  + atender_('Medellín,_Antioquia',_'Riosucio,_Caldas')
#  + atender_('Neiva,_Huila',_'Riosucio,_Caldas')
#  + atender_('Pasto,_Nariño',_'Riosucio,_Caldas')
#  + atender_('Pereira,_Risaralda',_'Riosucio,_Caldas')
#  + atender_('Popayán,_Cauca',_'Riosucio,_Caldas')
#  + atender_('Salamina,_Caldas',_'Riosucio,_Caldas')
#  + atender_('Santa_Marta,_Magdalena',_'Riosucio,_Caldas')
#  + atender_('Santana,_Huila',_'Riosucio,_Caldas')
#  + atender_('Valledupar,_Cesar',_'Riosucio,_Caldas') = 1
#
# R1_Aguadas,_Caldas: atender_('Aguadas,_Caldas',_'Aguadas,_Caldas')
#  + atender_('Barbosa,_Santander',_'Aguadas,_Caldas')
#  + atender_('Bogotá,_Cundinamarca',_'Aguadas,_Caldas')
#  + atender_('Bucaramanga,_Santander',_'Aguadas,_Caldas')
#  + atender_('Calarcá,_Quindío',_'Aguadas,_Caldas')
#  + atender_('Cali,_Valle_del_Cauca',_'Aguadas,_Caldas')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Aguadas,_Caldas')
#  + atender_('Filandia,_Quindío',_'Aguadas,_Caldas')
#  + atender_('Génova,_Quindío',_'Aguadas,_Caldas')
#  + atender_('La_Dorada,_Caldas_',_'Aguadas,_Caldas')
#  + atender_('Medellín,_Antioquia',_'Aguadas,_Caldas')
#  + atender_('Neiva,_Huila',_'Aguadas,_Caldas')
#  + atender_('Pasto,_Nariño',_'Aguadas,_Caldas')
#  + atender_('Pereira,_Risaralda',_'Aguadas,_Caldas')
#  + atender_('Popayán,_Cauca',_'Aguadas,_Caldas')
#  + atender_('Salamina,_Caldas',_'Aguadas,_Caldas')
#  + atender_('Santa_Marta,_Magdalena',_'Aguadas,_Caldas')
#  + atender_('Santana,_Huila',_'Aguadas,_Caldas')
#  + atender_('Valledupar,_Cesar',_'Aguadas,_Caldas') = 1
#
# R1_Morales,_Cauca: atender_('Aguadas,_Caldas',_'Morales,_Cauca')
#  + atender_('Barbosa,_Santander',_'Morales,_Cauca')
#  + atender_('Bogotá,_Cundinamarca',_'Morales,_Cauca')
#  + atender_('Bucaramanga,_Santander',_'Morales,_Cauca')
#  + atender_('Calarcá,_Quindío',_'Morales,_Cauca')
#  + atender_('Cali,_Valle_del_Cauca',_'Morales,_Cauca')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Morales,_Cauca')
#  + atender_('Filandia,_Quindío',_'Morales,_Cauca')
#  + atender_('Génova,_Quindío',_'Morales,_Cauca')
#  + atender_('La_Dorada,_Caldas_',_'Morales,_Cauca')
#  + atender_('Medellín,_Antioquia',_'Morales,_Cauca')
#  + atender_('Neiva,_Huila',_'Morales,_Cauca')
#  + atender_('Pasto,_Nariño',_'Morales,_Cauca')
#  + atender_('Pereira,_Risaralda',_'Morales,_Cauca')
#  + atender_('Popayán,_Cauca',_'Morales,_Cauca')
#  + atender_('Salamina,_Caldas',_'Morales,_Cauca')
#  + atender_('Santa_Marta,_Magdalena',_'Morales,_Cauca')
#  + atender_('Santana,_Huila',_'Morales,_Cauca')
#  + atender_('Valledupar,_Cesar',_'Morales,_Cauca') = 1
#
# R1_El_Tambo,_Cauca: atender_('Aguadas,_Caldas',_'El_Tambo,_Cauca')
#  + atender_('Barbosa,_Santander',_'El_Tambo,_Cauca')
#  + atender_('Bogotá,_Cundinamarca',_'El_Tambo,_Cauca')
#  + atender_('Bucaramanga,_Santander',_'El_Tambo,_Cauca')
#  + atender_('Calarcá,_Quindío',_'El_Tambo,_Cauca')
#  + atender_('Cali,_Valle_del_Cauca',_'El_Tambo,_Cauca')
#  + atender_('Cúcuta,_Nor._de_Santander',_'El_Tambo,_Cauca')
#  + atender_('Filandia,_Quindío',_'El_Tambo,_Cauca')
#  + atender_('Génova,_Quindío',_'El_Tambo,_Cauca')
#  + atender_('La_Dorada,_Caldas_',_'El_Tambo,_Cauca')
#  + atender_('Medellín,_Antioquia',_'El_Tambo,_Cauca')
#  + atender_('Neiva,_Huila',_'El_Tambo,_Cauca')
#  + atender_('Pasto,_Nariño',_'El_Tambo,_Cauca')
#  + atender_('Pereira,_Risaralda',_'El_Tambo,_Cauca')
#  + atender_('Popayán,_Cauca',_'El_Tambo,_Cauca')
#  + atender_('Salamina,_Caldas',_'El_Tambo,_Cauca')
#  + atender_('Santa_Marta,_Magdalena',_'El_Tambo,_Cauca')
#  + atender_('Santana,_Huila',_'El_Tambo,_Cauca')
#  + atender_('Valledupar,_Cesar',_'El_Tambo,_Cauca') = 1
#
# R1_Bolívar,_Cauca: atender_('Aguadas,_Caldas',_'Bolívar,_Cauca')
#  + atender_('Barbosa,_Santander',_'Bolívar,_Cauca')
#  + atender_('Bogotá,_Cundinamarca',_'Bolívar,_Cauca')
#  + atender_('Bucaramanga,_Santander',_'Bolívar,_Cauca')
#  + atender_('Calarcá,_Quindío',_'Bolívar,_Cauca')
#  + atender_('Cali,_Valle_del_Cauca',_'Bolívar,_Cauca')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Bolívar,_Cauca')
#  + atender_('Filandia,_Quindío',_'Bolívar,_Cauca')
#  + atender_('Génova,_Quindío',_'Bolívar,_Cauca')
#  + atender_('La_Dorada,_Caldas_',_'Bolívar,_Cauca')
#  + atender_('Medellín,_Antioquia',_'Bolívar,_Cauca')
#  + atender_('Neiva,_Huila',_'Bolívar,_Cauca')
#  + atender_('Pasto,_Nariño',_'Bolívar,_Cauca')
#  + atender_('Pereira,_Risaralda',_'Bolívar,_Cauca')
#  + atender_('Popayán,_Cauca',_'Bolívar,_Cauca')
#  + atender_('Salamina,_Caldas',_'Bolívar,_Cauca')
#  + atender_('Santa_Marta,_Magdalena',_'Bolívar,_Cauca')
#  + atender_('Santana,_Huila',_'Bolívar,_Cauca')
#  + atender_('Valledupar,_Cesar',_'Bolívar,_Cauca') = 1
#
# R1_Aguachica,_Cesar: atender_('Aguadas,_Caldas',_'Aguachica,_Cesar')
#  + atender_('Barbosa,_Santander',_'Aguachica,_Cesar')
#  + atender_('Bogotá,_Cundinamarca',_'Aguachica,_Cesar')
#  + atender_('Bucaramanga,_Santander',_'Aguachica,_Cesar')
#  + atender_('Calarcá,_Quindío',_'Aguachica,_Cesar')
#  + atender_('Cali,_Valle_del_Cauca',_'Aguachica,_Cesar')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Aguachica,_Cesar')
#  + atender_('Filandia,_Quindío',_'Aguachica,_Cesar')
#  + atender_('Génova,_Quindío',_'Aguachica,_Cesar')
#  + atender_('La_Dorada,_Caldas_',_'Aguachica,_Cesar')
#  + atender_('Medellín,_Antioquia',_'Aguachica,_Cesar')
#  + atender_('Neiva,_Huila',_'Aguachica,_Cesar')
#  + atender_('Pasto,_Nariño',_'Aguachica,_Cesar')
#  + atender_('Pereira,_Risaralda',_'Aguachica,_Cesar')
#  + atender_('Popayán,_Cauca',_'Aguachica,_Cesar')
#  + atender_('Salamina,_Caldas',_'Aguachica,_Cesar')
#  + atender_('Santa_Marta,_Magdalena',_'Aguachica,_Cesar')
#  + atender_('Santana,_Huila',_'Aguachica,_Cesar')
#  + atender_('Valledupar,_Cesar',_'Aguachica,_Cesar') = 1
#
# R1_San_Diego,_Cesar: atender_('Aguadas,_Caldas',_'San_Diego,_Cesar')
#  + atender_('Barbosa,_Santander',_'San_Diego,_Cesar')
#  + atender_('Bogotá,_Cundinamarca',_'San_Diego,_Cesar')
#  + atender_('Bucaramanga,_Santander',_'San_Diego,_Cesar')
#  + atender_('Calarcá,_Quindío',_'San_Diego,_Cesar')
#  + atender_('Cali,_Valle_del_Cauca',_'San_Diego,_Cesar')
#  + atender_('Cúcuta,_Nor._de_Santander',_'San_Diego,_Cesar')
#  + atender_('Filandia,_Quindío',_'San_Diego,_Cesar')
#  + atender_('Génova,_Quindío',_'San_Diego,_Cesar')
#  + atender_('La_Dorada,_Caldas_',_'San_Diego,_Cesar')
#  + atender_('Medellín,_Antioquia',_'San_Diego,_Cesar')
#  + atender_('Neiva,_Huila',_'San_Diego,_Cesar')
#  + atender_('Pasto,_Nariño',_'San_Diego,_Cesar')
#  + atender_('Pereira,_Risaralda',_'San_Diego,_Cesar')
#  + atender_('Popayán,_Cauca',_'San_Diego,_Cesar')
#  + atender_('Salamina,_Caldas',_'San_Diego,_Cesar')
#  + atender_('Santa_Marta,_Magdalena',_'San_Diego,_Cesar')
#  + atender_('Santana,_Huila',_'San_Diego,_Cesar')
#  + atender_('Valledupar,_Cesar',_'San_Diego,_Cesar') = 1
#
# R1_Caparrapí,_Cundinamarca:
#  atender_('Aguadas,_Caldas',_'Caparrapí,_Cundinamarca')
#  + atender_('Barbosa,_Santander',_'Caparrapí,_Cundinamarca')
#  + atender_('Bogotá,_Cundinamarca',_'Caparrapí,_Cundinamarca')
#  + atender_('Bucaramanga,_Santander',_'Caparrapí,_Cundinamarca')
#  + atender_('Calarcá,_Quindío',_'Caparrapí,_Cundinamarca')
#  + atender_('Cali,_Valle_del_Cauca',_'Caparrapí,_Cundinamarca')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Caparrapí,_Cundinamarca')
#  + atender_('Filandia,_Quindío',_'Caparrapí,_Cundinamarca')
#  + atender_('Génova,_Quindío',_'Caparrapí,_Cundinamarca')
#  + atender_('La_Dorada,_Caldas_',_'Caparrapí,_Cundinamarca')
#  + atender_('Medellín,_Antioquia',_'Caparrapí,_Cundinamarca')
#  + atender_('Neiva,_Huila',_'Caparrapí,_Cundinamarca')
#  + atender_('Pasto,_Nariño',_'Caparrapí,_Cundinamarca')
#  + atender_('Pereira,_Risaralda',_'Caparrapí,_Cundinamarca')
#  + atender_('Popayán,_Cauca',_'Caparrapí,_Cundinamarca')
#  + atender_('Salamina,_Caldas',_'Caparrapí,_Cundinamarca')
#  + atender_('Santa_Marta,_Magdalena',_'Caparrapí,_Cundinamarca')
#  + atender_('Santana,_Huila',_'Caparrapí,_Cundinamarca')
#  + atender_('Valledupar,_Cesar',_'Caparrapí,_Cundinamarca') = 1
#
# R1_Viotá,_Cundinamarca: atender_('Aguadas,_Caldas',_'Viotá,_Cundinamarca')
#  + atender_('Barbosa,_Santander',_'Viotá,_Cundinamarca')
#  + atender_('Bogotá,_Cundinamarca',_'Viotá,_Cundinamarca')
#  + atender_('Bucaramanga,_Santander',_'Viotá,_Cundinamarca')
#  + atender_('Calarcá,_Quindío',_'Viotá,_Cundinamarca')
#  + atender_('Cali,_Valle_del_Cauca',_'Viotá,_Cundinamarca')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Viotá,_Cundinamarca')
#  + atender_('Filandia,_Quindío',_'Viotá,_Cundinamarca')
#  + atender_('Génova,_Quindío',_'Viotá,_Cundinamarca')
#  + atender_('La_Dorada,_Caldas_',_'Viotá,_Cundinamarca')
#  + atender_('Medellín,_Antioquia',_'Viotá,_Cundinamarca')
#  + atender_('Neiva,_Huila',_'Viotá,_Cundinamarca')
#  + atender_('Pasto,_Nariño',_'Viotá,_Cundinamarca')
#  + atender_('Pereira,_Risaralda',_'Viotá,_Cundinamarca')
#  + atender_('Popayán,_Cauca',_'Viotá,_Cundinamarca')
#  + atender_('Salamina,_Caldas',_'Viotá,_Cundinamarca')
#  + atender_('Santa_Marta,_Magdalena',_'Viotá,_Cundinamarca')
#  + atender_('Santana,_Huila',_'Viotá,_Cundinamarca')
#  + atender_('Valledupar,_Cesar',_'Viotá,_Cundinamarca') = 1
#
# R1_Sasaima,_Cundinamarca: atender_('Aguadas,_Caldas',_'Sasaima,_Cundinamarca')
#  + atender_('Barbosa,_Santander',_'Sasaima,_Cundinamarca')
#  + atender_('Bogotá,_Cundinamarca',_'Sasaima,_Cundinamarca')
#  + atender_('Bucaramanga,_Santander',_'Sasaima,_Cundinamarca')
#  + atender_('Calarcá,_Quindío',_'Sasaima,_Cundinamarca')
#  + atender_('Cali,_Valle_del_Cauca',_'Sasaima,_Cundinamarca')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Sasaima,_Cundinamarca')
#  + atender_('Filandia,_Quindío',_'Sasaima,_Cundinamarca')
#  + atender_('Génova,_Quindío',_'Sasaima,_Cundinamarca')
#  + atender_('La_Dorada,_Caldas_',_'Sasaima,_Cundinamarca')
#  + atender_('Medellín,_Antioquia',_'Sasaima,_Cundinamarca')
#  + atender_('Neiva,_Huila',_'Sasaima,_Cundinamarca')
#  + atender_('Pasto,_Nariño',_'Sasaima,_Cundinamarca')
#  + atender_('Pereira,_Risaralda',_'Sasaima,_Cundinamarca')
#  + atender_('Popayán,_Cauca',_'Sasaima,_Cundinamarca')
#  + atender_('Salamina,_Caldas',_'Sasaima,_Cundinamarca')
#  + atender_('Santa_Marta,_Magdalena',_'Sasaima,_Cundinamarca')
#  + atender_('Santana,_Huila',_'Sasaima,_Cundinamarca')
#  + atender_('Valledupar,_Cesar',_'Sasaima,_Cundinamarca') = 1
#
# R1_Neiva,_Huila: atender_('Aguadas,_Caldas',_'Neiva,_Huila')
#  + atender_('Barbosa,_Santander',_'Neiva,_Huila')
#  + atender_('Bogotá,_Cundinamarca',_'Neiva,_Huila')
#  + atender_('Bucaramanga,_Santander',_'Neiva,_Huila')
#  + atender_('Calarcá,_Quindío',_'Neiva,_Huila')
#  + atender_('Cali,_Valle_del_Cauca',_'Neiva,_Huila')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Neiva,_Huila')
#  + atender_('Filandia,_Quindío',_'Neiva,_Huila')
#  + atender_('Génova,_Quindío',_'Neiva,_Huila')
#  + atender_('La_Dorada,_Caldas_',_'Neiva,_Huila')
#  + atender_('Medellín,_Antioquia',_'Neiva,_Huila')
#  + atender_('Neiva,_Huila',_'Neiva,_Huila')
#  + atender_('Pasto,_Nariño',_'Neiva,_Huila')
#  + atender_('Pereira,_Risaralda',_'Neiva,_Huila')
#  + atender_('Popayán,_Cauca',_'Neiva,_Huila')
#  + atender_('Salamina,_Caldas',_'Neiva,_Huila')
#  + atender_('Santa_Marta,_Magdalena',_'Neiva,_Huila')
#  + atender_('Santana,_Huila',_'Neiva,_Huila')
#  + atender_('Valledupar,_Cesar',_'Neiva,_Huila') = 1
#
# R1_Pitalito,_Huila: atender_('Aguadas,_Caldas',_'Pitalito,_Huila')
#  + atender_('Barbosa,_Santander',_'Pitalito,_Huila')
#  + atender_('Bogotá,_Cundinamarca',_'Pitalito,_Huila')
#  + atender_('Bucaramanga,_Santander',_'Pitalito,_Huila')
#  + atender_('Calarcá,_Quindío',_'Pitalito,_Huila')
#  + atender_('Cali,_Valle_del_Cauca',_'Pitalito,_Huila')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Pitalito,_Huila')
#  + atender_('Filandia,_Quindío',_'Pitalito,_Huila')
#  + atender_('Génova,_Quindío',_'Pitalito,_Huila')
#  + atender_('La_Dorada,_Caldas_',_'Pitalito,_Huila')
#  + atender_('Medellín,_Antioquia',_'Pitalito,_Huila')
#  + atender_('Neiva,_Huila',_'Pitalito,_Huila')
#  + atender_('Pasto,_Nariño',_'Pitalito,_Huila')
#  + atender_('Pereira,_Risaralda',_'Pitalito,_Huila')
#  + atender_('Popayán,_Cauca',_'Pitalito,_Huila')
#  + atender_('Salamina,_Caldas',_'Pitalito,_Huila')
#  + atender_('Santa_Marta,_Magdalena',_'Pitalito,_Huila')
#  + atender_('Santana,_Huila',_'Pitalito,_Huila')
#  + atender_('Valledupar,_Cesar',_'Pitalito,_Huila') = 1
#
# R1_Gigante,_Huila: atender_('Aguadas,_Caldas',_'Gigante,_Huila')
#  + atender_('Barbosa,_Santander',_'Gigante,_Huila')
#  + atender_('Bogotá,_Cundinamarca',_'Gigante,_Huila')
#  + atender_('Bucaramanga,_Santander',_'Gigante,_Huila')
#  + atender_('Calarcá,_Quindío',_'Gigante,_Huila')
#  + atender_('Cali,_Valle_del_Cauca',_'Gigante,_Huila')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Gigante,_Huila')
#  + atender_('Filandia,_Quindío',_'Gigante,_Huila')
#  + atender_('Génova,_Quindío',_'Gigante,_Huila')
#  + atender_('La_Dorada,_Caldas_',_'Gigante,_Huila')
#  + atender_('Medellín,_Antioquia',_'Gigante,_Huila')
#  + atender_('Neiva,_Huila',_'Gigante,_Huila')
#  + atender_('Pasto,_Nariño',_'Gigante,_Huila')
#  + atender_('Pereira,_Risaralda',_'Gigante,_Huila')
#  + atender_('Popayán,_Cauca',_'Gigante,_Huila')
#  + atender_('Salamina,_Caldas',_'Gigante,_Huila')
#  + atender_('Santa_Marta,_Magdalena',_'Gigante,_Huila')
#  + atender_('Santana,_Huila',_'Gigante,_Huila')
#  + atender_('Valledupar,_Cesar',_'Gigante,_Huila') = 1
#
# R1_Santa_Marta,_Magdalena:
#  atender_('Aguadas,_Caldas',_'Santa_Marta,_Magdalena')
#  + atender_('Barbosa,_Santander',_'Santa_Marta,_Magdalena')
#  + atender_('Bogotá,_Cundinamarca',_'Santa_Marta,_Magdalena')
#  + atender_('Bucaramanga,_Santander',_'Santa_Marta,_Magdalena')
#  + atender_('Calarcá,_Quindío',_'Santa_Marta,_Magdalena')
#  + atender_('Cali,_Valle_del_Cauca',_'Santa_Marta,_Magdalena')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Santa_Marta,_Magdalena')
#  + atender_('Filandia,_Quindío',_'Santa_Marta,_Magdalena')
#  + atender_('Génova,_Quindío',_'Santa_Marta,_Magdalena')
#  + atender_('La_Dorada,_Caldas_',_'Santa_Marta,_Magdalena')
#  + atender_('Medellín,_Antioquia',_'Santa_Marta,_Magdalena')
#  + atender_('Neiva,_Huila',_'Santa_Marta,_Magdalena')
#  + atender_('Pasto,_Nariño',_'Santa_Marta,_Magdalena')
#  + atender_('Pereira,_Risaralda',_'Santa_Marta,_Magdalena')
#  + atender_('Popayán,_Cauca',_'Santa_Marta,_Magdalena')
#  + atender_('Salamina,_Caldas',_'Santa_Marta,_Magdalena')
#  + atender_('Santa_Marta,_Magdalena',_'Santa_Marta,_Magdalena')
#  + atender_('Santana,_Huila',_'Santa_Marta,_Magdalena')
#  + atender_('Valledupar,_Cesar',_'Santa_Marta,_Magdalena') = 1
#
# R1_La_Unión,_Nariño: atender_('Aguadas,_Caldas',_'La_Unión,_Nariño')
#  + atender_('Barbosa,_Santander',_'La_Unión,_Nariño')
#  + atender_('Bogotá,_Cundinamarca',_'La_Unión,_Nariño')
#  + atender_('Bucaramanga,_Santander',_'La_Unión,_Nariño')
#  + atender_('Calarcá,_Quindío',_'La_Unión,_Nariño')
#  + atender_('Cali,_Valle_del_Cauca',_'La_Unión,_Nariño')
#  + atender_('Cúcuta,_Nor._de_Santander',_'La_Unión,_Nariño')
#  + atender_('Filandia,_Quindío',_'La_Unión,_Nariño')
#  + atender_('Génova,_Quindío',_'La_Unión,_Nariño')
#  + atender_('La_Dorada,_Caldas_',_'La_Unión,_Nariño')
#  + atender_('Medellín,_Antioquia',_'La_Unión,_Nariño')
#  + atender_('Neiva,_Huila',_'La_Unión,_Nariño')
#  + atender_('Pasto,_Nariño',_'La_Unión,_Nariño')
#  + atender_('Pereira,_Risaralda',_'La_Unión,_Nariño')
#  + atender_('Popayán,_Cauca',_'La_Unión,_Nariño')
#  + atender_('Salamina,_Caldas',_'La_Unión,_Nariño')
#  + atender_('Santa_Marta,_Magdalena',_'La_Unión,_Nariño')
#  + atender_('Santana,_Huila',_'La_Unión,_Nariño')
#  + atender_('Valledupar,_Cesar',_'La_Unión,_Nariño') = 1
#
# R1_Pasto,_Nariño: atender_('Aguadas,_Caldas',_'Pasto,_Nariño')
#  + atender_('Barbosa,_Santander',_'Pasto,_Nariño')
#  + atender_('Bogotá,_Cundinamarca',_'Pasto,_Nariño')
#  + atender_('Bucaramanga,_Santander',_'Pasto,_Nariño')
#  + atender_('Calarcá,_Quindío',_'Pasto,_Nariño')
#  + atender_('Cali,_Valle_del_Cauca',_'Pasto,_Nariño')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Pasto,_Nariño')
#  + atender_('Filandia,_Quindío',_'Pasto,_Nariño')
#  + atender_('Génova,_Quindío',_'Pasto,_Nariño')
#  + atender_('La_Dorada,_Caldas_',_'Pasto,_Nariño')
#  + atender_('Medellín,_Antioquia',_'Pasto,_Nariño')
#  + atender_('Neiva,_Huila',_'Pasto,_Nariño')
#  + atender_('Pasto,_Nariño',_'Pasto,_Nariño')
#  + atender_('Pereira,_Risaralda',_'Pasto,_Nariño')
#  + atender_('Popayán,_Cauca',_'Pasto,_Nariño')
#  + atender_('Salamina,_Caldas',_'Pasto,_Nariño')
#  + atender_('Santa_Marta,_Magdalena',_'Pasto,_Nariño')
#  + atender_('Santana,_Huila',_'Pasto,_Nariño')
#  + atender_('Valledupar,_Cesar',_'Pasto,_Nariño') = 1
#
# R1_Samaniego,_Nariño: atender_('Aguadas,_Caldas',_'Samaniego,_Nariño')
#  + atender_('Barbosa,_Santander',_'Samaniego,_Nariño')
#  + atender_('Bogotá,_Cundinamarca',_'Samaniego,_Nariño')
#  + atender_('Bucaramanga,_Santander',_'Samaniego,_Nariño')
#  + atender_('Calarcá,_Quindío',_'Samaniego,_Nariño')
#  + atender_('Cali,_Valle_del_Cauca',_'Samaniego,_Nariño')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Samaniego,_Nariño')
#  + atender_('Filandia,_Quindío',_'Samaniego,_Nariño')
#  + atender_('Génova,_Quindío',_'Samaniego,_Nariño')
#  + atender_('La_Dorada,_Caldas_',_'Samaniego,_Nariño')
#  + atender_('Medellín,_Antioquia',_'Samaniego,_Nariño')
#  + atender_('Neiva,_Huila',_'Samaniego,_Nariño')
#  + atender_('Pasto,_Nariño',_'Samaniego,_Nariño')
#  + atender_('Pereira,_Risaralda',_'Samaniego,_Nariño')
#  + atender_('Popayán,_Cauca',_'Samaniego,_Nariño')
#  + atender_('Salamina,_Caldas',_'Samaniego,_Nariño')
#  + atender_('Santa_Marta,_Magdalena',_'Samaniego,_Nariño')
#  + atender_('Santana,_Huila',_'Samaniego,_Nariño')
#  + atender_('Valledupar,_Cesar',_'Samaniego,_Nariño') = 1
#
# R1_Sardinata,_Norte_de_Santander:
#  atender_('Aguadas,_Caldas',_'Sardinata,_Norte_de_Santander')
#  + atender_('Barbosa,_Santander',_'Sardinata,_Norte_de_Santander')
#  + atender_('Bogotá,_Cundinamarca',_'Sardinata,_Norte_de_Santander')
#  + atender_('Bucaramanga,_Santander',_'Sardinata,_Norte_de_Santander')
#  + atender_('Calarcá,_Quindío',_'Sardinata,_Norte_de_Santander')
#  + atender_('Cali,_Valle_del_Cauca',_'Sardinata,_Norte_de_Santander')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Sardinata,_Norte_de_Santander')
#  + atender_('Filandia,_Quindío',_'Sardinata,_Norte_de_Santander')
#  + atender_('Génova,_Quindío',_'Sardinata,_Norte_de_Santander')
#  + atender_('La_Dorada,_Caldas_',_'Sardinata,_Norte_de_Santander')
#  + atender_('Medellín,_Antioquia',_'Sardinata,_Norte_de_Santander')
#  + atender_('Neiva,_Huila',_'Sardinata,_Norte_de_Santander')
#  + atender_('Pasto,_Nariño',_'Sardinata,_Norte_de_Santander')
#  + atender_('Pereira,_Risaralda',_'Sardinata,_Norte_de_Santander')
#  + atender_('Popayán,_Cauca',_'Sardinata,_Norte_de_Santander')
#  + atender_('Salamina,_Caldas',_'Sardinata,_Norte_de_Santander')
#  + atender_('Santa_Marta,_Magdalena',_'Sardinata,_Norte_de_Santander')
#  + atender_('Santana,_Huila',_'Sardinata,_Norte_de_Santander')
#  + atender_('Valledupar,_Cesar',_'Sardinata,_Norte_de_Santander') = 1
#
# R1_Ocaña,_Norte_de_Santander:
#  atender_('Aguadas,_Caldas',_'Ocaña,_Norte_de_Santander')
#  + atender_('Barbosa,_Santander',_'Ocaña,_Norte_de_Santander')
#  + atender_('Bogotá,_Cundinamarca',_'Ocaña,_Norte_de_Santander')
#  + atender_('Bucaramanga,_Santander',_'Ocaña,_Norte_de_Santander')
#  + atender_('Calarcá,_Quindío',_'Ocaña,_Norte_de_Santander')
#  + atender_('Cali,_Valle_del_Cauca',_'Ocaña,_Norte_de_Santander')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Ocaña,_Norte_de_Santander')
#  + atender_('Filandia,_Quindío',_'Ocaña,_Norte_de_Santander')
#  + atender_('Génova,_Quindío',_'Ocaña,_Norte_de_Santander')
#  + atender_('La_Dorada,_Caldas_',_'Ocaña,_Norte_de_Santander')
#  + atender_('Medellín,_Antioquia',_'Ocaña,_Norte_de_Santander')
#  + atender_('Neiva,_Huila',_'Ocaña,_Norte_de_Santander')
#  + atender_('Pasto,_Nariño',_'Ocaña,_Norte_de_Santander')
#  + atender_('Pereira,_Risaralda',_'Ocaña,_Norte_de_Santander')
#  + atender_('Popayán,_Cauca',_'Ocaña,_Norte_de_Santander')
#  + atender_('Salamina,_Caldas',_'Ocaña,_Norte_de_Santander')
#  + atender_('Santa_Marta,_Magdalena',_'Ocaña,_Norte_de_Santander')
#  + atender_('Santana,_Huila',_'Ocaña,_Norte_de_Santander')
#  + atender_('Valledupar,_Cesar',_'Ocaña,_Norte_de_Santander') = 1
#
# R1_Convención,_Norte_de_Santander:
#  atender_('Aguadas,_Caldas',_'Convención,_Norte_de_Santander')
#  + atender_('Barbosa,_Santander',_'Convención,_Norte_de_Santander')
#  + atender_('Bogotá,_Cundinamarca',_'Convención,_Norte_de_Santander')
#  + atender_('Bucaramanga,_Santander',_'Convención,_Norte_de_Santander')
#  + atender_('Calarcá,_Quindío',_'Convención,_Norte_de_Santander')
#  + atender_('Cali,_Valle_del_Cauca',_'Convención,_Norte_de_Santander')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Convención,_Norte_de_Santander')
#  + atender_('Filandia,_Quindío',_'Convención,_Norte_de_Santander')
#  + atender_('Génova,_Quindío',_'Convención,_Norte_de_Santander')
#  + atender_('La_Dorada,_Caldas_',_'Convención,_Norte_de_Santander')
#  + atender_('Medellín,_Antioquia',_'Convención,_Norte_de_Santander')
#  + atender_('Neiva,_Huila',_'Convención,_Norte_de_Santander')
#  + atender_('Pasto,_Nariño',_'Convención,_Norte_de_Santander')
#  + atender_('Pereira,_Risaralda',_'Convención,_Norte_de_Santander')
#  + atender_('Popayán,_Cauca',_'Convención,_Norte_de_Santander')
#  + atender_('Salamina,_Caldas',_'Convención,_Norte_de_Santander')
#  + atender_('Santa_Marta,_Magdalena',_'Convención,_Norte_de_Santander')
#  + atender_('Santana,_Huila',_'Convención,_Norte_de_Santander')
#  + atender_('Valledupar,_Cesar',_'Convención,_Norte_de_Santander') = 1
#
# R1_Génova,_Quindío: atender_('Aguadas,_Caldas',_'Génova,_Quindío')
#  + atender_('Barbosa,_Santander',_'Génova,_Quindío')
#  + atender_('Bogotá,_Cundinamarca',_'Génova,_Quindío')
#  + atender_('Bucaramanga,_Santander',_'Génova,_Quindío')
#  + atender_('Calarcá,_Quindío',_'Génova,_Quindío')
#  + atender_('Cali,_Valle_del_Cauca',_'Génova,_Quindío')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Génova,_Quindío')
#  + atender_('Filandia,_Quindío',_'Génova,_Quindío')
#  + atender_('Génova,_Quindío',_'Génova,_Quindío')
#  + atender_('La_Dorada,_Caldas_',_'Génova,_Quindío')
#  + atender_('Medellín,_Antioquia',_'Génova,_Quindío')
#  + atender_('Neiva,_Huila',_'Génova,_Quindío')
#  + atender_('Pasto,_Nariño',_'Génova,_Quindío')
#  + atender_('Pereira,_Risaralda',_'Génova,_Quindío')
#  + atender_('Popayán,_Cauca',_'Génova,_Quindío')
#  + atender_('Salamina,_Caldas',_'Génova,_Quindío')
#  + atender_('Santa_Marta,_Magdalena',_'Génova,_Quindío')
#  + atender_('Santana,_Huila',_'Génova,_Quindío')
#  + atender_('Valledupar,_Cesar',_'Génova,_Quindío') = 1
#
# R1_Calarcá,_Quindío: atender_('Aguadas,_Caldas',_'Calarcá,_Quindío')
#  + atender_('Barbosa,_Santander',_'Calarcá,_Quindío')
#  + atender_('Bogotá,_Cundinamarca',_'Calarcá,_Quindío')
#  + atender_('Bucaramanga,_Santander',_'Calarcá,_Quindío')
#  + atender_('Calarcá,_Quindío',_'Calarcá,_Quindío')
#  + atender_('Cali,_Valle_del_Cauca',_'Calarcá,_Quindío')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Calarcá,_Quindío')
#  + atender_('Filandia,_Quindío',_'Calarcá,_Quindío')
#  + atender_('Génova,_Quindío',_'Calarcá,_Quindío')
#  + atender_('La_Dorada,_Caldas_',_'Calarcá,_Quindío')
#  + atender_('Medellín,_Antioquia',_'Calarcá,_Quindío')
#  + atender_('Neiva,_Huila',_'Calarcá,_Quindío')
#  + atender_('Pasto,_Nariño',_'Calarcá,_Quindío')
#  + atender_('Pereira,_Risaralda',_'Calarcá,_Quindío')
#  + atender_('Popayán,_Cauca',_'Calarcá,_Quindío')
#  + atender_('Salamina,_Caldas',_'Calarcá,_Quindío')
#  + atender_('Santa_Marta,_Magdalena',_'Calarcá,_Quindío')
#  + atender_('Santana,_Huila',_'Calarcá,_Quindío')
#  + atender_('Valledupar,_Cesar',_'Calarcá,_Quindío') = 1
#
# R1_Quimbaya,_Quindío: atender_('Aguadas,_Caldas',_'Quimbaya,_Quindío')
#  + atender_('Barbosa,_Santander',_'Quimbaya,_Quindío')
#  + atender_('Bogotá,_Cundinamarca',_'Quimbaya,_Quindío')
#  + atender_('Bucaramanga,_Santander',_'Quimbaya,_Quindío')
#  + atender_('Calarcá,_Quindío',_'Quimbaya,_Quindío')
#  + atender_('Cali,_Valle_del_Cauca',_'Quimbaya,_Quindío')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Quimbaya,_Quindío')
#  + atender_('Filandia,_Quindío',_'Quimbaya,_Quindío')
#  + atender_('Génova,_Quindío',_'Quimbaya,_Quindío')
#  + atender_('La_Dorada,_Caldas_',_'Quimbaya,_Quindío')
#  + atender_('Medellín,_Antioquia',_'Quimbaya,_Quindío')
#  + atender_('Neiva,_Huila',_'Quimbaya,_Quindío')
#  + atender_('Pasto,_Nariño',_'Quimbaya,_Quindío')
#  + atender_('Pereira,_Risaralda',_'Quimbaya,_Quindío')
#  + atender_('Popayán,_Cauca',_'Quimbaya,_Quindío')
#  + atender_('Salamina,_Caldas',_'Quimbaya,_Quindío')
#  + atender_('Santa_Marta,_Magdalena',_'Quimbaya,_Quindío')
#  + atender_('Santana,_Huila',_'Quimbaya,_Quindío')
#  + atender_('Valledupar,_Cesar',_'Quimbaya,_Quindío') = 1
#
# R1_Pereira,_Risaralda: atender_('Aguadas,_Caldas',_'Pereira,_Risaralda')
#  + atender_('Barbosa,_Santander',_'Pereira,_Risaralda')
#  + atender_('Bogotá,_Cundinamarca',_'Pereira,_Risaralda')
#  + atender_('Bucaramanga,_Santander',_'Pereira,_Risaralda')
#  + atender_('Calarcá,_Quindío',_'Pereira,_Risaralda')
#  + atender_('Cali,_Valle_del_Cauca',_'Pereira,_Risaralda')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Pereira,_Risaralda')
#  + atender_('Filandia,_Quindío',_'Pereira,_Risaralda')
#  + atender_('Génova,_Quindío',_'Pereira,_Risaralda')
#  + atender_('La_Dorada,_Caldas_',_'Pereira,_Risaralda')
#  + atender_('Medellín,_Antioquia',_'Pereira,_Risaralda')
#  + atender_('Neiva,_Huila',_'Pereira,_Risaralda')
#  + atender_('Pasto,_Nariño',_'Pereira,_Risaralda')
#  + atender_('Pereira,_Risaralda',_'Pereira,_Risaralda')
#  + atender_('Popayán,_Cauca',_'Pereira,_Risaralda')
#  + atender_('Salamina,_Caldas',_'Pereira,_Risaralda')
#  + atender_('Santa_Marta,_Magdalena',_'Pereira,_Risaralda')
#  + atender_('Santana,_Huila',_'Pereira,_Risaralda')
#  + atender_('Valledupar,_Cesar',_'Pereira,_Risaralda') = 1
#
# R1_Santuario,_Risaralda: atender_('Aguadas,_Caldas',_'Santuario,_Risaralda')
#  + atender_('Barbosa,_Santander',_'Santuario,_Risaralda')
#  + atender_('Bogotá,_Cundinamarca',_'Santuario,_Risaralda')
#  + atender_('Bucaramanga,_Santander',_'Santuario,_Risaralda')
#  + atender_('Calarcá,_Quindío',_'Santuario,_Risaralda')
#  + atender_('Cali,_Valle_del_Cauca',_'Santuario,_Risaralda')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Santuario,_Risaralda')
#  + atender_('Filandia,_Quindío',_'Santuario,_Risaralda')
#  + atender_('Génova,_Quindío',_'Santuario,_Risaralda')
#  + atender_('La_Dorada,_Caldas_',_'Santuario,_Risaralda')
#  + atender_('Medellín,_Antioquia',_'Santuario,_Risaralda')
#  + atender_('Neiva,_Huila',_'Santuario,_Risaralda')
#  + atender_('Pasto,_Nariño',_'Santuario,_Risaralda')
#  + atender_('Pereira,_Risaralda',_'Santuario,_Risaralda')
#  + atender_('Popayán,_Cauca',_'Santuario,_Risaralda')
#  + atender_('Salamina,_Caldas',_'Santuario,_Risaralda')
#  + atender_('Santa_Marta,_Magdalena',_'Santuario,_Risaralda')
#  + atender_('Santana,_Huila',_'Santuario,_Risaralda')
#  + atender_('Valledupar,_Cesar',_'Santuario,_Risaralda') = 1
#
# R1_Belén_de_Umbria,_Risaralda:
#  atender_('Aguadas,_Caldas',_'Belén_de_Umbria,_Risaralda')
#  + atender_('Barbosa,_Santander',_'Belén_de_Umbria,_Risaralda')
#  + atender_('Bogotá,_Cundinamarca',_'Belén_de_Umbria,_Risaralda')
#  + atender_('Bucaramanga,_Santander',_'Belén_de_Umbria,_Risaralda')
#  + atender_('Calarcá,_Quindío',_'Belén_de_Umbria,_Risaralda')
#  + atender_('Cali,_Valle_del_Cauca',_'Belén_de_Umbria,_Risaralda')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Belén_de_Umbria,_Risaralda')
#  + atender_('Filandia,_Quindío',_'Belén_de_Umbria,_Risaralda')
#  + atender_('Génova,_Quindío',_'Belén_de_Umbria,_Risaralda')
#  + atender_('La_Dorada,_Caldas_',_'Belén_de_Umbria,_Risaralda')
#  + atender_('Medellín,_Antioquia',_'Belén_de_Umbria,_Risaralda')
#  + atender_('Neiva,_Huila',_'Belén_de_Umbria,_Risaralda')
#  + atender_('Pasto,_Nariño',_'Belén_de_Umbria,_Risaralda')
#  + atender_('Pereira,_Risaralda',_'Belén_de_Umbria,_Risaralda')
#  + atender_('Popayán,_Cauca',_'Belén_de_Umbria,_Risaralda')
#  + atender_('Salamina,_Caldas',_'Belén_de_Umbria,_Risaralda')
#  + atender_('Santa_Marta,_Magdalena',_'Belén_de_Umbria,_Risaralda')
#  + atender_('Santana,_Huila',_'Belén_de_Umbria,_Risaralda')
#  + atender_('Valledupar,_Cesar',_'Belén_de_Umbria,_Risaralda') = 1
#
# R1_Rionegro,_Santander: atender_('Aguadas,_Caldas',_'Rionegro,_Santander')
#  + atender_('Barbosa,_Santander',_'Rionegro,_Santander')
#  + atender_('Bogotá,_Cundinamarca',_'Rionegro,_Santander')
#  + atender_('Bucaramanga,_Santander',_'Rionegro,_Santander')
#  + atender_('Calarcá,_Quindío',_'Rionegro,_Santander')
#  + atender_('Cali,_Valle_del_Cauca',_'Rionegro,_Santander')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Rionegro,_Santander')
#  + atender_('Filandia,_Quindío',_'Rionegro,_Santander')
#  + atender_('Génova,_Quindío',_'Rionegro,_Santander')
#  + atender_('La_Dorada,_Caldas_',_'Rionegro,_Santander')
#  + atender_('Medellín,_Antioquia',_'Rionegro,_Santander')
#  + atender_('Neiva,_Huila',_'Rionegro,_Santander')
#  + atender_('Pasto,_Nariño',_'Rionegro,_Santander')
#  + atender_('Pereira,_Risaralda',_'Rionegro,_Santander')
#  + atender_('Popayán,_Cauca',_'Rionegro,_Santander')
#  + atender_('Salamina,_Caldas',_'Rionegro,_Santander')
#  + atender_('Santa_Marta,_Magdalena',_'Rionegro,_Santander')
#  + atender_('Santana,_Huila',_'Rionegro,_Santander')
#  + atender_('Valledupar,_Cesar',_'Rionegro,_Santander') = 1
#
# R1_Bucaramanga,_Santander:
#  atender_('Aguadas,_Caldas',_'Bucaramanga,_Santander')
#  + atender_('Barbosa,_Santander',_'Bucaramanga,_Santander')
#  + atender_('Bogotá,_Cundinamarca',_'Bucaramanga,_Santander')
#  + atender_('Bucaramanga,_Santander',_'Bucaramanga,_Santander')
#  + atender_('Calarcá,_Quindío',_'Bucaramanga,_Santander')
#  + atender_('Cali,_Valle_del_Cauca',_'Bucaramanga,_Santander')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Bucaramanga,_Santander')
#  + atender_('Filandia,_Quindío',_'Bucaramanga,_Santander')
#  + atender_('Génova,_Quindío',_'Bucaramanga,_Santander')
#  + atender_('La_Dorada,_Caldas_',_'Bucaramanga,_Santander')
#  + atender_('Medellín,_Antioquia',_'Bucaramanga,_Santander')
#  + atender_('Neiva,_Huila',_'Bucaramanga,_Santander')
#  + atender_('Pasto,_Nariño',_'Bucaramanga,_Santander')
#  + atender_('Pereira,_Risaralda',_'Bucaramanga,_Santander')
#  + atender_('Popayán,_Cauca',_'Bucaramanga,_Santander')
#  + atender_('Salamina,_Caldas',_'Bucaramanga,_Santander')
#  + atender_('Santa_Marta,_Magdalena',_'Bucaramanga,_Santander')
#  + atender_('Santana,_Huila',_'Bucaramanga,_Santander')
#  + atender_('Valledupar,_Cesar',_'Bucaramanga,_Santander') = 1
#
# R1_Barbosa,_Santander: atender_('Aguadas,_Caldas',_'Barbosa,_Santander')
#  + atender_('Barbosa,_Santander',_'Barbosa,_Santander')
#  + atender_('Bogotá,_Cundinamarca',_'Barbosa,_Santander')
#  + atender_('Bucaramanga,_Santander',_'Barbosa,_Santander')
#  + atender_('Calarcá,_Quindío',_'Barbosa,_Santander')
#  + atender_('Cali,_Valle_del_Cauca',_'Barbosa,_Santander')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Barbosa,_Santander')
#  + atender_('Filandia,_Quindío',_'Barbosa,_Santander')
#  + atender_('Génova,_Quindío',_'Barbosa,_Santander')
#  + atender_('La_Dorada,_Caldas_',_'Barbosa,_Santander')
#  + atender_('Medellín,_Antioquia',_'Barbosa,_Santander')
#  + atender_('Neiva,_Huila',_'Barbosa,_Santander')
#  + atender_('Pasto,_Nariño',_'Barbosa,_Santander')
#  + atender_('Pereira,_Risaralda',_'Barbosa,_Santander')
#  + atender_('Popayán,_Cauca',_'Barbosa,_Santander')
#  + atender_('Salamina,_Caldas',_'Barbosa,_Santander')
#  + atender_('Santa_Marta,_Magdalena',_'Barbosa,_Santander')
#  + atender_('Santana,_Huila',_'Barbosa,_Santander')
#  + atender_('Valledupar,_Cesar',_'Barbosa,_Santander') = 1
#
# R1_Socorro,_Santander: atender_('Aguadas,_Caldas',_'Socorro,_Santander')
#  + atender_('Barbosa,_Santander',_'Socorro,_Santander')
#  + atender_('Bogotá,_Cundinamarca',_'Socorro,_Santander')
#  + atender_('Bucaramanga,_Santander',_'Socorro,_Santander')
#  + atender_('Calarcá,_Quindío',_'Socorro,_Santander')
#  + atender_('Cali,_Valle_del_Cauca',_'Socorro,_Santander')
#  + atender_('Cúcuta,_Nor._de_Santander',_'Socorro,_Santander')
# ...
# 0 <= atender_('Salamina,_Caldas',_'Barbosa,_Santander') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Belén_de_Umbria,_Risaralda') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Bolívar,_Cauca') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Bucaramanga,_Santander') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Caicedonia,_Valle') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Calarcá,_Quindío') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Caparrapí,_Cundinamarca') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Cartago,_Valle') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Chaparral,_Tolima') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Convención,_Norte_de_Santander') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Dabeiba,_Antioquia') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Dolores,_Tolima') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'El_Tambo,_Cauca') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Florencia,_Caquetá') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Gigante,_Huila') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Génova,_Quindío') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Ibagué,_Tolima') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Jamundí,_Valle') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'La_Unión,_Nariño') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Labranzagrande,_Boyacá') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Líbano,_Tolima') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Manizales,_Caldas') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Medellín,_Antioquia') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Mesetas,_Meta') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Miraflores,_Boyacá') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Moniquirá,_Boyacá') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Morales,_Cauca') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Neiva,_Huila') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Nunchía,_Casanare') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Ocaña,_Norte_de_Santander') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Pasto,_Nariño') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Pensilvania,_Caldas') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Pereira,_Risaralda') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Pitalito,_Huila') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Puerto_Milán,_Caquetá') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Quimbaya,_Quindío') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Rionegro,_Santander') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Riosucio,_Caldas') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Salgar,_Antioquia') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Samaniego,_Nariño') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'San_Diego,_Cesar') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'San_Pablo_de_Borbur,_Boyacá') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Santa_Marta,_Magdalena') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Santuario,_Risaralda') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Sardinata,_Norte_de_Santander') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Sasaima,_Cundinamarca') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Sevilla,_Valle') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Simacota,_Santander') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Socorro,_Santander') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Tulua,_Valle') <= 1 Integer
# 0 <= atender_('Salamina,_Caldas',_'Viotá,_Cundinamarca') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Aguachica,_Cesar') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Aguadas,_Caldas') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Andes,_Antioquia') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Anserma,_Caldas') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Barbosa,_Santander') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Belén_de_Umbria,_Risaralda') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Bolívar,_Cauca') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Bucaramanga,_Santander') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Caicedonia,_Valle') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Calarcá,_Quindío') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Caparrapí,_Cundinamarca') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Cartago,_Valle') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Chaparral,_Tolima') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Convención,_Norte_de_Santander') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Dabeiba,_Antioquia') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Dolores,_Tolima') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'El_Tambo,_Cauca') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Florencia,_Caquetá') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Gigante,_Huila') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Génova,_Quindío') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Ibagué,_Tolima') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Jamundí,_Valle') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'La_Unión,_Nariño') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Labranzagrande,_Boyacá') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Líbano,_Tolima') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Manizales,_Caldas') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Medellín,_Antioquia') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Mesetas,_Meta') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Miraflores,_Boyacá') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Moniquirá,_Boyacá') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Morales,_Cauca') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Neiva,_Huila') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Nunchía,_Casanare') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Ocaña,_Norte_de_Santander') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Pasto,_Nariño') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Pensilvania,_Caldas') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Pereira,_Risaralda') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Pitalito,_Huila') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Puerto_Milán,_Caquetá') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Quimbaya,_Quindío') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Rionegro,_Santander') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Riosucio,_Caldas') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Salgar,_Antioquia') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Samaniego,_Nariño') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'San_Diego,_Cesar') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'San_Pablo_de_Borbur,_Boyacá') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Santa_Marta,_Magdalena') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Santuario,_Risaralda') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Sardinata,_Norte_de_Santander') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Sasaima,_Cundinamarca') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Sevilla,_Valle') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Simacota,_Santander') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Socorro,_Santander') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Tulua,_Valle') <= 1 Integer
# 0 <= atender_('Santa_Marta,_Magdalena',_'Viotá,_Cundinamarca') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Aguachica,_Cesar') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Aguadas,_Caldas') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Andes,_Antioquia') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Anserma,_Caldas') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Barbosa,_Santander') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Belén_de_Umbria,_Risaralda') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Bolívar,_Cauca') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Bucaramanga,_Santander') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Caicedonia,_Valle') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Calarcá,_Quindío') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Caparrapí,_Cundinamarca') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Cartago,_Valle') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Chaparral,_Tolima') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Convención,_Norte_de_Santander') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Dabeiba,_Antioquia') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Dolores,_Tolima') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'El_Tambo,_Cauca') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Florencia,_Caquetá') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Gigante,_Huila') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Génova,_Quindío') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Ibagué,_Tolima') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Jamundí,_Valle') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'La_Unión,_Nariño') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Labranzagrande,_Boyacá') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Líbano,_Tolima') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Manizales,_Caldas') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Medellín,_Antioquia') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Mesetas,_Meta') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Miraflores,_Boyacá') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Moniquirá,_Boyacá') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Morales,_Cauca') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Neiva,_Huila') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Nunchía,_Casanare') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Ocaña,_Norte_de_Santander') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Pasto,_Nariño') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Pensilvania,_Caldas') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Pereira,_Risaralda') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Pitalito,_Huila') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Puerto_Milán,_Caquetá') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Quimbaya,_Quindío') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Rionegro,_Santander') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Riosucio,_Caldas') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Salgar,_Antioquia') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Samaniego,_Nariño') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'San_Diego,_Cesar') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'San_Pablo_de_Borbur,_Boyacá') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Santa_Marta,_Magdalena') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Santuario,_Risaralda') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Sardinata,_Norte_de_Santander') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Sasaima,_Cundinamarca') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Sevilla,_Valle') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Simacota,_Santander') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Socorro,_Santander') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Tulua,_Valle') <= 1 Integer
# 0 <= atender_('Santana,_Huila',_'Viotá,_Cundinamarca') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Aguachica,_Cesar') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Aguadas,_Caldas') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Andes,_Antioquia') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Anserma,_Caldas') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Barbosa,_Santander') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Belén_de_Umbria,_Risaralda') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Bolívar,_Cauca') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Bucaramanga,_Santander') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Caicedonia,_Valle') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Calarcá,_Quindío') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Caparrapí,_Cundinamarca') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Cartago,_Valle') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Chaparral,_Tolima') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Convención,_Norte_de_Santander') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Dabeiba,_Antioquia') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Dolores,_Tolima') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'El_Tambo,_Cauca') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Florencia,_Caquetá') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Gigante,_Huila') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Génova,_Quindío') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Ibagué,_Tolima') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Jamundí,_Valle') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'La_Unión,_Nariño') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Labranzagrande,_Boyacá') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Líbano,_Tolima') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Manizales,_Caldas') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Medellín,_Antioquia') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Mesetas,_Meta') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Miraflores,_Boyacá') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Moniquirá,_Boyacá') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Morales,_Cauca') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Neiva,_Huila') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Nunchía,_Casanare') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Ocaña,_Norte_de_Santander') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Pasto,_Nariño') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Pensilvania,_Caldas') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Pereira,_Risaralda') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Pitalito,_Huila') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Puerto_Milán,_Caquetá') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Quimbaya,_Quindío') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Rionegro,_Santander') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Riosucio,_Caldas') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Salgar,_Antioquia') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Samaniego,_Nariño') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'San_Diego,_Cesar') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'San_Pablo_de_Borbur,_Boyacá') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Santa_Marta,_Magdalena') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Santuario,_Risaralda') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Sardinata,_Norte_de_Santander') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Sasaima,_Cundinamarca') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Sevilla,_Valle') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Simacota,_Santander') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Socorro,_Santander') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Tulua,_Valle') <= 1 Integer
# 0 <= atender_('Valledupar,_Cesar',_'Viotá,_Cundinamarca') <= 1 Integer
# 0 <= operar_Aguadas,_Caldas <= 1 Integer
# 0 <= operar_Barbosa,_Santander <= 1 Integer
# 0 <= operar_Bogotá,_Cundinamarca <= 1 Integer
# 0 <= operar_Bucaramanga,_Santander <= 1 Integer
# 0 <= operar_Calarcá,_Quindío <= 1 Integer
# 0 <= operar_Cali,_Valle_del_Cauca <= 1 Integer
# 0 <= operar_Cúcuta,_Nor._de_Santander <= 1 Integer
# 0 <= operar_Filandia,_Quindío <= 1 Integer
# 0 <= operar_Génova,_Quindío <= 1 Integer
# 0 <= operar_La_Dorada,_Caldas_ <= 1 Integer
# 0 <= operar_Medellín,_Antioquia <= 1 Integer
# 0 <= operar_Neiva,_Huila <= 1 Integer
# 0 <= operar_Pasto,_Nariño <= 1 Integer
# 0 <= operar_Pereira,_Risaralda <= 1 Integer
# 0 <= operar_Popayán,_Cauca <= 1 Integer
# 0 <= operar_Salamina,_Caldas <= 1 Integer
# 0 <= operar_Santa_Marta,_Magdalena <= 1 Integer
# 0 <= operar_Santana,_Huila <= 1 Integer
# 0 <= operar_Valledupar,_Cesar <= 1 Integer

# %%
# Esta celda esta reservada para uso del equipo docente

# %% [markdown]
# **Pregunta 4 (5 puntos)**
#
# * Crea la siguiente restricción, asígnale el nombre `'R2_'+str(<indice_del_para_todo>)` y añádela al modelo:
# >2. No se debe superar la capacidad de los depósitos y sólo se puede atender CACs desde un depósito si se decide operar el mismo.
# >>$\sum_{j \in J}d_{j}x_{ij} \leq k_{i}y_{i}, \; \forall i \in I$

# %%
# your code here
#d = producción
#k = capacidad
for i in I:
    problema += (
        lp.lpSum(produccion[j] * x[(i, j)] for j in J) <= capacidad[i] * y[i],
        'R2_' + str(i)
    )

# %%
# Esta celda esta reservada para uso del equipo docente

# %%
# Esta celda esta reservada para uso del equipo docente

# %% [markdown]
# ### Invocar el optimizador

# %%
print(lp.LpStatus[problema.solve()])
# Out:
# Optimal

# %% [markdown]
# ## Reporte de resultados - Minimización de costos ($z_1$)
# ---

# %% [markdown]
# **Función objetivo $z_1$**

# %%
z1 = lp.value(problema.objective)
min_costo = z1
print(f"Costo Total: ${z1: .2f}")
print(f"Costo Total Relativo al Mínimo Costo: {z1/min_costo*100: .2f}%")
# Out:
# Costo Total: $ 4318336.74
# Costo Total Relativo al Mínimo Costo:  100.00%

# %% [markdown]
# **Función objetivo $z_2$**

# %% [markdown]
# **Pregunta 5 (5 puntos)**
#
# * Guarda en una variable `z2` el valor de la satisfacción total dado por la expresión:
# > $z_2 = \sum_{j \in J} d_{j} \sum_{\{i \in I | h_{ij} \leq r\}} x_{ij}$
#
# **Recuerda que** en PuLP puedes usar la función `lp.value(<expresion>)` para evaluar una expresión, reemplazando los valores de las variables por aquellos de la solución óptima. Esta función sólo debe ser llamada luego de usar `<modelo>.solve()` y haber obtenido una solución óptima.

# %%
# your code here
z2 = lp.value(
    lp.lpSum(
        produccion[j] * lp.lpSum(x[(i, j)] for i in I if distancia[(i, j)] <= r)
        for j in J
    )
)

print(z2)
# Out:
# 373.75000000000006

# %%
for j in J:
    for i in I:
        if(distancia[(i,j)] <= r):
            produccion[j] * x[(i, j)]

# %%
# Esta celda esta reservada para uso del equipo docente

# %% [markdown]
# **Depósitos en operación**

# %%
print("Se decidió operar", sum(y[i].value() for i in I), "depósitos")
# Out:
# Se decidió operar 15.0 depósitos

# %% [markdown]
# **Asignación de CACs a Depósitos**

# %%
matrix = []
for j in J:
    row = []
    for i in I:
        if y[i].value() == 1:
            if x[i,j].value() == 1:
                row.append('X')
            elif x[i,j].value() == 0:
                row.append('-')
            else:
                row.append('Error')
    matrix.append(row)

df = pd.DataFrame(matrix, index=J, columns=[i for i in I if y[i].value() == 1])
df.head(10)
# Out:
#                             Medellín, Antioquia La Dorada, Caldas   \
# Andes, Antioquia                              X                  -
# Medellín, Antioquia                           X                  -
# Dabeiba, Antioquia                            X                  -
# Salgar, Antioquia                             X                  -
# San Pablo de Borbur, Boyacá                   -                  X
# Labranzagrande, Boyacá                        -                  -
# Miraflores, Boyacá                            -                  -
# Moniquirá, Boyacá                             -                  -
# Manizales, Caldas                             -                  -
# Anserma, Caldas                               -                  -
#
#                             Aguadas, Caldas Salamina, Caldas Popayán, Cauca  \
# Andes, Antioquia                          -                -              -
# Medellín, Antioquia                       -                -              -
# Dabeiba, Antioquia                        -                -              -
# Salgar, Antioquia                         -                -              -
# San Pablo de Borbur, Boyacá               -                -              -
# Labranzagrande, Boyacá                    -                -              -
# Miraflores, Boyacá                        -                -              -
# Moniquirá, Boyacá                         -                -              -
# Manizales, Caldas                         -                X              -
# Anserma, Caldas                           X                -              -
#
#                             Valledupar, Cesar Santana, Huila Neiva, Huila  \
# Andes, Antioquia                            -              -            -
# Medellín, Antioquia                         -              -            -
# Dabeiba, Antioquia                          -              -            -
# Salgar, Antioquia                           -              -            -
# San Pablo de Borbur, Boyacá                 -              -            -
# Labranzagrande, Boyacá                      -              -            -
# Miraflores, Boyacá                          -              -            -
# Moniquirá, Boyacá                           -              -            -
# Manizales, Caldas                           -              -            -
# Anserma, Caldas                             -              -            -
#
#                             Cúcuta, Nor. de Santander Pasto, Nariño  \
# Andes, Antioquia                                    -             -
# Medellín, Antioquia                                 -             -
# Dabeiba, Antioquia                                  -             -
# Salgar, Antioquia                                   -             -
# San Pablo de Borbur, Boyacá                         -             -
# Labranzagrande, Boyacá                              -             -
# Miraflores, Boyacá                                  -             -
# Moniquirá, Boyacá                                   -             -
# Manizales, Caldas                                   -             -
# Anserma, Caldas                                     -             -
#
#                             Génova, Quindío Filandia, Quindío  \
# Andes, Antioquia                          -                 -
# Medellín, Antioquia                       -                 -
# Dabeiba, Antioquia                        -                 -
# Salgar, Antioquia                         -                 -
# San Pablo de Borbur, Boyacá               -                 -
# Labranzagrande, Boyacá                    -                 -
# Miraflores, Boyacá                        -                 -
# Moniquirá, Boyacá                         -                 -
# Manizales, Caldas                         -                 -
# Anserma, Caldas                           -                 -
#
#                             Bucaramanga, Santander Barbosa, Santander  \
# Andes, Antioquia                                 -                  -
# Medellín, Antioquia                              -                  -
# Dabeiba, Antioquia                               -                  -
# Salgar, Antioquia                                -                  -
# San Pablo de Borbur, Boyacá                      -                  -
# Labranzagrande, Boyacá                           X                  -
# Miraflores, Boyacá                               -                  X
# Moniquirá, Boyacá                                -                  X
# Manizales, Caldas                                -                  -
# Anserma, Caldas                                  -                  -
#
#                             Cali, Valle del Cauca
# Andes, Antioquia                                -
# Medellín, Antioquia                             -
# Dabeiba, Antioquia                              -
# Salgar, Antioquia                               -
# San Pablo de Borbur, Boyacá                     -
# Labranzagrande, Boyacá                          -
# Miraflores, Boyacá                              -
# Moniquirá, Boyacá                               -
# Manizales, Caldas                               -
# Anserma, Caldas                                 -

# %% [markdown]
# ### Visualizaciones
# ---

# %% [markdown]
# **Mapa de la asignación**

# %%
# Para los mapas
import folium
# Para los marcadores de los mapas
from folium.plugins import BeautifyIcon

m = folium.Map(location=[6.2, -74.5], tiles="OpenStreetMap", zoom_start=6)

for j, lat_lon in cacs_lat_lon.items():
    folium.Marker(
        location=lat_lon,
        tooltip=j,
        icon=BeautifyIcon(
            icon="circle",
            inner_icon_style="color:blue;font-size:7px;opacity:0.9;position: relative;top:-0.5px;",
            background_color="transparent",
            border_color="transparent",
        ),
    ).add_to(m)
for i, lat_lon in depositos_lat_lon.items():
    if y[i].value() > 0:
        folium.Marker(
            location=lat_lon,
            tooltip=i,
            icon=BeautifyIcon(
                icon="caret-up",
                inner_icon_style="color:red;font-size:20px;opacity:0.9;position: relative;top:-4.5px;",
                background_color="transparent",
                border_color="transparent",
            ),
        ).add_to(m)

red = [(i, j) for i in I for j in J if x[i, j].value() > 0]
for i, j in red:
    folium.PolyLine(
        [depositos_lat_lon[i], cacs_lat_lon[j]], color="black", weight=1, opacity=1
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_60712ab44211aedb2a0130cef7507171 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_60712ab44211aedb2a0130cef7507171&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_60712ab44211aedb2a0130cef7507171 = L.map(
#                 &quot;map_60712ab44211aedb2a0130cef7507171&quot;,
#                 {
#                     center: [6.2, -74.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1ff42ca541c68ce8b4f1dd02547ff369 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1ff42ca541c68ce8b4f1dd02547ff369.addTo(map_60712ab44211aedb2a0130cef7507171);
#
#
#             var marker_888e6a41cce9a6d8fc711db26035241d = L.marker(
#                 [5.62412, -75.95589],
#                 {
# }
#             ).addTo(map_60712ab44211aedb2a0130cef7507171);
#
#
#             var beautify_icon_dc0b90a5058e4c301d6391997a56764e = new L.BeautifyIcon.icon(
#                 {
#   &quot;icon&quot;: &quot;circle&quot;,
#   &quot;borderWidth&quot;: 3,
#   &quot;borderColor&quot;: &quot;transparent&quot;,
#   &quot;textColor&quot;: &quot;#000&quot;,
#   &quot;backgroundColor&quot;: &quot;transparent&quot;,
#   &quot;innerIconStyle&quot;: &quot;color:blue;font-size:7px;opacity:0.9;position: relative;top:-0.5px;&quot;,
#   &quot;spin&quot;: false,
#   &quot;isAlphaNumericIcon&quot;: false,
# }
#             )
#             marker_888e6a41cce9a6d8fc711db26035241d.setIcon(beautify_icon_dc0b90a5058e4c301d6391997a56764e);
#
#
#             marker_888e6a41cce9a6d8fc711db26035241d.bindTooltip(
#                 `&lt;div&gt;
#                      Andes, Antioquia
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_888e6a41cce9a6d8fc711db26035241d.setIcon(beautify_icon_dc0b90a5058e4c301d6391997a56764e);
#
#
#             var marker_b54c82bb00ff121c24f46743c595feaf = L.marker(
#                 [6.26868, -75.59639],
#                 {
# }
#             ).addTo(map_60712ab44211aedb2a0130cef7507171);
#
#
#             var beautify_icon_208bfa50d452256429c06c3cfe51180c = new L.BeautifyIcon.icon(
#                 {
#   &quot;icon&quot;: &quot;circle&quot;,
#   &quot;borderWidth&quot;: 3,
#   &quot;borderColor&quot;: &quot;transparent&quot;,
#   &quot;textColor&quot;: &quot;#000&quot;,
#   &quot;backgroundColor&quot;: &quot;transparent&quot;,
#   &quot;innerIconStyle&quot;: &quot;color:blue;font-size:7px;opacity:0.9;position: relative;top:-0.5px;&quot;,
#   &quot;spin&quot;: false,
#   &quot;isAlphaNumericIcon&quot;: false,
# }
#             )
#             marker_b54c82bb00ff121c24f46743c595feaf.setIcon(beautify_icon_208bfa50d452256429c06c3cfe51180c);
#
#
#             marker_b54c82bb00ff121c24f46743c595feaf.bindTooltip(
#                 `&lt;div&gt;
#                      Medellín, Antioquia
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_b54c82bb00ff121c24f46743c595feaf.setIcon(beautify_icon_208bfa50d452256429c06c3cfe51180c);
#
#
#             var marker_cbc88731a045423adb83d32bd8febd78 = L.marker(
#                 [6.95267, -76.29085],
#                 {
# }
#             ).addTo(map_60712ab44211aedb2a0130cef7507171);
#
#
#             var beautify_icon_9a21520ab6dc64320f1338403c23a539 = new L.BeautifyIcon.icon(
#                 {
#   &quot;icon&quot;: &quot;circle&quot;,
#   &quot;borderWidth&quot;: 3,
#   &quot;borderColor&quot;: &quot;transparent&quot;,
#   &quot;textColor&quot;: &quot;#000&quot;,
#   &quot;backgroundColor&quot;: &quot;transparent&quot;,
#   &quot;innerIconStyle&quot;: &quot;color:blue;font-size:7px;opacity:0.9;position: relative;top:-0.5px;&quot;,
#   &quot;spin&quot;: false,
#   &quot;isAlphaNumericIcon&quot;: false,
# }
#             )
#             marker_cbc88731a045423adb83d32bd8febd78.setIcon(beautify_icon_9a21520ab6dc64320f1338403c23a539);
#
#
#             marker_cbc88731a045423adb83d32bd8febd78.bindTooltip(
#                 `&lt;div&gt;
#                      Dabeiba, Antioquia
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_cbc88731a045423adb83d32bd8febd78.setIcon(beau

# %% [markdown]
# ## Modelado - Maximización de satisfacción ($z_2$)
# ---
# A continuación queremos explorar el cambio en las funciones objetivo $z_1$ y $z_2$ cuando se prioriza $z_2$. Las restricciones y variables del problema permanecen igual, pero la solución cambiará.

# %% [markdown]
# ### Declaración del modelo

# %%
problema = lp.LpProblem(sense=lp.LpMaximize)

# %% [markdown]
# ### Variables de Decisión
#
# >* $x_{ij}=\begin{cases}1, & \text{si el CAC } j \in J \text{ es atendido por el depósito } i \in I \\0, & \text{de lo contrario} \end{cases}$
# >* $y_{i}=\begin{cases} 1, & \text{si se decide operar el depósito } i \in I  \\ 0, & \text{de lo contrario} \end{cases}$

# %%
x = lp.LpVariable.dicts('atender', [(i,j) for i in I for j in J], cat=lp.LpBinary)
y = lp.LpVariable.dicts('operar', I, cat=lp.LpBinary)

# %% [markdown]
# ### Función Objetivo
# Maximizar satisfacción de los CACs
# >$\max z_2 = \sum_{j \in J} d_{j} \sum_{\{i \in I | h_{ij} \leq r\}} x_{ij}.$
#
# Esta expresión es equivalente a:
# >$\max z_2 = \sum_{j \in J} \sum_{\{i \in I | h_{ij} \leq r\}}d_{j} x_{ij}.$

# %% [markdown]
# **Pregunta 6 (5 puntos)**
# * Crea la función objetivo y agrégala al modelo `problema`
#
# > **Ejemplo**:
# >> $ \sum_{i \in I}c_i x_i$
# es equivalente a `lp.lpSum(c[i]*x[i] for i in I)`

# %%
# your code here
costo_transporte = {
    (i, j): q * produccion[j] * distancia[(i, j)]
    for i in I
    for j in J
}

# %%
# Esta celda esta reservada para uso del equipo docente

# %%
# Esta celda esta reservada para uso del equipo docente

# %% [markdown]
# ### Restricciones
# ____

# %% [markdown]
# **Pregunta 7 (10 puntos)**
#
# * Crea la siguiente restricción, asígnale el nombre `'R1_'+str(<indice_del_para_todo>)` y añádela al modelo:
# >1. Cada CAC debe ser atendido por un único depósito
# >>`# Para desarrollo del estudiante`

# %%
# your code here
for j in J:
    problema += (
        lp.lpSum(x[(i, j)] for i in I) == 1,
        'R1_' + str(j)
    )

# %%
# Esta celda esta reservada para uso del equipo docente

# %% [markdown]
# **Pregunta 8 (5 puntos)**
#
# * Crea la siguiente restricción, asígnale el nombre `'R2_'+str(<indice_del_para_todo>)` y añádela al modelo:
# >2. No se debe superar la capacidad de los depósitos y sólo se puede atender CACs desde un depósito si se decide operar el mismo.
# >>$\sum_{j \in J}d_{j}x_{ij} \leq k_{i}y_{i}, \; \forall i \in I$

# %%
# your code here
for i in I:
    problema += (
        lp.lpSum(produccion[j] * x[(i, j)] for j in J) <= capacidad[i] * y[i],
        'R2_' + str(i)
    )

# %%
# Esta celda esta reservada para uso del equipo docente

# %%
# Esta celda esta reservada para uso del equipo docente

# %% [markdown]
# ### Invocar el optimizador

# %%
print(lp.LpStatus[problema.solve()])
# Out:
# Optimal

# %% [markdown]
# ## Reporte de resultados - Maximización de satisfacción ($z_2$)
# ---

# %% [markdown]
# **Función objetivo $z_1$**

# %% [markdown]
# **Pregunta 9 (5 puntos)**
#
# * Guarda en una variable `z1` el valor del costo total de operación y transporte:
# >`# Para desarrollo del estudiante`
#
# **Recuerda que** en PuLP puedes usar la función `lp.value(<expresion>)` para evaluar una expresión, reemplazando los valores de las variables por aquellos de la solución óptima. Esta función sólo debe ser llamada luego de usar `<modelo>.solve()` y haber obtenido una solución óptima.

# %%
# your code here
z1 = lp.value(
    lp.lpSum(costo_fijo[i] * y[i] for i in I) +
    lp.lpSum(costo_transporte[(i, j)] * x[(i, j)] for i in I for j in J)
)

# %%
print(f"Costo Total: ${z1: .2f}")
print(f"Costo Total Relativo al Mínimo Costo: {z1 / min_costo * 100: .2f}%")
# Out:
# Costo Total: $ 10632549.49
# Costo Total Relativo al Mínimo Costo:  246.22%

# %%
# Esta celda esta reservada para uso del equipo docente

# %% [markdown]
# **Función objetivo $z_2$**

# %%
z2 = lp.value(problema.objective)
print(f"Satisfacción Total: {z2: .2f}")
print(
    f"Satisfacción Total Relativa al Total de Producción: {z2 / sum(produccion.values()) * 100: .2f}%"
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 z2 = lp.value(problema.objective)
#       2 print(f"Satisfacción Total: {z2: .2f}")
#       3 print(
#       4     f"Satisfacción Total Relativa al Total de Producción: {z2 / sum(produccion.values()) * 100: .2f}%"
#       5 )
#
# File c:\Users\Rago\AppData\Local\Programs\Python\Python312\Lib\site-packages\pulp\utilities.py:24, in value(x)
#      22     return x
#      23 else:
# ---> 24     return x.value()
#
# AttributeError: 'NoneType' object has no attribute 'value'

# %% [markdown]
# **Depósitos en operación**

# %%
print("Se decidió operar", sum([y[i].value() for i in I]), "depósitos")
# Out:
# Se decidió operar 19.0 depósitos

# %% [markdown]
# **Asignación de CACs a Depósitos**

# %%
matrix = []
for j in J:
    row = []
    for i in I:
        if y[i].value() == 1:
            if x[i, j].value() == 1:
                row.append("X")
            elif x[i, j].value() == 0:
                row.append("-")
            else:
                row.append("Error")
    matrix.append(row)

df = pd.DataFrame(matrix, index=J, columns=[i for i in I if y[i].value() == 1])
df.head(10)
# Out:
#                             Medellín, Antioquia La Dorada, Caldas  \
# Andes, Antioquia                              X                 -
# Medellín, Antioquia                           X                 -
# Dabeiba, Antioquia                            X                 -
# Salgar, Antioquia                             X                 -
# San Pablo de Borbur, Boyacá                   -                 -
# Labranzagrande, Boyacá                        -                 -
# Miraflores, Boyacá                            -                 -
# Moniquirá, Boyacá                             -                 -
# Manizales, Caldas                             -                 -
# Anserma, Caldas                               -                 X
#
#                             Aguadas, Caldas Salamina, Caldas Popayán, Cauca  \
# Andes, Antioquia                          -                -              -
# Medellín, Antioquia                       -                -              -
# Dabeiba, Antioquia                        -                -              -
# Salgar, Antioquia                         -                -              -
# San Pablo de Borbur, Boyacá               -                -              -
# Labranzagrande, Boyacá                    -                -              -
# Miraflores, Boyacá                        -                -              -
# Moniquirá, Boyacá                         -                -              -
# Manizales, Caldas                         -                X              -
# Anserma, Caldas                           -                -              -
#
#                             Valledupar, Cesar Bogotá, Cundinamarca  \
# Andes, Antioquia                            -                    -
# Medellín, Antioquia                         -                    -
# Dabeiba, Antioquia                          -                    -
# Salgar, Antioquia                           -                    -
# San Pablo de Borbur, Boyacá                 -                    X
# Labranzagrande, Boyacá                      -                    -
# Miraflores, Boyacá                          -                    X
# Moniquirá, Boyacá                           -                    -
# Manizales, Caldas                           -                    -
# Anserma, Caldas                             -                    -
#
#                             Santana, Huila Neiva, Huila  \
# Andes, Antioquia                         -            -
# Medellín, Antioquia                      -            -
# Dabeiba, Antioquia                       -            -
# Salgar, Antioquia                        -            -
# San Pablo de Borbur, Boyacá              -            -
# Labranzagrande, Boyacá                   -            -
# Miraflores, Boyacá                       -            -
# Moniquirá, Boyacá                        -            -
# Manizales, Caldas                        -            -
# Anserma, Caldas                          -            -
#
#                             Santa Marta, Magdalena Cúcuta, Nor. de Santander  \
# Andes, Antioquia                                 -                         -
# Medellín, Antioquia                              -                         -
# Dabeiba, Antioquia                               -                         -
# Salgar, Antioquia                                -                         -
# San Pablo de Borbur, Boyacá                      -                         -
# Labranzagrande, Boyacá                           -                         -
# Miraflores, Boyacá                               -                         -
# Moniquirá, Boyacá                                -                         -
# Manizales, Caldas                                -                         -
# Anserma, Caldas                                  -                         -
#
#                             Pasto, Nariño Génova, Quindío Calarcá, Quindío  \
# Andes, Antioquia                        -               -                -
# Medellín, Antioquia                     -               -                -
# Dabeiba, Antioquia                      -               -                -
# Salgar, Antioquia                       -               -                -
# San Pablo de Borbur, Boyacá             -               -                -
# Labranzagrande, Boyacá                  -               -                -
# Miraflores, Boyacá                      -               -                -
# Moniquirá, Boyacá                       -               -                -
# Manizales, Caldas                       -               -                -
# Anserma, Caldas                         -               -                -
#
#                             Filandia, Quindío Pereira, Risaralda  \
# Andes, Antioquia                            -                  -
# Medellín, Antioquia                         -                  -
# Dabeiba, Antioquia                          -                  -
# Salgar, Antioquia                           -                  -
# San Pablo de Borbur, Boyacá                 -                  -
# Labranzagrande, Boyacá                      -                  -
# Miraflores, Boyacá                          -                  -
# Moniquirá, Boyacá                           -                  -
# Manizales, Caldas                           -                  -
# Anserma, Caldas                             -                  -
#
#                             Bucaramanga, Santander Barbosa, Santander  \
# Andes, Antioquia                                 -                  -
# Medellín, Antioquia                              -                  -
# Dabeiba, Antioquia                               -                  -
# Salgar, Antioquia                                -                  -
# San Pablo de Borbur, Boyacá                      -                  -
# Labranzagrande, Boyacá                           -                  X
# Miraflores, Boyacá                               -                  -
# Moniquirá, Boyacá                                -                  X
# Manizales, Caldas                                -                  -
# Anserma, Caldas                                  -                  -
#
#                             Cali, Valle del Cauca
# Andes, Antioquia                                -
# Medellín, Antioquia                             -
# Dabeiba, Antioquia                              -
# Salgar, Antioquia                               -
# San Pablo de Borbur, Boyacá                     -
# Labranzagrande, Boyacá                          -
# Miraflores, Boyacá                              -
# Moniquirá, Boyacá                               -
# Manizales, Caldas                               -
# Anserma, Caldas                                 -

# %% [markdown]
# ### Visualizaciones
# ---

# %% [markdown]
# **Mapa de la asignación**

# %%
m = folium.Map(location=[6.2, -74.5], tiles="OpenStreetMap", zoom_start=6)

for j, lat_lon in cacs_lat_lon.items():
    folium.Marker(
        location=lat_lon,
        tooltip=j,
        icon=BeautifyIcon(
            icon="circle",
            inner_icon_style="color:blue;font-size:7px;opacity:0.9;position: relative;top:-0.5px;",
            background_color="transparent",
            border_color="transparent",
        ),
    ).add_to(m)
for i, lat_lon in depositos_lat_lon.items():
    if y[i].value() > 0:
        folium.Marker(
            location=lat_lon,
            tooltip=i,
            icon=BeautifyIcon(
                icon="caret-up",
                inner_icon_style="color:red;font-size:20px;opacity:0.9;position: relative;top:-4.5px;",
                background_color="transparent",
                border_color="transparent",
            ),
        ).add_to(m)

red = [(i, j) for i in I for j in J if x[i, j].value() > 0]
for i, j in red:
    folium.PolyLine(
        [depositos_lat_lon[i], cacs_lat_lon[j]], color="black", weight=1, opacity=1
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c67b5fcd5c87b2c3c9b06755ddb05fd3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c67b5fcd5c87b2c3c9b06755ddb05fd3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c67b5fcd5c87b2c3c9b06755ddb05fd3 = L.map(
#                 &quot;map_c67b5fcd5c87b2c3c9b06755ddb05fd3&quot;,
#                 {
#                     center: [6.2, -74.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2cb410e542f6fee7e64b302838957187 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c67b5fcd5c87b2c3c9b06755ddb05fd3);
#
#
#             var marker_827261ecc1b5b91fc2c75b17e67a7744 = L.marker(
#                 [5.62412, -75.95589],
#                 {}
#             ).addTo(map_c67b5fcd5c87b2c3c9b06755ddb05fd3);
#
#
#             var beautify_icon_30bb63b7174aa7b79dfc2341954ef50c = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;transparent&quot;, &quot;borderColor&quot;: &quot;transparent&quot;, &quot;borderWidth&quot;: 3, &quot;icon&quot;: &quot;circle&quot;, &quot;innerIconStyle&quot;: &quot;color:blue;font-size:7px;opacity:0.9;position: relative;top:-0.5px;&quot;, &quot;isAlphaNumericIcon&quot;: false, &quot;spin&quot;: false, &quot;textColor&quot;: &quot;#000&quot;}
#             )
#             marker_827261ecc1b5b91fc2c75b17e67a7744.setIcon(beautify_icon_30bb63b7174aa7b79dfc2341954ef50c);
#
#
#             marker_827261ecc1b5b91fc2c75b17e67a7744.bindTooltip(
#                 `&lt;div&gt;
#                      Andes, Antioquia
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_983231cdb45c053701c5911b28ecf7c9 = L.marker(
#                 [6.26868, -75.59639],
#                 {}
#             ).addTo(map_c67b5fcd5c87b2c3c9b06755ddb05fd3);
#
#
#             var beautify_icon_67e8beb9915181f7879b85349ba77086 = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;transparent&quot;, &quot;borderColor&quot;: &quot;transparent&quot;, &quot;borderWidth&quot;: 3, &quot;icon&quot;: &quot;circle&quot;, &quot;innerIconStyle&quot;: &quot;color:blue;font-size:7px;opacity:0.9;position: relative;top:-0.5px;&quot;, &quot;isAlphaNumericIcon&quot;: false, &quot;spin&quot;: false, &quot;textColor&quot;: &quot;#000&quot;}
#             )
#             marker_983231cdb45c053701c5911b28ecf7c9.setIcon(beautify_icon_67e8beb9915181f7879b85349ba77086);
#
#
#             marker_983231cdb45c053701c5911b28ecf7c9.bindTooltip(
#                 `&lt;div&gt;
#                      Medellín, Antioquia
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4605ee1f30cb19f8b45e5c8304c08b4b = L.marker(
#                 [6.95267, -76.29085],
#                 {}
#             ).addTo(map_c67b5fcd5c87b2c3c9b06755ddb05fd3);
#
#
#             var beautify_icon_4757caa21d9e4d1609662d2bd5dd46f9 = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;transparent&quot;, &quot;borderColor&quot;: &quot;transparent&quot;, &quot;borderWidth&quot;: 3, &quot;icon&quot;: &quot;circle&quot;, &quot;innerIconStyle&quot;: &quot;color:blue;font-size:7px;opacity:0.9;position: relative;top:-0.5px;&quot;, &quot;isAlphaNumericIcon&quot;: false, &quot;spin&quot;: false, &quot;textColor&quot;: &quot;#000&quot;}
#             )
#             marker_4605ee1f30cb19f8b45e5c8304c08b4b.setIcon(beautify_icon_4757caa21d9e4d1609662d2bd5dd46f9);
#
#
#             marker_4605ee1f30cb19f8b45e5c8304c08b4b.bindTooltip(
#                 `&lt;div&gt;
#                      Dabeiba, Antioquia
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e2d29793070fb88f430ccab5434d82e7 = L.marker(
#                 [5.96643, -75.97188],
#                 {}
#             ).addTo(map_c67b5fcd5c87b2c3c9b06755ddb05fd3);
#
#
#             var beautify_icon_506a7d3a770feba648468254e5aef419 = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;transparent&quot;, &quot;borderColor&quot;: &quot;transparent&quot;, &quot;borderWidth&quot;: 3, &quot;icon&quot;: &quot;circle&quot;, &quot;innerIconStyle&quot;: &quot;color:blue;font-size:7px;opacity:0.9;position: relative;top:-0.5px;&quot;, &quot;isAlphaNumericIcon&quot;: false, &quot;spin&quot;: false, &quot;textColor&quot;: &quot;#000&quot;}
#             )
#             marker_e2d29793070fb88f430ccab5434

# %% [markdown]
# ## Modelado - Maximización de satisfacción ($z_2$) con restricción de costos ($z_1$)
# ---
# Por último, queremos encontrar un solución intermedia entre la que minimiza los costos y la que maximiza la satisfacción. Hay varias maneras de hacer esto. La que vamos a implementar es colocar una restricción sobre los costos $z_1$ que esté entre los valores obtenidos en los dos casos anteriores.
#
# Recordemos que al minimizar los costos, se obtuvo un costo total de 4,318,336.74. Este costo será nuestro punto de referencia. No podemos obtener un costo menor a este. Por otro lado, al maximizar la satisfacción, obtuvimos un costo de 4,837,569.38. Así que en el peor de los casos, el costo es aproximadamente 12.02% mayor al primer caso. Entonces, para obtener una solución intermedia, debemos escoger un umbral entre estos dos valores para crear una restricción sobre los costos. Una posibilidad es restringir que el costo total $z_1$ sea a lo sumo 2% mayor que el mejor costo mientras se maximiza la satisfacción $z_2$.

# %% [markdown]
# ### Declaración del modelo

# %%
problema = lp.LpProblem(sense=lp.LpMaximize)

# %% [markdown]
# ### Variables de Decisión
#
# >* $x_{ij}=\begin{cases}1, & \text{si el CAC } j \in J \text{ es atendido por el depósito } i \in I \\0, & \text{de lo contrario} \end{cases}$
# >* $y_{i}=\begin{cases} 1, & \text{Si se decide operar el depósito } i \in I  \\ 0, & \text{de lo contrario} \end{cases}$

# %%
x = lp.LpVariable.dicts("atender", [(i, j) for i in I for j in J], cat=lp.LpBinary)
y = lp.LpVariable.dicts("operar", I, cat=lp.LpBinary)

# %% [markdown]
# ### Función Objetivo
# Maximizar satisfacción de los CACs
# >$\max z_2 = \sum_{j \in J} d_{j} \sum_{\{i \in I | h_{ij} \leq r\}} x_{ij}$

# %% [markdown]
# **Pregunta 10 (5 puntos)**
# * Crea la función objetivo y agrégala al modelo `problema`
#
# > **Ejemplo**:
# >> $ \sum_{i \in I}c_i x_i$
# es equivalente a `lp.lpSum(c[i]*x[i] for i in I)`

# %%
# your code here

problema += (
    lp.lpSum(
        produccion[j] * lp.lpSum(x[(i, j)] for i in I if distancia[(i, j)] <= r)
        for j in J
    )
)

# %%
# Esta celda esta reservada para uso del equipo docente

# %%
# Esta celda esta reservada para uso del equipo docente

# %% [markdown]
# ### Restricciones
# ____

# %% [markdown]
# **Pregunta 11 (10 puntos)**
#
# * Crea la siguiente restricción, asígnale el nombre `'R1_'+str(<indice_del_para_todo>)` y añádela al modelo:
# >1. Cada CAC debe ser atendido por un único depósito
# >>`# Para desarrollo del estudiante`

# %%
# your code here
for j in J:
    problema += (
        lp.lpSum(x[(i, j)] for i in I) == 1,
        'R1_' + str(j)
    )

# %%
# Esta celda esta reservada para uso del equipo docente

# %% [markdown]
# **Pregunta 12 (5 puntos)**
#
# * Crea la siguiente restricción, asígnale el nombre `'R2_'+str(<indice_del_para_todo>)` y añádela al modelo:
# >2. No se debe superar la capacidad de los depósitos y sólo se puede atender CACs desde un depósito si se decide operar el mismo.
# >>$\sum_{j \in J}d_{j}x_{ij} \leq k_{i}y_{i}, \; \forall i \in I$

# %%
# your code here

for i in I:
    problema += (
        lp.lpSum(produccion[j] * x[(i, j)] for j in J) <= capacidad[i] * y[i],
        'R2_' + str(i)
    )

# %%
# Esta celda esta reservada para uso del equipo docente

# %% [markdown]
# **Pregunta 13 (10 puntos)**
#
# * Crea la siguiente restricción, asígnale el nombre `'R3'` y añádela al modelo:
# >El costo total no debe superar en más de un 2% al mejor costo obtenido.
# >>`# Para desarrollo del estudiante`
#
# **Nota:** Utiliza el valor `z1_` a continuación como el mejor costo obtenido. Inclúyelo en la restricción según sea conveniente.

# %%
z1_ = 4318336.74

# %%
# your code here
problema += (
    lp.lpSum(costo_fijo[i] * y[i] for i in I) +
    lp.lpSum(costo_transporte[(i, j)] * x[(i, j)] for i in I for j in J)
    <= 1.02 * z1_,
    'R3'
)

# %%
# Esta celda esta reservada para uso del equipo docente

# %%
# Esta celda esta reservada para uso del equipo docente

# %% [markdown]
# ### Invocar el optimizador

# %%
print(lp.LpStatus[problema.solve()])
# Out:
# Optimal

# %% [markdown]
# ## Reporte de resultados - Maximización de satisfacción ($z_2$) con restricción de costos ($z_1$)
# ---

# %% [markdown]
# **Función objetivo $z_1$**

# %% [markdown]
# **Pregunta 14 (5 puntos)**
#
# * Guarda en una variable `z1` el valor del costo total de operación y transporte:
# >`# Para desarrollo del estudiante`
#
# **Recuerda que** en PuLP puedes usar la función `lp.value(<expresion>)` para evaluar una expresión, reemplazando los valores de las variables por aquellos de la solución óptima. Esta función sólo debe ser llamada luego de usar `<modelo>.solve()` y haber obtenido una solución óptima.

# %%
# your code here
z1 = float(format(lp.value(lp.lpSum(costo_fijo[i] * y[i] for i in I)
+ lp.lpSum(costo_transporte[i,j]* x[i, j] for i in I for j in J))))
z1
# Out:
# 4395103.840364418

# %%
print(f"Costo Total: ${z1: .2f}")
print(f"Costo Total Relativo al Mínimo Costo: {z1 / min_costo * 100: .2f}%")
# Out:
# Costo Total: $ 4395103.84
# Costo Total Relativo al Mínimo Costo:  101.78%

# %%
# Esta celda esta reservada para uso del equipo docente

# %% [markdown]
# **Función objetivo $z_2$**

# %%
z2 = lp.value(problema.objective)
print(f"Satisfacción Total: {z2: .2f}")
print(f"Satisfacción Total Relativa al Total de Producción: {z2 / sum(produccion.values()) * 100: .2f}%")
# Out:
# Satisfacción Total:  396.67
# Satisfacción Total Relativa al Total de Producción:  94.39%

# %% [markdown]
# **Depósitos en operación**

# %%
print("Se decidió operar", sum(y[i].value() for i in I), "depósitos")
# Out:
# Se decidió operar 17.0 depósitos

# %% [markdown]
# **Asignación de CACs a Depósitos**

# %%
matrix = []
for j in J:
    row = []
    for i in I:
        if y[i].value() == 1:
            if x[i, j].value() == 1:
                row.append("X")
            elif x[i, j].value() == 0:
                row.append("-")
            else:
                row.append("Error")
    matrix.append(row)

df = pd.DataFrame(matrix, index=J, columns=[i for i in I if y[i].value() == 1])
df.head(10)
# Out:
#                             Medellín, Antioquia La Dorada, Caldas  \
# Andes, Antioquia                              X                 -
# Medellín, Antioquia                           X                 -
# Dabeiba, Antioquia                            X                 -
# Salgar, Antioquia                             X                 -
# San Pablo de Borbur, Boyacá                   -                 X
# Labranzagrande, Boyacá                        -                 -
# Miraflores, Boyacá                            -                 X
# Moniquirá, Boyacá                             -                 -
# Manizales, Caldas                             -                 -
# Anserma, Caldas                               -                 X
#
#                             Aguadas, Caldas Salamina, Caldas Popayán, Cauca  \
# Andes, Antioquia                          -                -              -
# Medellín, Antioquia                       -                -              -
# Dabeiba, Antioquia                        -                -              -
# Salgar, Antioquia                         -                -              -
# San Pablo de Borbur, Boyacá               -                -              -
# Labranzagrande, Boyacá                    -                -              -
# Miraflores, Boyacá                        -                -              -
# Moniquirá, Boyacá                         -                -              -
# Manizales, Caldas                         -                X              -
# Anserma, Caldas                           -                -              -
#
#                             Valledupar, Cesar Santana, Huila Neiva, Huila  \
# Andes, Antioquia                            -              -            -
# Medellín, Antioquia                         -              -            -
# Dabeiba, Antioquia                          -              -            -
# Salgar, Antioquia                           -              -            -
# San Pablo de Borbur, Boyacá                 -              -            -
# Labranzagrande, Boyacá                      -              -            -
# Miraflores, Boyacá                          -              -            -
# Moniquirá, Boyacá                           -              -            -
# Manizales, Caldas                           -              -            -
# Anserma, Caldas                             -              -            -
#
#                             Santa Marta, Magdalena Cúcuta, Nor. de Santander  \
# Andes, Antioquia                                 -                         -
# Medellín, Antioquia                              -                         -
# Dabeiba, Antioquia                               -                         -
# Salgar, Antioquia                                -                         -
# San Pablo de Borbur, Boyacá                      -                         -
# Labranzagrande, Boyacá                           -                         -
# Miraflores, Boyacá                               -                         -
# Moniquirá, Boyacá                                -                         -
# Manizales, Caldas                                -                         -
# Anserma, Caldas                                  -                         -
#
#                             Pasto, Nariño Génova, Quindío Calarcá, Quindío  \
# Andes, Antioquia                        -               -                -
# Medellín, Antioquia                     -               -                -
# Dabeiba, Antioquia                      -               -                -
# Salgar, Antioquia                       -               -                -
# San Pablo de Borbur, Boyacá             -               -                -
# Labranzagrande, Boyacá                  -               -                -
# Miraflores, Boyacá                      -               -                -
# Moniquirá, Boyacá                       -               -                -
# Manizales, Caldas                       -               -                -
# Anserma, Caldas                         -               -                -
#
#                             Filandia, Quindío Bucaramanga, Santander  \
# Andes, Antioquia                            -                      -
# Medellín, Antioquia                         -                      -
# Dabeiba, Antioquia                          -                      -
# Salgar, Antioquia                           -                      -
# San Pablo de Borbur, Boyacá                 -                      -
# Labranzagrande, Boyacá                      -                      -
# Miraflores, Boyacá                          -                      -
# Moniquirá, Boyacá                           -                      -
# Manizales, Caldas                           -                      -
# Anserma, Caldas                             -                      -
#
#                             Barbosa, Santander Cali, Valle del Cauca
# Andes, Antioquia                             -                     -
# Medellín, Antioquia                          -                     -
# Dabeiba, Antioquia                           -                     -
# Salgar, Antioquia                            -                     -
# San Pablo de Borbur, Boyacá                  -                     -
# Labranzagrande, Boyacá                       X                     -
# Miraflores, Boyacá                           -                     -
# Moniquirá, Boyacá                            X                     -
# Manizales, Caldas                            -                     -
# Anserma, Caldas                              -                     -

# %% [markdown]
# ### Visualizaciones
# ---

# %% [markdown]
# **Mapa de la asignación**

# %%
m = folium.Map(location=[6.2, -74.5], tiles="OpenStreetMap", zoom_start=6)

for j, lat_lon in cacs_lat_lon.items():
    folium.Marker(
        location=lat_lon,
        tooltip=j,
        icon=BeautifyIcon(
            icon="circle",
            inner_icon_style="color:blue;font-size:7px;opacity:0.9;position: relative;top:-0.5px;",
            background_color="transparent",
            border_color="transparent",
        ),
    ).add_to(m)

for i, lat_lon in depositos_lat_lon.items():
    if y[i].value() > 0:
        folium.Marker(
            location=lat_lon,
            tooltip=i,
            icon=BeautifyIcon(
                icon="caret-up",
                inner_icon_style="color:red;font-size:20px;opacity:0.9;position: relative;top:-4.5px;",
                background_color="transparent",
                border_color="transparent",
            ),
        ).add_to(m)

red = [(i, j) for i in I for j in J if x[i, j].value() > 0]
for i, j in red:
    folium.PolyLine(
        [depositos_lat_lon[i], cacs_lat_lon[j]], color="black", weight=1, opacity=1
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0ce1fb29c8ad5ec7367dd088497790e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0ce1fb29c8ad5ec7367dd088497790e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0ce1fb29c8ad5ec7367dd088497790e6 = L.map(
#                 &quot;map_0ce1fb29c8ad5ec7367dd088497790e6&quot;,
#                 {
#                     center: [6.2, -74.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8caf5a91dd1ee08d7d25c3d5a722858 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0ce1fb29c8ad5ec7367dd088497790e6);
#
#
#             var marker_cd33b4988981820491bca7966e22f7f1 = L.marker(
#                 [5.62412, -75.95589],
#                 {}
#             ).addTo(map_0ce1fb29c8ad5ec7367dd088497790e6);
#
#
#             var beautify_icon_58dfb8fd1781ca6d998a5a74057f9ceb = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;transparent&quot;, &quot;borderColor&quot;: &quot;transparent&quot;, &quot;borderWidth&quot;: 3, &quot;icon&quot;: &quot;circle&quot;, &quot;innerIconStyle&quot;: &quot;color:blue;font-size:7px;opacity:0.9;position: relative;top:-0.5px;&quot;, &quot;isAlphaNumericIcon&quot;: false, &quot;spin&quot;: false, &quot;textColor&quot;: &quot;#000&quot;}
#             )
#             marker_cd33b4988981820491bca7966e22f7f1.setIcon(beautify_icon_58dfb8fd1781ca6d998a5a74057f9ceb);
#
#
#             marker_cd33b4988981820491bca7966e22f7f1.bindTooltip(
#                 `&lt;div&gt;
#                      Andes, Antioquia
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2de003c7803e384af72599bb5eae7568 = L.marker(
#                 [6.26868, -75.59639],
#                 {}
#             ).addTo(map_0ce1fb29c8ad5ec7367dd088497790e6);
#
#
#             var beautify_icon_325ee4b45b66e14df74b3736718ae45f = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;transparent&quot;, &quot;borderColor&quot;: &quot;transparent&quot;, &quot;borderWidth&quot;: 3, &quot;icon&quot;: &quot;circle&quot;, &quot;innerIconStyle&quot;: &quot;color:blue;font-size:7px;opacity:0.9;position: relative;top:-0.5px;&quot;, &quot;isAlphaNumericIcon&quot;: false, &quot;spin&quot;: false, &quot;textColor&quot;: &quot;#000&quot;}
#             )
#             marker_2de003c7803e384af72599bb5eae7568.setIcon(beautify_icon_325ee4b45b66e14df74b3736718ae45f);
#
#
#             marker_2de003c7803e384af72599bb5eae7568.bindTooltip(
#                 `&lt;div&gt;
#                      Medellín, Antioquia
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f5bdab0cef6a62fc429b4bf80815ace3 = L.marker(
#                 [6.95267, -76.29085],
#                 {}
#             ).addTo(map_0ce1fb29c8ad5ec7367dd088497790e6);
#
#
#             var beautify_icon_d1ab9c30b9eaee8a49c51588c344f4ab = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;transparent&quot;, &quot;borderColor&quot;: &quot;transparent&quot;, &quot;borderWidth&quot;: 3, &quot;icon&quot;: &quot;circle&quot;, &quot;innerIconStyle&quot;: &quot;color:blue;font-size:7px;opacity:0.9;position: relative;top:-0.5px;&quot;, &quot;isAlphaNumericIcon&quot;: false, &quot;spin&quot;: false, &quot;textColor&quot;: &quot;#000&quot;}
#             )
#             marker_f5bdab0cef6a62fc429b4bf80815ace3.setIcon(beautify_icon_d1ab9c30b9eaee8a49c51588c344f4ab);
#
#
#             marker_f5bdab0cef6a62fc429b4bf80815ace3.bindTooltip(
#                 `&lt;div&gt;
#                      Dabeiba, Antioquia
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_adc0c170c8d7d3f5932859b8827239f5 = L.marker(
#                 [5.96643, -75.97188],
#                 {}
#             ).addTo(map_0ce1fb29c8ad5ec7367dd088497790e6);
#
#
#             var beautify_icon_250a353582bde30f533870153b587d0f = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;transparent&quot;, &quot;borderColor&quot;: &quot;transparent&quot;, &quot;borderWidth&quot;: 3, &quot;icon&quot;: &quot;circle&quot;, &quot;innerIconStyle&quot;: &quot;color:blue;font-size:7px;opacity:0.9;position: relative;top:-0.5px;&quot;, &quot;isAlphaNumericIcon&quot;: false, &quot;spin&quot;: false, &quot;textColor&quot;: &quot;#000&quot;}
#             )
#             marker_adc0c170c8d7d3f5932859b8827

# %% [markdown]
# ### Reflexión
# ---
# ¿De qué forma podrías obtener soluciones intermedias adicionales? ¿Podrías presentarlas gráficamente como una frontera de Pareto? ¿Si tuvieras que recomendar alguna solución, con qué criterio la escogerías?
