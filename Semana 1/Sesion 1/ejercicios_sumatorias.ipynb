# %% [markdown]
# # Ejercicio 3

# %%
def ejercicio3(n):
    return sum(k**2 for k in range(1, n + 1))

ejercicio3(2)
# Out:
# 5

# %% [markdown]
# # Ejercicio 4

# %%
def ejercicio4(n):
    return sum(k**3 for k in range(1, n + 1))
ejercicio4(2)
# Out:
# 9
